# %%
import numpy as np
import pandas as pd

# %%
police = pd.read_csv('fatal-police-shootings-data.csv')

# %%
police
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4582  5038            Jeffrey Michael Gibble  2019-09-16              shot
# 4583  5041                  Kristopher Adams  2019-09-16              shot
# 4584  5066                             TK TK  2019-09-16              shot
# 4585  5032                   Gay Ellen Plack  2019-09-17              shot
# 4586  5034                             TK TK  2019-09-17              shot
# 4587  5043            Scott Gabriel Spangler  2019-09-18              shot
# 4588  5045                 John Emory Sawyer  2019-09-19              shot
# 4589  5044            Jordan Michael Griffin  2019-09-20              shot
# 4590  5058                 Adam Paul English  2019-09-20              shot
# 4591  5049                  Jeffrey Peterson  2019-09-21              shot
# 4592  5050                             TK TK  2019-09-22              shot
# 4593  5046                             TK TK  2019-09-23              shot
# 4594  5047              Jeffery Tyler Aycock  2019-09-23              shot
# 4595  5048                    Charles Nation  2019-09-23              shot
# 4596  5051                   Jarod Lee Smith  2019-09-24              shot
# 4597  5068                    Haywood Cannon  2019-09-24              shot
# 4598  5069            Ronald Michael McCrary  2019-09-24              shot
# 4599  5053                  Daryl Strickland  2019-09-25              shot
# 4600  5067                  Kevin Dudenhefer  2019-09-25  shot and Tasered
# 4601  5052                     Leonard Shand  2019-09-26              shot
# 4602  5054               Chad Willis Huggins  2019-09-26              shot
# 4603  5055                             TK TK  2019-09-26              shot
# 4604  5057                             TK TK  2019-09-26              shot
# 4605  5059                    Haywood Cannon  2019-09-26              shot
# 4606  5063              Jamaal Ramone Taylor  2019-09-28              shot
# 4607  5065                             TK TK  2019-09-28              shot
# 4608  5060                    Dewayne Morgan  2019-09-29  shot and Tasered
# 4609  5061                             TK TK  2019-09-29              shot
# 4610  5062                   Richard Cabrera  2019-09-29              shot
# 4611  5064                  Antonio Williams  2019-09-29              shot
#
#                armed   age gender race              city state  \
# 0                gun  53.0      M    A           Shelton    WA
# 1                gun  47.0      M    W             Aloha    OR
# 2            unarmed  23.0      M    H           Wichita    KS
# 3         toy weapon  32.0      M    W     San Francisco    CA
# 4           nail gun  39.0      M    H             Evans    CO
# 5                gun  18.0      M    W           Guthrie    OK
# 6                gun  22.0      M    H          Chandler    AZ
# 7                gun  35.0      M    W           Assaria    KS
# 8            unarmed  34.0      F    W        Burlington    IA
# 9         toy weapon  47.0      M    B         Knoxville    PA
# 10             knife  25.0      M    W          Stockton    CA
# 11               gun  31.0      M    B          Freeport    TX
# 12             knife  41.0      M    B          Columbus    OH
# 13               gun  30.0      M    W        Des Moines    IA
# 14               gun  37.0      M    B       New Orleans    LA
# 15               NaN  28.0      M    W           Huntley    MT
# 16            shovel  42.0      M    W    Salt Lake City    UT
# 17           unarmed  36.0      M    B            Strong    AR
# 18               gun  49.0      M    W          Syracuse    UT
# 19               gun  71.0      M    W           England    AR
# 20               gun  33.0      M    H           El Paso    TX
# 21               gun  39.0      M    W            Arcola    IL
# 22               gun  23.0      M    H        South Gate    CA
# 23               gun  29.0      M    H   North Las Vegas    NV
# 24               gun  34.0      M    W       Albuquerque    NM
# 25             knife  43.0      M    W        Jourdanton    TX
# 26               NaN  24.0      M    B          St. Paul    MN
# 27               NaN  29.0      M    W   Franklin County    MO
# 28               gun  34.0      M    B        Chesapeake    VA
# 29             knife  75.0      M    W        Old Bridge    NJ
# ...              ...   ...    ...  ...               ...   ...
# 4582             gun  33.0      M    W       Elizabethon    TN
# 4583             gun  37.0      M  NaN            Sanger    TX
# 4584             gun   NaN      M  NaN           Houston    TX
# 4585         hatchet  57.0      F    W          Richmond    VA
# 4586         vehicle   NaN      M  NaN            Milton    FL
# 4587    undetermined  43.0      M  NaN             Salem    OR
# 4588  unknown weapon  74.0      M  NaN       Soddy Daisy    TN
# 4589      pellet gun  18.0      M  NaN        Long Beach    CA
# 4590             gun  21.0      M  NaN       Gainesville    GA
# 4591    undetermined  29.0      M  NaN               Ada    OK
# 4592             gun  74.0      M    W            Austin    TX
# 4593             gun   NaN      M    H       Los Angeles    CA
# 4594             gun  28.0      M    W      Floyd County    GA
# 4595  unknown weapon  31.0      M  NaN            Lowell    AR
# 4596             gun  41.0      M  NaN        Huntington    WV
# 4597             gun  67.0      M  NaN         Richlands    NC
# 4598           knife  63.0      M  NaN           Sanford    NC
# 4599             gun  64.0      M  NaN        Hartsville    SC
# 4600             gun  32.0      M    W           Lacombe    LA
# 4601           knife  49.0      M    B       Hyattsville    MD
# 4602             gun  28.0      M    W  Lexington County    SC
# 4603         vehicle   NaN      M  NaN          La Habra    CA
# 4604             gun   NaN      M  NaN            Dallas    TX
# 4605             gun  67.0      M  NaN      Jacksonville    NC
# 4606           knife  31.0      M  NaN         Baltimore    MD
# 4607             gun   NaN      M  NaN            Boston    MA
# 4608             NaN  37.0      M    W          Longview    TX
# 4609    undetermined   NaN      M  NaN          Monument    CO
# 4610             gun  38.0      M  NaN             Miami    FL
# 4611             gun  27.0      M  NaN          New York    NY
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# 5                       False        attack  Not fleeing        False
# 6                       False        attack          Car        False
# 7                       False        attack  Not fleeing        False
# 8                       False         other  Not fleeing         True
# 9                       False        attack  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 11                      False        attack  Not fleeing        False
# 12                       True         other  Not fleeing        False
# 13                      False        attack          Car        False
# 14                      False        attack         Foot         True
# 15                      False  undetermined  Not fleeing        False
# 16                      False        attack  Not fleeing         True
# 17                      False        attack  Not fleeing        False
# 18                      False        attack  Not fleeing         True
# 19                      False        attack  Not fleeing        False
# 20                      False        attack  Not fleeing        False
# 21                       True        attack  Not fleeing        False
# 22                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 24                      False        attack         Foot         True
# 25                       True         other  Not fleeing        False
# 26                      False        attack  Not fleeing        False
# 27                      False        attack  Not fleeing        False
# 28                       True        attack  Not fleeing        False
# 29                      False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 4582                    False        attack         Foot        False
# 4583                    False        attack         Foot        False
# 4584                    False        attack         Foot        False
# 4585                     True        attack  Not fleeing         True
# 4586                    False        attack          Car        False
# 4587                    False        attack  Not fleeing        False
# 4588                     True         other  Not fleeing        False
# 4589                    False        attack  Not fleeing        False
# 4590                    False        attack  Not fleeing         True
# 4591                    False        attack  Not fleeing        False
# 4592                    False        attack  Not fleeing        False
# 4593                    False         other          NaN        False
# 4594                    False        attack         Foot        False
# 4595                    False         other  Not fleeing        False
# 4596                    False        attack  Not fleeing        False
# 4597                    False        attack          Car        False
# 4598                    False         other          NaN        False
# 4599                    False        attack  Not fleeing        False
# 4600                     True        attack  Not fleeing        False
# 4601                    False        attack  Not fleeing        False
# 4602                    False        attack        Other        False
# 4603                    False        attack          Car        False
# 4604                    False        attack  Not fleeing        False
# 4605                    False        attack  Not fleeing        False
# 4606                    False        attack         Foot        False
# 4607                    False        attack         Foot        False
# 4608                    False        attack         Foot        False
# 4609                    False        attack  Not fleeing        False
# 4610                    False        attack          NaN        False
# 4611                    False        attack  Not fleeing        False
#
# [4612 rows x 14 columns]

# %%
police.shape
# Out:
# (4612, 14)

# %%
police.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
police["id"]
# Out:
# 0          3
# 1          4
# 2          5
# 3          8
# 4          9
# 5         11
# 6         13
# 7         15
# 8         16
# 9         17
# 10        19
# 11        21
# 12        22
# 13        25
# 14        27
# 15        29
# 16        32
# 17        36
# 18        37
# 19        38
# 20       325
# 21        42
# 22        43
# 23        45
# 24        46
# 25        48
# 26        49
# 27        50
# 28        51
# 29        52
#         ...
# 4582    5038
# 4583    5041
# 4584    5066
# 4585    5032
# 4586    5034
# 4587    5043
# 4588    5045
# 4589    5044
# 4590    5058
# 4591    5049
# 4592    5050
# 4593    5046
# 4594    5047
# 4595    5048
# 4596    5051
# 4597    5068
# 4598    5069
# 4599    5053
# 4600    5067
# 4601    5052
# 4602    5054
# 4603    5055
# 4604    5057
# 4605    5059
# 4606    5063
# 4607    5065
# 4608    5060
# 4609    5061
# 4610    5062
# 4611    5064
# Name: id, Length: 4612, dtype: int64

# %%
police[police['manner_of_death'].str.contains('shot and Tasered')]
# Out:
#         id                      name        date   manner_of_death  \
# 2        5        John Paul Quintero  2015-01-03  shot and Tasered
# 10      19            Patrick Wetter  2015-01-06  shot and Tasered
# 23      45         Salvador Figueroa  2015-01-11  shot and Tasered
# 38      68             Zaki Shinwary  2015-01-16  shot and Tasered
# 43      83             Carter Castle  2015-01-18  shot and Tasered
# 51     100        Kristiana Coignard  2015-01-22  shot and Tasered
# 69     346               Matautu Nuu  2015-01-28  shot and Tasered
# 75     339     Edward Donnell Bright  2015-01-31  shot and Tasered
# 100    138   Antonio Zambrano-Montes  2015-02-10  shot and Tasered
# 112    150               Lavall Hall  2015-02-15  shot and Tasered
# 131    266            Jerome Nichols  2015-02-23  shot and Tasered
# 132    371              Daniel Elrod  2015-02-23  shot and Tasered
# 137    177            Joseph Biegert  2015-02-24  shot and Tasered
# 140    180    Alexander Phillip Long  2015-02-26  shot and Tasered
# 147    187            Deven Guilford  2015-02-28  shot and Tasered
# 154    194    Charly Leundeu Keunang  2015-03-01  shot and Tasered
# 219    233    Christopher Ryan Healy  2015-03-22  shot and Tasered
# 220    234              Denzel Brown  2015-03-22  shot and Tasered
# 228    242          Joseph Tassinari  2015-03-25  shot and Tasered
# 248    288              Donald Hicks  2015-04-02  shot and Tasered
# 253    297              Walter Scott  2015-04-04  shot and Tasered
# 266    534                Mark Smith  2015-04-09  shot and Tasered
# 328    424    Erick Emmanuel Sanchez  2015-04-30  shot and Tasered
# 352    449             Bruce Zalonka  2015-05-12  shot and Tasered
# 366    467          Jonathan  Colley  2015-05-20  shot and Tasered
# 368    486       Nikki Jo Burtsfield  2015-05-20  shot and Tasered
# 387    491               Feras Morad  2015-05-27  shot and Tasered
# 388    492              Simon Hubble  2015-05-27  shot and Tasered
# 392    494                Kyle Baker  2015-05-28  shot and Tasered
# 404    513                 Rudy Baca  2015-06-03  shot and Tasered
# ...    ...                       ...         ...               ...
# 3625  3975           Aquantis Givens  2018-08-17  shot and Tasered
# 3627  3982            Andres Arteaga  2018-08-18  shot and Tasered
# 3667  4020        Dereshia Blackwell  2018-09-09  shot and Tasered
# 3701  4064             Michael Perez  2018-09-27  shot and Tasered
# 3738  4096       Jacob E. Albrethsen  2018-10-12  shot and Tasered
# 3753  4129          James Lyle Kuehn  2018-10-17  shot and Tasered
# 3766  4120          Tafahree Maynard  2018-10-22  shot and Tasered
# 3801  4166                     TK TK  2018-11-07  shot and Tasered
# 3812  4178                Marty West  2018-11-12  shot and Tasered
# 3863  4239     Demontry Floytra Boyd  2018-12-01  shot and Tasered
# 3927  4411            Paul Arbitelle  2018-12-30  shot and Tasered
# 3955  4353           Andre C. Gladen  2019-01-06  shot and Tasered
# 3962  4520             Jerald Wilson  2019-01-08  shot and Tasered
# 3970  4522                     TK TK  2019-01-11  shot and Tasered
# 4004  4406        Kevin Grant Vawter  2019-01-23  shot and Tasered
# 4022  4430               Carl Thayer  2019-01-28  shot and Tasered
# 4039  4456               Hunter Alan  2019-02-06  shot and Tasered
# 4100  4523                     TK TK  2019-03-01  shot and Tasered
# 4115  4529             Danny Brogdon  2019-03-05  shot and Tasered
# 4118  4537  Antonio Joseph Valentine  2019-03-05  shot and Tasered
# 4154  4580            Kenneth Cherry  2019-03-18  shot and Tasered
# 4182  4669  Ondrae Levado Hutchinson  2019-03-30  shot and Tasered
# 4191  4680                     TK TK  2019-04-01  shot and Tasered
# 4223  4635                Henry Lane  2019-04-14  shot and Tasered
# 4249  4692              Isaiah Lewis  2019-04-29  shot and Tasered
# 4407  4854      Olivio Sandoval Diaz  2019-07-04  shot and Tasered
# 4420  4859              Jason Harris  2019-07-09  shot and Tasered
# 4460  4923   Mauris Nishanga DeSilva  2019-07-31  shot and Tasered
# 4600  5067          Kevin Dudenhefer  2019-09-25  shot and Tasered
# 4608  5060            Dewayne Morgan  2019-09-29  shot and Tasered
#
#                  armed   age gender race              city state  \
# 2              unarmed  23.0      M    H           Wichita    KS
# 10               knife  25.0      M    W          Stockton    CA
# 23                 gun  29.0      M    H   North Las Vegas    NV
# 38               knife  48.0      M    O           Fremont    CA
# 43                 gun  67.0      M    W           Gunlock    KY
# 51               knife  17.0      F    W          Longview    TX
# 69              hammer  35.0      M    A          Stockton    CA
# 75               knife  54.0      M    B      Randallstown    MD
# 100            unarmed  35.0      M    H             Pasco    WA
# 112            unarmed  25.0      M    B     Miami Gardens    FL
# 131              knife  42.0      M    W         Allentown    PA
# 132            unarmed  39.0      M    W             Omaha    NE
# 137              knife  30.0      M    W         Green Bay    WI
# 140            unarmed  31.0      M    W       Terre Haute    IN
# 147            unarmed  17.0      M    W   Roxand Township    MI
# 154            unarmed  43.0      M    B       Los Angeles    CA
# 219              knife  36.0      M    W          Portland    OR
# 220       undetermined  21.0      M    B             Islip    NY
# 228                gun  63.0      M    W          Glendale    AZ
# 248                gun  63.0      M    W        Metropolis    IL
# 253            unarmed  50.0      M    B  North Charleston    SC
# 266                NaN  54.0      M  NaN        Kellyville    OK
# 328       metal object  22.0      M    H           El Paso    TX
# 352                gun  46.0      M    O          Honolulu    HI
# 366              knife  52.0      M    W             Green    OH
# 368              knife  39.0      F    W          Gillette    WY
# 387            unarmed  20.0      M    O        Long Beach    CA
# 388        screwdriver  33.0      M    W            Alpine    CA
# 392   lawn mower blade  18.0      M    W           Trenton    MI
# 404            unarmed  36.0      M    H         Los Lunas    NM
# ...                ...   ...    ...  ...               ...   ...
# 3625               gun  21.0      M    B            Austin    TX
# 3627               gun  28.0      M    H           Phoenix    AZ
# 3667     gun and knife  39.0      F    B     Missouri City    TX
# 3701             knife  37.0      M    H          Honolulu    HI
# 3738             knife  17.0      M    W              Orem    OR
# 3753             knife  61.0      M    W            Kearns    UT
# 3766  lawn mower blade  18.0      M    B        Snellville    GA
# 3801               gun   NaN      M  NaN       San Antonio    TX
# 3812             knife  63.0      M    W            Fresno    CA
# 3863             knife  43.0      M    B         Las Vegas    NV
# 3927             knife  45.0      M    W           Danbury    CT
# 3955             knife  36.0      M    B          Portland    OR
# 3962       beer bottle  33.0      M  NaN           Midland    TX
# 3970                ax   NaN      M  NaN        Huntsville    TX
# 4004             knife  46.0      M    W       South Haven    IN
# 4022             knife  45.0      M  NaN     Tehama County    CA
# 4039             knife  48.0      M  NaN          Edinburg    TX
# 4100      undetermined  29.0      M    H         Fairfield    TX
# 4115             knife  56.0      M    W          Muskogee    OK
# 4118               gun  32.0      M    B      Jacksonville    FL
# 4154      sharp object  36.0      M    W         Mansfield    OH
# 4182               gun  30.0      M    B            Durham    NC
# 4191      undetermined  29.0      M  NaN         Fairfield    TX
# 4223     walking stick  42.0      M    N         Red Bluff    CA
# 4249           unarmed  17.0      M    B            Edmond    OK
# 4407     piece of wood  47.0      M    H           Roswell    GA
# 4420             knife  36.0      M  NaN     Rancho Mirage    CA
# 4460             knife  46.0      M  NaN            Austin    TX
# 4600               gun  32.0      M    W           Lacombe    LA
# 4608               NaN  37.0      M    W          Longview    TX
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 2                       False         other  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 38                      False         other  Not fleeing        False
# 43                       True        attack  Not fleeing        False
# 51                       True         other  Not fleeing        False
# 69                       True        attack  Not fleeing        False
# 75                       True         other  Not fleeing        False
# 100                      True         other         Foot        False
# 112                      True         other  Not fleeing        False
# 131                     False        attack          Car        False
# 132                     False         other  Not fleeing        False
# 137                      True        attack  Not fleeing        False
# 140                     False         other  Not fleeing        False
# 147                     False        attack  Not fleeing         True
# 154                      True        attack  Not fleeing         True
# 219                      True         other         Foot        False
# 220                     False        attack          Car        False
# 228                      True         other  Not fleeing        False
# 248                      True        attack  Not fleeing        False
# 253                     False         other         Foot        False
# 266                     False        attack        Other        False
# 328                     False         other  Not fleeing        False
# 352                     False        attack  Not fleeing        False
# 366                     False         other  Not fleeing        False
# 368                     False         other          Car        False
# 387                     False         other  Not fleeing        False
# 388                      True         other  Not fleeing        False
# 392                     False        attack  Not fleeing        False
# 404                     False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 3625                    False        attack          NaN        False
# 3627                    False         other         Foot        False
# 3667                    False         other  Not fleeing        False
# 3701                    False         other  Not fleeing        False
# 3738                    False         other  Not fleeing        False
# 3753                    False         other          NaN        False
# 3766                    False         other  Not fleeing        False
# 3801                    False        attack  Not fleeing        False
# 3812                     True        attack  Not fleeing         True
# 3863                    False        attack  Not fleeing         True
# 3927                    False         other  Not fleeing        False
# 3955                     True         other  Not fleeing        False
# 3962                    False        attack  Not fleeing        False
# 3970                    False         other  Not fleeing        False
# 4004                     True        attack  Not fleeing         True
# 4022                    False         other        Other        False
# 4039                     True        attack  Not fleeing        False
# 4100                    False  undetermined          NaN        False
# 4115                    False         other  Not fleeing        False
# 4118                    False         other  Not fleeing        False
# 4154                    False         other  Not fleeing        False
# 4182                    False        attack         Foot         True
# 4191                    False         other  Not fleeing        False
# 4223                     True         other         Foot        False
# 4249                    False        attack         Foot        False
# 4407                    False        attack  Not fleeing        False
# 4420                    False        attack  Not fleeing         True
# 4460                     True         other  Not fleeing        False
# 4600                     True        attack  Not fleeing        False
# 4608                    False        attack         Foot        False
#
# [230 rows x 14 columns]

# %%
police[police['manner_of_death'].str.contains('shot')]
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4582  5038            Jeffrey Michael Gibble  2019-09-16              shot
# 4583  5041                  Kristopher Adams  2019-09-16              shot
# 4584  5066                             TK TK  2019-09-16              shot
# 4585  5032                   Gay Ellen Plack  2019-09-17              shot
# 4586  5034                             TK TK  2019-09-17              shot
# 4587  5043            Scott Gabriel Spangler  2019-09-18              shot
# 4588  5045                 John Emory Sawyer  2019-09-19              shot
# 4589  5044            Jordan Michael Griffin  2019-09-20              shot
# 4590  5058                 Adam Paul English  2019-09-20              shot
# 4591  5049                  Jeffrey Peterson  2019-09-21              shot
# 4592  5050                             TK TK  2019-09-22              shot
# 4593  5046                             TK TK  2019-09-23              shot
# 4594  5047              Jeffery Tyler Aycock  2019-09-23              shot
# 4595  5048                    Charles Nation  2019-09-23              shot
# 4596  5051                   Jarod Lee Smith  2019-09-24              shot
# 4597  5068                    Haywood Cannon  2019-09-24              shot
# 4598  5069            Ronald Michael McCrary  2019-09-24              shot
# 4599  5053                  Daryl Strickland  2019-09-25              shot
# 4600  5067                  Kevin Dudenhefer  2019-09-25  shot and Tasered
# 4601  5052                     Leonard Shand  2019-09-26              shot
# 4602  5054               Chad Willis Huggins  2019-09-26              shot
# 4603  5055                             TK TK  2019-09-26              shot
# 4604  5057                             TK TK  2019-09-26              shot
# 4605  5059                    Haywood Cannon  2019-09-26              shot
# 4606  5063              Jamaal Ramone Taylor  2019-09-28              shot
# 4607  5065                             TK TK  2019-09-28              shot
# 4608  5060                    Dewayne Morgan  2019-09-29  shot and Tasered
# 4609  5061                             TK TK  2019-09-29              shot
# 4610  5062                   Richard Cabrera  2019-09-29              shot
# 4611  5064                  Antonio Williams  2019-09-29              shot
#
#                armed   age gender race              city state  \
# 0                gun  53.0      M    A           Shelton    WA
# 1                gun  47.0      M    W             Aloha    OR
# 2            unarmed  23.0      M    H           Wichita    KS
# 3         toy weapon  32.0      M    W     San Francisco    CA
# 4           nail gun  39.0      M    H             Evans    CO
# 5                gun  18.0      M    W           Guthrie    OK
# 6                gun  22.0      M    H          Chandler    AZ
# 7                gun  35.0      M    W           Assaria    KS
# 8            unarmed  34.0      F    W        Burlington    IA
# 9         toy weapon  47.0      M    B         Knoxville    PA
# 10             knife  25.0      M    W          Stockton    CA
# 11               gun  31.0      M    B          Freeport    TX
# 12             knife  41.0      M    B          Columbus    OH
# 13               gun  30.0      M    W        Des Moines    IA
# 14               gun  37.0      M    B       New Orleans    LA
# 15               NaN  28.0      M    W           Huntley    MT
# 16            shovel  42.0      M    W    Salt Lake City    UT
# 17           unarmed  36.0      M    B            Strong    AR
# 18               gun  49.0      M    W          Syracuse    UT
# 19               gun  71.0      M    W           England    AR
# 20               gun  33.0      M    H           El Paso    TX
# 21               gun  39.0      M    W            Arcola    IL
# 22               gun  23.0      M    H        South Gate    CA
# 23               gun  29.0      M    H   North Las Vegas    NV
# 24               gun  34.0      M    W       Albuquerque    NM
# 25             knife  43.0      M    W        Jourdanton    TX
# 26               NaN  24.0      M    B          St. Paul    MN
# 27               NaN  29.0      M    W   Franklin County    MO
# 28               gun  34.0      M    B        Chesapeake    VA
# 29             knife  75.0      M    W        Old Bridge    NJ
# ...              ...   ...    ...  ...               ...   ...
# 4582             gun  33.0      M    W       Elizabethon    TN
# 4583             gun  37.0      M  NaN            Sanger    TX
# 4584             gun   NaN      M  NaN           Houston    TX
# 4585         hatchet  57.0      F    W          Richmond    VA
# 4586         vehicle   NaN      M  NaN            Milton    FL
# 4587    undetermined  43.0      M  NaN             Salem    OR
# 4588  unknown weapon  74.0      M  NaN       Soddy Daisy    TN
# 4589      pellet gun  18.0      M  NaN        Long Beach    CA
# 4590             gun  21.0      M  NaN       Gainesville    GA
# 4591    undetermined  29.0      M  NaN               Ada    OK
# 4592             gun  74.0      M    W            Austin    TX
# 4593             gun   NaN      M    H       Los Angeles    CA
# 4594             gun  28.0      M    W      Floyd County    GA
# 4595  unknown weapon  31.0      M  NaN            Lowell    AR
# 4596             gun  41.0      M  NaN        Huntington    WV
# 4597             gun  67.0      M  NaN         Richlands    NC
# 4598           knife  63.0      M  NaN           Sanford    NC
# 4599             gun  64.0      M  NaN        Hartsville    SC
# 4600             gun  32.0      M    W           Lacombe    LA
# 4601           knife  49.0      M    B       Hyattsville    MD
# 4602             gun  28.0      M    W  Lexington County    SC
# 4603         vehicle   NaN      M  NaN          La Habra    CA
# 4604             gun   NaN      M  NaN            Dallas    TX
# 4605             gun  67.0      M  NaN      Jacksonville    NC
# 4606           knife  31.0      M  NaN         Baltimore    MD
# 4607             gun   NaN      M  NaN            Boston    MA
# 4608             NaN  37.0      M    W          Longview    TX
# 4609    undetermined   NaN      M  NaN          Monument    CO
# 4610             gun  38.0      M  NaN             Miami    FL
# 4611             gun  27.0      M  NaN          New York    NY
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# 5                       False        attack  Not fleeing        False
# 6                       False        attack          Car        False
# 7                       False        attack  Not fleeing        False
# 8                       False         other  Not fleeing         True
# 9                       False        attack  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 11                      False        attack  Not fleeing        False
# 12                       True         other  Not fleeing        False
# 13                      False        attack          Car        False
# 14                      False        attack         Foot         True
# 15                      False  undetermined  Not fleeing        False
# 16                      False        attack  Not fleeing         True
# 17                      False        attack  Not fleeing        False
# 18                      False        attack  Not fleeing         True
# 19                      False        attack  Not fleeing        False
# 20                      False        attack  Not fleeing        False
# 21                       True        attack  Not fleeing        False
# 22                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 24                      False        attack         Foot         True
# 25                       True         other  Not fleeing        False
# 26                      False        attack  Not fleeing        False
# 27                      False        attack  Not fleeing        False
# 28                       True        attack  Not fleeing        False
# 29                      False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 4582                    False        attack         Foot        False
# 4583                    False        attack         Foot        False
# 4584                    False        attack         Foot        False
# 4585                     True        attack  Not fleeing         True
# 4586                    False        attack          Car        False
# 4587                    False        attack  Not fleeing        False
# 4588                     True         other  Not fleeing        False
# 4589                    False        attack  Not fleeing        False
# 4590                    False        attack  Not fleeing         True
# 4591                    False        attack  Not fleeing        False
# 4592                    False        attack  Not fleeing        False
# 4593                    False         other          NaN        False
# 4594                    False        attack         Foot        False
# 4595                    False         other  Not fleeing        False
# 4596                    False        attack  Not fleeing        False
# 4597                    False        attack          Car        False
# 4598                    False         other          NaN        False
# 4599                    False        attack  Not fleeing        False
# 4600                     True        attack  Not fleeing        False
# 4601                    False        attack  Not fleeing        False
# 4602                    False        attack        Other        False
# 4603                    False        attack          Car        False
# 4604                    False        attack  Not fleeing        False
# 4605                    False        attack  Not fleeing        False
# 4606                    False        attack         Foot        False
# 4607                    False        attack         Foot        False
# 4608                    False        attack         Foot        False
# 4609                    False        attack  Not fleeing        False
# 4610                    False        attack          NaN        False
# 4611                    False        attack  Not fleeing        False
#
# [4612 rows x 14 columns]

# %%
police['gender'].value_counts()
# Out:
# M    4398
# F     210
# Name: gender, dtype: int64

# %%
police['gender'].value_counts('F')
# Out:
# M    0.954427
# F    0.045573
# Name: gender, dtype: float64

# %%
police['manner_of_death'].value_counts()
# Out:
# shot                4382
# shot and Tasered     230
# Name: manner_of_death, dtype: int64

# %%
police['armed'].value_counts()
# Out:
# gun                                 2562
# knife                                689
# unarmed                              294
# undetermined                         189
# toy weapon                           161
# vehicle                               82
# unknown weapon                        60
# machete                               39
# ax                                    23
# Taser                                 19
# gun and knife                         16
# sword                                 16
# baseball bat                          13
# hammer                                12
# metal pipe                            11
# box cutter                            10
# hatchet                               10
# screwdriver                            9
# crossbow                               9
# sharp object                           7
# gun and car                            7
# pipe                                   6
# blunt object                           5
# piece of wood                          5
# metal object                           4
# shovel                                 4
# rock                                   4
# baton                                  4
# scissors                               4
# gun and vehicle                        4
#                                     ...
# wrench                                 1
# bayonet                                1
# contractor's level                     1
# motorcycle                             1
# nail gun                               1
# bean-bag gun                           1
# hand torch                             1
# metal rake                             1
# barstool                               1
# baseball bat and fireplace poker       1
# spear                                  1
# fireworks                              1
# flashlight                             1
# oar                                    1
# pepper spray                           1
# machete and gun                        1
# flagpole                               1
# claimed to be armed                    1
# tire iron                              1
# baseball bat and bottle                1
# vehicle and gun                        1
# metal hand tool                        1
# cordless drill                         1
# walking stick                          1
# gun and sword                          1
# carjack                                1
# samurai sword                          1
# chainsaw                               1
# bow and arrow                          1
# air conditioner                        1
# Name: armed, Length: 84, dtype: int64

# %%
police
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4582  5038            Jeffrey Michael Gibble  2019-09-16              shot
# 4583  5041                  Kristopher Adams  2019-09-16              shot
# 4584  5066                             TK TK  2019-09-16              shot
# 4585  5032                   Gay Ellen Plack  2019-09-17              shot
# 4586  5034                             TK TK  2019-09-17              shot
# 4587  5043            Scott Gabriel Spangler  2019-09-18              shot
# 4588  5045                 John Emory Sawyer  2019-09-19              shot
# 4589  5044            Jordan Michael Griffin  2019-09-20              shot
# 4590  5058                 Adam Paul English  2019-09-20              shot
# 4591  5049                  Jeffrey Peterson  2019-09-21              shot
# 4592  5050                             TK TK  2019-09-22              shot
# 4593  5046                             TK TK  2019-09-23              shot
# 4594  5047              Jeffery Tyler Aycock  2019-09-23              shot
# 4595  5048                    Charles Nation  2019-09-23              shot
# 4596  5051                   Jarod Lee Smith  2019-09-24              shot
# 4597  5068                    Haywood Cannon  2019-09-24              shot
# 4598  5069            Ronald Michael McCrary  2019-09-24              shot
# 4599  5053                  Daryl Strickland  2019-09-25              shot
# 4600  5067                  Kevin Dudenhefer  2019-09-25  shot and Tasered
# 4601  5052                     Leonard Shand  2019-09-26              shot
# 4602  5054               Chad Willis Huggins  2019-09-26              shot
# 4603  5055                             TK TK  2019-09-26              shot
# 4604  5057                             TK TK  2019-09-26              shot
# 4605  5059                    Haywood Cannon  2019-09-26              shot
# 4606  5063              Jamaal Ramone Taylor  2019-09-28              shot
# 4607  5065                             TK TK  2019-09-28              shot
# 4608  5060                    Dewayne Morgan  2019-09-29  shot and Tasered
# 4609  5061                             TK TK  2019-09-29              shot
# 4610  5062                   Richard Cabrera  2019-09-29              shot
# 4611  5064                  Antonio Williams  2019-09-29              shot
#
#                armed   age gender race              city state  \
# 0                gun  53.0      M    A           Shelton    WA
# 1                gun  47.0      M    W             Aloha    OR
# 2            unarmed  23.0      M    H           Wichita    KS
# 3         toy weapon  32.0      M    W     San Francisco    CA
# 4           nail gun  39.0      M    H             Evans    CO
# 5                gun  18.0      M    W           Guthrie    OK
# 6                gun  22.0      M    H          Chandler    AZ
# 7                gun  35.0      M    W           Assaria    KS
# 8            unarmed  34.0      F    W        Burlington    IA
# 9         toy weapon  47.0      M    B         Knoxville    PA
# 10             knife  25.0      M    W          Stockton    CA
# 11               gun  31.0      M    B          Freeport    TX
# 12             knife  41.0      M    B          Columbus    OH
# 13               gun  30.0      M    W        Des Moines    IA
# 14               gun  37.0      M    B       New Orleans    LA
# 15               NaN  28.0      M    W           Huntley    MT
# 16            shovel  42.0      M    W    Salt Lake City    UT
# 17           unarmed  36.0      M    B            Strong    AR
# 18               gun  49.0      M    W          Syracuse    UT
# 19               gun  71.0      M    W           England    AR
# 20               gun  33.0      M    H           El Paso    TX
# 21               gun  39.0      M    W            Arcola    IL
# 22               gun  23.0      M    H        South Gate    CA
# 23               gun  29.0      M    H   North Las Vegas    NV
# 24               gun  34.0      M    W       Albuquerque    NM
# 25             knife  43.0      M    W        Jourdanton    TX
# 26               NaN  24.0      M    B          St. Paul    MN
# 27               NaN  29.0      M    W   Franklin County    MO
# 28               gun  34.0      M    B        Chesapeake    VA
# 29             knife  75.0      M    W        Old Bridge    NJ
# ...              ...   ...    ...  ...               ...   ...
# 4582             gun  33.0      M    W       Elizabethon    TN
# 4583             gun  37.0      M  NaN            Sanger    TX
# 4584             gun   NaN      M  NaN           Houston    TX
# 4585         hatchet  57.0      F    W          Richmond    VA
# 4586         vehicle   NaN      M  NaN            Milton    FL
# 4587    undetermined  43.0      M  NaN             Salem    OR
# 4588  unknown weapon  74.0      M  NaN       Soddy Daisy    TN
# 4589      pellet gun  18.0      M  NaN        Long Beach    CA
# 4590             gun  21.0      M  NaN       Gainesville    GA
# 4591    undetermined  29.0      M  NaN               Ada    OK
# 4592             gun  74.0      M    W            Austin    TX
# 4593             gun   NaN      M    H       Los Angeles    CA
# 4594             gun  28.0      M    W      Floyd County    GA
# 4595  unknown weapon  31.0      M  NaN            Lowell    AR
# 4596             gun  41.0      M  NaN        Huntington    WV
# 4597             gun  67.0      M  NaN         Richlands    NC
# 4598           knife  63.0      M  NaN           Sanford    NC
# 4599             gun  64.0      M  NaN        Hartsville    SC
# 4600             gun  32.0      M    W           Lacombe    LA
# 4601           knife  49.0      M    B       Hyattsville    MD
# 4602             gun  28.0      M    W  Lexington County    SC
# 4603         vehicle   NaN      M  NaN          La Habra    CA
# 4604             gun   NaN      M  NaN            Dallas    TX
# 4605             gun  67.0      M  NaN      Jacksonville    NC
# 4606           knife  31.0      M  NaN         Baltimore    MD
# 4607             gun   NaN      M  NaN            Boston    MA
# 4608             NaN  37.0      M    W          Longview    TX
# 4609    undetermined   NaN      M  NaN          Monument    CO
# 4610             gun  38.0      M  NaN             Miami    FL
# 4611             gun  27.0      M  NaN          New York    NY
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# 5                       False        attack  Not fleeing        False
# 6                       False        attack          Car        False
# 7                       False        attack  Not fleeing        False
# 8                       False         other  Not fleeing         True
# 9                       False        attack  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 11                      False        attack  Not fleeing        False
# 12                       True         other  Not fleeing        False
# 13                      False        attack          Car        False
# 14                      False        attack         Foot         True
# 15                      False  undetermined  Not fleeing        False
# 16                      False        attack  Not fleeing         True
# 17                      False        attack  Not fleeing        False
# 18                      False        attack  Not fleeing         True
# 19                      False        attack  Not fleeing        False
# 20                      False        attack  Not fleeing        False
# 21                       True        attack  Not fleeing        False
# 22                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 24                      False        attack         Foot         True
# 25                       True         other  Not fleeing        False
# 26                      False        attack  Not fleeing        False
# 27                      False        attack  Not fleeing        False
# 28                       True        attack  Not fleeing        False
# 29                      False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 4582                    False        attack         Foot        False
# 4583                    False        attack         Foot        False
# 4584                    False        attack         Foot        False
# 4585                     True        attack  Not fleeing         True
# 4586                    False        attack          Car        False
# 4587                    False        attack  Not fleeing        False
# 4588                     True         other  Not fleeing        False
# 4589                    False        attack  Not fleeing        False
# 4590                    False        attack  Not fleeing         True
# 4591                    False        attack  Not fleeing        False
# 4592                    False        attack  Not fleeing        False
# 4593                    False         other          NaN        False
# 4594                    False        attack         Foot        False
# 4595                    False         other  Not fleeing        False
# 4596                    False        attack  Not fleeing        False
# 4597                    False        attack          Car        False
# 4598                    False         other          NaN        False
# 4599                    False        attack  Not fleeing        False
# 4600                     True        attack  Not fleeing        False
# 4601                    False        attack  Not fleeing        False
# 4602                    False        attack        Other        False
# 4603                    False        attack          Car        False
# 4604                    False        attack  Not fleeing        False
# 4605                    False        attack  Not fleeing        False
# 4606                    False        attack         Foot        False
# 4607                    False        attack         Foot        False
# 4608                    False        attack         Foot        False
# 4609                    False        attack  Not fleeing        False
# 4610                    False        attack          NaN        False
# 4611                    False        attack  Not fleeing        False
#
# [4612 rows x 14 columns]

# %%
police['state'].value_counts()
# Out:
# CA    698
# TX    410
# FL    281
# AZ    223
# CO    159
# GA    151
# OK    138
# OH    134
# WA    127
# NC    127
# TN    120
# MO    114
# LA     96
# PA     95
# IL     95
# NM     91
# AL     88
# VA     84
# IN     82
# NY     80
# KY     80
# NV     79
# WI     73
# SC     72
# OR     72
# MI     72
# AR     68
# MD     67
# NJ     59
# MN     57
# MS     57
# UT     51
# WV     50
# KS     45
# ID     35
# AK     32
# MA     31
# IA     29
# HI     26
# MT     24
# NE     20
# CT     18
# ME     17
# SD     15
# DC     13
# WY     13
# NH     12
# DE     11
# ND      9
# VT      8
# RI      4
# Name: state, dtype: int64

# %%
police
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4582  5038            Jeffrey Michael Gibble  2019-09-16              shot
# 4583  5041                  Kristopher Adams  2019-09-16              shot
# 4584  5066                             TK TK  2019-09-16              shot
# 4585  5032                   Gay Ellen Plack  2019-09-17              shot
# 4586  5034                             TK TK  2019-09-17              shot
# 4587  5043            Scott Gabriel Spangler  2019-09-18              shot
# 4588  5045                 John Emory Sawyer  2019-09-19              shot
# 4589  5044            Jordan Michael Griffin  2019-09-20              shot
# 4590  5058                 Adam Paul English  2019-09-20              shot
# 4591  5049                  Jeffrey Peterson  2019-09-21              shot
# 4592  5050                             TK TK  2019-09-22              shot
# 4593  5046                             TK TK  2019-09-23              shot
# 4594  5047              Jeffery Tyler Aycock  2019-09-23              shot
# 4595  5048                    Charles Nation  2019-09-23              shot
# 4596  5051                   Jarod Lee Smith  2019-09-24              shot
# 4597  5068                    Haywood Cannon  2019-09-24              shot
# 4598  5069            Ronald Michael McCrary  2019-09-24              shot
# 4599  5053                  Daryl Strickland  2019-09-25              shot
# 4600  5067                  Kevin Dudenhefer  2019-09-25  shot and Tasered
# 4601  5052                     Leonard Shand  2019-09-26              shot
# 4602  5054               Chad Willis Huggins  2019-09-26              shot
# 4603  5055                             TK TK  2019-09-26              shot
# 4604  5057                             TK TK  2019-09-26              shot
# 4605  5059                    Haywood Cannon  2019-09-26              shot
# 4606  5063              Jamaal Ramone Taylor  2019-09-28              shot
# 4607  5065                             TK TK  2019-09-28              shot
# 4608  5060                    Dewayne Morgan  2019-09-29  shot and Tasered
# 4609  5061                             TK TK  2019-09-29              shot
# 4610  5062                   Richard Cabrera  2019-09-29              shot
# 4611  5064                  Antonio Williams  2019-09-29              shot
#
#                armed   age gender race              city state  \
# 0                gun  53.0      M    A           Shelton    WA
# 1                gun  47.0      M    W             Aloha    OR
# 2            unarmed  23.0      M    H           Wichita    KS
# 3         toy weapon  32.0      M    W     San Francisco    CA
# 4           nail gun  39.0      M    H             Evans    CO
# 5                gun  18.0      M    W           Guthrie    OK
# 6                gun  22.0      M    H          Chandler    AZ
# 7                gun  35.0      M    W           Assaria    KS
# 8            unarmed  34.0      F    W        Burlington    IA
# 9         toy weapon  47.0      M    B         Knoxville    PA
# 10             knife  25.0      M    W          Stockton    CA
# 11               gun  31.0      M    B          Freeport    TX
# 12             knife  41.0      M    B          Columbus    OH
# 13               gun  30.0      M    W        Des Moines    IA
# 14               gun  37.0      M    B       New Orleans    LA
# 15               NaN  28.0      M    W           Huntley    MT
# 16            shovel  42.0      M    W    Salt Lake City    UT
# 17           unarmed  36.0      M    B            Strong    AR
# 18               gun  49.0      M    W          Syracuse    UT
# 19               gun  71.0      M    W           England    AR
# 20               gun  33.0      M    H           El Paso    TX
# 21               gun  39.0      M    W            Arcola    IL
# 22               gun  23.0      M    H        South Gate    CA
# 23               gun  29.0      M    H   North Las Vegas    NV
# 24               gun  34.0      M    W       Albuquerque    NM
# 25             knife  43.0      M    W        Jourdanton    TX
# 26               NaN  24.0      M    B          St. Paul    MN
# 27               NaN  29.0      M    W   Franklin County    MO
# 28               gun  34.0      M    B        Chesapeake    VA
# 29             knife  75.0      M    W        Old Bridge    NJ
# ...              ...   ...    ...  ...               ...   ...
# 4582             gun  33.0      M    W       Elizabethon    TN
# 4583             gun  37.0      M  NaN            Sanger    TX
# 4584             gun   NaN      M  NaN           Houston    TX
# 4585         hatchet  57.0      F    W          Richmond    VA
# 4586         vehicle   NaN      M  NaN            Milton    FL
# 4587    undetermined  43.0      M  NaN             Salem    OR
# 4588  unknown weapon  74.0      M  NaN       Soddy Daisy    TN
# 4589      pellet gun  18.0      M  NaN        Long Beach    CA
# 4590             gun  21.0      M  NaN       Gainesville    GA
# 4591    undetermined  29.0      M  NaN               Ada    OK
# 4592             gun  74.0      M    W            Austin    TX
# 4593             gun   NaN      M    H       Los Angeles    CA
# 4594             gun  28.0      M    W      Floyd County    GA
# 4595  unknown weapon  31.0      M  NaN            Lowell    AR
# 4596             gun  41.0      M  NaN        Huntington    WV
# 4597             gun  67.0      M  NaN         Richlands    NC
# 4598           knife  63.0      M  NaN           Sanford    NC
# 4599             gun  64.0      M  NaN        Hartsville    SC
# 4600             gun  32.0      M    W           Lacombe    LA
# 4601           knife  49.0      M    B       Hyattsville    MD
# 4602             gun  28.0      M    W  Lexington County    SC
# 4603         vehicle   NaN      M  NaN          La Habra    CA
# 4604             gun   NaN      M  NaN            Dallas    TX
# 4605             gun  67.0      M  NaN      Jacksonville    NC
# 4606           knife  31.0      M  NaN         Baltimore    MD
# 4607             gun   NaN      M  NaN            Boston    MA
# 4608             NaN  37.0      M    W          Longview    TX
# 4609    undetermined   NaN      M  NaN          Monument    CO
# 4610             gun  38.0      M  NaN             Miami    FL
# 4611             gun  27.0      M  NaN          New York    NY
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# 5                       False        attack  Not fleeing        False
# 6                       False        attack          Car        False
# 7                       False        attack  Not fleeing        False
# 8                       False         other  Not fleeing         True
# 9                       False        attack  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 11                      False        attack  Not fleeing        False
# 12                       True         other  Not fleeing        False
# 13                      False        attack          Car        False
# 14                      False        attack         Foot         True
# 15                      False  undetermined  Not fleeing        False
# 16                      False        attack  Not fleeing         True
# 17                      False        attack  Not fleeing        False
# 18                      False        attack  Not fleeing         True
# 19                      False        attack  Not fleeing        False
# 20                      False        attack  Not fleeing        False
# 21                       True        attack  Not fleeing        False
# 22                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 24                      False        attack         Foot         True
# 25                       True         other  Not fleeing        False
# 26                      False        attack  Not fleeing        False
# 27                      False        attack  Not fleeing        False
# 28                       True        attack  Not fleeing        False
# 29                      False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 4582                    False        attack         Foot        False
# 4583                    False        attack         Foot        False
# 4584                    False        attack         Foot        False
# 4585                     True        attack  Not fleeing         True
# 4586                    False        attack          Car        False
# 4587                    False        attack  Not fleeing        False
# 4588                     True         other  Not fleeing        False
# 4589                    False        attack  Not fleeing        False
# 4590                    False        attack  Not fleeing         True
# 4591                    False        attack  Not fleeing        False
# 4592                    False        attack  Not fleeing        False
# 4593                    False         other          NaN        False
# 4594                    False        attack         Foot        False
# 4595                    False         other  Not fleeing        False
# 4596                    False        attack  Not fleeing        False
# 4597                    False        attack          Car        False
# 4598                    False         other          NaN        False
# 4599                    False        attack  Not fleeing        False
# 4600                     True        attack  Not fleeing        False
# 4601                    False        attack  Not fleeing        False
# 4602                    False        attack        Other        False
# 4603                    False        attack          Car        False
# 4604                    False        attack  Not fleeing        False
# 4605                    False        attack  Not fleeing        False
# 4606                    False        attack         Foot        False
# 4607                    False        attack         Foot        False
# 4608                    False        attack         Foot        False
# 4609                    False        attack  Not fleeing        False
# 4610                    False        attack          NaN        False
# 4611                    False        attack  Not fleeing        False
#
# [4612 rows x 14 columns]

# %%
city_population = pd.read_csv('CityPopulation2000.csv', encoding = "ISO-8859-1")

# %%
city_population
# Out:
#       Geographic Area                               City     Population
# 0                  AL                         Abanda CDP            192
# 1                  AL                     Abbeville city           2688
# 2                  AL                    Adamsville city           4522
# 3                  AL                       Addison town            758
# 4                  AL                         Akron town            356
# 5                  AL                     Alabaster city          30352
# 6                  AL                   Albertville city          21160
# 7                  AL                Alexander City city          14875
# 8                  AL                     Alexandria CDP           3917
# 9                  AL                    Aliceville city           2486
# 10                 AL                       Allgood town            622
# 11                 AL                       Altoona town            933
# 12                 AL                     Andalusia city           9015
# 13                 AL                      Anderson town            282
# 14                 AL                      Anniston city          23106
# 15                 AL                          Arab city           8050
# 16                 AL                       Ardmore town           1194
# 17                 AL                          Argo town           4071
# 18                 AL                        Ariton town            764
# 19                 AL                         Arley town            357
# 20                 AL                       Ashford town           2148
# 21                 AL                       Ashland town           2037
# 22                 AL                      Ashville city           2212
# 23                 AL                        Athens city          21897
# 24                 AL                        Atmore city          10194
# 25                 AL                       Attalla city           6048
# 26                 AL                        Auburn city  53380(r38811)
# 27                 AL                  Autaugaville town            870
# 28                 AL                          Avon town            543
# 29                 AL                           Axis CDP            757
# ...               ...                                ...            ...
# 29493     Puerto Rico               San Isidro comunidad           6828
# 29494     Puerto Rico                 San José comunidad           2900
# 29495     Puerto Rico               San Juan zona urbana         381931
# 29496     Puerto Rico            San Lorenzo zona urbana           8037
# 29497     Puerto Rico          San Sebastián zona urbana           9622
# 29498     Puerto Rico            Santa Bárbara comunidad           4622
# 29499     Puerto Rico              Santa Clara comunidad            982
# 29500     Puerto Rico           Santa Isabel zona urbana           5976
# 29501     Puerto Rico            Santo Domingo comunidad           3156
# 29502     Puerto Rico                   Stella comunidad           1088
# 29503     Puerto Rico                   Suárez comunidad           1931
# 29504     Puerto Rico                 Tallaboa comunidad            925
# 29505     Puerto Rico            Tallaboa Alta comunidad           1816
# 29506     Puerto Rico                    Tibes comunidad            362
# 29507     Puerto Rico                Tiburones comunidad           1616
# 29508     Puerto Rico  Tierras Nuevas Poniente comunidad           3228
# 29509     Puerto Rico               Toa Alta zona urbana           3713
# 29510     Puerto Rico               Toa Baja zona urbana           1513
# 29511     Puerto Rico          Trujillo Alto zona urbana          48437
# 29512     Puerto Rico                 Utuado zona urbana           8397
# 29513     Puerto Rico                    Vayas comunidad            528
# 29514     Puerto Rico                  Vázquez comunidad           1890
# 29515     Puerto Rico              Vega Alta zona urbana          10266
# 29516     Puerto Rico              Vega Baja zona urbana          25905
# 29517     Puerto Rico                  Vieques comunidad           3316
# 29518     Puerto Rico                Vieques zona urbana           1938
# 29519     Puerto Rico               Villalba zona urbana           3384
# 29520     Puerto Rico                Yabucoa zona urbana           6047
# 29521     Puerto Rico                  Yauco zona urbana          17186
# 29522     Puerto Rico                   Yaurel comunidad           1050
#
# [29523 rows x 3 columns]

# %%
grouped_tbl = police.groupby("city").agg(len)
selected_tbl = grouped_tbl[["id"]]
selected_tbl.rename(columns={'id':'kill counts'})
# Out:
#                               kill counts
# city
# 300 block of State Line Road            1
# Abbeville                               1
# Aberdeen                                2
# Abilene                                 2
# Abingdon                                2
# Abington Township                       1
# Acworth                                 1
# Ada                                     1
# Adams County                            3
# Addison                                 1
# Adelanto                                1
# Affton                                  1
# Aguanga                                 1
# Ahwatukee                               1
# Aiea                                    1
# Aiken                                   2
# Aitkin                                  1
# Akron                                   6
# Alamo                                   2
# Alamogordo                              2
# Alamosa                                 2
# Albany                                  2
# Albert Lea                              1
# Albuquerque                            31
# Alderwood Manor                         1
# Aldie                                   1
# Alexandria                              4
# Algoma Township                         1
# Alhambra                                1
# Aliceville                              1
# ...                                   ...
# Winter Haven                            1
# Winters                                 1
# Wise County                             1
# Wolf Creek                              1
# Wolfe County                            1
# Wood County                             1
# Wood Lake                               1
# Woodbridge                              2
# Woodford                                1
# Woodland                                1
# Woodlawn                                1
# Woodstock                               1
# Woodville                               2
# Wyoming                                 2
# Wythe County                            1
# Wytheville                              1
# Yakima                                  4
# Yellville                               1
# Yonkers                                 2
# Yorba Linda                             1
# York                                    5
# York County                             2
# Youngtown                               1
# Yreka                                   1
# Yuba City                               2
# Yucca Valley                            1
# Yulee                                   1
# Yuma                                    3
# Zanesville                              1
# Zion                                    2
#
# [2211 rows x 1 columns]

# %%
police[police['city'].str.contains('300')]
# Out:
#         id              name        date manner_of_death  armed   age gender  \
# 2928  3247  Salvador Byassee  2017-12-26            shot  knife  34.0      M
#
#      race                          city state  signs_of_mental_illness  \
# 2928  NaN  300 block of State Line Road    TN                    False
#
#      threat_level   flee  body_camera
# 2928        other  Other        False

# %%
x=police['city'].value_counts()
x
# Out:
# Los Angeles           71
# Phoenix               69
# Houston               47
# Las Vegas             41
# San Antonio           36
# Columbus              34
# Chicago               34
# Albuquerque           31
# Miami                 29
# St. Louis             29
# Austin                28
# Kansas City           26
# Denver                26
# Jacksonville          26
# Oklahoma City         25
# Tucson                25
# Bakersfield           21
# Tulsa                 21
# Louisville            18
# New York              18
# Atlanta               18
# Mesa                  17
# Fresno                17
# Dallas                17
# Indianapolis          16
# Portland              16
# Orlando               16
# Baltimore             16
# San Jose              16
# San Francisco         15
#                       ..
# Bastrop                1
# West Olive             1
# Coos Bay               1
# McLemoresville         1
# Lehigh                 1
# New Britain            1
# Laguna Pueblo          1
# Immokalee              1
# Richfield              1
# Riverton               1
# Casselberry            1
# South Greensburg       1
# Mt. Pleasant           1
# Goodyear               1
# Mascotte               1
# Eldorado               1
# Calexico               1
# Surfside Beach         1
# East Flat Rock         1
# Butte                  1
# Middle River           1
# Moraine                1
# Naschitti              1
# St. Clair Township     1
# Del Mar                1
# Ruth                   1
# Emporia                1
# Warren County          1
# Fox Crossing           1
# Decatur County         1
# Name: city, Length: 2211, dtype: int64

# %%
dict_x=dict(x)

# %%
len(dict_x)
# Out:
# 2211

# %%
next(iter( dict_x.items()))
# Out:
# ('Los Angeles', 71)

# %%
list(dict_x.items())[0][1]
# Out:
# 71

# %%
def change_key_values_to_list(dic):
    dic_lst=list(dic.items())
    for i in range(len(dic_lst)):
        number= dic_lst[i][1]
        lst_with_number=[number]
        dic[dic_lst[i][0]]=lst_with_number

change_key_values_to_list(dict_x)

print(len(dict_x))

dict_x.items()
# Out:
# 2211
# dict_items([('Los Angeles', [71]), ('Phoenix', [69]), ('Houston', [47]), ('Las Vegas', [41]), ('San Antonio', [36]), ('Columbus', [34]), ('Chicago', [34]), ('Albuquerque', [31]), ('Miami', [29]), ('St. Louis', [29]), ('Austin', [28]), ('Kansas City', [26]), ('Denver', [26]), ('Jacksonville', [26]), ('Oklahoma City', [25]), ('Tucson', [25]), ('Bakersfield', [21]), ('Tulsa', [21]), ('Louisville', [18]), ('New York', [18]), ('Atlanta', [18]), ('Mesa', [17]), ('Fresno', [17]), ('Dallas', [17]), ('Indianapolis', [16]), ('Portland', [16]), ('Orlando', [16]), ('Baltimore', [16]), ('San Jose', [16]), ('San Francisco', [15]), ('Colorado Springs', [15]), ('Aurora', [15]), ('Washington', [15]), ('Arlington', [15]), ('Springfield', [15]), ('Charlotte', [15]), ('Fort Worth', [14]), ('Long Beach', [14]), ('San Diego', [14]), ('Memphis', [14]), ('Philadelphia', [14]), ('Pueblo', [12]), ('Spokane', [11]), ('Salt Lake City', [11]), ('Reno', [11]), ('Seattle', [11]), ('Milwaukee', [11]), ('Westminster', [11]), ('Jackson', [11]), ('El Paso', [11]), ('Stockton', [11]), ('San Bernardino', [10]), ('Sacramento', [10]), ('Glendale', [10]), ('Santa Ana', [10]), ('Tacoma', [10]), ('Richmond', [10]), ('Omaha', [10]), ('Baton Rouge', [10]), ('Las Cruces', [10]), ('Honolulu', [10]), ('Greenville', [10]), ('Shreveport', [9]), ('Huntsville', [9]), ('Tampa', [9]), ('Detroit', [9]), ('New Orleans', [9]), ('Fairbanks', [9]), ('Newark', [9]), ('Oakland', [9]), ('Anaheim', [9]), ('Wichita', [9]), ('St. Paul', [9]), ('Billings', [9]), ('Clinton', [9]), ('Amarillo', [9]), ('Lakewood', [9]), ('Flagstaff', [9]), ('Anchorage', [9]), ('Tempe', [8]), ('Vancouver', [8]), ('Redding', [8]), ('Longview', [8]), ('Wilmington', [8]), ('Modesto', [8]), ('Boston', [8]), ('Lancaster', [8]), ('Birmingham', [8]), ('Clarksville', [7]), ('Durham', [7]), ('Boise', [7]), ('Odessa', [7]), ('Cincinnati', [7]), ('Nashville', [7]), ('Norfolk', [7]), ('Little Rock', [7]), ('Charleston', [7]), ('Lakeland', [7]), ('Hemet', [7]), ('Scottsdale', [6]), ('Midland', [6]), ('Auburn', [6]), ('Des Moines', [6]), ('Minneapolis', [6]), ('Ontario', [6]), ('Brooklyn', [6]), ('Florence', [6]), ('Kingman', [6]), ('Ogden', [6]), ('Cleveland', [6]), ('Antioch', [6]), ('Akron', [6]), ('Garland', [6]), ('Knoxville', [6]), ('Kent', [6]), ('Casper', [5]), ('Centennial', [5]), ('Burlington', [5]), ('Toledo', [5]), ('Fremont', [5]), ('Chattanooga', [5]), ('Chester', [5]), ('Dayton', [5]), ('Shelbyville', [5]), ('Sparks', [5]), ('Van Nuys', [5]), ('Fayetteville', [5]), ('Franklin', [5]), ('Riverside', [5]), ('Gary', [5]), ('York', [5]), ('Fort Pierce', [5]), ('Monroe', [5]), ('Henderson', [5]), ('Columbia', [5]), ('Greeley', [5]), ('Beaumont', [5]), ('West Jordan', [5]), ('Eugene', [5]), ('Fairfield', [5]), ('Montgomery', [5]), ('Fontana', [5]), ('Gainesville', [5]), ('Jurupa Valley', [5]), ('Irving', [5]), ('Miami Gardens', [4]), ('Vineland', [4]), ('Visalia', [4]), ('Phenix City', [4]), ('Peoria', [4]), ('Laredo', [4]), ('Mission', [4]), ('Smyrna', [4]), ('Waco', [4]), ('Deltona', [4]), ('North Las Vegas', [4]), ('Savannah', [4]), ('Douglas', [4]), ('Brooksville', [4]), ('Buckeye', [4]), ('Princeton', [4]), ('Pasadena', [4]), ('Hollywood', [4]), ('Palmdale', [4]), ('Lincoln', [4]), ('Virginia Beach', [4]), ('Yakima', [4]), ('Torrance', [4]), ('Chico', [4]), ('Piedmont', [4]), ('Harrisburg', [4]), ('Hilo', [4]), ('Fort Collins', [4]), ('Augusta', [4]), ('Roswell', [4]), ('Danville', [4]), ('Farmington', [4]), ('Weatherford', [4]), ('Federal Way', [4]), ('Grand Junction', [4]), ('Gilbert', [4]), ('Napa', [4]), ('Pittsburgh', [4]), ('Fort Wayne', [4]), ('Lynn', [4]), ('Brownsville', [4]), ('Trenton', [4]), ('Raleigh', [4]), ('Kirkland', [4]), ('Gulfport', [4]), ('Beaverton', [4]), ('Evansville', [4]), ('Azusa', [4]), ('St. Joseph', [4]), ('Indio', [4]), ('West Memphis', [4]), ('Vallejo', [4]), ('Corpus Christi', [4]), ('Topeka', [4]), ('Medford', [4]), ('Chickasha', [4]), ('Salem', [4]), ('Barstow', [4]), ('Alexand ...

# %%
'prepping city->state'
city_state=police[['city','state']]
print(len(city_state))
city_state['city'][0]
city_state_dic={}
for i in range(len(city_state)):
    city_state_dic[city_state['city'][i]]=city_state['state'][i]
print(len(city_state_dic))
list(city_state_dic.items())
# Out:
# 4612
# 2211
# [('Shelton', 'WA'),
#  ('Aloha', 'OR'),
#  ('Wichita', 'KS'),
#  ('San Francisco', 'CA'),
#  ('Evans', 'CO'),
#  ('Guthrie', 'OK'),
#  ('Chandler', 'AZ'),
#  ('Assaria', 'KS'),
#  ('Burlington', 'IA'),
#  ('Knoxville', 'TN'),
#  ('Stockton', 'CA'),
#  ('Freeport', 'TX'),
#  ('Columbus', 'OH'),
#  ('Des Moines', 'IA'),
#  ('New Orleans', 'LA'),
#  ('Huntley', 'MT'),
#  ('Salt Lake City', 'UT'),
#  ('Strong', 'AR'),
#  ('Syracuse', 'NY'),
#  ('England', 'AR'),
#  ('El Paso', 'TX'),
#  ('Arcola', 'IL'),
#  ('South Gate', 'CA'),
#  ('North Las Vegas', 'NV'),
#  ('Albuquerque', 'NM'),
#  ('Jourdanton', 'TX'),
#  ('St. Paul', 'MN'),
#  ('Franklin County', 'OH'),
#  ('Chesapeake', 'VA'),
#  ('Old Bridge', 'NJ'),
#  ('Lake Jackson', 'TX'),
#  ('Draper', 'UT'),
#  ('Indianapolis', 'IN'),
#  ('Aurora', 'CO'),
#  ('Bloomington', 'MN'),
#  ('Fairfield', 'TX'),
#  ('Evangeline Parish', 'LA'),
#  ('Mabank', 'TX'),
#  ('Fremont', 'CA'),
#  ('Muskogee', 'OK'),
#  ('Los Angeles', 'CA'),
#  ('Fort Worth', 'TX'),
#  ('Maricopa', 'AZ'),
#  ('Gunlock', 'KY'),
#  ('Weymouth', 'MA'),
#  ('Scottsdale', 'AZ'),
#  ('Hemet', 'CA'),
#  ('Chapeno', 'TX'),
#  ('St. Louis', 'MO'),
#  ('Derry', 'NH'),
#  ('Sierra Blanca', 'TX'),
#  ('Longview', 'TX'),
#  ('Austin', 'TX'),
#  ('Fort Lauderdale', 'FL'),
#  ('Levelland', 'TX'),
#  ('Rexburg', 'ID'),
#  ('Baltimore', 'MD'),
#  ('Pueblo', 'CO'),
#  ('Winslow', 'AZ'),
#  ('Denver', 'CO'),
#  ('New Hope', 'MN'),
#  ('Tahoka', 'TX'),
#  ('Wasco', 'CA'),
#  ('Phoenix', 'AZ'),
#  ('Morenci', 'AZ'),
#  ('Omaha', 'NE'),
#  ('Sunset', 'TX'),
#  ('Rosenberg', 'TX'),
#  ('Stillwater', 'MN'),
#  ('Wyoming', 'MI'),
#  ('Billings', 'MT'),
#  ('Houston', 'TX'),
#  ('Randallstown', 'MD'),
#  ('Bay City', 'MI'),
#  ('Hummelstown', 'PA'),
#  ('Apple Valley', 'CA'),
#  ('Emeryville', 'CA'),
#  ('Antioch', 'CA'),
#  ('Douglas', 'AZ'),
#  ('Tallahassee', 'FL'),
#  ('Orlando', 'FL'),
#  ('Tempe', 'AZ'),
#  ('Lorena', 'TX'),
#  ('Memphis', 'TN'),
#  ('Chino', 'CA'),
#  ('Oklahoma City', 'OK'),
#  ('Calimesa', 'CA'),
#  ('Gastonia', 'NC'),
#  ('Anchorage', 'AK'),
#  ('New City', 'NY'),
#  ('Orange County', 'FL'),
#  ('Nocona', 'TX'),
#  ('Smyrna', 'TN'),
#  ('Dallas', 'TX'),
#  ('Pasco', 'WA'),
#  ('Whitehaven', 'TN'),
#  ('New Castle', 'IN'),
#  ('San Jose', 'CA'),
#  ('Dadeville', 'AL'),
#  ('San Bernardino', 'CA'),
#  ('Kansas City', 'KS'),
#  ('Reading', 'MA'),
#  ('McLemoresville', 'TN'),
#  ('San Manuel', 'AZ'),
#  ('Essex', 'MD'),
#  ('Laredo', 'TX'),
#  ('Miami Gardens', 'FL'),
#  ('Iuka', 'MS'),
#  ('Colton', 'CA'),
#  ('Marana', 'AZ'),
#  ('Boise', 'ID'),
#  ('Provo', 'UT'),
#  ('Gaston County', 'NC'),
#  ('Springfield', 'FL'),
#  ('Eaton Rapids Township', 'MI'),
#  ('Tewksbury', 'MA'),
#  ('Del Rio', 'TX'),
#  ('Charlotte', 'NC'),
#  ('Euless', 'TX'),
#  ('Homewood', 'AL'),
#  ('Birmingham', 'AL'),
#  ('Ruidoso', 'NM'),
#  ('Palm Bay', 'FL'),
#  ('Allentown', 'PA'),
#  ('Denham Springs', 'LA'),
#  ('Powder Springs', 'GA'),
#  ('Clarkesville', 'GA'),
#  ('Millbrook', 'AL'),
#  ('Green Bay', 'WI'),
#  ('Las Vegas', 'NV'),
#  ('Terre Haute', 'IN'),
#  ('Lakeland', 'FL'),
#  ('Gulfport', 'MS'),
#  ('Sylvester', 'GA'),
#  ('Santa Ana', 'CA'),
#  ('Pelzer', 'SC'),
#  ('Roxand Township', 'MI'),
#  ('St Louis', 'MO'),
#  ('Tucson', 'AZ'),
#  ('Columbia', 'MO'),
#  ('Tarboro', 'NC'),
#  ('La Paz County', 'AZ'),
#  ('Barton', 'MS'),
#  ('Joilet', 'IL'),
#  ('Salisbury', 'NC'),
#  ('Deltona', 'FL'),
#  ('Milwaukee', 'WI'),
#  ('Burbank', 'CA'),
#  ('Lincoln', 'CA'),
#  ('Putnam Hall', 'FL'),
#  ('Madison', 'ME'),
#  ('Claymont', 'DE'),
#  ('Anaheim', 'CA'),
#  ('Brevard', 'NC'),
#  ('Dinosaur', 'CO'),
#  ('Cocoa', 'FL'),
#  ('Atlanta', 'GA'),
#  ('Baton Rouge', 'LA'),
#  ('Port Wentworth', 'GA'),
#  ('Ontario', 'CA'),
#  ('Cleveland', 'OH'),
#  ('Kingman', 'AZ'),
#  ('Bay Minette', 'AL'),
#  ('Hoover', 'AL'),
#  ('Elkton', 'MD'),
#  ('Washington', 'DC'),
#  ('Fontana', 'CA'),
#  ('Walnut Creek', 'CA'),
#  ('Napa', 'CA'),
#  ('San Antonio', 'TX'),
#  ('Follansbee', 'WV'),
#  ('Kenosha', 'WI'),
#  ('Ruth', 'MS'),
#  ('Onalaska', 'TX'),
#  ('Sacramento', 'CA'),
#  ('Medford', 'OR'),
#  ('Dublin', 'NC'),
#  ('Bakersfield', 'CA'),
#  ('Glendale', 'AZ'),
#  ('Jacksonville', 'NC'),
#  ('Sumas', 'WA'),
#  ('Lawrence County', 'AL'),
#  ('Middleton', 'ID'),
#  ('Red Valley', 'AZ'),
#  ('Coal County', 'OK'),
#  ('Clarendon', 'NY'),
#  ('Harmony', 'TX'),
#  ('Cottonwood', 'CA'),
#  ('Vallejo', 'CA'),
#  ('Portland', 'OR'),
#  ('Islip', 'NY'),
#  ('Santa Clara', 'CA'),
#  ('Fond du Lac', 'WI'),
#  ('Portsmouth', 'VA'),
#  ('Johnsonville', 'SC'),
#  ('South Los Angeles', 'CA'),
#  ('Gardner', 'KS'),
#  ('Wilmington', 'DE'),
#  ('Encinitas', 'CA'),
#  ('Fort Pierce', 'FL'),
#  ('Webster', 'TX'),
#  ('Oxnard', 'CA'),
#  ('Fort Ashby', 'WV'),
#  ('Boston', 'MA'),
#  ('Jasper', 'OH'),
#  ('Elizabethtown', 'KY'),
#  ('Eugene', 'OR'),
#  ('Boulder City', 'NV'),
#  ('Carollwood', 'FL'),
#  ('Baytown', 'TX'),
#  ('Fort Meade', 'MD'),
#  ('Hawthorne', 'CA'),
#  ('Hamilton', 'AL'),
#  ('Rock Island', 'IL'),
#  ('Metropolis', 'IL'),
#  ('Tulsa', 'OK'),
#  ('Pineville', 'LA'),
#  ('Winchester', 'CA'),
#  ('Zion', 'IL'),
#  ('North Charleston', 'SC'),
#  ('Orange', 'NJ'),
#  ('Edgewood', 'NM'),
#  ('Tehachapi', 'CA'),
#  ('Harvey', 'IL'),
#  ('Jefferson County', 'ID'),
#  ('Pottawatomie County', 'OK'),
#  ('Valdosta', 'GA'),
#  ('Sunnyvale', 'CA'),
#  ('Kellyville', 'OK'),
#  ('Navarre', 'FL'),
#  ('Monon', 'IN'),
#  ('Straban Township', 'PA'),
#  ('Boiling Springs', 'SC'),
#  ('Corning', 'WI'),
#  ('Topeka', 'KS'),
#  ('Sand Springs', 'OK'),
#  ('Salemburg', 'NC'),
#  ('Alton', 'IL'),
#  ('DeSoto', 'TX'),
#  ('Jonesboro', 'AR'),
#  ('Miami', 'FL'),
#  ('Spartanburg', 'SC'),
#  ('Cañon City', 'CO'),
#  ('Montclair', 'CA'),
#  ('Shafter', 'CA'),
#  ('Chicago', 'IL'),
#  ('Jennings', 'MO'),
#  ('Panama City', 'FL'),
#  ('Wilmore', 'KY'),
#  ('Sidney', 'NE'),
#  ('Mission', 'TX'),
#  ('Trenton', 'NJ'),
#  ('Lakewood', 'CO'),
#  ('Irmo', 'SC'),
#  ('Bisbee', 'AZ'),
#  ('Queens', 'NY'),
#  ('Eldorado Springs', 'CO'),
#  ('Sylmar', 'CA'),
#  ('Rufe', 'OK'),
#  ('Long Beach', 'CA'),
#  ('Windsor', 'CA'),
#  ('Trinidad', 'CO'),
#  ('Victoria', 'TX'),
#  ('New York', 'NY'),
#  ('Clermont', 'FL'),
#  ('Bunch', 'OK'),
#  ('Kings County', 'CA'),
#  ('Fountain Valley', 'CA'),
#  ('Detroit', 'MI'),
#  ('Mansfield', 'OH'),
#  ('Marion', 'AR'),
#  ('Chickasha', 'OK'),
#  ('Mesa', 'AZ'),
#  ('Elk Grove', 'CA'),
#  ('Emporia', 'VA'),
#  ('Nashville', 'TN'),
#  ('San Diego', 'CA'),
#  ('Roosevelt', 'UT'),
#  ('Garland', 'TX'),
#  ('Chavies', 'KY'),
#  ('Kennewick', 'WA'),
#  ('Venice', 'CA'),
#  ('South El Monte', 'CA'),
#  ('Pulaski', 'VA'),
#  ('Wake Forest', 'NC'),
#  ('Lawrenceville', 'GA'),
#  ('Beacon', 'NY'),
#  ('Cerritos', 'CA'),
#  ('Kearny', 'AZ'),
#  ('Constantia', 'NY'),
#  ('Fridley', 'MN'),
#  ('Tacoma', 'WA'),
#  ('Landover', 'MD'),
#  ('St. Augustine', 'FL'),
#  ('Honolulu', 'HI'),
#  ('Rancho Santa Margarita', 'CA'),
#  ('Portage', 'IN'),
#  ('Rockford', 'IL'),
#  ('St. Petersburg', 'FL'),
#  ('Arlington', 'TX'),
#  ('Cabot', 'AR'),
#  ('Grand Junction', 'CO'),
#  ('Lancaster', 'PA'),
#  ('Green', 'OH'),
#  ('Owensboro', 'KY'),
#  ('Gillette', 'WY'),
#  ('Ft. Lauderdale', 'FL'),
#  ('Hackensack', 'NJ'),
#  ('Charleston', 'WV'),
#  ('Somerset', 'PA'),
#  ('Sedalia', 'CO'),
#  ('Eagar', 'AZ'),
#  ('Huntsville', 'AL'),
#  ('Snohomish', 'WA'),
#  ('Bossier City', 'LA'),
#  ('Ideal Beach', 'NJ'),
#  ('Edmond', 'OK'),
#  ('Rockville', 'MD'),
#  ('Alpine', 'CA'),
#  ('Northglenn', 'CO'),
#  ('Carrollton', 'TX'),
#  ('Lyndhurst', 'NJ'),
#  ('Okmulgee County', 'OK'),
#  ('Wilderville', 'OR'),
#  ('Palestine', 'TX'),
#  ('Greece', 'NY'),
#  ('Roslindale', 'MA'),
#  ('Azle', 'TX'),
#  ('Delano', 'CA'),
#  ('Los Lunas', 'NM'),
#  ('Ellis County', 'TX'),
#  ('Fuqua', 'TX'),
#  ('Byram', 'NJ'),
#  ('Santa Maria', 'CA'),
#  ('Morgantown', 'WV'),
#  ('Oakland', 'CA'),
#  ('North Port', 'FL'),
#  ('Watsonsville', 'CA'),
#  ('Midland', 'TX'),
#  ('Strasburg', 'CO'),
#  ('Melbourne', 'FL'),
#  ('Woodland', 'WA'),
#  ('Beech Grove', 'IN'),
#  ('Sun City', 'SC'),
#  ('Findlay', 'OH'),
#  ('Tomball', 'TX'),
#  ('Cincinnati', 'OH'),
#  ('Bronx', 'NY'),
#  ('Pompano Beach', 'FL'),
#  ('Bexar County', 'TX'),
#  ('Kokomo', 'IN'),
#  ('Fort Wayne', 'IN'),
#  ('Louisville', 'KY'),
#  ('Hutchins', 'TX'),
#  ('South Lake Tahoe', 'CA'),
#  ('Visalia', 'CA'),
#  ('Wood Lake', 'ND'),
#  ('Clanton', 'AL'),
#  ('Hobbs', 'NM'),
#  ('Coney Island', 'NY'),
#  ('Greeley', 'CO'),
#  ('Azusa', 'CA'),
#  ('Ronda', 'NC'),
#  ('Citrus Heights', 'CA'),
#  ('Augusta', 'GA'),
#  ('Pittsburgh', 'PA'),
#  ('Hutchinson', 'KS'),
#  ('Weatherford', 'TX'),
#  ('York County', 'PA'),
#  ('Owings Mills', 'MD'),
#  ('Fresno', 'CA'),
#  ('Malone', 'NY'),
#  ('Tahlequah', 'OK'),
#  ('Edinburg', 'TX'),
#  ('Franklin', 'NC'),
#  ('McMinnville', 'TN'),
#  ('Josephine County', 'OR'),
#  ('Brockton', 'MA'),
#  ('Meadow Bridge', 'WV'),
#  ('West Covina', 'CA'),
#  ('Camden', 'NJ'),
#  ('Miami Beach', 'FL'),
#  ('Morristown', 'TN'),
#  ('Newport News', 'VA'),
#  ('Henderson', 'NV'),
#  ('Pleasanton', 'CA'),
#  ('Hawaiian Gardens', 'CA'),
#  ('Bath', 'NH'),
#  ('Atwater', 'CA'),
#  ('Atlantic City', 'NJ'),
#  ('Sugar Creek', 'MO'),
#  ('Beaverton', 'OR'),
#  ('Ashe County', 'NC'),
#  ('Parowan', 'UT'),
#  ('Boulder Creek', 'CA'),
#  ('Covington', 'GA'),
#  ('Olivehurst', 'CA'),
#  ('Plantation', 'FL'),
#  ('River Forest', 'IL'),
#  ('Casper', 'WY'),
#  ('Stone Mountain', 'GA'),
#  ('Dunsmuir', 'CA'),
#  ('Lynn', 'MA'),
#  ('Mascotte', 'FL'),
#  ('Southington', 'OH'),
#  ('Moreno Valley', 'CA'),
#  ('Wauwatosa', 'WI'),
#  ('Homestead', 'FL'),
#  ('Chattanooga', 'TN'),
#  ('Cheyenne', 'WY'),
#  ('Opp', 'AL'),
#  ('Seattle', 'WA'),
#  ('Needles', 'CA'),
#  ('Brownsville', 'TX'),
#  ('Fort Collins', 'CO'),
#  ('Colby', 'KS'),
#  ('Mt. Auburn', 'OH'),
#  ('Winnie', 'TX'),
#  ('White', 'GA'),
#  ('Oakland Park', 'FL'),
#  ('Jesup', 'GA'),
#  ('Monroe', 'GA'),
#  ('Philadelphia', 'PA'),
#  ('Dayton', 'OH'),
#  ('Plymouth', 'MN'),
#  ('Myrtle Beach', 'SC'),
#  ('Meadow Vista', 'CA'),
#  ('Studio City', 'CA'),
#  ('Pinnacle', 'NC'),
#  ('Decatur', 'GA'),
#  ('Micanopy', 'FL'),
#  ('Shreveport', 'LA'),
#  ('Seneca', 'SC'),
#  ('Houma', 'LA'),
#  ('Boulder', 'CO'),
#  ('Manila', 'AR'),
#  ('Las Cruces', 'NM'),
#  ('Logan', 'UT'),
#  ('Gardnerville Ranchos', 'NV'),
#  ('Whittier', 'CA'),
#  ('Roswell', 'GA'),
#  ('Nitro', 'WV'),
#  ('Campbelltown', 'PA'),
#  ('Powhatan County', 'VA'),
#  ('Muncie', 'IN'),
#  ('San Diego County', 'CA'),
#  ('Rantoul', 'IL'),
#  ('Greenfield', 'WI'),
#  ('Maui', 'HI'),
#  ('Richmond', 'VA'),
#  ('Elsmere', 'KY'),
#  ('Superior', 'MT'),
#  ('Greenville', 'NC'),
#  ('Brookshire', 'TX'),
#  ('Summerville', 'SC'),
#  ('Spokane', 'WA'),
#  ('Ardmore', 'OK'),
#  ('Pittston', 'PA'),
#  ('Gilbert', 'AZ'),
#  ('Sandpoint', 'ID'),
#  ('Waco', 'TX'),
#  ('Odessa', 'TX'),
#  ('Toledo', 'OH'),
#  ('Staten Island', 'NY'),
#  ('Boerne', 'TX'),
#  ('District Heights', 'MD'),
#  ('Bolton', 'VT'),
#  ('Hanover', 'CO'),
#  ('Inyokern', 'CA'),
#  ('Carson City', 'NV'),
#  ('Kerrville', 'TX'),
#  ('Bloomfield Township', 'MI'),
#  ('Hunters', 'WA'),
#  ('Canton', 'OH'),
#  ('Beverly', 'MA'),
#  ('Tuscaloosa', 'AL'),
#  ('Grapeview', 'WA'),
#  ('North East', 'MD'),
#  ('Cohasset', 'MN'),
#  ('Troy', 'MI'),
#  ('King George', 'VA'),
#  ('Arab', 'AL'),
#  ('Brick Township', 'NJ'),
#  ('Archdale', 'NC'),
#  ('Santa Fe', 'NM'),
#  ('West Chester', 'PA'),
#  ('Thonotosassa', 'FL'),
#  ('Hendersonville', 'NC'),
#  ('West Jordan', 'UT'),
#  ('Spanish Fork', 'UT'),
#  ('Mount Vernon', 'NY'),
#  ('Cushing', 'OK'),
#  ('Loveland', 'CO'),
#  ('Bluefield', 'WV'),
#  ('Twinsburg', 'OH'),
#  ('Artesia', 'CA'),
#  ('Prescott', 'AZ'),
#  ('Mitchell', 'SD'),
#  ('French Lick', 'IN'),
#  ('Weitchpec', 'CA'),
#  ('Springtown', 'TX'),
#  ('Merrimack', 'NH'),
#  ('Durham', 'NC'),
#  ('Virginia Beach', 'VA'),
#  ('Little Havana', 'FL'),
#  ('Fairbanks', 'AK'),
#  ('Ashwaubenon', 'WI'),
#  ('El Monte', 'CA'),
#  ('Potsdam', 'NY'),
#  ('Lodi', 'CA'),
#  ('Downey', 'CA'),
#  ('Chester', 'SC'),
#  ('Broomfield', 'CO'),
#  ('Sylacauga', 'AL'),
#  ('West Knox', 'TN'),
#  ('Wellman', 'IA'),
#  ('McAlester', 'OK'),
#  ('Clute', 'TX'),
#  ('Princeton', 'NJ'),
#  ('Barstow', 'CA'),
#  ('Chalmette', 'LA'),
#  ('Panorama City', 'CA'),
#  ('Alexandria', 'VA'),
#  ('Lead', 'SD'),
#  ('Brodhead', 'KY'),
#  ('Dickson', 'TN'),
#  ('Slidell', 'LA'),
#  ('Washington County', 'AL'),
#  ('Harrisonburg', 'VA'),
#  ('Shelbyville', 'TX'),
#  ('Sand City', 'CA'),
#  ('Paris', 'TX'),
#  ('Barberville', 'FL'),
#  ('Auburndale', 'FL'),
#  ('Niceville', 'FL'),
#  ('Happy Valley', 'CA'),
#  ('McKinney', 'TX'),
#  ('Reisterstown', 'MD'),
#  ('Grayson County', 'VA'),
#  ('Fountain', 'CO'),
#  ('Akron', 'OH'),
#  ('Wilhoit', 'AZ'),
#  ('Lovington', 'NM'),
#  ('Rossville', 'GA'),
#  ('Ponder', 'TX'),
#  ('San Ysidro', 'CA'),
#  ('Rapid City', 'SD'),
#  ('Mora', 'MN'),
#  ('Beckley', 'WV'),
#  ('Sierra Vista', 'AZ'),
#  ('Rialto', 'CA'),
#  ('Amarillo', 'TX'),
#  ('Van Nuys', 'CA'),
#  ('Muscle Shoals', 'AL'),
#  ('Hurst', 'IL'),
#  ('Woodbridge', 'VA'),
#  ('Midwest City', 'OK'),
#  ('Monterey', 'CA'),
#  ('West Palm Beach', 'FL'),
#  ('Aguanga', 'CA'),
#  ('Old Saybrook', 'CT'),
#  ('Pinion Hills', 'CA'),
#  ('Cato Township', 'MI'),
#  ('Lisle', 'IL'),
#  ('Lakes Charles', 'LA'),
#  ('Taylors', 'SC'),
#  ('West Odessa', 'TX'),
#  ('Lawton', 'OK'),
#  ('Brookhaven', 'MS'),
#  ('Cartersville', 'GA'),
#  ('Naples', 'ME'),
#  ('Indio', 'CA'),
#  ('Seaside', 'OR'),
#  ('Monroeville', 'AL'),
#  ('Parma', 'OH'),
#  ('Kirkland', 'WA'),
#  ('Valinda', 'CA'),
#  ('Barrow County', 'GA'),
#  ('Modesto', 'CA'),
#  ('York', 'WI'),
#  ('Palm Beach Gardens', 'FL'),
#  ('Truth or Consequences', 'NM'),
#  ('Mandeville', 'LA'),
#  ('Cedar Rapids', 'IA'),
#  ('Calexico', 'CA'),
#  ('West Goshen', 'CA'),
#  ('Kentwood', 'MI'),
#  ('Carmichael', 'CA'),
#  ('Pine Top', 'KY'),
#  ('New Paltz', 'NY'),
#  ('Highgrove', 'CA'),
#  ('Cape Coral', 'FL'),
#  ('Cathedral City', 'CA'),
#  ('Zanesville', 'OH'),
#  ('Paddock Lake', 'WI'),
#  ('Kenai Peninsula', 'AK'),
#  ('Talking Rock', 'GA'),
#  ('Frederick', 'MD'),
#  ('Tampa', 'FL'),
#  ('Savannah', 'GA'),
#  ('Point Loma', 'CA'),
#  ('Smithville', 'MS'),
#  ('Salem', 'OR'),
#  ('Hohenwald', 'TN'),
#  ('Old Town', 'ME'),
#  ('Burkesville', 'KY'),
#  ('Mesquite', 'TX'),
#  ('Norwood', 'OK'),
#  ('Colorado Springs', 'CO'),
#  ('Opelika', 'AL'),
#  ('Eureka', 'CA'),
#  ('Council', 'ID'),
#  ('Marksville', 'LA'),
#  ('Merced', 'CA'),
#  ('Pacific Beach', 'CA'),
#  ('Hominy', 'OK'),
#  ('Lakeshire', 'MO'),
#  ('Goose Creek', 'SC'),
#  ('Wadesboro', 'NC'),
#  ('North Laredo', 'TX'),
#  ('Braxton County', 'WV'),
#  ('Chico', 'CA'),
#  ('Brighton', 'CO'),
#  ('Dillon', 'MT'),
#  ('Aiken', 'SC'),
#  ('Gibson County', 'TN'),
#  ('Jurupa Valley', 'CA'),
#  ('Eden', 'GA'),
#  ('Spring Lake', 'NC'),
#  ('Germantown', 'PA'),
#  ('Minneapolis', 'MN'),
#  ('Leon County', 'TX'),
#  ('Whitfield County', 'GA'),
#  ('Cayce', 'SC'),
#  ('Little Egg Harbor', 'NJ'),
#  ('Opa-Locka', 'FL'),
#  ('Benton Township', 'MI'),
#  ('Manatee', 'FL'),
#  ('Paulding County', 'GA'),
#  ('Colbert', 'OK'),
#  ('Reno', 'NV'),
#  ('Corpus Christi', 'TX'),
#  ('Columbia Heights', 'MN'),
#  ('Ozark', 'AR'),
#  ('Lampe', 'MO'),
#  ('Seagoville', 'TX'),
#  ('Celina', 'OH'),
#  ('Maysville', 'MO'),
#  ('Wink', 'TX'),
#  ('Bangor', 'ME'),
#  ('Norwalk', 'CA'),
#  ('Deming', 'NM'),
#  ('Big Springs', 'NE'),
#  ('Mount Washington', 'PA'),
#  ('Irving', 'TX'),
#  ('Neenah', 'WI'),
#  ('Richmond Heights', 'OH'),
#  ('Laramie', 'WY'),
#  ('Yonkers', 'NY'),
#  ('Leitchfield', 'KY'),
#  ('Pryor', 'OK'),
#  ('Marina', 'CA'),
#  ('Lynwood', 'CA'),
#  ('Healdton', 'OK'),
#  ('East Stroudsburg', 'PA'),
#  ('Denton', 'TX'),
#  ('Thurston County', 'WA'),
#  ('Mountain View', 'CO'),
#  ('Middle River', 'MD'),
#  ('Humboldt', 'TN'),
#  ('Gilroy', 'CA'),
#  ('Mount Hope', 'WI'),
#  ('Camarillo', 'CA'),
#  ('Kent', 'WA'),
#  ('Northwood', 'OH'),
#  ('Taos', 'NM'),
#  ('Concord', 'CA'),
#  ('Palmdale', 'CA'),
#  ('Douglasville', 'GA'),
#  ('Breaux Bridge', 'LA'),
#  ('Canaan Township', 'PA'),
#  ('Smartsville', 'CA'),
#  ('Ludlow', 'KY'),
#  ('Brooksville', 'FL'),
#  ('Dearborn', 'MI'),
#  ('Winnsboro', 'LA'),
#  ('Pride', 'LA'),
#  ('Lansing', 'IL'),
#  ('Porterville', 'CA'),
#  ('Palo Alto', 'CA'),
#  ('Homedale', 'ID'),
#  ('Lucedale', 'MS'),
#  ('Suffolk', 'VA'),
#  ('Santa Nella', 'CA'),
#  ('Rosemead', 'CA'),
#  ('Rawlins', 'WY'),
#  ('Livingston', 'TN'),
#  ('Maryneal', 'TX'),
#  ('Sioux Falls', 'SD'),
#  ('Ragley', 'LA'),
#  ('Olympia', 'WA'),
#  ('Johnson City', 'TN'),
#  ('Redding', 'CA'),
#  ('Ceres', 'CA'),
#  ('Upper Darby', 'PA'),
#  ('Carrizozo', 'NM'),
#  ('Daviess County', 'KY'),
#  ('Geneva', 'WI'),
#  ('Acworth', 'GA'),
#  ('Kelso', 'WA'),
#  ('Rising Sun', 'MD'),
#  ('San Fernando', 'CA'),
#  ('Penn Township', 'PA'),
#  ('Spenard', 'AK'),
#  ('Norfolk', 'VA'),
#  ('Sevierville', 'TN'),
#  ('Cle Elum', 'WA'),
#  ('Santa Clarita', 'CA'),
#  ('Elkins', 'WV'),
#  ('Southfield', 'MI'),
#  ('Hollywood Hills', 'CA'),
#  ('El Cajon', 'CA'),
#  ('Petroleum', 'WV'),
#  ('Belle Glade', 'FL'),
#  ('North Hills', 'CA'),
#  ('Rainbow City', 'AL'),
#  ('Union City', 'GA'),
#  ('Statesville', 'NC'),
#  ('Port Barre', 'LA'),
#  ('Meridianville', 'AL'),
#  ('Eufaula', 'AL'),
#  ('Burns', 'OR'),
#  ('Mountain Pine', 'AR'),
#  ('Latta', 'SC'),
#  ('Lenoir City', 'TN'),
#  ('Cobb County', 'GA'),
#  ('Clackamas County', 'OR'),
#  ('Phenix City', 'AL'),
#  ('Wilkinsburg', 'PA'),
#  ('Immokalee', 'FL'),
#  ('Saginaw', 'MI'),
#  ('Newark', 'NJ'),
#  ('Rancho Cordova', 'CA'),
#  ('Schulter', 'OK'),
#  ('Ocala', 'FL'),
#  ('Rosebud', 'SD'),
#  ('Perry Township', 'OH'),
#  ('Hilo', 'HI'),
#  ('Milton', 'FL'),
#  ('Union Grove', 'NC'),
#  ('Manchester', 'NH'),
#  ('Abingdon', 'VA'),
#  ('Barrow', 'AK'),
#  ('Roseville', 'CA'),
#  ('Henderson County', 'TX'),
#  ('Maiden', 'NC'),
#  ('Urbandale', 'IA'),
#  ('Beckville', 'TX'),
#  ('Arvonia', 'VA'),
#  ('Bradenton', 'FL'),
#  ('Jal', 'NM'),
#  ('Yorba Linda', 'CA'),
#  ('Republic', 'MO'),
#  ('Mena', 'AR'),
#  ('Commerce', 'GA'),
#  ('Ogden', 'UT'),
#  ('Elizabethton', 'TN'),
#  ('Inglewood', 'CA'),
#  ('Fairborn', 'OH'),
#  ('Ripon', 'CA'),
#  ('Blue Springs', 'MO'),
#  ('Bailey', 'NC'),
#  ('East Troy', 'WI'),
#  ('Montgomery', 'NY'),
#  ('Silver Springs', 'NV'),
#  ('Hesston', 'KS'),
#  ('Roanoke', 'VA'),
#  ('Rapid Valley', 'SD'),
#  ('Ashville', 'AL'),
#  ('Raleigh', 'NC'),
#  ('Gautier', 'MS'),
#  ('Bel Air', 'MD'),
#  ('Johnstown', 'PA'),
#  ('Sims', 'AR'),
#  ('East Bernstadt', 'KY'),
#  ('Cheektowaga', 'NY'),
#  ('Beaumont', 'CA'),
#  ('Bismarck', 'ND'),
#  ('Rochester', 'NY'),
#  ('Carlsbad', 'NM'),
#  ('Biloxi', 'MS'),
#  ('Colorado City', 'CO'),
#  ('Rosalia', 'KS'),
#  ('Clinton', 'TN'),
#  ('Greensboro', 'NC'),
#  ('Addison', 'TX'),
#  ('Piedmont', 'AL'),
#  ('Vancouver', 'WA'),
#  ('Russellville', 'AR'),
#  ('Evansville', 'IN'),
#  ('Florence', 'MS'),
#  ('Anson County', 'NC'),
#  ('Burnsville', 'NC'),
#  ('Byron', 'CA'),
#  ('Idaho Falls', 'ID'),
#  ('White Plains', 'KY'),
#  ('Hopewell', 'VA'),
#  ('Fort Littleton', 'PA'),
#  ('Gainesville', 'GA'),
#  ('Stamford', 'CT'),
#  ('South Greensburg', 'PA'),
#  ('Fredericksburg', 'VA'),
#  ('Thornton', 'CO'),
#  ('Braintree', 'MA'),
#  ('Pawtucket', 'RI'),
#  ('Redlands', 'CA'),
#  ('Pueblo of Laguna', 'NM'),
#  ('Lowell', 'AR'),
#  ('Grundy', 'VA'),
#  ("Lee's Summit", 'MO'),
#  ('Kinston', 'NC'),
#  ('Splendora', 'TX'),
#  ('Clearlake Park', 'CA'),
#  ('Aitkin', 'MN'),
#  ('Jackson', 'MI'),
#  ('Lockhart', 'TX'),
#  ('Raceland', 'LA'),
#  ('Macon County', 'AL'),
#  ('Eau Claire', 'WI'),
#  ('West Springfield', 'MA'),
#  ('Oak Hill', 'OH'),
#  ('Gallatin', 'TN'),
#  ('Lake Hallie', 'WI'),
#  ('New Brunswick', 'NJ'),
#  ('Rotterdam', 'NY'),
#  ('Benton', 'AR'),
#  ('Noma', 'FL'),
#  ('Llano', 'TX'),
#  ('Sparta', 'NC'),
#  ('McPherson', 'KS'),
#  ('Lake Elsinore', 'CA'),
#  ('Cache', 'OK'),
#  ('Vineland', 'NJ'),
#  ('Greenbelt', 'MD'),
#  ('Mableton', 'GA'),
#  ('Perryville', 'AR'),
#  ('Everett', 'WA'),
#  ('Berne', 'NY'),
#  ('Antigo', 'WI'),
#  ('Fayetteville', 'NC'),
#  ('East Flat Rock', 'NC'),
#  ('Kingsbury', 'TX'),
#  ('Milcreek', 'UT'),
#  ('Westminster', 'CA'),
#  ('Wausau', 'WI'),
#  ('Alamo', 'TN'),
#  ('Burien', 'WA'),
#  ('Temecula', 'CA'),
#  ('Buffalo', 'NY'),
#  ('Gretna', 'LA'),
#  ('Weirton', 'WV'),
#  ('Lake Stevens', 'WA'),
#  ('Presque Isle', 'ME'),
#  ('St. Martin', 'MS'),
#  ('Hog Valley', 'FL'),
#  ('Nacogdoches', 'TX'),
#  ('Taunton', 'MA'),
#  ('Byng', 'OK'),
#  ('Boyle Heights', 'CA'),
#  ('Jacksonsville', 'FL'),
#  ('Osteen', 'FL'),
#  ('Stockbridge', 'GA'),
#  ('Shawnee National Forest', 'IL'),
#  ('Riverdale', 'GA'),
#  ('Siskiyou County', 'CA'),
#  ('Sullivan', 'IN'),
#  ('Fisty', 'KY'),
#  ('Chesterfield County', 'SC'),
#  ('Oregon City', 'OR'),
#  ('Flagstaff', 'AZ'),
#  ('Hallandale Beach', 'FL'),
#  ('Oxford', 'AL'),
#  ('Gresham', 'OR'),
#  ('Harrisonville', 'MO'),
#  ('Washington Park', 'IL'),
#  ('Solvang', 'CA'),
#  ('Sneads', 'FL'),
#  ('Socorro', 'NM'),
#  ('Eastaboga', 'AL'),
#  ('Deland', 'FL'),
#  ('Stoneville', 'NC'),
#  ('Tualatin', 'OR'),
#  ('Bend', 'OR'),
#  ('Newnan', 'GA'),
#  ('Berea', 'KY'),
#  ('Wasilla', 'AK'),
#  ('Parker', 'CO'),
#  ('Yreka', 'CA'),
#  ('Wagoner', 'OK'),
#  ('Turlock', 'CA'),
#  ('Norman', 'OK'),
#  ('Port Arthur', 'TX'),
#  ('Ishpeming Township', 'MI'),
#  ('Somerton', 'AZ'),
#  ('Iredell County', 'NC'),
#  ('Yakima', 'WA'),
#  ('Tupelo', 'MS'),
#  ('Maywood', 'CA'),
#  ('Eagle Mountain', 'UT'),
#  ('Hiseville', 'KY'),
#  ('Schenectady', 'NY'),
#  ('Mobile', 'AL'),
#  ('Tiverton', 'RI'),
#  ('Chula Vista', 'CA'),
#  ('Pembine', 'WI'),
#  ('Butte', 'MT'),
#  ('Montpelier', 'VT'),
#  ('Fort Walton Beach', 'FL'),
#  ('Hardeeville', 'SC'),
#  ('Lake Havasu City', 'AZ'),
#  ('Peterborough', 'NH'),
#  ('Lawndale', 'IL'),
#  ('Wellington', 'UT'),
#  ('Walls', 'MS'),
#  ('Bellville', 'TX'),
#  ('Belleville', 'IL'),
#  ('Paterson', 'NJ'),
#  ('Farmington', 'NM'),
#  ('Fulshear', 'TX'),
#  ('Riverview', 'FL'),
#  ('Pinellas Park', 'FL'),
#  ('Buckeye', 'AZ'),
#  ('Columbia Township', 'MI'),
#  ('Thomaston', 'CT'),
#  ('Dolton', 'IL'),
#  ('Boone', 'IA'),
#  ('Cochran', 'GA'),
#  ('Laguna Pueblo', 'NM'),
#  ('Frederica', 'DE'),
#  ('Barbourville', 'KY'),
#  ('Ouachita Parish', 'LA'),
#  ('Fort Madison', 'IA'),
#  ('Park County', 'CO'),
#  ('Landrum', 'SC'),
#  ('Asheville', 'NC'),
#  ('Bristol', 'TN'),
#  ('New Iberia', 'LA'),
#  ('Fullerton', 'CA'),
#  ('Rosser', 'TX'),
#  ('Yuma', 'AZ'),
#  ('Falcon Heights', 'MN'),
#  ('Rush Springs', 'OK'),
#  ('Bell', 'CA'),
#  ('Clovis', 'NM'),
#  ('Selma', 'CA'),
#  ('Broken Bow', 'OK'),
#  ('East St. Louis', 'IL'),
#  ('Romulus', 'MI'),
#  ('St. Joseph', 'MO'),
#  ('Middletown', 'DE'),
#  ('Peachland', 'NC'),
#  ('Lake Asbury', 'FL'),
#  ('Little Egg Harbor Township', 'NJ'),
#  ('Sheboygan', 'WI'),
#  ('Buckhannon', 'WV'),
#  ('Gallup', 'NM'),
#  ('Pine River', 'WI'),
#  ('Estill Springs', 'TN'),
#  ('Metairie', 'LA'),
#  ('Malta', 'MT'),
#  ('Sparks', 'NV'),
#  ('La Quinta', 'CA'),
#  ('Compton', 'CA'),
#  ('City Terrace', 'CA'),
#  ('Pleasant Hill', 'NC'),
#  ('Phelps', 'KY'),
#  ('Wapato', 'WA'),
#  ('Edmund', 'SC'),
#  ('Stafford', 'VA'),
#  ('Lake City', 'SC'),
#  ('Hammett', 'ID'),
#  ('Castaic', 'CA'),
#  ('Clearfield', 'UT'),
#  ('Scott County', 'KY'),
#  ('Aldie', 'VA'),
#  ('East Point', 'GA'),
#  ('Santee', 'CA'),
#  ('Beaver Dam', 'WI'),
#  ('Harrisburg', 'PA'),
#  ('Little Mountain', 'SC'),
#  ('Wilkesboro', 'NC'),
#  ('Georgetown', 'KY'),
#  ('Circleville', 'OH'),
#  ('Plaquemine', 'LA'),
#  ('Tukwila', 'WA'),
#  ('Vista', 'CA'),
#  ('Hayward', 'CA'),
#  ('Falls Church', 'VA'),
#  ('Counce', 'TN'),
#  ('Rome', 'OH'),
#  ...]

# %%
list(city_state_dic.items())[5]
# Out:
# ('Guthrie', 'OK')

# %%
'prepping to add states'
dic_cs_lst=list(city_state_dic.items())
dic_lst=list(dict_x.items())
dic_lst[0][1]
# Out:
# [71]

# %%
'adding states'
def add_state_to_dictionary(lst_of_dic):
    for i in range(len(lst_of_dic)):
        for x in range(len(dic_cs_lst)):
            if lst_of_dic[i][0] is dic_cs_lst[x][0]:
                lst_of_dic[i][1].append(dic_cs_lst[x][1])
    return lst_of_dic
city_kills_state=add_state_to_dictionary(dic_lst)
city_kills_state[598][0]
# Out:
# 'Floral City'

# %%
len(x)
# Out:
# 2211

# %%
'prepping pop->per capita'
city_kills_state_list=list(city_kills_state)
city_pop_dic={}
for i in range(len(city_population)):
    city_pop_dic[city_population['City'][i]]=[city_population['Population'][i],city_population['Geographic Area'][i]]
print(len(city_pop_dic))
city_pop_dic_lst=list(city_pop_dic.items())
city_pop_dic_lst
# Out:
# 24473
# [('Abanda CDP', ['192', 'AL']),
#  ('Abbeville city', ['5237', 'SC']),
#  ('Adamsville city', ['4522', 'AL']),
#  ('Addison town', ['13056', 'TX']),
#  ('Akron town', ['1167', 'IN']),
#  ('Alabaster city', ['30352', 'AL']),
#  ('Albertville city', ['7044', 'MN']),
#  ('Alexander City city', ['14875', 'AL']),
#  ('Alexandria CDP', ['3917', 'AL']),
#  ('Aliceville city', ['2486', 'AL']),
#  ('Allgood town', ['622', 'AL']),
#  ('Altoona town', ['933', 'AL']),
#  ('Andalusia city', ['9015', 'AL']),
#  ('Anderson town', ['282', 'AL']),
#  ('Anniston city', ['23106', 'AL']),
#  ('Arab city', ['8050', 'AL']),
#  ('Ardmore town', ['1194', 'AL']),
#  ('Argo town', ['4071', 'AL']),
#  ('Ariton town', ['764', 'AL']),
#  ('Arley town', ['357', 'AL']),
#  ('Ashford town', ['2148', 'AL']),
#  ('Ashland town', ['7225', 'VA']),
#  ('Ashville city', ['2212', 'AL']),
#  ('Athens city', ['12710', 'TX']),
#  ('Atmore city', ['10194', 'AL']),
#  ('Attalla city', ['6048', 'AL']),
#  ('Auburn city', ['70180', 'WA']),
#  ('Autaugaville town', ['870', 'AL']),
#  ('Avon town', ['12446', 'IN']),
#  ('Axis CDP', ['757', 'AL']),
#  ('Babbie town', ['603', 'AL']),
#  ('Baileyton town', ['431', 'TN']),
#  ('Bakerhill town', ['279', 'AL']),
#  ('Ballplay CDP', ['1580', 'AL']),
#  ('Banks town', ['124', 'AR']),
#  ('Bay Minette city', ['8044', 'AL']),
#  ('Bayou La Batre city', ['2558', 'AL']),
#  ('Bear Creek town', ['1070', 'AL']),
#  ('Beatrice town', ['301', 'AL']),
#  ('Beaverton town', ['201', 'AL']),
#  ('Belgreen CDP', ['129', 'AL']),
#  ('Belk town', ['215', 'AL']),
#  ('Bellamy CDP', ['543', 'AL']),
#  ('Belle Fontaine CDP', ['608', 'AL']),
#  ('Benton town', ['1385', 'TN']),
#  ('Berry town', ['1148', 'AL']),
#  ('Bessemer city', ['1905', 'MI']),
#  ('Billingsley town', ['144', 'AL']),
#  ('Birmingham city', ['20103', 'MI']),
#  ('Black town', ['207', 'AL']),
#  ('Blountsville town', ['134', 'IN']),
#  ('Blue Ridge CDP', ['3084', 'VA']),
#  ('Blue Springs town', ['96', 'AL']),
#  ('Boaz city', ['9551', 'AL']),
#  ('Boligee town', ['328', 'AL']),
#  ('Bon Air town', ['116', 'AL']),
#  ('Boykin CDP', ['100', 'SC']),
#  ('Brantley town', ['809', 'AL']),
#  ('Brantleyville CDP', ['884', 'AL']),
#  ('Brent city', ['4947', 'AL']),
#  ('Brewton city', ['5408', 'AL']),
#  ('Bridgeport city', ['8149', 'WV']),
#  ('Brighton city', ['7444', 'MI']),
#  ('Brilliant town', ['900', 'AL']),
#  ('Bristow Cove CDP', ['683', 'AL']),
#  ('Brook Highland CDP', ['6746', 'AL']),
#  ('Brookside town', ['233', 'CO']),
#  ('Brookwood town', ['1828', 'AL']),
#  ('Broomtown CDP', ['182', 'AL']),
#  ('Brundidge city', ['2076', 'AL']),
#  ('Bucks CDP', ['32', 'AL']),
#  ('Butler town', ['17', 'SD']),
#  ('Calera city', ['11620', 'AL']),
#  ('Calvert CDP', ['277', 'AL']),
#  ('Camden city', ['3582', 'TN']),
#  ('Camp Hill town', ['1014', 'AL']),
#  ('Carbon Hill city', ['2021', 'AL']),
#  ('Cardiff town', ['55', 'AL']),
#  ('Carlisle-Rockledge CDP', ['2137', 'AL']),
#  ('Carlton CDP', ['694', 'MT']),
#  ('Carolina town', ['297', 'AL']),
#  ('Carrollton town', ['190', 'MS']),
#  ('Castleberry town', ['583', 'AL']),
#  ('Catherine CDP', ['228', 'CO']),
#  ('Cedar Bluff town', ['1137', 'VA']),
#  ('Center Point city', ['2421', 'IA']),
#  ('Centre city', ['3489', 'AL']),
#  ('Centreville city', ['5309', 'IL']),
#  ('Chatom town', ['1288', 'AL']),
#  ('Chelsea city', ['4944', 'MI']),
#  ('Cherokee town', ['1048', 'AL']),
#  ('Chickasaw city', ['6106', 'AL']),
#  ('Childersburg city', ['5175', 'AL']),
#  ('Choccolocco CDP', ['2804', 'AL']),
#  ('Chunchula CDP', ['210', 'AL']),
#  ('Citronelle city', ['3905', 'AL']),
#  ('Clanton city', ['8619', 'AL']),
#  ('Clay city', ['1181', 'KY']),
#  ('Clayhatchee town', ['589', 'AL']),
#  ('Clayton town', ['821', 'OK']),
#  ('Cleveland town', ['202', 'VA']),
#  ('Clio city', ['2646', 'MI']),
#  ('Coaling town', ['1657', 'AL']),
#  ('Coats Bend CDP', ['1394', 'AL']),
#  ('Coffee Springs town', ['228', 'AL']),
#  ('Coffeeville town', ['905', 'MS']),
#  ('Coker town', ['979', 'AL']),
#  ('Collinsville town', ['1624', 'TX']),
#  ('Colony town', ['136', 'OK']),
#  ('Columbia town', ['83', 'VA']),
#  ('Columbiana city', ['6384', 'OH']),
#  ('Concord CDP', ['1458', 'VA']),
#  ('Coosada town', ['1224', 'AL']),
#  ('Cordova city', ['2239', 'AK']),
#  ('Cottonwood town', ['9', 'SD']),
#  ('County Line town', ['258', 'AL']),
#  ('Courtland town', ['1284', 'VA']),
#  ('Cowarts town', ['1871', 'AL']),
#  ('Creola city', ['1926', 'AL']),
#  ('Crossville town', ['1862', 'AL']),
#  ('Cuba town', ['346', 'AL']),
#  ('Cullman city', ['14775', 'AL']),
#  ('Cullomburg CDP', ['171', 'AL']),
#  ('Cusseta town', ['123', 'AL']),
#  ('Dadeville city', ['3230', 'AL']),
#  ('Daleville city', ['5295', 'AL']),
#  ('Daphne city', ['21570', 'AL']),
#  ('Dauphin Island town', ['1238', 'AL']),
#  ('Daviston town', ['214', 'AL']),
#  ('Dayton town', ['757', 'WY']),
#  ('Deatsville town', ['1154', 'AL']),
#  ('Decatur city', ['6042', 'TX']),
#  ('Deer Park CDP', ['27745', 'NY']),
#  ('Delta CDP', ['197', 'AL']),
#  ('Demopolis city', ['7483', 'AL']),
#  ('Detroit town', ['732', 'TX']),
#  ('Dodge City town', ['593', 'AL']),
#  ('Dora city', ['2025', 'AL']),
#  ('Dothan city', ['65496', 'AL']),
#  ('Double Springs town', ['1083', 'AL']),
#  ('Douglas town', ['32', 'OK']),
#  ('Dozier town', ['329', 'AL']),
#  ('Dunnavant CDP', ['981', 'AL']),
#  ('Dutton town', ['316', 'MT']),
#  ('East Brewton city', ['2478', 'AL']),
#  ('East Point CDP', ['201', 'AL']),
#  ('Eclectic town', ['1001', 'AL']),
#  ('Edgewater CDP', ['9023', 'MD']),
#  ('Edwardsville town', ['202', 'AL']),
#  ('Egypt CDP', ['2391', 'PA']),
#  ('Elba city', ['152', 'MN']),
#  ('Elberta town', ['1498', 'AL']),
#  ('Eldridge town', ['130', 'AL']),
#  ('Elkmont town', ['434', 'AL']),
#  ('Elmore town', ['1262', 'AL']),
#  ('Emelle town', ['53', 'AL']),
#  ('Emerald Mountain CDP', ['2561', 'AL']),
#  ('Enterprise city', ['1711', 'UT']),
#  ('Epes town', ['192', 'AL']),
#  ('Ethelsville town', ['81', 'AL']),
#  ('Eufaula city', ['2813', 'OK']),
#  ('Eunola CDP', ['243', 'AL']),
#  ('Eutaw town', ['2934', 'AL']),
#  ('Eva town', ['519', 'AL']),
#  ('Evergreen city', ['3944', 'AL']),
#  ('Excel town', ['723', 'AL']),
#  ('Fairfield city', ['2951', 'TX']),
#  ('Fairford CDP', ['186', 'AL']),
#  ('Fairhope city', ['15326', 'AL']),
#  ('Fairview town', ['408', 'WV']),
#  ('Falkville town', ['1279', 'AL']),
#  ('Faunsdale town', ['98', 'AL']),
#  ('Fayette city', ['2688', 'MO']),
#  ('Fayetteville CDP', ['3128', 'PA']),
#  ('Fitzpatrick CDP', ['83', 'AL']),
#  ('Five Points town', ['141', 'AL']),
#  ('Flomaton town', ['1440', 'AL']),
#  ('Florala town', ['1980', 'AL']),
#  ('Florence city', ['1136', 'TX']),
#  ('Foley city', ['161', 'MO']),
#  ('Forestdale CDP', ['4099', 'MA']),
#  ('Forkland town', ['649', 'AL']),
#  ('Fort Deposit town', ['1344', 'AL']),
#  ('Fort Payne city', ['14012', 'AL']),
#  ('Fort Rucker CDP', ['4636', 'AL']),
#  ('Franklin town', ['721', 'WV']),
#  ('Fredonia CDP', ['199', 'AL']),
#  ('Frisco City town', ['1309', 'AL']),
#  ('Fruitdale CDP', ['1177', 'OR']),
#  ('Fruithurst town', ['284', 'AL']),
#  ('Fulton town', ['1358', 'TX']),
#  ('Fultondale city', ['8380', 'AL']),
#  ('Fyffe town', ['1018', 'AL']),
#  ('Gadsden city', ['36856', 'AL']),
#  ('Gainesville town', ['208', 'AL']),
#  ('Gallant CDP', ['855', 'AL']),
#  ('Gantt town', ['222', 'AL']),
#  ('Garden City town', ['562', 'UT']),
#  ('Gardendale city', ['13893', 'AL']),
#  ('Gaylesville town', ['144', 'AL']),
#  ('Geiger town', ['170', 'AL']),
#  ('Geneva city', ['6215', 'OH']),
#  ('Georgiana town', ['1738', 'AL']),
#  ('Geraldine town', ['261', 'MT']),
#  ('Gilbertown town', ['215', 'AL']),
#  ('Glen Allen town', ['85', 'MO']),
#  ('Glencoe city', ['5631', 'MN']),
#  ('Glenwood town', ['464', 'UT']),
#  ('Goldville town', ['55', 'AL']),
#  ('Good Hope town', ['2264', 'AL']),
#  ('Goodwater town', ['1475', 'AL']),
#  ('Gordo town', ['1750', 'AL']),
#  ('Gordon town', ['332', 'AL']),
#  ('Gordonville town', ['326', 'AL']),
#  ('Goshen town', ['361', 'VA']),
#  ('Graham CDP', ['23491', 'WA']),
#  ('Grand Bay CDP', ['3672', 'AL']),
#  ('Grant town', ['896', 'AL']),
#  ('Grayson Valley CDP', ['5736', 'AL']),
#  ('Graysville city', ['2165', 'AL']),
#  ('Greensboro city', ['269666', 'NC']),
#  ('Greenville city', ['25557', 'TX']),
#  ('Grimes town', ['558', 'AL']),
#  ('Grove Hill town', ['1570', 'AL']),
#  ('Guin city', ['2376', 'AL']),
#  ('Gulfcrest CDP', ['161', 'AL']),
#  ('Gulf Shores city', ['9741', 'AL']),
#  ('Guntersville city', ['8197', 'AL']),
#  ('Gurley town', ['801', 'AL']),
#  ('Gu-Win town', ['176', 'AL']),
#  ('Hackleburg town', ['1516', 'AL']),
#  ('Hackneyville CDP', ['347', 'AL']),
#  ('Haleburg town', ['103', 'AL']),
#  ('Haleyville city', ['4173', 'AL']),
#  ('Hamilton city', ['3095', 'TX']),
#  ('Hammondville town', ['488', 'AL']),
#  ('Hanceville city', ['2982(r38813)', 'AL']),
#  ('Harpersville town', ['1637', 'AL']),
#  ('Hartford city', ['14223', 'WI']),
#  ('Hartselle city', ['14255', 'AL']),
#  ('Harvest CDP', ['5281', 'AL']),
#  ('Hatton CDP', ['261', 'AL']),
#  ('Hayden town', ['1810', 'CO']),
#  ('Hayneville town', ['932', 'AL']),
#  ('Hazel Green CDP', ['228', 'KY']),
#  ('Headland city', ['4510', 'AL']),
#  ('Heath town', ['254', 'AL']),
#  ('Heflin city', ['3480', 'AL']),
#  ('Helena city', ['28190', 'MT']),
#  ('Henagar city', ['2344', 'AL']),
#  ('Highland Lake town', ['412', 'AL']),
#  ('Highland Lakes CDP', ['3926', 'AL']),
#  ('Hillsboro town', ['260', 'WV']),
#  ('Hissop CDP', ['658', 'AL']),
#  ('Hobson CDP', ['126', 'AL']),
#  ('Hobson City town', ['771', 'AL']),
#  ('Hodges town', ['155', 'SC']),
#  ('Hokes Bluff city', ['4286', 'AL']),
#  ('Hollins CDP', ['14673', 'VA']),
#  ('Hollis Crossroads CDP', ['608', 'AL']),
#  ('Holly Pond town', ['798', 'AL']),
#  ('Hollywood town', ['4714', 'SC']),
#  ('Holt CDP', ['23973', 'MI']),
#  ('Holtville CDP', ['4096', 'AL']),
#  ('Homewood city', ['25167', 'AL']),
#  ('Hoover city', ['81619', 'AL']),
#  ('Horn Hill town', ['228', 'AL']),
#  ('Hueytown city', ['16105', 'AL']),
#  ('Huguley CDP', ['2540', 'AL']),
#  ('Huntsville city', ['38548', 'TX']),
#  ('Hurtsboro town', ['553', 'AL']),
#  ('Hytop town', ['354', 'AL']),
#  ('Ider town', ['723', 'AL']),
#  ('Indian Springs Village city', ['2363', 'AL']),
#  ('Irondale city', ['445', 'MO']),
#  ('Ivalee CDP', ['879', 'AL']),
#  ('Jackson city', ['65211', 'TN']),
#  ("Jacksons' Gap town", ['828', 'AL']),
#  ('Jacksonville city', ['14544', 'TX']),
#  ('Jasper city', ['7590', 'TX']),
#  ('Jemison city', ['2585', 'AL']),
#  ('Joppa CDP', ['501', 'AL']),
#  ('Kansas town', ['802', 'OK']),
#  ('Kellyton town', ['217', 'AL']),
#  ('Kennedy town', ['447', 'AL']),
#  ('Killen town', ['1108', 'AL']),
#  ('Kimberly town', ['2711', 'AL']),
#  ('Kinsey town', ['2198', 'AL']),
#  ('Kinston town', ['540', 'AL']),
#  ('Ladonia CDP', ['3142', 'AL']),
#  ('La Fayette city', ['3003', 'AL']),
#  ('Lakeview town', ['107', 'TX']),
#  ('Lake View town', ['807', 'SC']),
#  ('Lanett city', ['6468', 'AL']),
#  ('Langston town', ['1724', 'OK']),
#  ('Leeds city', ['427', 'ND']),
#  ('Leesburg town', ['42616', 'VA']),
#  ('Leighton town', ['729', 'AL']),
#  ('Leroy CDP', ['911', 'AL']),
#  ('Lester town', ['348', 'WV']),
#  ('Level Plains town', ['2085', 'AL']),
#  ('Lexington town', ['1177', 'TX']),
#  ('Libertyville town', ['117', 'AL']),
#  ('Lincoln city', ['2406', 'ND']),
#  ('Linden city', ['1988', 'TX']),
#  ('Lineville city', ['217', 'IA']),
#  ('Lipscomb city', ['2210', 'AL']),
#  ('Lisman town', ['539', 'AL']),
#  ('Littleville town', ['1011', 'AL']),
#  ('Livingston city', ['7044', 'MT']),
#  ('Loachapoka town', ['180', 'AL']),
#  ('Lockhart town', ['488', 'SC']),
#  ('Locust Fork town', ['1186', 'AL']),
#  ('Lookout Mountain CDP', ['1621', 'AL']),
#  ('Louisville town', ['519', 'AL']),
#  ('Lowndesboro town', ['115', 'AL']),
#  ('Loxley town', ['1632', 'AL']),
#  ('Luverne city', ['31', 'ND']),
#  ('Lynn town', ['1097', 'IN']),
#  ('McDonald Chapel CDP', ['717', 'AL']),
#  ('Macedonia CDP', ['292', 'AL']),
#  ('McIntosh town', ['452', 'FL']),
#  ('McKenzie town', ['530', 'AL']),
#  ('McMullen town', ['10', 'AL']),
#  ('Madison city', ['233209', 'WI']),
#  ('Madrid town', ['350', 'AL']),
#  ('Magnolia Springs town', ['723', 'AL']),
#  ('Malcolm CDP', ['187', 'AL']),
#  ('Malvern town', ['1448', 'AL']),
#  ('Maplesville town', ['708', 'AL']),
#  ('Marbury CDP', ['1418', 'AL']),
#  ('Margaret town', ['4428', 'AL']),
#  ('Marion city', ['1260', 'WI']),
#  ('Maytown town', ['385', 'AL']),
#  ('Meadowbrook CDP', ['18312', 'VA']),
#  ('Megargel CDP', ['62', 'AL']),
#  ('Memphis town', ['29', 'AL']),
#  ('Mentone town', ['1001', 'IN']),
#  ('Meridianville CDP', ['6021', 'AL']),
#  ('Midfield city', ['5365', 'AL']),
#  ('Midland City town', ['2344', 'AL']),
#  ('Midway town', ['4679', 'NC']),
#  ('Mignon CDP', ['1284', 'AL']),
#  ('Millbrook city', ['14640', 'AL']),
#  ('Millerville CDP', ['278', 'AL']),
#  ('Millport town', ['1049', 'AL']),
#  ('Millry town', ['546', 'AL']),
#  ('Minor CDP', ['1094', 'AL']),
#  ('Mobile city', ['195111(r38814)', 'AL']),
#  ('Monroeville city', ['6519', 'AL']),
#  ('Montevallo city', ['6323', 'AL']),
#  ('Montgomery city', ['1638', 'WV']),
#  ('Moody city', ['1371', 'TX']),
#  ('Moores Mill CDP', ['5682', 'AL']),
#  ('Mooresville town', ['32711', 'NC']),
#  ('Morris town', ['1859', 'AL']),
#  ('Morrison Crossroads CDP', ['219', 'AL']),
#  ('Mosses town', ['1029', 'AL']),
#  ('Moulton city', ['605', 'IA']),
#  ('Moundville town', ['124', 'MO']),
#  ('Mountain Brook city', ['20413(r38815)', 'AL']),
#  ('Mount Olive CDP (Coosa County)', ['371', 'AL']),
#  ('Mount Olive CDP (Jefferson County)', ['4079', 'AL']),
#  ('Mount Vernon town', ['2662', 'TX']),
#  ('Movico CDP', ['305', 'AL']),
#  ('Mulga town', ['836', 'AL']),
#  ('Munford town', ['1292', 'AL']),
#  ('Muscle Shoals city', ['13146', 'AL']),
#  ('Myrtlewood town', ['130', 'AL']),
#  ('Nanafalia CDP', ['94', 'AL']),
#  ('Nances Creek CDP', ['407', 'AL']),
#  ('Napier Field town', ['354', 'AL']),
#  ('Natural Bridge town', ['37', 'AL']),
#  ('Nauvoo town', ['221', 'AL']),
#  ('Nectar town', ['345', 'AL']),
#  ('Needham town', ['94', 'AL']),
#  ('Newbern town', ['3313', 'TN']),
#  ('New Brockton town', ['1146', 'AL']),
#  ('New Hope city', ['1082', 'TN']),
#  ('New Market CDP', ['816', 'PA']),
#  ('New Site town', ['773', 'AL']),
#  ('Newton town', ['789', 'UT']),
#  ('New Union CDP', ['1431', 'TN']),
#  ('Newville town', ['539', 'AL']),
#  ('North Courtland town', ['632', 'AL']),
#  ('North Johns town', ['145', 'AL']),
#  ('Northport city', ['23330', 'AL']),
#  ('Notasulga town', ['965', 'AL']),
#  ('Oak Grove town', ['603', 'TX']),
#  ('Oak Hill town', ['26', 'AL']),
#  ('Oakman town', ['789', 'AL']),
#  ('Odenville town', ['3585', 'AL']),
#  ('Ohatchee town', ['1170', 'AL']),
#  ('Oneonta city', ['13901', 'NY']),
#  ('Onycha town', ['184', 'AL']),
#  ('Opelika city', ['26477(r38816)', 'AL']),
#  ('Opp city', ['6659', 'AL']),
#  ('Orange Beach city', ['5441', 'AL']),
#  ('Orrville town', ['204', 'AL']),
#  ('Our Town CDP', ['641', 'AL']),
#  ('Owens Cross Roads town', ['1521', 'AL']),
#  ('Oxford city', ['21371', 'OH']),
#  ('Ozark city', ['17820', 'MO']),
#  ('Paint Rock town', ['273', 'TX']),
#  ('Panola CDP', ['144', 'AL']),
#  ('Parrish town', ['982', 'AL']),
#  ('Pelham city', ['3898', 'GA']),
#  ('Pell City city', ['12695', 'AL']),
#  ('Pennington town', ['221', 'AL']),
#  ('Penton CDP', ['201', 'AL']),
#  ('Perdido Beach town', ['581', 'AL']),
#  ('Peterman CDP', ['89', 'AL']),
#  ('Petrey town', ['58', 'AL']),
#  ('Phenix City city', ['32822', 'AL']),
#  ('Phil Campbell town', ['1148', 'AL']),
#  ('Pickensville town', ['608', 'AL']),
#  ('Piedmont city', ['222(r48386)', 'SD']),
#  ('Pike Road town', ['5406', 'AL']),
#  ('Pinckard town', ['647', 'AL']),
#  ('Pine Apple town', ['132', 'AL']),
#  ('Pine Hill town', ['975', 'AL']),
#  ('Pine Level CDP', ['227', 'FL']),
#  ('Pine Ridge town', ['2064', 'SC']),
#  ('Pinson city', ['7163', 'AL']),
#  ('Pisgah town', ['722', 'AL']),
#  ('Pleasant Grove city', ['33509', 'UT']),
#  ('Pleasant Groves town', ['420', 'AL']),
#  ('Point Clear CDP', ['2125', 'AL']),
#  ('Pollard town', ['137', 'AL']),
#  ('Powell town', ['136', 'TX']),
#  ('Prattville city', ['33960', 'AL']),
#  ('Priceville town', ['2658', 'AL']),
#  ('Prichard city', ['22659', 'AL']),
#  ('Providence town', ['223', 'AL']),
#  ('Putnam CDP', ['7214', 'CT']),
#  ('Ragland town', ['1639', 'AL']),
#  ('Rainbow City city', ['9602', 'AL']),
#  ('Rainsville city', ['4948', 'AL']),
#  ('Ranburne town', ['409', 'AL']),
#  ('Ray CDP', ['443', 'AL']),
#  ('Red Bay city', ['3158', 'AL']),
#  ('Redland CDP', ['1047', 'TX']),
#  ('Red Level town', ['487', 'AL']),
#  ('Redstone Arsenal CDP', ['1946', 'AL']),
#  ('Reece City town', ['653', 'AL']),
#  ('Reeltown CDP', ['766', 'AL']),
#  ('Reform town', ['1702', 'AL']),
#  ('Rehobeth town', ['1297', 'AL']),
#  ('Repton town', ['282', 'AL']),
#  ('Ridgeville town', ['1979', 'SC']),
#  ('River Falls town', ['526', 'AL']),
#  ('Riverside town', ['52', 'WY']),
#  ('Riverview town', ['184', 'AL']),
#  ('Roanoke city', ['97032', 'VA']),
#  ('Robertsdale city', ['5276', 'AL']),
#  ('Rock Creek CDP', ['1456', 'AL']),
#  ('Rockford town', ['470', 'WA']),
#  ('Rock Mills CDP', ['600', 'AL']),
#  ('Rockville CDP', ['7474', 'CT']),
#  ('Rogersville town', ['4420', 'TN']),
#  ('Rosa town', ['316', 'AL']),
#  ('Russellville city', ['807', 'MO']),
#  ('Rutledge town', ['1122', 'TN']),
#  ('St. Florian town', ['413', 'AL']),
#  ('St. Stephens CDP', ['8759', 'NC']),
#  ('Saks CDP', ['10744', 'AL']),
#  ('Samson city', ['1940', 'AL']),
#  ('Sand Rock town', ['560', 'AL']),
#  ('Sanford town', ['164', 'TX']),
#  ('Saraland city', ['13405', 'AL']),
#  ('Sardis City town', ['1704', 'AL']),
#  ('Satsuma city', ['6168', 'AL']),
#  ('Scottsboro city', ['14770', 'AL']),
#  ('Section town', ['770', 'AL']),
#  ('Selma city', ['5540', 'TX']),
#  ('Selmont-West Selmont CDP', ['2671', 'AL']),
#  ('Sheffield city', ['1172', 'IA']),
#  ('Shelby CDP', ['539', 'IN']),
#  ('Shiloh town', ['274', 'AL']),
#  ('Shoal Creek CDP', ['1400', 'AL']),
#  ('Shorter town', ['474', 'AL']),
#  ('Silas town', ['452', 'AL']),
#  ('Silverhill town', ['706', 'AL']),
#  ('Sims Chapel CDP', ['153', 'AL']),
#  ('Sipsey town', ['437', 'AL']),
#  ('Skyline town', ['851', 'AL']),
#  ('Slocomb city', ['1980', 'AL']),
#  ('Smiths Station city', ['4926', 'AL']),
#  ('Smoke Rise CDP', ['1825', 'AL']),
#  ('Snead town', ['835', 'AL']),
#  ('Somerville town', ['3094', 'TN']),
#  ('Southside city', ['8412', 'AL']),
#  ('South Vinemont town', ['749', 'AL']),
#  ('Spanish Fort city', ['6798', 'AL']),
#  ('Spring Garden CDP', ['16', 'CA']),
#  ('Springville city', ['29466', 'UT']),
#  ('Spruce Pine CDP', ['222', 'AL']),
#  ('Standing Rock CDP', ['168', 'AL']),
#  ('Steele town', ['1043', 'AL']),
#  ('Sterrett CDP', ['712', 'AL']),
#  ('Stevenson city', ['1465', 'WA']),
#  ('Stewartville CDP', ['1767', 'AL']),
#  ('Sulligent city', ['1927', 'AL']),
#  ('Sumiton city', ['2520', 'AL']),
#  ('Summerdale town', ['862', 'AL']),
#  ('Susan Moore town', ['763', 'AL']),
#  ('Sweet Water town', ['258', 'AL']),
#  ('Sylacauga city', ['12749', 'AL']),
#  ('Sylvania town', ['1837', 'AL']),
#  ('Sylvan Springs town', ['1542', 'AL']),
#  ('Talladega city', ['15676(r38817)', 'AL']),
#  ('Talladega Springs town', ['166', 'AL']),
#  ('Tallassee city', ['4819', 'AL']),
#  ('Tarrant city', ['6397(r38818)', 'AL']),
#  ('Taylor town', ['4112', 'AZ']),
#  ('Theodore CDP', ['6130', 'AL']),
#  ('Thomaston town', ['417', 'AL']),
#  ('Thomasville city', ['26757', 'NC']),
#  ('Thorsby town', ['1980', 'AL']),
#  ('Tibbie CDP', ['41', 'AL']),
#  ('Tidmore Bend CDP', ['1245', 'AL']),
#  ('Tillmans Corner CDP', ['17398', 'AL']),
#  ('Town Creek town', ['1100', 'AL']),
#  ('Toxey town', ['137', 'AL']),
#  ('Trafford town', ['646', 'AL']),
#  ('Triana town', ['496', 'AL']),
#  ('Trinity town', ['2095', 'AL']),
#  ('Troy city', ['1645', 'TX']),
#  ('Trussville city', ['19933(r38819)', 'AL']),
#  ('Tuscaloosa city', ['90468', 'AL']),
#  ('Tuscumbia city', ['8423', 'AL']),
#  ('Tuskegee city', ['9865(r38820)', 'AL']),
#  ('Twin town', ['399', 'AL']),
#  ('Underwood-Petersville CDP', ['3247', 'AL']),
#  ('Union town', ['565', 'WV']),
#  ('Union Grove town', ['77', 'AL']),
#  ('Union Springs city', ['3980', 'AL']),
#  ('Uniontown town', ['294', 'WA']),
#  ('Uriah CDP', ['294', 'AL']),
#  ('Valley city', ['1875', 'NE']),
#  ('Valley Grande city', ['4020', 'AL']),
#  ('Valley Head town', ['558', 'AL']),
#  ('Vance town', ['170', 'SC']),
#  ('Vandiver CDP', ['1135', 'AL']),
#  ('Vernon city', ['11002', 'TX']),
#  ('Vestavia Hills city', ['34033(r38821)', 'AL']),
#  ('Vina town', ['358', 'AL']),
#  ('Vincent town', ['1988(r38822)', 'AL']),
#  ('Vinegar Bend CDP', ['192', 'AL']),
#  ('Vredenburgh town', ['312', 'AL']),
#  ('Wadley town', ['751', 'AL']),
#  ('Waldo town', ['283', 'AL']),
#  ('Walnut Grove town', ['1911', 'MS']),
#  ('Warrior city', ['3176', 'AL']),
#  ('Waterloo town', ['166', 'SC']),
#  ('Waverly town', ['106', 'WA']),
#  ('Weaver city', ['3038', 'AL']),
#  ('Webb town', ['565', 'MS']),
#  ('Wedowee town', ['823', 'AL']),
#  ('Weogufka CDP', ['282', 'AL']),
#  ('West Blocton town', ['1240', 'AL']),
#  ('West End-Cobb Town CDP', ['3465', 'AL']),
#  ('West Jefferson town', ['1299', 'NC']),
#  ('Westover town', ['1275', 'AL']),
#  ('West Point town', ['3306', 'VA']),
#  ('Wetumpka city', ['6528', 'AL']),
#  ('Whatley CDP', ['150', 'AL']),
#  ('White Hall town', ['648', 'WV']),
#  ('White Plains CDP', ['1074', 'NC']),
#  ('Whitesboro CDP', ['250', 'OK']),
#  ('Wilsonville town', ['1827', 'AL']),
#  ('Wilton town', ['687', 'AL']),
#  ('Winfield city', ['524', 'TX']),
#  ('Woodland town', ['809', 'NC']),
#  ('Woodstock town', ['5097', 'VA']),
#  ('Woodville town', ['2586', 'TX']),
#  ('Yellow Bluff town', ['188', 'AL']),
#  ('York city', ['7736', 'SC']),
#  ('Adak city', ['326', 'AK']),
#  ('Akhiok city', ['71', 'AK']),
#  ('Akiachak CDP', ['627', 'AK']),
#  ('Akiak city', ['346', 'AK']),
#  ('Akutan city', ['1027', 'AK']),
#  ('Alakanuk city', ['677', 'AK']),
#  ('Alatna CDP', ['37', 'AK']),
#  ('Alcan Border CDP', ['33', 'AK']),
#  ('Aleknagik city', ['219', 'AK']),
#  ('Aleneva CDP', ['37', 'AK']),
#  ('Allakaket city', ['105', 'AK']),
#  ('Ambler city', ['258', 'AK']),
#  ('Anaktuvuk Pass city', ['324', 'AK']),
#  ('Anchorage municipality', ['291826', 'AK']),
#  ('Anchor Point CDP', ['1930', 'AK']),
#  ('Anderson city', ['222', 'TX']),
#  ('Angoon city', ['459', 'AK']),
#  ('Aniak city', ['501', 'AK']),
#  ('Anvik city', ['85', 'AK']),
#  ('Arctic Village CDP', ['152', 'AK']),
#  ('Atka city', ['61', 'AK']),
#  ('Atmautluak CDP', ['277', 'AK']),
#  ('Atqasuk city', ['233', 'AK']),
#  ('Attu Station CDP', ['21', 'AK']),
#  ('Badger CDP', ['19482', 'AK']),
#  ('Barrow city', ['4212', 'AK']),
#  ('Bear Creek CDP', ['1948', 'FL']),
#  ('Beaver CDP', ['1308', 'WV']),
#  ('Beluga CDP', ['20', 'AK']),
#  ('Bethel city', ['466', 'MN']),
#  ('Bettles city', ['12', 'AK']),
#  ('Big Delta CDP', ['591', 'AK']),
#  ('Big Lake CDP', ['1835', 'WA']),
#  ('Birch Creek CDP', ['33', 'AK']),
#  ('Brevig Mission city', ['388', 'AK']),
#  ('Buckland city', ['416', 'AK']),
#  ('Buffalo Soapstone CDP', ['855', 'AK']),
#  ('Butte CDP', ['3246', 'AK']),
#  ('Cantwell CDP', ['219', 'AK']),
#  ('Central CDP', ['613', 'UT']),
#  ('Chalkyitsik CDP', ['69', 'AK']),
#  ('Chase CDP', ['978', 'PA']),
#  ('Chefornak city', ['418', 'AK']),
#  ('Chena Ridge CDP', ['5791', 'AK']),
#  ('Chenega CDP', ['76', 'AK']),
#  ('Chevak city', ['938', 'AK']),
#  ('Chickaloon CDP', ['272', 'AK']),
#  ('Chicken CDP', ['7', 'AK']),
#  ('Chignik city', ['91', 'AK']),
#  ('Chignik Lagoon CDP', ['78', 'AK']),
#  ('Chignik Lake CDP', ['73', 'AK']),
#  ('Chiniak CDP', ['47', 'AK']),
#  ('Chisana CDP', ['0', 'AK']),
#  ('Chistochina CDP', ['93', 'AK']),
#  ('Chitina CDP', ['126', 'AK']),
#  ('Chuathbaluk city', ['118', 'AK']),
#  ('Circle CDP', ['104', 'AK']),
#  ('Clam Gulch CDP', ['176', 'AK']),
#  ("Clark's Point city", ['62', 'AK']),
#  ('Coffman Cove city', ['176', 'AK']),
#  ('Cohoe CDP', ['1364', 'AK']),
#  ('Cold Bay city', ['108', 'AK']),
#  ('Coldfoot CDP', ['10', 'AK']),
#  ('College CDP', ['12964', 'AK']),
#  ('Cooper Landing CDP', ['289', 'AK']),
#  ('Copper Center CDP', ['328', 'AK']),
#  ('Covenant Life CDP', ['86', 'AK']),
#  ('Craig city', ['248', 'MO']),
#  ('Crooked Creek CDP', ['639', 'GA']),
#  ('Crown Point CDP', ['74', 'AK']),
#  ('Deering city', ['98', 'ND']),
#  ('Delta Junction city', ['958', 'AK']),
#  ('Deltana CDP', ['2251', 'AK']),
#  ('Diamond Ridge CDP', ['1156', 'AK']),
#  ('Dillingham city', ['2329', 'AK']),
#  ('Diomede city', ['115', 'AK']),
#  ('Dot Lake CDP', ['13', 'AK']),
#  ('Dot Lake Village CDP', ['62', 'AK']),
#  ('Dry Creek CDP', ['227', 'OK']),
#  ('Eagle city', ['19908', 'ID']),
#  ('Eagle Village CDP', ['67', 'AK']),
#  ('Edna Bay CDP', ['42', 'AK']),
#  ('Eek city', ['296', 'AK']),
#  ('Egegik city', ['109', 'AK']),
#  ('Eielson AFB CDP', ['2647', 'AK']),
#  ('Ekwok city', ['115', 'AK']),
#  ('Elfin Cove CDP', ['20', 'AK']),
#  ('Elim city', ['330', 'AK']),
#  ('Emmonak city', ['762', 'AK']),
#  ('Ester CDP', ['2422', 'AK']),
#  ('Eureka Roadhouse CDP', ['29', 'AK']),
#  ('Evansville CDP', ['15', 'AK']),
#  ('Excursion Inlet CDP', ['12', 'AK']),
#  ('Fairbanks city', ['31535', 'AK']),
#  ('False Pass city', ['35', 'AK']),
#  ('Farmers Loop CDP', ['4853', 'AK']),
#  ('Farm Loop CDP', ['1028', 'AK']),
#  ('Ferry CDP', ['33', 'AK']),
#  ('Fishhook CDP', ['4679', 'AK']),
#  ('Flat CDP', ['0', 'AK']),
#  ('Fort Greely CDP', ['539', 'AK']),
#  ('Fort Yukon city', ['583', 'AK']),
#  ('Four Mile Road CDP', ['43', 'AK']),
#  ('Fox CDP', ['417', 'AK']),
#  ('Fox River CDP', ['685', 'AK']),
#  ('Fritz Creek CDP', ['1932', 'AK']),
#  ('Funny River CDP', ['877', 'AK']),
#  ('Gakona CDP', ['218', 'AK']),
#  ('Galena city', ['440', 'MO']),
#  ('Gambell city', ['681', 'AK']),
#  ('Game Creek CDP', ['18', 'AK']),
#  ('Gateway CDP', ['8401', 'FL']),
#  ('Glacier View CDP', ['234', 'AK']),
#  ('Glennallen CDP', ['483', 'AK']),
#  ('Goldstream CDP', ['3557', 'AK']),
#  ('Golovin city', ['156', 'AK']),
#  ('Goodnews Bay city', ['243', 'AK']),
#  ('Grayling city', ['1884', 'MI']),
#  ('Gulkana CDP', ['119', 'AK']),
#  ('Gustavus city', ['442', 'AK']),
#  ('Haines CDP', ['1713', 'AK']),
#  ('Halibut Cove CDP', ['76', 'AK']),
#  ('Happy Valley CDP', ['519', 'NM']),
#  ('Harding-Birch Lakes CDP', ['299', 'AK']),
#  ('Healy CDP', ['234', 'KS']),
#  ('Healy Lake CDP', ['13', 'AK']),
#  ('Hobart Bay CDP', ['1', 'AK']),
#  ('Hollis CDP', ['112', 'AK']),
#  ('Holy Cross city', ['374', 'IA']),
#  ('Homer city', ['5003', 'AK']),
#  ('Hoonah city', ['760', 'AK']),
#  ('Hooper Bay city', ['1093', 'AK']),
#  ('Hope CDP', ['195', 'NJ']),
#  ('Houston city', ['2099451(r49478)', 'TX']),
#  ('Hughes city', ['1441', 'AR']),
#  ('Huslia city', ['275', 'AK']),
#  ('Hydaburg city', ['376', 'AK']),
#  ('Hyder CDP', ['87', 'AK']),
#  ('Igiugig CDP', ['50(r38845)', 'AK']),
#  ('Iliamna CDP', ['109', 'AK']),
#  ('Ivanof Bay CDP', ['7', 'AK']),
#  ('Juneau city and borough', ['31275', 'AK']),
#  ('Kachemak city', ['472', 'AK']),
#  ('Kake city', ['557', 'AK']),
#  ('Kaktovik city', ['239', 'AK']),
#  ('Kalifornsky CDP', ['7850', 'AK']),
#  ('Kaltag city', ['190', 'AK']),
#  ('Karluk CDP', ['37', 'AK']),
#  ('Kasaan city', ['49', 'AK']),
#  ('Kasigluk CDP', ['569', 'AK']),
#  ('Kasilof CDP', ['549', 'AK']),
#  ('Kenai city', ['7100(r38846)', 'AK']),
#  ('Kenny Lake CDP', ['355', 'AK']),
#  ('Ketchikan city', ['8050', 'AK']),
#  ('Kiana city', ['361', 'AK']),
#  ('King Cove city', ['938', 'AK']),
#  ('King Salmon CDP', ['374', 'AK']),
#  ('Kipnuk CDP', ['639', 'AK']),
#  ('Kivalina city', ['374', 'AK']),
#  ('Klawock city', ['755', 'AK']),
#  ('Klukwan CDP', ['95', 'AK']),
#  ('Knik-Fairview CDP', ['14923', 'AK']),
#  ('Knik River CDP', ['744', 'AK']),
#  ('Kobuk city', ['151', 'AK']),
#  ('Kodiak city', ['6130', 'AK']),
#  ('Kodiak Station CDP', ['1301', 'AK']),
#  ('Kokhanok CDP', ['170', 'AK']),
#  ('Koliganek CDP', ['209', 'AK']),
#  ('Kongiganak CDP', ['439', 'AK']),
#  ('Kotlik city', ['577', 'AK']),
#  ('Kotzebue city', ['3201', 'AK']),
#  ('Koyuk city', ['332', 'AK']),
#  ('Koyukuk city', ['96', 'AK']),
#  ('Kupreanof city', ['27', 'AK']),
#  ('Kwethluk city', ['721', 'AK']),
#  ('Kwigillingok CDP', ['321', 'AK']),
#  ('Lake Louise CDP', ['46', 'AK']),
#  ('Lake Minchumina CDP', ['13', 'AK']),
#  ('Lakes CDP', ['8364', 'AK']),
#  ('Larsen Bay city', ['87', 'AK']),
#  ('Lazy Mountain CDP', ['1479', 'AK']),
#  ('Levelock CDP', ['69', 'AK']),
#  ('Lime Village CDP', ['29', 'AK']),
#  ('Livengood CDP', ['13', 'AK']),
#  ('Loring CDP', ['4', 'AK']),
#  ('Lowell Point CDP', ['80', 'AK']),
#  ('Lower Kalskag city', ['282', 'AK']),
#  ('Lutak CDP', ['49', 'AK']),
#  ('McCarthy CDP', ['28', 'AK']),
#  ('McGrath city', ['80', 'MN']),
#  ('McKinley Park CDP', ['185', 'AK']),
#  ('Manley Hot Springs CDP', ['89', 'AK']),
#  ('Manokotak city', ['442', 'AK']),
#  ('Marshall city', ['23523', 'TX']),
#  ('Meadow Lakes CDP', ['7570', 'AK']),
#  ('Mekoryuk city', ['191', 'AK']),
#  ('Mendeltna CDP', ['39', 'AK']),
#  ('Mentasta Lake CDP', ['112', 'AK']),
#  ('Mertarvik CDP', ['0', 'AK']),
#  ('Metlakatla CDP', ['1405', 'AK']),
#  ('Minto CDP', ['210', 'AK']),
#  ('Moose Creek CDP', ['747', 'AK']),
#  ('Moose Pass CDP', ['219', 'AK']),
#  ('Mosquito Lake CDP', ['309', 'AK']),
#  ('Mountain Village city', ['813', 'AK']),
#  ('Mud Bay CDP', ['212', 'AK']),
#  ('Nabesna CDP', ['5', 'AK']),
#  ('Naknek CDP', ['544', 'AK']),
#  ('Nanwalek CDP', ['254', 'AK']),
#  ('Napakiak city', ['354', 'AK']),
#  ('Napaskiak city', ['405', 'AK']),
#  ('Naukati Bay CDP', ['113', 'AK']),
#  ('Nelchina CDP', ['59', 'AK']),
#  ('Nelson Lagoon CDP', ['52', 'AK']),
#  ('Nenana city', ['378', 'AK']),
#  ('New Allakaket CDP', ['66', 'AK']),
#  ('Newhalen city', ['190', 'AK']),
#  ('New Stuyahok city', ['510', 'AK']),
#  ('Newtok CDP', ['354', 'AK']),
#  ('Nightmute city', ['280', 'AK']),
#  ('Nikiski CDP', ['4493', 'AK']),
#  ('Nikolaevsk CDP', ['318', 'AK']),
#  ('Nikolai city', ['94', 'AK']),
#  ('Nikolski CDP', ['18', 'AK']),
#  ('Ninilchik CDP', ['883', 'AK']),
#  ('Noatak CDP', ['514', 'AK']),
#  ('Nome city', ['588', 'TX']),
#  ('Nondalton city', ['164', 'AK']),
#  ('Noorvik city', ['668', 'AK']),
#  ('North Pole city', ['2117', 'AK']),
#  ('Northway CDP', ['71', 'AK']),
#  ('Northway Junction CDP', ['54', 'AK']),
#  ('Northway Village CDP', ['98', 'AK']),
#  ('Nuiqsut city', ['402', 'AK']),
#  ('Nulato city', ['264', 'AK']),
#  ('Nunam Iqua city', ['187', 'AK']),
#  ('Nunapitchuk city', ['496', 'AK']),
#  ('Old Harbor city', ['218', 'AK']),
#  ('Oscarville CDP', ['70', 'AK']),
#  ('Ouzinkie city', ['161', 'AK']),
#  ('Palmer city', ['111', 'KS']),
#  ('Paxson CDP', ['40', 'AK']),
#  ('Pedro Bay CDP', ['42', 'AK']),
#  ('Pelican city', ['88', 'AK']),
#  ('Perryville CDP', ['113', 'AK']),
#  ('Petersburg city', ['2467', 'WV']),
#  ('Petersville CDP', ['4', 'AK']),
#  ('Pilot Point city', ['3856', 'TX']),
#  ('Pilot Station city', ['568', 'AK']),
#  ('Pitkas Point CDP', ['109', 'AK']),
#  ('Platinum city', ['61', 'AK']),
#  ('Pleasant Valley CDP', ['1145', 'NY']),
#  ('Point Baker CDP', ['2991', 'FL']),
#  ('Point Hope city', ['674', 'AK']),
#  ('Point Lay CDP', ['189', 'AK']),
#  ('Point MacKenzie CDP', ['529', 'AK']),
#  ('Point Possession CDP', ['3', 'AK']),
#  ('Pope-Vannoy Landing CDP', ['6', 'AK']),
#  ('Portage Creek CDP', ['2', 'AK']),
#  ('Port Alexander city', ['52', 'AK']),
#  ('Port Alsworth CDP', ['159', 'AK']),
#  ('Port Clarence CDP', ['24', 'AK']),
#  ('Port Graham CDP', ['177', 'AK']),
#  ('Port Heiden city', ['102', 'AK']),
#  ('Port Lions city', ['194', 'AK']),
#  ('Port Protection CDP', ['48', 'AK']),
#  ('Primrose CDP', ['78', 'AK']),
#  ('Prudhoe Bay CDP', ['2174', 'AK']),
#  ('Quinhagak city', ['669', 'AK']),
#  ('Rampart CDP', ['24', 'AK']),
#  ('Red Devil CDP', ['23', 'AK']),
#  ('Red Dog Mine CDP', ['309', 'AK']),
#  ('Ridgeway CDP', ['2022', 'AK']),
#  ('Ruby city', ['166', 'AK']),
#  ('Russian Mission city', ['312', 'AK']),
#  ('St. George city', ['72897', 'UT']),
#  ("St. Mary's city", ['507', 'AK']),
#  ('St. Michael city', ['16399', 'MN']),
#  ('St. Paul city', ['421', 'OR']),
#  ('Salamatof CDP', ['980', 'AK']),
#  ('Salcha CDP', ['1095', 'AK']),
#  ('Sand Point city', ['976', 'AK']),
#  ('Savoonga city', ['671', 'AK']),
#  ('Saxman city', ['411', 'AK']),
#  ('Scammon Bay city', ['474', 'AK']),
#  ('Selawik city', ['829', 'AK']),
#  ('Seldovia city', ['255', 'AK']),
#  ('Seldovia Village CDP', ['165', 'AK']),
#  ('Seward city', ['6964', 'NE']),
#  ('Shageluk city', ['83', 'AK']),
#  ('Shaktoolik city', ['251', 'AK']),
#  ('Shishmaref city', ['563', 'AK']),
#  ('Shungnak city', ['262', 'AK']),
#  ('Silver Springs CDP', ['5296', 'NV']),
#  ('Sitka city and borough', ['8881', 'AK']),
#  ('Skagway CDP', ['920', 'AK']),
#  ('Skwentna CDP', ['37', 'AK']),
#  ('Slana CDP', ['147', 'AK']),
#  ('Sleetmute CDP', ['86', 'AK']),
#  ('Soldotna city', ['4163', 'AK']),
#  ('South Naknek CDP', ['79', 'AK']),
#  ('South Van Horn CDP', ['558', 'AK']),
#  ('Stebbins city', ['556', 'AK']),
#  ('Steele Creek CDP', ['6662', 'AK']),
#  ('Sterling CDP', ['27822', 'VA']),
#  ('Stevens Village CDP', ['78', 'AK']),
#  ('Stony River CDP', ['54', 'AK']),
#  ('Sunrise CDP', ['18', 'AK']),
#  ('Susitna CDP', ['18', 'AK']),
#  ('Susitna North CDP', ['1260', 'AK']),
#  ('Sutton-Alpine CDP', ['1447', 'AK']),
#  ('Takotna CDP', ['52', 'AK']),
#  ('Talkeetna CDP', ['876', 'AK']),
#  ('Tanacross CDP', ['136', 'AK']),
#  ('Tanaina CDP', ['8197', 'AK']),
#  ('Tanana city', ['246', 'AK']),
#  ('Tatitlek CDP', ['88', 'AK']),
#  ('Tazlina CDP', ['297', 'AK']),
#  ('Teller city', ['229', 'AK']),
#  ('Tenakee Springs city', ['131', 'AK']),
#  ('Tetlin CDP', ['127', 'AK']),
#  ('Thorne Bay city', ['471', 'AK']),
#  ('Togiak city', ['817', 'AK']),
#  ('Tok CDP', ['1258', 'AK']),
#  ('Toksook Bay city', ['590', 'AK']),
#  ('Tolsona CDP', ['30', 'AK']),
#  ('Tonsina CDP', ['78', 'AK']),
#  ('Trapper Creek CDP', ['481', 'AK']),
#  ('Tuluksak CDP', ['373', 'AK']),
#  ('Tuntutuliak CDP', ['408', 'AK']),
#  ('Tununak CDP', ['327', 'AK']),
#  ('Twin Hills CDP', ['74', 'AK']),
#  ('Two Rivers CDP', ['719', 'AK']),
#  ('Tyonek CDP', ['171', 'AK']),
#  ('Ugashik CDP', ['12', 'AK']),
#  ('Unalakleet city', ['688', 'AK']),
#  ('Unalaska city', ['4376', 'AK']),
#  ('Upper Kalskag city', ['210', 'AK']),
#  ('Valdez city', ['3976', 'AK']),
#  ('Venetie CDP', ['166', 'AK']),
#  ('Wainwright city', ['556', 'AK']),
#  ('Wales city', ['31', 'ND']),
#  ('Wasilla city', ['7831', 'AK']),
#  ('Whale Pass CDP', ['31', 'AK']),
#  ('White Mountain city', ['190', 'AK']),
#  ('Whitestone CDP', ['97', 'AK']),
#  ('Whitestone Logging Camp CDP', ['17', 'AK']),
#  ('Whittier city', ['85331', 'CA']),
#  ('Willow CDP', ['2102', 'AK']),
#  ('Willow Creek CDP', ['210', 'MT']),
#  ('Wiseman CDP', ['14', 'AK']),
#  ('Womens Bay CDP', ['719', 'AK']),
#  ('Wrangell city and borough', ['2369', 'AK']),
#  ('Yakutat CDP', ['662', 'AK']),
#  ('Aguila CDP', ['798', 'AZ']),
#  ('Ajo CDP', ['3304', 'AZ']),
#  ('Ak Chin CDP', ['30', 'AZ']),
#  ('Ak-Chin Village CDP', ['862', 'AZ']),
#  ('Alamo Lake CDP', ['25', 'AZ']),
#  ('Ali Chuk CDP', ['161', 'AZ']),
#  ('Ali Chukson CDP', ['132', 'AZ']),
#  ('Ali Molina CDP', ['71', 'AZ']),
#  ('Alpine CDP', ['171', 'OR']),
#  ('Amado CDP', ['295', 'AZ']),
#  ('Anegam CDP', ['151', 'AZ']),
#  ('Antares CDP', ['126', 'AZ']),
#  ('Anthem CDP', ['21700', 'AZ']),
#  ('Apache Junction city', ['35840', 'AZ']),
#  ('Arivaca CDP', ['695', 'AZ']),
#  ('Arivaca Junction CDP', ['1090', 'AZ']),
#  ('Arizona City CDP', ['10475', 'AZ']),
#  ('Arizona Village CDP', ['946', 'AZ']),
#  ('Arlington CDP', ['25', 'WY']),
#  ('Ash Fork CDP', ['396', 'AZ']),
#  ('Avenue B and C CDP', ['4176', 'AZ']),
#  ('Avondale city', ['440', 'MO']),
#  ('Avra Valley CDP', ['6050', 'AZ']),
#  ('Aztec CDP', ['47', 'AZ']),
#  ('Bagdad CDP', ['3761', 'FL']),
#  ('Bear Flat CDP', ['18', 'AZ']),
#  ('Beaver Dam CDP', ['1962', 'AZ']),
#  ('Beaver Valley CDP', ['231', 'AZ']),
#  ('Benson city', ['3240', 'MN']),
#  ('Beyerville CDP', ['177', 'AZ']),
#  ('Bisbee city', ['126', 'ND']),
#  ('Bitter Springs CDP', ['452', 'AZ']),
#  ('Black Canyon City CDP', ['2837', 'AZ']),
#  ('Blackwater CDP', ['1062', 'AZ']),
#  ('Bluewater CDP', ['172', 'CA']),
#  ('Bouse CDP', ['996', 'AZ']),
#  ('Bowie CDP', ['449', 'AZ']),
#  ('Brenda CDP', ['676', 'AZ']),
#  ('Bryce CDP', ['175', 'AZ']),
#  ('Buckeye town', ['50876', 'AZ']),
#  ('Buckshot CDP', ['153', 'AZ']),
#  ('Bullhead City city', ['39540', 'AZ']),
#  ('Burnside CDP', ['537', 'AZ']),
#  ('Bylas CDP', ['1962', 'AZ']),
#  ('Cactus Flats CDP', ['1518', 'AZ']),
#  ('Cactus Forest CDP', ['594', 'AZ']),
#  ('Cameron CDP', ['406', 'LA']),
#  ('Campo Bonito CDP', ['74', 'AZ']),
#  ('Camp Verde town', ['10873', 'AZ']),
#  ('Cane Beds CDP', ['448', 'AZ']),
#  ('Canyon Day CDP', ['1209', 'AZ']),
#  ('Carefree town', ['3363', 'AZ']),
#  ('Carrizo CDP', ['127', 'AZ']),
#  ('Casa Blanca CDP', ['54', 'TX']),
#  ('Casa Grande city', ['48571', 'AZ']),
#  ('Casas Adobes CDP', ['66795', 'AZ']),
#  ('Catalina CDP', ['7569', 'AZ']),
#  ('Catalina Foothills CDP', ['50796', 'AZ']),
#  ('Cave Creek town', ['5015', 'AZ']),
#  ('Cedar Creek CDP', ['318', 'AZ']),
#  ('Centennial Park CDP', ['1264', 'AZ']),
#  ('Central Heights-Midland City CDP', ['2534', 'AZ']),
#  ('Chandler city', ['2734', 'TX']),
#  ('Charco CDP', ['52', 'AZ']),
#  ('Chiawuli Tak CDP', ['78', 'AZ']),
#  ('Chilchinbito CDP', ['506', 'AZ']),
#  ('Chinle CDP', ['4518', 'AZ']),
#  ('Chino Valley town', ['10817', 'AZ']),
#  ...]

# %%
city_pop_dic_lst[6][0]
# Out:
# 'Albertville city'

# %%
city_kills_state[598][0]
# Out:
# 'Floral City'

# %%
city_pop_dic_lst[6][0] in city_kills_state[598][0]
# Out:
# False

# %%
city_pop_dic_lst[0][1][1]
# Out:
# 'AL'

# %%
city_kills_state[0][1][0]
# Out:
# 71

# %%
def get_state(lst_of_dic,x):
    return lst_of_dic[x][1][1]
def get_number(lst_of_dic,x):
    return lst_of_dic[x][1][0]

# %%
get_number(city_pop_dic_lst,0)
# Out:
# '192'

# %%
get_number(city_kills_state,0)
# Out:
# 71

# %%
'pop->per capita'
city_kills_state=x
def pop_to_per_capita(lst_of_dic):
    for i in range(len(lst_of_dic)):
        for x in range(len(city_pop_dic_lst)):
            if lst_of_dic[i][0] in city_pop_dic_lst[x][0]:
                if lst_of_dic[i][1][1] is city_pop_dic_lst[x][1][1]:
                    per_capita=(lst_of_dic[i][1][0])/float((city_pop_dic_lst[x][1][0]))
                    lst_of_dic[i][1][0]=per_capita
    return lst_of_dic
kills_per_capita=pop_to_per_capita(x)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-c280ff34459f> in <module>
#       9                     lst_of_dic[i][1][0]=per_capita
#      10     return lst_of_dic
# ---> 11 kills_per_capita=pop_to_per_capita(x)
#      12
#
# <ipython-input-40-c280ff34459f> in pop_to_per_capita(lst_of_dic)
#       4     for i in range(len(lst_of_dic)):
#       5         for x in range(len(city_pop_dic_lst)):
# ----> 6             if lst_of_dic[i][0] in city_pop_dic_lst[x][0]:
#       7                 if lst_of_dic[i][1][1] is city_pop_dic_lst[x][1][1]:
#       8                     per_capita=(lst_of_dic[i][1][0])/float((city_pop_dic_lst[x][1][0]))
#
# IndexError: invalid index to scalar variable.
