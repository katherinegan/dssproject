# %%
import numpy as np
import pandas as pd

# %%
police = pd.read_csv('fatal-police-shootings-data.csv')
police['city'] = police['city'].str.replace(r'city', '') #removes anything with a lower-cased ' city', done to try to clean up data
police['city'] = police['city'].str.lower() #makes everything lower case, done to try to clean up data
police['city'] = police['city'].str.replace(r'\s', '')

# %%
police
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4582  5038            Jeffrey Michael Gibble  2019-09-16              shot
# 4583  5041                  Kristopher Adams  2019-09-16              shot
# 4584  5066                             TK TK  2019-09-16              shot
# 4585  5032                   Gay Ellen Plack  2019-09-17              shot
# 4586  5034                             TK TK  2019-09-17              shot
# 4587  5043            Scott Gabriel Spangler  2019-09-18              shot
# 4588  5045                 John Emory Sawyer  2019-09-19              shot
# 4589  5044            Jordan Michael Griffin  2019-09-20              shot
# 4590  5058                 Adam Paul English  2019-09-20              shot
# 4591  5049                  Jeffrey Peterson  2019-09-21              shot
# 4592  5050                             TK TK  2019-09-22              shot
# 4593  5046                             TK TK  2019-09-23              shot
# 4594  5047              Jeffery Tyler Aycock  2019-09-23              shot
# 4595  5048                    Charles Nation  2019-09-23              shot
# 4596  5051                   Jarod Lee Smith  2019-09-24              shot
# 4597  5068                    Haywood Cannon  2019-09-24              shot
# 4598  5069            Ronald Michael McCrary  2019-09-24              shot
# 4599  5053                  Daryl Strickland  2019-09-25              shot
# 4600  5067                  Kevin Dudenhefer  2019-09-25  shot and Tasered
# 4601  5052                     Leonard Shand  2019-09-26              shot
# 4602  5054               Chad Willis Huggins  2019-09-26              shot
# 4603  5055                             TK TK  2019-09-26              shot
# 4604  5057                             TK TK  2019-09-26              shot
# 4605  5059                    Haywood Cannon  2019-09-26              shot
# 4606  5063              Jamaal Ramone Taylor  2019-09-28              shot
# 4607  5065                             TK TK  2019-09-28              shot
# 4608  5060                    Dewayne Morgan  2019-09-29  shot and Tasered
# 4609  5061                             TK TK  2019-09-29              shot
# 4610  5062                   Richard Cabrera  2019-09-29              shot
# 4611  5064                  Antonio Williams  2019-09-29              shot
#
#                armed   age gender race             city state  \
# 0                gun  53.0      M    A          shelton    WA
# 1                gun  47.0      M    W            aloha    OR
# 2            unarmed  23.0      M    H          wichita    KS
# 3         toy weapon  32.0      M    W     sanfrancisco    CA
# 4           nail gun  39.0      M    H            evans    CO
# 5                gun  18.0      M    W          guthrie    OK
# 6                gun  22.0      M    H         chandler    AZ
# 7                gun  35.0      M    W          assaria    KS
# 8            unarmed  34.0      F    W       burlington    IA
# 9         toy weapon  47.0      M    B        knoxville    PA
# 10             knife  25.0      M    W         stockton    CA
# 11               gun  31.0      M    B         freeport    TX
# 12             knife  41.0      M    B         columbus    OH
# 13               gun  30.0      M    W        desmoines    IA
# 14               gun  37.0      M    B       neworleans    LA
# 15               NaN  28.0      M    W          huntley    MT
# 16            shovel  42.0      M    W     saltlakecity    UT
# 17           unarmed  36.0      M    B           strong    AR
# 18               gun  49.0      M    W         syracuse    UT
# 19               gun  71.0      M    W          england    AR
# 20               gun  33.0      M    H           elpaso    TX
# 21               gun  39.0      M    W           arcola    IL
# 22               gun  23.0      M    H        southgate    CA
# 23               gun  29.0      M    H    northlasvegas    NV
# 24               gun  34.0      M    W      albuquerque    NM
# 25             knife  43.0      M    W       jourdanton    TX
# 26               NaN  24.0      M    B          st.paul    MN
# 27               NaN  29.0      M    W   franklincounty    MO
# 28               gun  34.0      M    B       chesapeake    VA
# 29             knife  75.0      M    W        oldbridge    NJ
# ...              ...   ...    ...  ...              ...   ...
# 4582             gun  33.0      M    W      elizabethon    TN
# 4583             gun  37.0      M  NaN           sanger    TX
# 4584             gun   NaN      M  NaN          houston    TX
# 4585         hatchet  57.0      F    W         richmond    VA
# 4586         vehicle   NaN      M  NaN           milton    FL
# 4587    undetermined  43.0      M  NaN            salem    OR
# 4588  unknown weapon  74.0      M  NaN       soddydaisy    TN
# 4589      pellet gun  18.0      M  NaN        longbeach    CA
# 4590             gun  21.0      M  NaN      gainesville    GA
# 4591    undetermined  29.0      M  NaN              ada    OK
# 4592             gun  74.0      M    W           austin    TX
# 4593             gun   NaN      M    H       losangeles    CA
# 4594             gun  28.0      M    W      floydcounty    GA
# 4595  unknown weapon  31.0      M  NaN           lowell    AR
# 4596             gun  41.0      M  NaN       huntington    WV
# 4597             gun  67.0      M  NaN        richlands    NC
# 4598           knife  63.0      M  NaN          sanford    NC
# 4599             gun  64.0      M  NaN       hartsville    SC
# 4600             gun  32.0      M    W          lacombe    LA
# 4601           knife  49.0      M    B      hyattsville    MD
# 4602             gun  28.0      M    W  lexingtoncounty    SC
# 4603         vehicle   NaN      M  NaN          lahabra    CA
# 4604             gun   NaN      M  NaN           dallas    TX
# 4605             gun  67.0      M  NaN     jacksonville    NC
# 4606           knife  31.0      M  NaN        baltimore    MD
# 4607             gun   NaN      M  NaN           boston    MA
# 4608             NaN  37.0      M    W         longview    TX
# 4609    undetermined   NaN      M  NaN         monument    CO
# 4610             gun  38.0      M  NaN            miami    FL
# 4611             gun  27.0      M  NaN          newyork    NY
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# 5                       False        attack  Not fleeing        False
# 6                       False        attack          Car        False
# 7                       False        attack  Not fleeing        False
# 8                       False         other  Not fleeing         True
# 9                       False        attack  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 11                      False        attack  Not fleeing        False
# 12                       True         other  Not fleeing        False
# 13                      False        attack          Car        False
# 14                      False        attack         Foot         True
# 15                      False  undetermined  Not fleeing        False
# 16                      False        attack  Not fleeing         True
# 17                      False        attack  Not fleeing        False
# 18                      False        attack  Not fleeing         True
# 19                      False        attack  Not fleeing        False
# 20                      False        attack  Not fleeing        False
# 21                       True        attack  Not fleeing        False
# 22                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 24                      False        attack         Foot         True
# 25                       True         other  Not fleeing        False
# 26                      False        attack  Not fleeing        False
# 27                      False        attack  Not fleeing        False
# 28                       True        attack  Not fleeing        False
# 29                      False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 4582                    False        attack         Foot        False
# 4583                    False        attack         Foot        False
# 4584                    False        attack         Foot        False
# 4585                     True        attack  Not fleeing         True
# 4586                    False        attack          Car        False
# 4587                    False        attack  Not fleeing        False
# 4588                     True         other  Not fleeing        False
# 4589                    False        attack  Not fleeing        False
# 4590                    False        attack  Not fleeing         True
# 4591                    False        attack  Not fleeing        False
# 4592                    False        attack  Not fleeing        False
# 4593                    False         other          NaN        False
# 4594                    False        attack         Foot        False
# 4595                    False         other  Not fleeing        False
# 4596                    False        attack  Not fleeing        False
# 4597                    False        attack          Car        False
# 4598                    False         other          NaN        False
# 4599                    False        attack  Not fleeing        False
# 4600                     True        attack  Not fleeing        False
# 4601                    False        attack  Not fleeing        False
# 4602                    False        attack        Other        False
# 4603                    False        attack          Car        False
# 4604                    False        attack  Not fleeing        False
# 4605                    False        attack  Not fleeing        False
# 4606                    False        attack         Foot        False
# 4607                    False        attack         Foot        False
# 4608                    False        attack         Foot        False
# 4609                    False        attack  Not fleeing        False
# 4610                    False        attack          NaN        False
# 4611                    False        attack  Not fleeing        False
#
# [4612 rows x 14 columns]

# %%
police.shape
# Out:
# (4612, 14)

# %%
police.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race          city state  signs_of_mental_illness threat_level  \
# 0      M    A       shelton    WA                     True       attack
# 1      M    W         aloha    OR                    False       attack
# 2      M    H       wichita    KS                    False        other
# 3      M    W  sanfrancisco    CA                     True       attack
# 4      M    H         evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
police["id"]
# Out:
# 0          3
# 1          4
# 2          5
# 3          8
# 4          9
# 5         11
# 6         13
# 7         15
# 8         16
# 9         17
# 10        19
# 11        21
# 12        22
# 13        25
# 14        27
# 15        29
# 16        32
# 17        36
# 18        37
# 19        38
# 20       325
# 21        42
# 22        43
# 23        45
# 24        46
# 25        48
# 26        49
# 27        50
# 28        51
# 29        52
#         ...
# 4582    5038
# 4583    5041
# 4584    5066
# 4585    5032
# 4586    5034
# 4587    5043
# 4588    5045
# 4589    5044
# 4590    5058
# 4591    5049
# 4592    5050
# 4593    5046
# 4594    5047
# 4595    5048
# 4596    5051
# 4597    5068
# 4598    5069
# 4599    5053
# 4600    5067
# 4601    5052
# 4602    5054
# 4603    5055
# 4604    5057
# 4605    5059
# 4606    5063
# 4607    5065
# 4608    5060
# 4609    5061
# 4610    5062
# 4611    5064
# Name: id, Length: 4612, dtype: int64

# %%
police[police['manner_of_death'].str.contains('shot and Tasered')]
# Out:
#         id                      name        date   manner_of_death  \
# 2        5        John Paul Quintero  2015-01-03  shot and Tasered
# 10      19            Patrick Wetter  2015-01-06  shot and Tasered
# 23      45         Salvador Figueroa  2015-01-11  shot and Tasered
# 38      68             Zaki Shinwary  2015-01-16  shot and Tasered
# 43      83             Carter Castle  2015-01-18  shot and Tasered
# 51     100        Kristiana Coignard  2015-01-22  shot and Tasered
# 69     346               Matautu Nuu  2015-01-28  shot and Tasered
# 75     339     Edward Donnell Bright  2015-01-31  shot and Tasered
# 100    138   Antonio Zambrano-Montes  2015-02-10  shot and Tasered
# 112    150               Lavall Hall  2015-02-15  shot and Tasered
# 131    266            Jerome Nichols  2015-02-23  shot and Tasered
# 132    371              Daniel Elrod  2015-02-23  shot and Tasered
# 137    177            Joseph Biegert  2015-02-24  shot and Tasered
# 140    180    Alexander Phillip Long  2015-02-26  shot and Tasered
# 147    187            Deven Guilford  2015-02-28  shot and Tasered
# 154    194    Charly Leundeu Keunang  2015-03-01  shot and Tasered
# 219    233    Christopher Ryan Healy  2015-03-22  shot and Tasered
# 220    234              Denzel Brown  2015-03-22  shot and Tasered
# 228    242          Joseph Tassinari  2015-03-25  shot and Tasered
# 248    288              Donald Hicks  2015-04-02  shot and Tasered
# 253    297              Walter Scott  2015-04-04  shot and Tasered
# 266    534                Mark Smith  2015-04-09  shot and Tasered
# 328    424    Erick Emmanuel Sanchez  2015-04-30  shot and Tasered
# 352    449             Bruce Zalonka  2015-05-12  shot and Tasered
# 366    467          Jonathan  Colley  2015-05-20  shot and Tasered
# 368    486       Nikki Jo Burtsfield  2015-05-20  shot and Tasered
# 387    491               Feras Morad  2015-05-27  shot and Tasered
# 388    492              Simon Hubble  2015-05-27  shot and Tasered
# 392    494                Kyle Baker  2015-05-28  shot and Tasered
# 404    513                 Rudy Baca  2015-06-03  shot and Tasered
# ...    ...                       ...         ...               ...
# 3625  3975           Aquantis Givens  2018-08-17  shot and Tasered
# 3627  3982            Andres Arteaga  2018-08-18  shot and Tasered
# 3667  4020        Dereshia Blackwell  2018-09-09  shot and Tasered
# 3701  4064             Michael Perez  2018-09-27  shot and Tasered
# 3738  4096       Jacob E. Albrethsen  2018-10-12  shot and Tasered
# 3753  4129          James Lyle Kuehn  2018-10-17  shot and Tasered
# 3766  4120          Tafahree Maynard  2018-10-22  shot and Tasered
# 3801  4166                     TK TK  2018-11-07  shot and Tasered
# 3812  4178                Marty West  2018-11-12  shot and Tasered
# 3863  4239     Demontry Floytra Boyd  2018-12-01  shot and Tasered
# 3927  4411            Paul Arbitelle  2018-12-30  shot and Tasered
# 3955  4353           Andre C. Gladen  2019-01-06  shot and Tasered
# 3962  4520             Jerald Wilson  2019-01-08  shot and Tasered
# 3970  4522                     TK TK  2019-01-11  shot and Tasered
# 4004  4406        Kevin Grant Vawter  2019-01-23  shot and Tasered
# 4022  4430               Carl Thayer  2019-01-28  shot and Tasered
# 4039  4456               Hunter Alan  2019-02-06  shot and Tasered
# 4100  4523                     TK TK  2019-03-01  shot and Tasered
# 4115  4529             Danny Brogdon  2019-03-05  shot and Tasered
# 4118  4537  Antonio Joseph Valentine  2019-03-05  shot and Tasered
# 4154  4580            Kenneth Cherry  2019-03-18  shot and Tasered
# 4182  4669  Ondrae Levado Hutchinson  2019-03-30  shot and Tasered
# 4191  4680                     TK TK  2019-04-01  shot and Tasered
# 4223  4635                Henry Lane  2019-04-14  shot and Tasered
# 4249  4692              Isaiah Lewis  2019-04-29  shot and Tasered
# 4407  4854      Olivio Sandoval Diaz  2019-07-04  shot and Tasered
# 4420  4859              Jason Harris  2019-07-09  shot and Tasered
# 4460  4923   Mauris Nishanga DeSilva  2019-07-31  shot and Tasered
# 4600  5067          Kevin Dudenhefer  2019-09-25  shot and Tasered
# 4608  5060            Dewayne Morgan  2019-09-29  shot and Tasered
#
#                  armed   age gender race             city state  \
# 2              unarmed  23.0      M    H          wichita    KS
# 10               knife  25.0      M    W         stockton    CA
# 23                 gun  29.0      M    H    northlasvegas    NV
# 38               knife  48.0      M    O          fremont    CA
# 43                 gun  67.0      M    W          gunlock    KY
# 51               knife  17.0      F    W         longview    TX
# 69              hammer  35.0      M    A         stockton    CA
# 75               knife  54.0      M    B     randallstown    MD
# 100            unarmed  35.0      M    H            pasco    WA
# 112            unarmed  25.0      M    B     miamigardens    FL
# 131              knife  42.0      M    W        allentown    PA
# 132            unarmed  39.0      M    W            omaha    NE
# 137              knife  30.0      M    W         greenbay    WI
# 140            unarmed  31.0      M    W       terrehaute    IN
# 147            unarmed  17.0      M    W   roxandtownship    MI
# 154            unarmed  43.0      M    B       losangeles    CA
# 219              knife  36.0      M    W         portland    OR
# 220       undetermined  21.0      M    B            islip    NY
# 228                gun  63.0      M    W         glendale    AZ
# 248                gun  63.0      M    W       metropolis    IL
# 253            unarmed  50.0      M    B  northcharleston    SC
# 266                NaN  54.0      M  NaN       kellyville    OK
# 328       metal object  22.0      M    H           elpaso    TX
# 352                gun  46.0      M    O         honolulu    HI
# 366              knife  52.0      M    W            green    OH
# 368              knife  39.0      F    W         gillette    WY
# 387            unarmed  20.0      M    O        longbeach    CA
# 388        screwdriver  33.0      M    W           alpine    CA
# 392   lawn mower blade  18.0      M    W          trenton    MI
# 404            unarmed  36.0      M    H         loslunas    NM
# ...                ...   ...    ...  ...              ...   ...
# 3625               gun  21.0      M    B           austin    TX
# 3627               gun  28.0      M    H          phoenix    AZ
# 3667     gun and knife  39.0      F    B     missouricity    TX
# 3701             knife  37.0      M    H         honolulu    HI
# 3738             knife  17.0      M    W             orem    OR
# 3753             knife  61.0      M    W           kearns    UT
# 3766  lawn mower blade  18.0      M    B       snellville    GA
# 3801               gun   NaN      M  NaN       sanantonio    TX
# 3812             knife  63.0      M    W           fresno    CA
# 3863             knife  43.0      M    B         lasvegas    NV
# 3927             knife  45.0      M    W          danbury    CT
# 3955             knife  36.0      M    B         portland    OR
# 3962       beer bottle  33.0      M  NaN          midland    TX
# 3970                ax   NaN      M  NaN       huntsville    TX
# 4004             knife  46.0      M    W       southhaven    IN
# 4022             knife  45.0      M  NaN     tehamacounty    CA
# 4039             knife  48.0      M  NaN         edinburg    TX
# 4100      undetermined  29.0      M    H        fairfield    TX
# 4115             knife  56.0      M    W         muskogee    OK
# 4118               gun  32.0      M    B     jacksonville    FL
# 4154      sharp object  36.0      M    W        mansfield    OH
# 4182               gun  30.0      M    B           durham    NC
# 4191      undetermined  29.0      M  NaN        fairfield    TX
# 4223     walking stick  42.0      M    N         redbluff    CA
# 4249           unarmed  17.0      M    B           edmond    OK
# 4407     piece of wood  47.0      M    H          roswell    GA
# 4420             knife  36.0      M  NaN     ranchomirage    CA
# 4460             knife  46.0      M  NaN           austin    TX
# 4600               gun  32.0      M    W          lacombe    LA
# 4608               NaN  37.0      M    W         longview    TX
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 2                       False         other  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 38                      False         other  Not fleeing        False
# 43                       True        attack  Not fleeing        False
# 51                       True         other  Not fleeing        False
# 69                       True        attack  Not fleeing        False
# 75                       True         other  Not fleeing        False
# 100                      True         other         Foot        False
# 112                      True         other  Not fleeing        False
# 131                     False        attack          Car        False
# 132                     False         other  Not fleeing        False
# 137                      True        attack  Not fleeing        False
# 140                     False         other  Not fleeing        False
# 147                     False        attack  Not fleeing         True
# 154                      True        attack  Not fleeing         True
# 219                      True         other         Foot        False
# 220                     False        attack          Car        False
# 228                      True         other  Not fleeing        False
# 248                      True        attack  Not fleeing        False
# 253                     False         other         Foot        False
# 266                     False        attack        Other        False
# 328                     False         other  Not fleeing        False
# 352                     False        attack  Not fleeing        False
# 366                     False         other  Not fleeing        False
# 368                     False         other          Car        False
# 387                     False         other  Not fleeing        False
# 388                      True         other  Not fleeing        False
# 392                     False        attack  Not fleeing        False
# 404                     False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 3625                    False        attack          NaN        False
# 3627                    False         other         Foot        False
# 3667                    False         other  Not fleeing        False
# 3701                    False         other  Not fleeing        False
# 3738                    False         other  Not fleeing        False
# 3753                    False         other          NaN        False
# 3766                    False         other  Not fleeing        False
# 3801                    False        attack  Not fleeing        False
# 3812                     True        attack  Not fleeing         True
# 3863                    False        attack  Not fleeing         True
# 3927                    False         other  Not fleeing        False
# 3955                     True         other  Not fleeing        False
# 3962                    False        attack  Not fleeing        False
# 3970                    False         other  Not fleeing        False
# 4004                     True        attack  Not fleeing         True
# 4022                    False         other        Other        False
# 4039                     True        attack  Not fleeing        False
# 4100                    False  undetermined          NaN        False
# 4115                    False         other  Not fleeing        False
# 4118                    False         other  Not fleeing        False
# 4154                    False         other  Not fleeing        False
# 4182                    False        attack         Foot         True
# 4191                    False         other  Not fleeing        False
# 4223                     True         other         Foot        False
# 4249                    False        attack         Foot        False
# 4407                    False        attack  Not fleeing        False
# 4420                    False        attack  Not fleeing         True
# 4460                     True         other  Not fleeing        False
# 4600                     True        attack  Not fleeing        False
# 4608                    False        attack         Foot        False
#
# [230 rows x 14 columns]

# %%
police[police['manner_of_death'].str.contains('shot')]
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4582  5038            Jeffrey Michael Gibble  2019-09-16              shot
# 4583  5041                  Kristopher Adams  2019-09-16              shot
# 4584  5066                             TK TK  2019-09-16              shot
# 4585  5032                   Gay Ellen Plack  2019-09-17              shot
# 4586  5034                             TK TK  2019-09-17              shot
# 4587  5043            Scott Gabriel Spangler  2019-09-18              shot
# 4588  5045                 John Emory Sawyer  2019-09-19              shot
# 4589  5044            Jordan Michael Griffin  2019-09-20              shot
# 4590  5058                 Adam Paul English  2019-09-20              shot
# 4591  5049                  Jeffrey Peterson  2019-09-21              shot
# 4592  5050                             TK TK  2019-09-22              shot
# 4593  5046                             TK TK  2019-09-23              shot
# 4594  5047              Jeffery Tyler Aycock  2019-09-23              shot
# 4595  5048                    Charles Nation  2019-09-23              shot
# 4596  5051                   Jarod Lee Smith  2019-09-24              shot
# 4597  5068                    Haywood Cannon  2019-09-24              shot
# 4598  5069            Ronald Michael McCrary  2019-09-24              shot
# 4599  5053                  Daryl Strickland  2019-09-25              shot
# 4600  5067                  Kevin Dudenhefer  2019-09-25  shot and Tasered
# 4601  5052                     Leonard Shand  2019-09-26              shot
# 4602  5054               Chad Willis Huggins  2019-09-26              shot
# 4603  5055                             TK TK  2019-09-26              shot
# 4604  5057                             TK TK  2019-09-26              shot
# 4605  5059                    Haywood Cannon  2019-09-26              shot
# 4606  5063              Jamaal Ramone Taylor  2019-09-28              shot
# 4607  5065                             TK TK  2019-09-28              shot
# 4608  5060                    Dewayne Morgan  2019-09-29  shot and Tasered
# 4609  5061                             TK TK  2019-09-29              shot
# 4610  5062                   Richard Cabrera  2019-09-29              shot
# 4611  5064                  Antonio Williams  2019-09-29              shot
#
#                armed   age gender race             city state  \
# 0                gun  53.0      M    A          shelton    WA
# 1                gun  47.0      M    W            aloha    OR
# 2            unarmed  23.0      M    H          wichita    KS
# 3         toy weapon  32.0      M    W     sanfrancisco    CA
# 4           nail gun  39.0      M    H            evans    CO
# 5                gun  18.0      M    W          guthrie    OK
# 6                gun  22.0      M    H         chandler    AZ
# 7                gun  35.0      M    W          assaria    KS
# 8            unarmed  34.0      F    W       burlington    IA
# 9         toy weapon  47.0      M    B        knoxville    PA
# 10             knife  25.0      M    W         stockton    CA
# 11               gun  31.0      M    B         freeport    TX
# 12             knife  41.0      M    B         columbus    OH
# 13               gun  30.0      M    W        desmoines    IA
# 14               gun  37.0      M    B       neworleans    LA
# 15               NaN  28.0      M    W          huntley    MT
# 16            shovel  42.0      M    W     saltlakecity    UT
# 17           unarmed  36.0      M    B           strong    AR
# 18               gun  49.0      M    W         syracuse    UT
# 19               gun  71.0      M    W          england    AR
# 20               gun  33.0      M    H           elpaso    TX
# 21               gun  39.0      M    W           arcola    IL
# 22               gun  23.0      M    H        southgate    CA
# 23               gun  29.0      M    H    northlasvegas    NV
# 24               gun  34.0      M    W      albuquerque    NM
# 25             knife  43.0      M    W       jourdanton    TX
# 26               NaN  24.0      M    B          st.paul    MN
# 27               NaN  29.0      M    W   franklincounty    MO
# 28               gun  34.0      M    B       chesapeake    VA
# 29             knife  75.0      M    W        oldbridge    NJ
# ...              ...   ...    ...  ...              ...   ...
# 4582             gun  33.0      M    W      elizabethon    TN
# 4583             gun  37.0      M  NaN           sanger    TX
# 4584             gun   NaN      M  NaN          houston    TX
# 4585         hatchet  57.0      F    W         richmond    VA
# 4586         vehicle   NaN      M  NaN           milton    FL
# 4587    undetermined  43.0      M  NaN            salem    OR
# 4588  unknown weapon  74.0      M  NaN       soddydaisy    TN
# 4589      pellet gun  18.0      M  NaN        longbeach    CA
# 4590             gun  21.0      M  NaN      gainesville    GA
# 4591    undetermined  29.0      M  NaN              ada    OK
# 4592             gun  74.0      M    W           austin    TX
# 4593             gun   NaN      M    H       losangeles    CA
# 4594             gun  28.0      M    W      floydcounty    GA
# 4595  unknown weapon  31.0      M  NaN           lowell    AR
# 4596             gun  41.0      M  NaN       huntington    WV
# 4597             gun  67.0      M  NaN        richlands    NC
# 4598           knife  63.0      M  NaN          sanford    NC
# 4599             gun  64.0      M  NaN       hartsville    SC
# 4600             gun  32.0      M    W          lacombe    LA
# 4601           knife  49.0      M    B      hyattsville    MD
# 4602             gun  28.0      M    W  lexingtoncounty    SC
# 4603         vehicle   NaN      M  NaN          lahabra    CA
# 4604             gun   NaN      M  NaN           dallas    TX
# 4605             gun  67.0      M  NaN     jacksonville    NC
# 4606           knife  31.0      M  NaN        baltimore    MD
# 4607             gun   NaN      M  NaN           boston    MA
# 4608             NaN  37.0      M    W         longview    TX
# 4609    undetermined   NaN      M  NaN         monument    CO
# 4610             gun  38.0      M  NaN            miami    FL
# 4611             gun  27.0      M  NaN          newyork    NY
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# 5                       False        attack  Not fleeing        False
# 6                       False        attack          Car        False
# 7                       False        attack  Not fleeing        False
# 8                       False         other  Not fleeing         True
# 9                       False        attack  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 11                      False        attack  Not fleeing        False
# 12                       True         other  Not fleeing        False
# 13                      False        attack          Car        False
# 14                      False        attack         Foot         True
# 15                      False  undetermined  Not fleeing        False
# 16                      False        attack  Not fleeing         True
# 17                      False        attack  Not fleeing        False
# 18                      False        attack  Not fleeing         True
# 19                      False        attack  Not fleeing        False
# 20                      False        attack  Not fleeing        False
# 21                       True        attack  Not fleeing        False
# 22                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 24                      False        attack         Foot         True
# 25                       True         other  Not fleeing        False
# 26                      False        attack  Not fleeing        False
# 27                      False        attack  Not fleeing        False
# 28                       True        attack  Not fleeing        False
# 29                      False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 4582                    False        attack         Foot        False
# 4583                    False        attack         Foot        False
# 4584                    False        attack         Foot        False
# 4585                     True        attack  Not fleeing         True
# 4586                    False        attack          Car        False
# 4587                    False        attack  Not fleeing        False
# 4588                     True         other  Not fleeing        False
# 4589                    False        attack  Not fleeing        False
# 4590                    False        attack  Not fleeing         True
# 4591                    False        attack  Not fleeing        False
# 4592                    False        attack  Not fleeing        False
# 4593                    False         other          NaN        False
# 4594                    False        attack         Foot        False
# 4595                    False         other  Not fleeing        False
# 4596                    False        attack  Not fleeing        False
# 4597                    False        attack          Car        False
# 4598                    False         other          NaN        False
# 4599                    False        attack  Not fleeing        False
# 4600                     True        attack  Not fleeing        False
# 4601                    False        attack  Not fleeing        False
# 4602                    False        attack        Other        False
# 4603                    False        attack          Car        False
# 4604                    False        attack  Not fleeing        False
# 4605                    False        attack  Not fleeing        False
# 4606                    False        attack         Foot        False
# 4607                    False        attack         Foot        False
# 4608                    False        attack         Foot        False
# 4609                    False        attack  Not fleeing        False
# 4610                    False        attack          NaN        False
# 4611                    False        attack  Not fleeing        False
#
# [4612 rows x 14 columns]

# %%
police['gender'].value_counts()
# Out:
# M    4398
# F     210
# Name: gender, dtype: int64

# %%
police['gender'].value_counts('F')
# Out:
# M    0.954427
# F    0.045573
# Name: gender, dtype: float64

# %%
police['manner_of_death'].value_counts()
# Out:
# shot                4382
# shot and Tasered     230
# Name: manner_of_death, dtype: int64

# %%
police['armed'].value_counts()
# Out:
# gun                                 2562
# knife                                689
# unarmed                              294
# undetermined                         189
# toy weapon                           161
# vehicle                               82
# unknown weapon                        60
# machete                               39
# ax                                    23
# Taser                                 19
# sword                                 16
# gun and knife                         16
# baseball bat                          13
# hammer                                12
# metal pipe                            11
# box cutter                            10
# hatchet                               10
# crossbow                               9
# screwdriver                            9
# gun and car                            7
# sharp object                           7
# pipe                                   6
# blunt object                           5
# piece of wood                          5
# gun and vehicle                        4
# scissors                               4
# shovel                                 4
# metal object                           4
# baton                                  4
# rock                                   4
#                                     ...
# tire iron                              1
# walking stick                          1
# metal hand tool                        1
# hand torch                             1
# metal rake                             1
# flagpole                               1
# air conditioner                        1
# baseball bat and fireplace poker       1
# motorcycle                             1
# pen                                    1
# gun and sword                          1
# cordless drill                         1
# spear                                  1
# samurai sword                          1
# chainsaw                               1
# claimed to be armed                    1
# carjack                                1
# oar                                    1
# bean-bag gun                           1
# nail gun                               1
# bow and arrow                          1
# flashlight                             1
# barstool                               1
# pepper spray                           1
# bayonet                                1
# wrench                                 1
# baseball bat and bottle                1
# vehicle and gun                        1
# machete and gun                        1
# stapler                                1
# Name: armed, Length: 84, dtype: int64

# %%
police
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4582  5038            Jeffrey Michael Gibble  2019-09-16              shot
# 4583  5041                  Kristopher Adams  2019-09-16              shot
# 4584  5066                             TK TK  2019-09-16              shot
# 4585  5032                   Gay Ellen Plack  2019-09-17              shot
# 4586  5034                             TK TK  2019-09-17              shot
# 4587  5043            Scott Gabriel Spangler  2019-09-18              shot
# 4588  5045                 John Emory Sawyer  2019-09-19              shot
# 4589  5044            Jordan Michael Griffin  2019-09-20              shot
# 4590  5058                 Adam Paul English  2019-09-20              shot
# 4591  5049                  Jeffrey Peterson  2019-09-21              shot
# 4592  5050                             TK TK  2019-09-22              shot
# 4593  5046                             TK TK  2019-09-23              shot
# 4594  5047              Jeffery Tyler Aycock  2019-09-23              shot
# 4595  5048                    Charles Nation  2019-09-23              shot
# 4596  5051                   Jarod Lee Smith  2019-09-24              shot
# 4597  5068                    Haywood Cannon  2019-09-24              shot
# 4598  5069            Ronald Michael McCrary  2019-09-24              shot
# 4599  5053                  Daryl Strickland  2019-09-25              shot
# 4600  5067                  Kevin Dudenhefer  2019-09-25  shot and Tasered
# 4601  5052                     Leonard Shand  2019-09-26              shot
# 4602  5054               Chad Willis Huggins  2019-09-26              shot
# 4603  5055                             TK TK  2019-09-26              shot
# 4604  5057                             TK TK  2019-09-26              shot
# 4605  5059                    Haywood Cannon  2019-09-26              shot
# 4606  5063              Jamaal Ramone Taylor  2019-09-28              shot
# 4607  5065                             TK TK  2019-09-28              shot
# 4608  5060                    Dewayne Morgan  2019-09-29  shot and Tasered
# 4609  5061                             TK TK  2019-09-29              shot
# 4610  5062                   Richard Cabrera  2019-09-29              shot
# 4611  5064                  Antonio Williams  2019-09-29              shot
#
#                armed   age gender race             city state  \
# 0                gun  53.0      M    A          shelton    WA
# 1                gun  47.0      M    W            aloha    OR
# 2            unarmed  23.0      M    H          wichita    KS
# 3         toy weapon  32.0      M    W     sanfrancisco    CA
# 4           nail gun  39.0      M    H            evans    CO
# 5                gun  18.0      M    W          guthrie    OK
# 6                gun  22.0      M    H         chandler    AZ
# 7                gun  35.0      M    W          assaria    KS
# 8            unarmed  34.0      F    W       burlington    IA
# 9         toy weapon  47.0      M    B        knoxville    PA
# 10             knife  25.0      M    W         stockton    CA
# 11               gun  31.0      M    B         freeport    TX
# 12             knife  41.0      M    B         columbus    OH
# 13               gun  30.0      M    W        desmoines    IA
# 14               gun  37.0      M    B       neworleans    LA
# 15               NaN  28.0      M    W          huntley    MT
# 16            shovel  42.0      M    W     saltlakecity    UT
# 17           unarmed  36.0      M    B           strong    AR
# 18               gun  49.0      M    W         syracuse    UT
# 19               gun  71.0      M    W          england    AR
# 20               gun  33.0      M    H           elpaso    TX
# 21               gun  39.0      M    W           arcola    IL
# 22               gun  23.0      M    H        southgate    CA
# 23               gun  29.0      M    H    northlasvegas    NV
# 24               gun  34.0      M    W      albuquerque    NM
# 25             knife  43.0      M    W       jourdanton    TX
# 26               NaN  24.0      M    B          st.paul    MN
# 27               NaN  29.0      M    W   franklincounty    MO
# 28               gun  34.0      M    B       chesapeake    VA
# 29             knife  75.0      M    W        oldbridge    NJ
# ...              ...   ...    ...  ...              ...   ...
# 4582             gun  33.0      M    W      elizabethon    TN
# 4583             gun  37.0      M  NaN           sanger    TX
# 4584             gun   NaN      M  NaN          houston    TX
# 4585         hatchet  57.0      F    W         richmond    VA
# 4586         vehicle   NaN      M  NaN           milton    FL
# 4587    undetermined  43.0      M  NaN            salem    OR
# 4588  unknown weapon  74.0      M  NaN       soddydaisy    TN
# 4589      pellet gun  18.0      M  NaN        longbeach    CA
# 4590             gun  21.0      M  NaN      gainesville    GA
# 4591    undetermined  29.0      M  NaN              ada    OK
# 4592             gun  74.0      M    W           austin    TX
# 4593             gun   NaN      M    H       losangeles    CA
# 4594             gun  28.0      M    W      floydcounty    GA
# 4595  unknown weapon  31.0      M  NaN           lowell    AR
# 4596             gun  41.0      M  NaN       huntington    WV
# 4597             gun  67.0      M  NaN        richlands    NC
# 4598           knife  63.0      M  NaN          sanford    NC
# 4599             gun  64.0      M  NaN       hartsville    SC
# 4600             gun  32.0      M    W          lacombe    LA
# 4601           knife  49.0      M    B      hyattsville    MD
# 4602             gun  28.0      M    W  lexingtoncounty    SC
# 4603         vehicle   NaN      M  NaN          lahabra    CA
# 4604             gun   NaN      M  NaN           dallas    TX
# 4605             gun  67.0      M  NaN     jacksonville    NC
# 4606           knife  31.0      M  NaN        baltimore    MD
# 4607             gun   NaN      M  NaN           boston    MA
# 4608             NaN  37.0      M    W         longview    TX
# 4609    undetermined   NaN      M  NaN         monument    CO
# 4610             gun  38.0      M  NaN            miami    FL
# 4611             gun  27.0      M  NaN          newyork    NY
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# 5                       False        attack  Not fleeing        False
# 6                       False        attack          Car        False
# 7                       False        attack  Not fleeing        False
# 8                       False         other  Not fleeing         True
# 9                       False        attack  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 11                      False        attack  Not fleeing        False
# 12                       True         other  Not fleeing        False
# 13                      False        attack          Car        False
# 14                      False        attack         Foot         True
# 15                      False  undetermined  Not fleeing        False
# 16                      False        attack  Not fleeing         True
# 17                      False        attack  Not fleeing        False
# 18                      False        attack  Not fleeing         True
# 19                      False        attack  Not fleeing        False
# 20                      False        attack  Not fleeing        False
# 21                       True        attack  Not fleeing        False
# 22                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 24                      False        attack         Foot         True
# 25                       True         other  Not fleeing        False
# 26                      False        attack  Not fleeing        False
# 27                      False        attack  Not fleeing        False
# 28                       True        attack  Not fleeing        False
# 29                      False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 4582                    False        attack         Foot        False
# 4583                    False        attack         Foot        False
# 4584                    False        attack         Foot        False
# 4585                     True        attack  Not fleeing         True
# 4586                    False        attack          Car        False
# 4587                    False        attack  Not fleeing        False
# 4588                     True         other  Not fleeing        False
# 4589                    False        attack  Not fleeing        False
# 4590                    False        attack  Not fleeing         True
# 4591                    False        attack  Not fleeing        False
# 4592                    False        attack  Not fleeing        False
# 4593                    False         other          NaN        False
# 4594                    False        attack         Foot        False
# 4595                    False         other  Not fleeing        False
# 4596                    False        attack  Not fleeing        False
# 4597                    False        attack          Car        False
# 4598                    False         other          NaN        False
# 4599                    False        attack  Not fleeing        False
# 4600                     True        attack  Not fleeing        False
# 4601                    False        attack  Not fleeing        False
# 4602                    False        attack        Other        False
# 4603                    False        attack          Car        False
# 4604                    False        attack  Not fleeing        False
# 4605                    False        attack  Not fleeing        False
# 4606                    False        attack         Foot        False
# 4607                    False        attack         Foot        False
# 4608                    False        attack         Foot        False
# 4609                    False        attack  Not fleeing        False
# 4610                    False        attack          NaN        False
# 4611                    False        attack  Not fleeing        False
#
# [4612 rows x 14 columns]

# %%
police['state'].value_counts()
# Out:
# CA    698
# TX    410
# FL    281
# AZ    223
# CO    159
# GA    151
# OK    138
# OH    134
# NC    127
# WA    127
# TN    120
# MO    114
# LA     96
# PA     95
# IL     95
# NM     91
# AL     88
# VA     84
# IN     82
# KY     80
# NY     80
# NV     79
# WI     73
# MI     72
# SC     72
# OR     72
# AR     68
# MD     67
# NJ     59
# MN     57
# MS     57
# UT     51
# WV     50
# KS     45
# ID     35
# AK     32
# MA     31
# IA     29
# HI     26
# MT     24
# NE     20
# CT     18
# ME     17
# SD     15
# DC     13
# WY     13
# NH     12
# DE     11
# ND      9
# VT      8
# RI      4
# Name: state, dtype: int64

# %%
police
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4582  5038            Jeffrey Michael Gibble  2019-09-16              shot
# 4583  5041                  Kristopher Adams  2019-09-16              shot
# 4584  5066                             TK TK  2019-09-16              shot
# 4585  5032                   Gay Ellen Plack  2019-09-17              shot
# 4586  5034                             TK TK  2019-09-17              shot
# 4587  5043            Scott Gabriel Spangler  2019-09-18              shot
# 4588  5045                 John Emory Sawyer  2019-09-19              shot
# 4589  5044            Jordan Michael Griffin  2019-09-20              shot
# 4590  5058                 Adam Paul English  2019-09-20              shot
# 4591  5049                  Jeffrey Peterson  2019-09-21              shot
# 4592  5050                             TK TK  2019-09-22              shot
# 4593  5046                             TK TK  2019-09-23              shot
# 4594  5047              Jeffery Tyler Aycock  2019-09-23              shot
# 4595  5048                    Charles Nation  2019-09-23              shot
# 4596  5051                   Jarod Lee Smith  2019-09-24              shot
# 4597  5068                    Haywood Cannon  2019-09-24              shot
# 4598  5069            Ronald Michael McCrary  2019-09-24              shot
# 4599  5053                  Daryl Strickland  2019-09-25              shot
# 4600  5067                  Kevin Dudenhefer  2019-09-25  shot and Tasered
# 4601  5052                     Leonard Shand  2019-09-26              shot
# 4602  5054               Chad Willis Huggins  2019-09-26              shot
# 4603  5055                             TK TK  2019-09-26              shot
# 4604  5057                             TK TK  2019-09-26              shot
# 4605  5059                    Haywood Cannon  2019-09-26              shot
# 4606  5063              Jamaal Ramone Taylor  2019-09-28              shot
# 4607  5065                             TK TK  2019-09-28              shot
# 4608  5060                    Dewayne Morgan  2019-09-29  shot and Tasered
# 4609  5061                             TK TK  2019-09-29              shot
# 4610  5062                   Richard Cabrera  2019-09-29              shot
# 4611  5064                  Antonio Williams  2019-09-29              shot
#
#                armed   age gender race             city state  \
# 0                gun  53.0      M    A          shelton    WA
# 1                gun  47.0      M    W            aloha    OR
# 2            unarmed  23.0      M    H          wichita    KS
# 3         toy weapon  32.0      M    W     sanfrancisco    CA
# 4           nail gun  39.0      M    H            evans    CO
# 5                gun  18.0      M    W          guthrie    OK
# 6                gun  22.0      M    H         chandler    AZ
# 7                gun  35.0      M    W          assaria    KS
# 8            unarmed  34.0      F    W       burlington    IA
# 9         toy weapon  47.0      M    B        knoxville    PA
# 10             knife  25.0      M    W         stockton    CA
# 11               gun  31.0      M    B         freeport    TX
# 12             knife  41.0      M    B         columbus    OH
# 13               gun  30.0      M    W        desmoines    IA
# 14               gun  37.0      M    B       neworleans    LA
# 15               NaN  28.0      M    W          huntley    MT
# 16            shovel  42.0      M    W     saltlakecity    UT
# 17           unarmed  36.0      M    B           strong    AR
# 18               gun  49.0      M    W         syracuse    UT
# 19               gun  71.0      M    W          england    AR
# 20               gun  33.0      M    H           elpaso    TX
# 21               gun  39.0      M    W           arcola    IL
# 22               gun  23.0      M    H        southgate    CA
# 23               gun  29.0      M    H    northlasvegas    NV
# 24               gun  34.0      M    W      albuquerque    NM
# 25             knife  43.0      M    W       jourdanton    TX
# 26               NaN  24.0      M    B          st.paul    MN
# 27               NaN  29.0      M    W   franklincounty    MO
# 28               gun  34.0      M    B       chesapeake    VA
# 29             knife  75.0      M    W        oldbridge    NJ
# ...              ...   ...    ...  ...              ...   ...
# 4582             gun  33.0      M    W      elizabethon    TN
# 4583             gun  37.0      M  NaN           sanger    TX
# 4584             gun   NaN      M  NaN          houston    TX
# 4585         hatchet  57.0      F    W         richmond    VA
# 4586         vehicle   NaN      M  NaN           milton    FL
# 4587    undetermined  43.0      M  NaN            salem    OR
# 4588  unknown weapon  74.0      M  NaN       soddydaisy    TN
# 4589      pellet gun  18.0      M  NaN        longbeach    CA
# 4590             gun  21.0      M  NaN      gainesville    GA
# 4591    undetermined  29.0      M  NaN              ada    OK
# 4592             gun  74.0      M    W           austin    TX
# 4593             gun   NaN      M    H       losangeles    CA
# 4594             gun  28.0      M    W      floydcounty    GA
# 4595  unknown weapon  31.0      M  NaN           lowell    AR
# 4596             gun  41.0      M  NaN       huntington    WV
# 4597             gun  67.0      M  NaN        richlands    NC
# 4598           knife  63.0      M  NaN          sanford    NC
# 4599             gun  64.0      M  NaN       hartsville    SC
# 4600             gun  32.0      M    W          lacombe    LA
# 4601           knife  49.0      M    B      hyattsville    MD
# 4602             gun  28.0      M    W  lexingtoncounty    SC
# 4603         vehicle   NaN      M  NaN          lahabra    CA
# 4604             gun   NaN      M  NaN           dallas    TX
# 4605             gun  67.0      M  NaN     jacksonville    NC
# 4606           knife  31.0      M  NaN        baltimore    MD
# 4607             gun   NaN      M  NaN           boston    MA
# 4608             NaN  37.0      M    W         longview    TX
# 4609    undetermined   NaN      M  NaN         monument    CO
# 4610             gun  38.0      M  NaN            miami    FL
# 4611             gun  27.0      M  NaN          newyork    NY
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# 5                       False        attack  Not fleeing        False
# 6                       False        attack          Car        False
# 7                       False        attack  Not fleeing        False
# 8                       False         other  Not fleeing         True
# 9                       False        attack  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 11                      False        attack  Not fleeing        False
# 12                       True         other  Not fleeing        False
# 13                      False        attack          Car        False
# 14                      False        attack         Foot         True
# 15                      False  undetermined  Not fleeing        False
# 16                      False        attack  Not fleeing         True
# 17                      False        attack  Not fleeing        False
# 18                      False        attack  Not fleeing         True
# 19                      False        attack  Not fleeing        False
# 20                      False        attack  Not fleeing        False
# 21                       True        attack  Not fleeing        False
# 22                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 24                      False        attack         Foot         True
# 25                       True         other  Not fleeing        False
# 26                      False        attack  Not fleeing        False
# 27                      False        attack  Not fleeing        False
# 28                       True        attack  Not fleeing        False
# 29                      False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 4582                    False        attack         Foot        False
# 4583                    False        attack         Foot        False
# 4584                    False        attack         Foot        False
# 4585                     True        attack  Not fleeing         True
# 4586                    False        attack          Car        False
# 4587                    False        attack  Not fleeing        False
# 4588                     True         other  Not fleeing        False
# 4589                    False        attack  Not fleeing        False
# 4590                    False        attack  Not fleeing         True
# 4591                    False        attack  Not fleeing        False
# 4592                    False        attack  Not fleeing        False
# 4593                    False         other          NaN        False
# 4594                    False        attack         Foot        False
# 4595                    False         other  Not fleeing        False
# 4596                    False        attack  Not fleeing        False
# 4597                    False        attack          Car        False
# 4598                    False         other          NaN        False
# 4599                    False        attack  Not fleeing        False
# 4600                     True        attack  Not fleeing        False
# 4601                    False        attack  Not fleeing        False
# 4602                    False        attack        Other        False
# 4603                    False        attack          Car        False
# 4604                    False        attack  Not fleeing        False
# 4605                    False        attack  Not fleeing        False
# 4606                    False        attack         Foot        False
# 4607                    False        attack         Foot        False
# 4608                    False        attack         Foot        False
# 4609                    False        attack  Not fleeing        False
# 4610                    False        attack          NaN        False
# 4611                    False        attack  Not fleeing        False
#
# [4612 rows x 14 columns]

# %%
city_population = pd.read_csv('CityPopulation2000.csv', encoding = "ISO-8859-1")

print(city_population.dtypes) #shows the type of data contained in cells

city_population['Population'] = city_population['Population'].str.replace(r'\(r.*\)', '')#removes anything that has a (r) in it, done to try to clean up data
city_population['City'] = city_population['City'].str.replace(r'\(.*\)', '')#removes anything that has a parenthesis in it, done to try to clean up data
city_population['City'] = city_population['City'].str.replace(r'CDP', '')#removes anything that has a 'CDP' in it, done to try to clean up data
city_population['City'] = city_population['City'].str.replace(r' city', '')#removes anything that has a lowercase spelling of 'city' in it, done to try to clean up data
city_population['City'] = city_population['City'].str.replace(r'\s', '')
city_population['City'] = city_population['City'].str.lower()#makes everthing lowercase, done to try to clean up data
type_dict = {'Geographic Area': 'str', 'City': 'str', 'Population': 'int64'}#done to change population values into an integer

city_population = city_population.astype(type_dict)#done to change population values into an integer

print(city_population.dtypes)

city_population
# Out:
# Geographic Area    object
# City               object
# Population         object
# dtype: object
# Geographic Area    object
# City               object
# Population          int64
# dtype: object
#       Geographic Area                            City  Population
# 0                  AL                          abanda         192
# 1                  AL                       abbeville        2688
# 2                  AL                      adamsville        4522
# 3                  AL                     addisontown         758
# 4                  AL                       akrontown         356
# 5                  AL                       alabaster       30352
# 6                  AL                     albertville       21160
# 7                  AL                   alexandercity       14875
# 8                  AL                      alexandria        3917
# 9                  AL                      aliceville        2486
# 10                 AL                     allgoodtown         622
# 11                 AL                     altoonatown         933
# 12                 AL                       andalusia        9015
# 13                 AL                    andersontown         282
# 14                 AL                        anniston       23106
# 15                 AL                            arab        8050
# 16                 AL                     ardmoretown        1194
# 17                 AL                        argotown        4071
# 18                 AL                      aritontown         764
# 19                 AL                       arleytown         357
# 20                 AL                     ashfordtown        2148
# 21                 AL                     ashlandtown        2037
# 22                 AL                        ashville        2212
# 23                 AL                          athens       21897
# 24                 AL                          atmore       10194
# 25                 AL                         attalla        6048
# 26                 AL                          auburn       53380
# 27                 AL                autaugavilletown         870
# 28                 AL                        avontown         543
# 29                 AL                            axis         757
# ...               ...                             ...         ...
# 29493     Puerto Rico              sanisidrocomunidad        6828
# 29494     Puerto Rico                sanjosécomunidad        2900
# 29495     Puerto Rico               sanjuanzonaurbana      381931
# 29496     Puerto Rico            sanlorenzozonaurbana        8037
# 29497     Puerto Rico          sansebastiánzonaurbana        9622
# 29498     Puerto Rico           santabárbaracomunidad        4622
# 29499     Puerto Rico             santaclaracomunidad         982
# 29500     Puerto Rico           santaisabelzonaurbana        5976
# 29501     Puerto Rico           santodomingocomunidad        3156
# 29502     Puerto Rico                 stellacomunidad        1088
# 29503     Puerto Rico                 suárezcomunidad        1931
# 29504     Puerto Rico               tallaboacomunidad         925
# 29505     Puerto Rico           tallaboaaltacomunidad        1816
# 29506     Puerto Rico                  tibescomunidad         362
# 29507     Puerto Rico              tiburonescomunidad        1616
# 29508     Puerto Rico  tierrasnuevasponientecomunidad        3228
# 29509     Puerto Rico               toaaltazonaurbana        3713
# 29510     Puerto Rico               toabajazonaurbana        1513
# 29511     Puerto Rico          trujilloaltozonaurbana       48437
# 29512     Puerto Rico                utuadozonaurbana        8397
# 29513     Puerto Rico                  vayascomunidad         528
# 29514     Puerto Rico                vázquezcomunidad        1890
# 29515     Puerto Rico              vegaaltazonaurbana       10266
# 29516     Puerto Rico              vegabajazonaurbana       25905
# 29517     Puerto Rico                viequescomunidad        3316
# 29518     Puerto Rico               viequeszonaurbana        1938
# 29519     Puerto Rico              villalbazonaurbana        3384
# 29520     Puerto Rico               yabucoazonaurbana        6047
# 29521     Puerto Rico                 yaucozonaurbana       17186
# 29522     Puerto Rico                 yaurelcomunidad        1050
#
# [29523 rows x 3 columns]

# %%
city_population['City'][2710:2720]
# Out:
# 2710          losalamitos
# 2711            losalamos
# 2712             losaltos
# 2713    losaltoshillstown
# 2714           losangeles
# 2715             losbanos
# 2716            losberros
# 2717         losgatostown
# 2718           losmolinos
# 2719            losolivos
# Name: City, dtype: object

# %%
city_population.dtypes
# Out:
# Geographic Area    object
# City               object
# Population          int64
# dtype: object

# %%
grouped_tbl = police.groupby("city").agg(len)
selected_tbl = grouped_tbl[["id"]]
selected_tbl.rename(columns={'id':'kill counts'})
# Out:
#                          kill counts
# city
# 300blockofstatelineroad            1
# abbeville                          1
# aberdeen                           2
# abilene                            2
# abingdon                           2
# abingtontownship                   1
# acworth                            1
# ada                                1
# adamscounty                        3
# addison                            1
# adelanto                           1
# affton                             1
# aguanga                            1
# ahwatukee                          1
# aiea                               1
# aiken                              2
# aitkin                             1
# akron                              6
# alamo                              2
# alamogordo                         2
# alamosa                            2
# albany                             2
# albertlea                          1
# albuquerque                       31
# alderwoodmanor                     1
# aldie                              1
# alexandria                         4
# algomatownship                     1
# alhambra                           1
# aliceville                         1
# ...                              ...
# winterhaven                        1
# winters                            1
# wisecounty                         1
# wolfcreek                          1
# wolfecounty                        1
# woodbridge                         2
# woodcounty                         1
# woodford                           1
# woodlake                           1
# woodland                           1
# woodlawn                           1
# woodstock                          1
# woodville                          2
# wyoming                            2
# wythecounty                        1
# wytheville                         1
# yakima                             4
# yellville                          1
# yonkers                            2
# yorbalinda                         1
# york                               5
# yorkcounty                         2
# youngtown                          1
# yreka                              1
# yubacity                           2
# yuccavalley                        1
# yulee                              1
# yuma                               3
# zanesville                         1
# zion                               2
#
# [2208 rows x 1 columns]

# %%
police[police['city'].str.contains('300')]
# Out:
#         id              name        date manner_of_death  armed   age gender  \
# 2928  3247  Salvador Byassee  2017-12-26            shot  knife  34.0      M
#
#      race                     city state  signs_of_mental_illness  \
# 2928  NaN  300blockofstatelineroad    TN                    False
#
#      threat_level   flee  body_camera
# 2928        other  Other        False

# %%
x=police['city'].value_counts()
print(len(x))
x
# Out:
# 2208
# losangeles          71
# phoenix             69
# houston             47
# lasvegas            41
# sanantonio          36
# columbus            34
# chicago             34
# albuquerque         31
# miami               29
# st.louis            29
# austin              28
# jacksonville        26
# kansascity          26
# denver              26
# oklahomacity        25
# tucson              25
# bakersfield         21
# tulsa               21
# louisville          18
# atlanta             18
# newyork             18
# dallas              17
# mesa                17
# fresno              17
# baltimore           16
# sanjose             16
# indianapolis        16
# portland            16
# orlando             16
# springfield         15
#                     ..
# dilley               1
# kalihi               1
# enid                 1
# castaic              1
# plantcity            1
# brooklet             1
# onalaska             1
# westdesmoines        1
# mt.auburn            1
# napavalley           1
# owingsmills          1
# walterhill           1
# lauderdalecounty     1
# fulton               1
# fallriver            1
# boyleheights         1
# commerce             1
# tyrone               1
# pink                 1
# newboston            1
# cheathamcounty       1
# norwood              1
# oregoncity           1
# brightontownship     1
# glenoma              1
# davidsonville        1
# sheboygan            1
# westchester          1
# pinionhills          1
# lauderdalelakes      1
# Name: city, Length: 2208, dtype: int64

# %%
dict_x=dict(x)

# %%
len(dict_x)
# Out:
# 2208

# %%
next(iter( dict_x.items()))
# Out:
# ('losangeles', 71)

# %%
list(dict_x.items())[0][1]
# Out:
# 71

# %%
'changes the numbers in the dictionary into a list with the number inside, allows me to add the state the shooting took place in to the kill count'
def change_key_values_to_list(dic):
    dic_lst=list(dic.items())
    for i in range(len(dic_lst)):
        number= dic_lst[i][1]
        lst_with_number=[number]
        dic[dic_lst[i][0]]=lst_with_number

change_key_values_to_list(dict_x)

print(len(dict_x))

dict_x
# Out:
# 2208
# {'losangeles': [71],
#  'phoenix': [69],
#  'houston': [47],
#  'lasvegas': [41],
#  'sanantonio': [36],
#  'columbus': [34],
#  'chicago': [34],
#  'albuquerque': [31],
#  'miami': [29],
#  'st.louis': [29],
#  'austin': [28],
#  'jacksonville': [26],
#  'kansascity': [26],
#  'denver': [26],
#  'oklahomacity': [25],
#  'tucson': [25],
#  'bakersfield': [21],
#  'tulsa': [21],
#  'louisville': [18],
#  'atlanta': [18],
#  'newyork': [18],
#  'dallas': [17],
#  'mesa': [17],
#  'fresno': [17],
#  'baltimore': [16],
#  'sanjose': [16],
#  'indianapolis': [16],
#  'portland': [16],
#  'orlando': [16],
#  'springfield': [15],
#  'aurora': [15],
#  'arlington': [15],
#  'charlotte': [15],
#  'sanfrancisco': [15],
#  'coloradosprings': [15],
#  'washington': [15],
#  'fortworth': [14],
#  'memphis': [14],
#  'philadelphia': [14],
#  'longbeach': [14],
#  'sandiego': [14],
#  'pueblo': [12],
#  'elpaso': [11],
#  'seattle': [11],
#  'westminster': [11],
#  'saltlakecity': [11],
#  'spokane': [11],
#  'stockton': [11],
#  'jackson': [11],
#  'reno': [11],
#  'milwaukee': [11],
#  'sacramento': [10],
#  'omaha': [10],
#  'richmond': [10],
#  'tacoma': [10],
#  'lascruces': [10],
#  'glendale': [10],
#  'batonrouge': [10],
#  'honolulu': [10],
#  'greenville': [10],
#  'santaana': [10],
#  'sanbernardino': [10],
#  'neworleans': [9],
#  'lakewood': [9],
#  'st.paul': [9],
#  'wichita': [9],
#  'fairbanks': [9],
#  'anaheim': [9],
#  'shreveport': [9],
#  'newark': [9],
#  'oakland': [9],
#  'flagstaff': [9],
#  'huntsville': [9],
#  'amarillo': [9],
#  'tampa': [9],
#  'clinton': [9],
#  'billings': [9],
#  'anchorage': [9],
#  'detroit': [9],
#  'birmingham': [8],
#  'modesto': [8],
#  'longview': [8],
#  'redding': [8],
#  'wilmington': [8],
#  'vancouver': [8],
#  'boston': [8],
#  'tempe': [8],
#  'lancaster': [8],
#  'clarksville': [7],
#  'charleston': [7],
#  'cincinnati': [7],
#  'boise': [7],
#  'nashville': [7],
#  'odessa': [7],
#  'hemet': [7],
#  'littlerock': [7],
#  'durham': [7],
#  'norfolk': [7],
#  'lakeland': [7],
#  'ontario': [6],
#  'ogden': [6],
#  'auburn': [6],
#  'brooklyn': [6],
#  'garland': [6],
#  'minneapolis': [6],
#  'desmoines': [6],
#  'antioch': [6],
#  'cleveland': [6],
#  'scottsdale': [6],
#  'kent': [6],
#  'kingman': [6],
#  'akron': [6],
#  'midland': [6],
#  'knoxville': [6],
#  'florence': [6],
#  'fontana': [5],
#  'henderson': [5],
#  'beaumont': [5],
#  'centennial': [5],
#  'monroe': [5],
#  'franklin': [5],
#  'montgomery': [5],
#  'fortpierce': [5],
#  'york': [5],
#  'westjordan': [5],
#  'toledo': [5],
#  'casper': [5],
#  'fairfield': [5],
#  'greeley': [5],
#  'gainesville': [5],
#  'chester': [5],
#  'fayetteville': [5],
#  'jurupavalley': [5],
#  'eugene': [5],
#  'riverside': [5],
#  'vannuys': [5],
#  'sparks': [5],
#  'burlington': [5],
#  'gary': [5],
#  'irving': [5],
#  'dayton': [5],
#  'shelbyville': [5],
#  'fremont': [5],
#  'chattanooga': [5],
#  'columbia': [5],
#  'northlasvegas': [4],
#  'sugarcreek': [4],
#  'pittsburgh': [4],
#  'azusa': [4],
#  'hilo': [4],
#  'savannah': [4],
#  'lincoln': [4],
#  'carrollton': [4],
#  'smyrna': [4],
#  'deland': [4],
#  'citrusheights': [4],
#  'inglewood': [4],
#  'beaverton': [4],
#  'phenixcity': [4],
#  'westmemphis': [4],
#  'deltona': [4],
#  'rapidcity': [4],
#  'terrehaute': [4],
#  'virginiabeach': [4],
#  'chickasha': [4],
#  'lynn': [4],
#  'corpuschristi': [4],
#  'farmington': [4],
#  'raleigh': [4],
#  'federalway': [4],
#  'evansville': [4],
#  'kirkland': [4],
#  'princeton': [4],
#  'grandjunction': [4],
#  'brownsville': [4],
#  'trenton': [4],
#  'augusta': [4],
#  'gilbert': [4],
#  'waco': [4],
#  'newcastle': [4],
#  'fortcollins': [4],
#  'englewood': [4],
#  'syracuse': [4],
#  'homewood': [4],
#  'weatherford': [4],
#  'brooksville': [4],
#  'northcharleston': [4],
#  'piedmont': [4],
#  'hamilton': [4],
#  'vineland': [4],
#  'sunnyvale': [4],
#  'boulder': [4],
#  'alexandria': [4],
#  'vallejo': [4],
#  'visalia': [4],
#  'fortwayne': [4],
#  'northglenn': [4],
#  'harrisburg': [4],
#  'buffalo': [4],
#  'miamigardens': [4],
#  'peoria': [4],
#  'buckeye': [4],
#  'medford': [4],
#  'mission': [4],
#  'chico': [4],
#  'laredo': [4],
#  'palmdale': [4],
#  'yakima': [4],
#  'indio': [4],
#  'barstow': [4],
#  'salem': [4],
#  'torrance': [4],
#  'bronx': [4],
#  'napa': [4],
#  'morgantown': [4],
#  'topeka': [4],
#  'gulfport': [4],
#  'pasadena': [4],
#  'eauclaire': [4],
#  'st.joseph': [4],
#  'douglas': [4],
#  'danville': [4],
#  'hollywood': [4],
#  'southgate': [4],
#  'roswell': [4],
#  'marana': [3],
#  'camden': [3],
#  'elkton': [3],
#  'rossville': [3],
#  'landover': [3],
#  'paterson': [3],
#  'bradenton': [3],
#  'mansfield': [3],
#  'wasilla': [3],
#  'troy': [3],
#  'kerrville': [3],
#  'belton': [3],
#  'montpelier': [3],
#  'newton': [3],
#  'homestead': [3],
#  'fairview': [3],
#  'rosebud': [3],
#  'meridian': [3],
#  'manchester': [3],
#  'silverspring': [3],
#  'allentown': [3],
#  'conroe': [3],
#  'carsoncity': [3],
#  'sparta': [3],
#  'hutchinson': [3],
#  'muncie': [3],
#  'lexington': [3],
#  'bend': [3],
#  'delano': [3],
#  'santafe': [3],
#  'reading': [3],
#  'newportnews': [3],
#  'sallisaw': [3],
#  'clearwater': [3],
#  'idahofalls': [3],
#  'covington': [3],
#  'colton': [3],
#  'atwater': [3],
#  'gardena': [3],
#  'spartanburg': [3],
#  'greatfalls': [3],
#  'stillwater': [3],
#  'pensacola': [3],
#  'santaclara': [3],
#  'madison': [3],
#  'edinburg': [3],
#  'cottonwood': [3],
#  'eastpoint': [3],
#  'marion': [3],
#  'southbend': [3],
#  'palmbay': [3],
#  'hanover': [3],
#  'loslunas': [3],
#  'portst.lucie': [3],
#  'jonesboro': [3],
#  'lawton': [3],
#  'huntingtonbeach': [3],
#  'orange': [3],
#  'athens': [3],
#  'st.augustine': [3],
#  'compton': [3],
#  'unioncity': [3],
#  'loveland': [3],
#  'lakeelsinore': [3],
#  'suncity': [3],
#  'valdosta': [3],
#  'mobile': [3],
#  'independence': [3],
#  'bristol': [3],
#  'ceres': [3],
#  'rockford': [3],
#  'victorville': [3],
#  'killeen': [3],
#  'ruidoso': [3],
#  'belleville': [3],
#  'harvey': [3],
#  'atlanticcity': [3],
#  'eagar': [3],
#  'hallandalebeach': [3],
#  'hampton': [3],
#  'st.petersburg': [3],
#  'rochester': [3],
#  'baytown': [3],
#  'springdale': [3],
#  'myrtlebeach': [3],
#  'parker': [3],
#  'cathedralcity': [3],
#  'fullerton': [3],
#  'paris': [3],
#  'whittier': [3],
#  'chandler': [3],
#  'lowell': [3],
#  'yuma': [3],
#  'redlands': [3],
#  'portsmouth': [3],
#  'bexarcounty': [3],
#  'burnsville': [3],
#  'hayward': [3],
#  'madera': [3],
#  'temecula': [3],
#  'avondale': [3],
#  'seaside': [3],
#  'hobbs': [3],
#  'salisbury': [3],
#  'metairie': [3],
#  'artesia': [3],
#  'marietta': [3],
#  'benton': [3],
#  'elizabethtown': [3],
#  'santamaria': [3],
#  'gastonia': [3],
#  'adamscounty': [3],
#  'chino': [3],
#  'cumming': [3],
#  'houma': [3],
#  'clanton': [2],
#  'bolton': [2],
#  'boerne': [2],
#  'st.cloud': [2],
#  'pompanobeach': [2],
#  'hendersonville': [2],
#  'bartlesville': [2],
#  'spanishfork': [2],
#  'roy': [2],
#  'highland': [2],
#  'henrycounty': [2],
#  'southaven': [2],
#  'georgetown': [2],
#  'timberville': [2],
#  'sanfernando': [2],
#  'yubacity': [2],
#  'montebello': [2],
#  'ranchomirage': [2],
#  'springhill': [2],
#  'parma': [2],
#  'hays': [2],
#  'hardeeville': [2],
#  'oakcliff': [2],
#  'whitehaven': [2],
#  'norwich': [2],
#  'floydcounty': [2],
#  'quartzsite': [2],
#  'southsaltlake': [2],
#  'fairoaks': [2],
#  'roanoke': [2],
#  'cobbcounty': [2],
#  'lompoc': [2],
#  'flint': [2],
#  'lenoir': [2],
#  'mcminnville': [2],
#  'easthartford': [2],
#  'churchhill': [2],
#  'sanford': [2],
#  'abingdon': [2],
#  'temple': [2],
#  'nashua': [2],
#  'magnolia': [2],
#  'lealman': [2],
#  'aiken': [2],
#  'taylors': [2],
#  'morris': [2],
#  'pulaski': [2],
#  'chesapeake': [2],
#  'greensboro': [2],
#  'clovis': [2],
#  'hesperia': [2],
#  'azle': [2],
#  'ripon': [2],
#  'aberdeen': [2],
#  'burbank': [2],
#  'sandcity': [2],
#  'thornton': [2],
#  'shelbytownship': [2],
#  'sullivan': [2],
#  'fortwaltonbeach': [2],
#  'dunsmuir': [2],
#  'selma': [2],
#  'llano': [2],
#  'capecoral': [2],
#  'oceanside': [2],
#  'redwoodcity': [2],
#  'greenvillecounty': [2],
#  'thomasville': [2],
#  'emeryville': [2],
#  'edmond': [2],
#  'alamosa': [2],
#  'pleasanton': [2],
#  'shirley': [2],
#  'fortlauderdale': [2],
#  'salinas': [2],
#  'hattiesburg': [2],
#  'fairfax': [2],
#  'risingsun': [2],
#  'eastbatonrouge': [2],
#  'portarthur': [2],
#  'johnsoncity': [2],
#  'lexingtoncounty': [2],
#  'ashland': [2],
#  'bluesprings': [2],
#  'lansing': [2],
#  'hollywoodhills': [2],
#  'buford': [2],
#  'brockton': [2],
#  'wakeforest': [2],
#  'livingston': [2],
#  'bailey': [2],
#  'waterfordtownship': [2],
#  'hallcounty': [2],
#  'klamathfalls': [2],
#  'deerpark': [2],
#  'palmbeachgardens': [2],
#  'austell': [2],
#  'picorivera': [2],
#  'tolleson': [2],
#  'ranchocordova': [2],
#  'soddy-daisy': [2],
#  'fountaininn': [2],
#  'kettering': [2],
#  'carmichael': [2],
#  'hackensack': [2],
#  'royaloak': [2],
#  'carlsbad': [2],
#  'harmony': [2],
#  'leitchfield': [2],
#  'muskogee': [2],
#  'wagoner': [2],
#  'owensboro': [2],
#  'randallstown': [2],
#  'elmonte': [2],
#  'yonkers': [2],
#  'millville': [2],
#  'lakestevens': [2],
#  'pearland': [2],
#  'hopewell': [2],
#  'stonecounty': [2],
#  'quincy': [2],
#  'sylacauga': [2],
#  'yorkcounty': [2],
#  'olathe': [2],
#  'kelso': [2],
#  'dover': [2],
#  'ozark': [2],
#  'joplin': [2],
#  'laramie': [2],
#  'woodbridge': [2],
#  'apachejunction': [2],
#  'appleton': [2],
#  'flatwoods': [2],
#  'allen': [2],
#  'gresham': [2],
#  'puna': [2],
#  'lagrange': [2],
#  'pointloma': [2],
#  'sylmar': [2],
#  'eustis': [2],
#  'douglasville': [2],
#  'metropolis': [2],
#  'aloha': [2],
#  'newiberia': [2],
#  'apex': [2],
#  'madisontownship': [2],
#  'plano': [2],
#  'iuka': [2],
#  'crandon': [2],
#  'pittsburg': [2],
#  'winslow': [2],
#  'brookville': [2],
#  'alamo': [2],
#  'racine': [2],
#  'loganville': [2],
#  'cartersville': [2],
#  'abilene': [2],
#  'franklincounty': [2],
#  'plymouthtownship': [2],
#  'pomona': [2],
#  'olivehurst': [2],
#  'lawrenceburg': [2],
#  'okmulgee': [2],
#  'vacaville': [2],
#  'kalamazoo': [2],
#  'sandsprings': [2],
#  'redbluff': [2],
#  'hoover': [2],
#  'pahrump': [2],
#  'largo': [2],
#  'woodville': [2],
#  'mountainhome': [2],
#  'winchester': [2],
#  'rockville': [2],
#  'catoosa': [2],
#  'spencer': [2],
#  'portage': [2],
#  'tulare': [2],
#  'clackamascounty': [2],
#  'burien': [2],
#  'anderson': [2],
#  'liberty': [2],
#  'spring': [2],
#  'grandforks': [2],
#  'tallahassee': [2],
#  'tarboro': [2],
#  'wauwatosa': [2],
#  'mableton': [2],
#  'biloxi': [2],
#  'chulavista': [2],
#  'riverview': [2],
#  'hardwick': [2],
#  'denton': [2],
#  'greece': [2],
#  'mounthope': [2],
#  'cincoranch': [2],
#  'alpine': [2],
#  'lodi': [2],
#  'prescott': [2],
#  'milton': [2],
#  'elcajon': [2],
#  'davenport': [2],
#  'lakejackson': [2],
#  'walnutcreek': [2],
#  'corning': [2],
#  'roseville': [2],
#  'archdale': [2],
#  'stockbridge': [2],
#  'missoula': [2],
#  'trinidad': [2],
#  'losbanos': [2],
#  'overlandpark': [2],
#  'huntersville': [2],
#  'southlaketahoe': [2],
#  'hudson': [2],
#  'nacogdoches': [2],
#  'hillsboro': [2],
#  'alton': [2],
#  'pawtucket': [2],
#  'morenovalley': [2],
#  'alamogordo': [2],
#  'wellington': [2],
#  'hickory': [2],
#  'clermont': [2],
#  'russellville': [2],
#  'saginaw': [2],
#  'lawndale': [2],
#  'palatka': [2],
#  'scottcounty': [2],
#  'cerritos': [2],
#  'vista': [2],
#  'cocoa': [2],
#  'nampa': [2],
#  'lumberton': [2],
#  'cache': [2],
#  'naples': [2],
#  'bernalillo': [2],
#  'coloradocity': [2],
#  'marysville': [2],
#  'hohenwald': [2],
#  'fairmont': [2],
#  'albany': [2],
#  'kokomo': [2],
#  'lemongrove': [2],
#  'uniontownship': [2],
#  'everett': [2],
#  'fortsmith': [2],
#  'vassalboro': [2],
#  'santaclarita': [2],
#  'portorange': [2],
#  'denhamsprings': [2],
#  'hurst': [2],
#  'lafollette': [2],
#  'sandpoint': [2],
#  "coeurd'alene": [2],
#  'deserthotsprings': [2],
#  'pinellaspark': [2],
#  'parkville': [2],
#  'sanysidro': [2],
#  'darlingtoncounty': [2],
#  'floralcity': [2],
#  'irmo': [2],
#  'dearborn': [2],
#  'jacksoncounty': [2],
#  'helena': [2],
#  'westvalleycity': [2],
#  'millbrook': [2],
#  'eufaula': [2],
#  'norman': [2],
#  'elkhart': [2],
#  'watervalley': [2],
#  'delraybeach': [2],
#  'monroecounty': [2],
#  'orangepark': [2],
#  'stonemountain': [2],
#  'surprise': [2],
#  'ocala': [2],
#  'waukesha': [2],
#  'katy': [2],
#  'forestpark': [2],
#  'sanmarcos': [2],
#  'lenoircity': [2],
#  'evans': [2],
#  'winnparish': [2],
#  'manchestertownship': [2],
#  'morristown': [2],
#  'mcalester': [2],
#  'casagrande': [2],
#  'cheyenne': [2],
#  'webster': [2],
#  'elliscounty': [2],
#  'sedalia': [2],
#  'kentwood': [2],
#  'pinebluff': [2],
#  'zion': [2],
#  'wyoming': [2],
#  'leaguecity': [2],
#  'geneva': [2],
#  'stlouis': [2],
#  'cedarrapids': [2],
#  'guthrie': [2],
#  'spanaway': [2],
#  'elkgrove': [2],
#  'canton': [2],
#  'boone': [2],
#  'lakewales': [2],
#  'presqueisle': [2],
#  'crescentcity': [2],
#  'tahlequah': [2],
#  'oxford': [2],
#  'harrisonburg': [2],
#  'arvada': [2],
#  'tupelo': [2],
#  'rialto': [2],
#  'london': [2],
#  'bassett': [2],
#  'queens': [2],
#  'schertz': [2],
#  'concord': [2],
#  'lemoore': [2],
#  'southelmonte': [2],
#  'pineville': [2],
#  'walton': [2],
#  'euless': [2],
#  'eagan': [2],
#  'terrytown': [2],
#  'kennewick': [2],
#  'beverly': [2],
#  'oldtown': [2],
#  'middletown': [2],
#  'tamarac': [2],
#  'edgewood': [1],
#  'stutsmancounty': [1],
#  'peterborough': [1],
#  'pahoa': [1],
#  'arvonia': [1],
#  'bardstown': [1],
#  'applevalley': [1],
#  'ragley': [1],
#  'charlottte': [1],
#  'westover': [1],
#  'chesterfieldcounty': [1],
#  'ouachitaparish': [1],
#  'chanhassen': [1],
#  'springtown': [1],
#  'newtongrove': [1],
#  'winters': [1],
#  'rocklin': [1],
#  'colby': [1],
#  'richmondheights': [1],
#  'rotterdam': [1],
#  'provo': [1],
#  'macoupincounty': [1],
#  'pemberton': [1],
#  'ramseur': [1],
#  'potsdam': [1],
#  'hindscounty': [1],
#  'navarre': [1],
#  'pikecounty': [1],
#  'washingtoncounty': [1],
#  'nocona': [1],
#  'belleglade': [1],
#  'fortsumner': [1],
#  'frametown': [1],
#  'batesville': [1],
#  'chathamcounty': [1],
#  'neenah': [1],
#  'carson': [1],
#  'spenard': [1],
#  'freeport': [1],
#  'dalton': [1],
#  'immokalee': [1],
#  'dentoncounty': [1],
#  'homer': [1],
#  'winterhaven': [1],
#  'northshore': [1],
#  'ventnor': [1],
#  'gallatin': [1],
#  'holiday': [1],
#  'meadtownship': [1],
#  'byron': [1],
#  'callahan': [1],
#  'byars': [1],
#  'bloomfieldtownship': [1],
#  'claibornecounty': [1],
#  'bushnell': [1],
#  'miltona': [1],
#  'ladylake': [1],
#  'laquinta': [1],
#  'ronda': [1],
#  'elkridge': [1],
#  'poultney': [1],
#  'brooklyncenter': [1],
#  'bullshoals': [1],
#  'lockhart': [1],
#  'sanrafael': [1],
#  'frenchlick': [1],
#  'twinsburg': [1],
#  'tishomingo': [1],
#  'portwentworth': [1],
#  'golden': [1],
#  'lacombe': [1],
#  'waukegan': [1],
#  'soddydaisy': [1],
#  'hurricane': [1],
#  'vadnaisheights': [1],
#  'portallen': [1],
#  'st.tammanyparish': [1],
#  'jesup': [1],
#  'tomball': [1],
#  'monckscorner': [1],
#  'greenbelt': [1],
#  'pattison': [1],
#  'mannford': [1],
#  'westouachita': [1],
#  'lebanon': [1],
#  'pima': [1],
#  'macon': [1],
#  'reynoldsville': [1],
#  'pacificbeach': [1],
#  'brawley': [1],
#  'laporte': [1],
#  'welch': [1],
#  'capecanaveral': [1],
#  'cayce': [1],
#  'swansea': [1],
#  'mauriceriver': [1],
#  "lee'ssummit": [1],
#  'blackfoot': [1],
#  'ft.lauderdale': [1],
#  'huron': [1],
#  'sunridge': [1],
#  'lincolnparish': [1],
#  'southhaven': [1],
#  'harriscounty': [1],
#  'jeffersoncounty': [1],
#  'rowe': [1],
#  'delrio': [1],
#  'peachtreecity': [1],
#  'ashtabula': [1],
#  'irvington': [1],
#  'anniston': [1],
#  'perryville': [1],
#  'northfortcollins': [1],
#  'hensley': [1],
#  'charlestonview': [1],
#  'campbelltown': [1],
#  'leedey': [1],
#  'mountaingrove': [1],
#  'petroleum': [1],
#  'breauxbridge': [1],
#  'sierrablanca': [1],
#  '300blockofstatelineroad': [1],
#  'trosper': [1],
#  'tunbridge': [1],
#  'santee': [1],
#  'bloomington': [1],
#  'glenvalley': [1],
#  'poncacity': [1],
#  'chalmette': [1],
#  'pocatello': [1],
#  'sunrise': [1],
#  'dearbornheights': [1],
#  'keaau': [1],
#  'bangor': [1],
#  'rainbowcity': [1],
#  'campo': [1],
#  'uniontown': [1],
#  'boring': [1],
#  'hummelstown': [1],
#  'sims': [1],
#  'graysoncounty': [1],
#  'newbrunswick': [1],
#  'hawaiiangardens': [1],
#  'elizabethon': [1],
#  'morenci': [1],
#  'culpeper': [1],
#  'cochrancounty': [1],
#  'tatecounty': [1],
#  'fonddulac': [1],
#  'strabantownship': [1],
#  'cheney': [1],
#  'randolphcounty': [1],
#  'orcutt': [1],
#  'goodyear': [1],
#  'littlehavana': [1],
#  'lakeview': [1],
#  'deridder': [1],
#  'emporia': [1],
#  'wales': [1],
#  'penasco': [1],
#  'applecreek': [1],
#  'talladega': [1],
#  'martinez': [1],
#  'cochran': [1],
#  'chinohills': [1],
#  'lakescharles': [1],
#  'longmont': [1],
#  'helena-westhelena': [1],
#  'mosspoint': [1],
#  'bonaire': [1],
#  'decatur': [1],
#  'pinetop-lakeside': [1],
#  'showlow': [1],
#  'kirkwood': [1],
#  'irvine': [1],
#  'morehead': [1],
#  'bunch': [1],
#  'wapato': [1],
#  'eatonrapidstownship': [1],
#  'unioncounty': [1],
#  'whitehall': [1],
#  'plantation': [1],
#  'millerton': [1],
#  'islip': [1],
#  'hixson': [1],
#  'watsonville': [1],
#  'vandalia': [1],
#  'quinlan': [1],
#  'spokanevalley': [1],
#  'leavenworth': [1],
#  'dakotacity': [1],
#  'mannington': [1],
#  'childress': [1],
#  'columbiaheights': [1],
#  'jeffersonville': [1],
#  'tukwila': [1],
#  'downey': [1],
#  'westmonroe': [1],
#  'mountainpine': [1],
#  'gunlock': [1],
#  'kahuku': [1],
#  'buttecounty': [1],
#  'lodgegrass': [1],
#  'nicholasville': [1],
#  'watagua': [1],
#  'paloalto': [1],
#  'glenwood': [1],
#  'parowan': [1],
#  'ansoncounty': [1],
#  'tewksbury': [1],
#  'portst.joe': [1],
#  'beckley': [1],
#  'oldsaybrook': [1],
#  'humboldt': [1],
#  'jamaica': [1],
#  'osteen': [1],
#  'charlottesville': [1],
#  'northeast': [1],
#  'wimberley': [1],
#  'polkcounty': [1],
#  'villapark': [1],
#  'newlondon': [1],
#  'kendalelakes': [1],
#  'peachland': [1],
#  'richtonpark': [1],
#  'anadarko': [1],
#  'eclectic': [1],
#  'mckinney': [1],
#  'aguanga': [1],
#  'maricopa': [1],
#  'elko': [1],
#  'venice': [1],
#  'brownstown': [1],
#  'blackriverfalls': [1],
#  'barbourville': [1],
#  'dundalk': [1],
#  'bisbee': [1],
#  'myra': [1],
#  'waynecounty': [1],
#  'manatee': [1],
#  'fallschurch': [1],
#  'wilderville': [1],
#  'waldoboro': [1],
#  'chinle': [1],
#  'nikolaevsk': [1],
#  'bossiercity': [1],
#  'grandprairie': [1],
#  'monahans': [1],
#  'gunnisoncounty': [1],
#  'sneads': [1],
#  'jasper': [1],
#  'horseheads': [1],
#  'chestertown': [1],
#  'indiantown': [1],
#  'larimercounty': [1],
#  'pittsfield': [1],
#  'sanger': [1],
#  'wasco': [1],
#  'weymouth': [1],
#  'rector': [1],
#  'hopkinscounty': [1],
#  'mercury': [1],
#  'belgrade': [1],
#  'palermo': [1],
#  'rockledge': [1],
#  'dearborncounty': [1],
#  'pocahontascounty': [1],
#  'newpaltz': [1],
#  'eaststroudsburg': [1],
#  'lauderhill': [1],
#  'panoramacity': [1],
#  'blackmantownship': [1],
#  'christiancounty': [1],
#  'grenada': [1],
#  'catotownship': [1],
#  'olympia': [1],
#  'aragonite': [1],
#  'elsereno': [1],
#  'lawtey': [1],
#  'simpsonville': [1],
#  'fairborn': [1],
#  'uniongrove': [1],
#  'oneida': [1],
#  'wausau': [1],
#  'orangecity': [1],
#  'lyndhurst': [1],
#  'sancarlospark': [1],
#  'tremont': [1],
#  'tustin': [1],
#  'tehachapi': [1],
#  'overlea': [1],
#  'formosa': [1],
#  'idealbeach': [1],
#  'bellville': [1],
#  'easthollywood': [1],
#  'rangley': [1],
#  'coralsprings': [1],
#  'wythecounty': [1],
#  'greenecounty': [1],
#  'kinston': [1],
#  'paulden': [1],
#  'farmersbranch': [1],
#  'scarbo': [1],
#  'taunton': [1],
#  'burnet': [1],
#  'ohatchee': [1],
#  'rifle': [1],
#  'amity': [1],
#  'oilsprings': [1],
#  'oaks': [1],
#  'kingsland': [1],
#  'coalcounty': [1],
#  'lynchburg': [1],
#  'enoree': [1],
#  'gilroy': [1],
#  'poplarbluff': [1],
#  'dadeville': [1],
#  'mandeville': [1],
#  'hammond': [1],
#  'newalbany': [1],
#  'wilhoit': [1],
#  'eatoncounty': [1],
#  'lewistown': [1],
#  'wallawalla': [1],
#  'gonzalescounty': [1],
#  'oldbridge': [1],
#  'windsor': [1],
#  'camarillo': [1],
#  'grandprarie': [1],
#  ...}

# %%
city_state=police[['city','state']]
city_state
# Out:
#                  city state
# 0             shelton    WA
# 1               aloha    OR
# 2             wichita    KS
# 3        sanfrancisco    CA
# 4               evans    CO
# 5             guthrie    OK
# 6            chandler    AZ
# 7             assaria    KS
# 8          burlington    IA
# 9           knoxville    PA
# 10           stockton    CA
# 11           freeport    TX
# 12           columbus    OH
# 13          desmoines    IA
# 14         neworleans    LA
# 15            huntley    MT
# 16       saltlakecity    UT
# 17             strong    AR
# 18           syracuse    UT
# 19            england    AR
# 20             elpaso    TX
# 21             arcola    IL
# 22          southgate    CA
# 23      northlasvegas    NV
# 24        albuquerque    NM
# 25         jourdanton    TX
# 26            st.paul    MN
# 27     franklincounty    MO
# 28         chesapeake    VA
# 29          oldbridge    NJ
# ...               ...   ...
# 4582      elizabethon    TN
# 4583           sanger    TX
# 4584          houston    TX
# 4585         richmond    VA
# 4586           milton    FL
# 4587            salem    OR
# 4588       soddydaisy    TN
# 4589        longbeach    CA
# 4590      gainesville    GA
# 4591              ada    OK
# 4592           austin    TX
# 4593       losangeles    CA
# 4594      floydcounty    GA
# 4595           lowell    AR
# 4596       huntington    WV
# 4597        richlands    NC
# 4598          sanford    NC
# 4599       hartsville    SC
# 4600          lacombe    LA
# 4601      hyattsville    MD
# 4602  lexingtoncounty    SC
# 4603          lahabra    CA
# 4604           dallas    TX
# 4605     jacksonville    NC
# 4606        baltimore    MD
# 4607           boston    MA
# 4608         longview    TX
# 4609         monument    CO
# 4610            miami    FL
# 4611          newyork    NY
#
# [4612 rows x 2 columns]

# %%
'prep work on police to add the associated state to the city'
city_state=police[['city','state']]
print(len(city_state))
city_state['city'][0]
city_state_dic={}
for i in range(len(city_state)):
    city_state_dic[city_state['city'][i]]=city_state['state'][i]
print(len(city_state_dic))
list(city_state_dic.items())
# Out:
# 4612
# 2208
# [('shelton', 'WA'),
#  ('aloha', 'OR'),
#  ('wichita', 'KS'),
#  ('sanfrancisco', 'CA'),
#  ('evans', 'CO'),
#  ('guthrie', 'OK'),
#  ('chandler', 'AZ'),
#  ('assaria', 'KS'),
#  ('burlington', 'IA'),
#  ('knoxville', 'TN'),
#  ('stockton', 'CA'),
#  ('freeport', 'TX'),
#  ('columbus', 'OH'),
#  ('desmoines', 'IA'),
#  ('neworleans', 'LA'),
#  ('huntley', 'MT'),
#  ('saltlakecity', 'UT'),
#  ('strong', 'AR'),
#  ('syracuse', 'NY'),
#  ('england', 'AR'),
#  ('elpaso', 'TX'),
#  ('arcola', 'IL'),
#  ('southgate', 'CA'),
#  ('northlasvegas', 'NV'),
#  ('albuquerque', 'NM'),
#  ('jourdanton', 'TX'),
#  ('st.paul', 'MN'),
#  ('franklincounty', 'OH'),
#  ('chesapeake', 'VA'),
#  ('oldbridge', 'NJ'),
#  ('lakejackson', 'TX'),
#  ('draper', 'UT'),
#  ('indianapolis', 'IN'),
#  ('aurora', 'CO'),
#  ('bloomington', 'MN'),
#  ('fairfield', 'TX'),
#  ('evangelineparish', 'LA'),
#  ('mabank', 'TX'),
#  ('fremont', 'CA'),
#  ('muskogee', 'OK'),
#  ('losangeles', 'CA'),
#  ('fortworth', 'TX'),
#  ('maricopa', 'AZ'),
#  ('gunlock', 'KY'),
#  ('weymouth', 'MA'),
#  ('scottsdale', 'AZ'),
#  ('hemet', 'CA'),
#  ('chapeno', 'TX'),
#  ('st.louis', 'MO'),
#  ('derry', 'NH'),
#  ('sierrablanca', 'TX'),
#  ('longview', 'TX'),
#  ('austin', 'TX'),
#  ('fortlauderdale', 'FL'),
#  ('levelland', 'TX'),
#  ('rexburg', 'ID'),
#  ('baltimore', 'MD'),
#  ('pueblo', 'CO'),
#  ('winslow', 'AZ'),
#  ('denver', 'CO'),
#  ('newhope', 'MN'),
#  ('tahoka', 'TX'),
#  ('wasco', 'CA'),
#  ('phoenix', 'AZ'),
#  ('morenci', 'AZ'),
#  ('omaha', 'NE'),
#  ('sunset', 'TX'),
#  ('rosenberg', 'TX'),
#  ('stillwater', 'MN'),
#  ('wyoming', 'MI'),
#  ('billings', 'MT'),
#  ('houston', 'TX'),
#  ('randallstown', 'MD'),
#  ('baycity', 'MI'),
#  ('hummelstown', 'PA'),
#  ('applevalley', 'CA'),
#  ('emeryville', 'CA'),
#  ('antioch', 'CA'),
#  ('douglas', 'AZ'),
#  ('tallahassee', 'FL'),
#  ('orlando', 'FL'),
#  ('tempe', 'AZ'),
#  ('lorena', 'TX'),
#  ('memphis', 'TN'),
#  ('chino', 'CA'),
#  ('oklahomacity', 'OK'),
#  ('calimesa', 'CA'),
#  ('gastonia', 'NC'),
#  ('anchorage', 'AK'),
#  ('newcity', 'NY'),
#  ('orangecounty', 'FL'),
#  ('nocona', 'TX'),
#  ('smyrna', 'TN'),
#  ('dallas', 'TX'),
#  ('pasco', 'WA'),
#  ('whitehaven', 'TN'),
#  ('newcastle', 'IN'),
#  ('sanjose', 'CA'),
#  ('dadeville', 'AL'),
#  ('sanbernardino', 'CA'),
#  ('kansascity', 'KS'),
#  ('reading', 'MA'),
#  ('mclemoresville', 'TN'),
#  ('sanmanuel', 'AZ'),
#  ('essex', 'MD'),
#  ('laredo', 'TX'),
#  ('miamigardens', 'FL'),
#  ('iuka', 'MS'),
#  ('colton', 'CA'),
#  ('marana', 'AZ'),
#  ('boise', 'ID'),
#  ('provo', 'UT'),
#  ('gastoncounty', 'NC'),
#  ('springfield', 'FL'),
#  ('eatonrapidstownship', 'MI'),
#  ('tewksbury', 'MA'),
#  ('delrio', 'TX'),
#  ('charlotte', 'NC'),
#  ('euless', 'TX'),
#  ('homewood', 'AL'),
#  ('birmingham', 'AL'),
#  ('ruidoso', 'NM'),
#  ('palmbay', 'FL'),
#  ('allentown', 'PA'),
#  ('denhamsprings', 'LA'),
#  ('powdersprings', 'GA'),
#  ('clarkesville', 'GA'),
#  ('millbrook', 'AL'),
#  ('greenbay', 'WI'),
#  ('lasvegas', 'NV'),
#  ('terrehaute', 'IN'),
#  ('lakeland', 'FL'),
#  ('gulfport', 'MS'),
#  ('sylvester', 'GA'),
#  ('santaana', 'CA'),
#  ('pelzer', 'SC'),
#  ('roxandtownship', 'MI'),
#  ('stlouis', 'MO'),
#  ('tucson', 'AZ'),
#  ('columbia', 'MO'),
#  ('tarboro', 'NC'),
#  ('lapazcounty', 'AZ'),
#  ('barton', 'MS'),
#  ('joilet', 'IL'),
#  ('salisbury', 'NC'),
#  ('deltona', 'FL'),
#  ('milwaukee', 'WI'),
#  ('burbank', 'CA'),
#  ('lincoln', 'CA'),
#  ('putnamhall', 'FL'),
#  ('madison', 'ME'),
#  ('claymont', 'DE'),
#  ('anaheim', 'CA'),
#  ('brevard', 'NC'),
#  ('dinosaur', 'CO'),
#  ('cocoa', 'FL'),
#  ('atlanta', 'GA'),
#  ('batonrouge', 'LA'),
#  ('portwentworth', 'GA'),
#  ('ontario', 'CA'),
#  ('cleveland', 'OH'),
#  ('kingman', 'AZ'),
#  ('bayminette', 'AL'),
#  ('hoover', 'AL'),
#  ('elkton', 'MD'),
#  ('washington', 'DC'),
#  ('fontana', 'CA'),
#  ('walnutcreek', 'CA'),
#  ('napa', 'CA'),
#  ('sanantonio', 'TX'),
#  ('follansbee', 'WV'),
#  ('kenosha', 'WI'),
#  ('ruth', 'MS'),
#  ('onalaska', 'TX'),
#  ('sacramento', 'CA'),
#  ('medford', 'OR'),
#  ('dublin', 'NC'),
#  ('bakersfield', 'CA'),
#  ('glendale', 'AZ'),
#  ('jacksonville', 'NC'),
#  ('sumas', 'WA'),
#  ('lawrencecounty', 'AL'),
#  ('middleton', 'ID'),
#  ('redvalley', 'AZ'),
#  ('coalcounty', 'OK'),
#  ('clarendon', 'NY'),
#  ('harmony', 'TX'),
#  ('cottonwood', 'CA'),
#  ('vallejo', 'CA'),
#  ('portland', 'OR'),
#  ('islip', 'NY'),
#  ('santaclara', 'CA'),
#  ('fonddulac', 'WI'),
#  ('portsmouth', 'VA'),
#  ('johnsonville', 'SC'),
#  ('southlosangeles', 'CA'),
#  ('gardner', 'KS'),
#  ('wilmington', 'DE'),
#  ('encinitas', 'CA'),
#  ('fortpierce', 'FL'),
#  ('webster', 'TX'),
#  ('oxnard', 'CA'),
#  ('fortashby', 'WV'),
#  ('boston', 'MA'),
#  ('jasper', 'OH'),
#  ('elizabethtown', 'KY'),
#  ('eugene', 'OR'),
#  ('bouldercity', 'NV'),
#  ('carollwood', 'FL'),
#  ('baytown', 'TX'),
#  ('fortmeade', 'MD'),
#  ('hawthorne', 'CA'),
#  ('hamilton', 'AL'),
#  ('rockisland', 'IL'),
#  ('metropolis', 'IL'),
#  ('tulsa', 'OK'),
#  ('pineville', 'LA'),
#  ('winchester', 'CA'),
#  ('zion', 'IL'),
#  ('northcharleston', 'SC'),
#  ('orange', 'NJ'),
#  ('edgewood', 'NM'),
#  ('tehachapi', 'CA'),
#  ('harvey', 'IL'),
#  ('jeffersoncounty', 'ID'),
#  ('pottawatomiecounty', 'OK'),
#  ('valdosta', 'GA'),
#  ('sunnyvale', 'CA'),
#  ('kellyville', 'OK'),
#  ('navarre', 'FL'),
#  ('monon', 'IN'),
#  ('strabantownship', 'PA'),
#  ('boilingsprings', 'SC'),
#  ('corning', 'WI'),
#  ('topeka', 'KS'),
#  ('sandsprings', 'OK'),
#  ('salemburg', 'NC'),
#  ('alton', 'IL'),
#  ('desoto', 'TX'),
#  ('jonesboro', 'AR'),
#  ('miami', 'FL'),
#  ('spartanburg', 'SC'),
#  ('cañoncity', 'CO'),
#  ('montclair', 'CA'),
#  ('shafter', 'CA'),
#  ('chicago', 'IL'),
#  ('jennings', 'MO'),
#  ('panamacity', 'FL'),
#  ('wilmore', 'KY'),
#  ('sidney', 'NE'),
#  ('mission', 'TX'),
#  ('trenton', 'NJ'),
#  ('lakewood', 'CO'),
#  ('irmo', 'SC'),
#  ('bisbee', 'AZ'),
#  ('queens', 'NY'),
#  ('eldoradosprings', 'CO'),
#  ('sylmar', 'CA'),
#  ('rufe', 'OK'),
#  ('longbeach', 'CA'),
#  ('windsor', 'CA'),
#  ('trinidad', 'CO'),
#  ('victoria', 'TX'),
#  ('newyork', 'NY'),
#  ('clermont', 'FL'),
#  ('bunch', 'OK'),
#  ('kingscounty', 'CA'),
#  ('fountainvalley', 'CA'),
#  ('detroit', 'MI'),
#  ('mansfield', 'OH'),
#  ('marion', 'AR'),
#  ('chickasha', 'OK'),
#  ('mesa', 'AZ'),
#  ('elkgrove', 'CA'),
#  ('emporia', 'VA'),
#  ('nashville', 'TN'),
#  ('sandiego', 'CA'),
#  ('roosevelt', 'UT'),
#  ('garland', 'TX'),
#  ('chavies', 'KY'),
#  ('kennewick', 'WA'),
#  ('venice', 'CA'),
#  ('southelmonte', 'CA'),
#  ('pulaski', 'VA'),
#  ('wakeforest', 'NC'),
#  ('lawrenceville', 'GA'),
#  ('beacon', 'NY'),
#  ('cerritos', 'CA'),
#  ('kearny', 'AZ'),
#  ('constantia', 'NY'),
#  ('fridley', 'MN'),
#  ('tacoma', 'WA'),
#  ('landover', 'MD'),
#  ('st.augustine', 'FL'),
#  ('honolulu', 'HI'),
#  ('ranchosantamargarita', 'CA'),
#  ('portage', 'IN'),
#  ('rockford', 'IL'),
#  ('st.petersburg', 'FL'),
#  ('arlington', 'TX'),
#  ('cabot', 'AR'),
#  ('grandjunction', 'CO'),
#  ('lancaster', 'PA'),
#  ('green', 'OH'),
#  ('owensboro', 'KY'),
#  ('gillette', 'WY'),
#  ('ft.lauderdale', 'FL'),
#  ('hackensack', 'NJ'),
#  ('charleston', 'WV'),
#  ('somerset', 'PA'),
#  ('sedalia', 'CO'),
#  ('eagar', 'AZ'),
#  ('huntsville', 'AL'),
#  ('snohomish', 'WA'),
#  ('bossiercity', 'LA'),
#  ('idealbeach', 'NJ'),
#  ('edmond', 'OK'),
#  ('rockville', 'MD'),
#  ('alpine', 'CA'),
#  ('northglenn', 'CO'),
#  ('carrollton', 'TX'),
#  ('lyndhurst', 'NJ'),
#  ('okmulgeecounty', 'OK'),
#  ('wilderville', 'OR'),
#  ('palestine', 'TX'),
#  ('greece', 'NY'),
#  ('roslindale', 'MA'),
#  ('azle', 'TX'),
#  ('delano', 'CA'),
#  ('loslunas', 'NM'),
#  ('elliscounty', 'TX'),
#  ('fuqua', 'TX'),
#  ('byram', 'NJ'),
#  ('santamaria', 'CA'),
#  ('morgantown', 'WV'),
#  ('oakland', 'CA'),
#  ('northport', 'FL'),
#  ('watsonsville', 'CA'),
#  ('midland', 'TX'),
#  ('strasburg', 'CO'),
#  ('melbourne', 'FL'),
#  ('woodland', 'WA'),
#  ('beechgrove', 'IN'),
#  ('suncity', 'SC'),
#  ('findlay', 'OH'),
#  ('tomball', 'TX'),
#  ('cincinnati', 'OH'),
#  ('bronx', 'NY'),
#  ('pompanobeach', 'FL'),
#  ('bexarcounty', 'TX'),
#  ('kokomo', 'IN'),
#  ('fortwayne', 'IN'),
#  ('louisville', 'KY'),
#  ('hutchins', 'TX'),
#  ('southlaketahoe', 'CA'),
#  ('visalia', 'CA'),
#  ('woodlake', 'ND'),
#  ('clanton', 'AL'),
#  ('hobbs', 'NM'),
#  ('coneyisland', 'NY'),
#  ('greeley', 'CO'),
#  ('azusa', 'CA'),
#  ('ronda', 'NC'),
#  ('citrusheights', 'CA'),
#  ('augusta', 'GA'),
#  ('pittsburgh', 'PA'),
#  ('hutchinson', 'KS'),
#  ('weatherford', 'TX'),
#  ('yorkcounty', 'PA'),
#  ('owingsmills', 'MD'),
#  ('fresno', 'CA'),
#  ('malone', 'NY'),
#  ('tahlequah', 'OK'),
#  ('edinburg', 'TX'),
#  ('franklin', 'NC'),
#  ('mcminnville', 'TN'),
#  ('josephinecounty', 'OR'),
#  ('brockton', 'MA'),
#  ('meadowbridge', 'WV'),
#  ('westcovina', 'CA'),
#  ('camden', 'NJ'),
#  ('miamibeach', 'FL'),
#  ('morristown', 'TN'),
#  ('newportnews', 'VA'),
#  ('henderson', 'NV'),
#  ('pleasanton', 'CA'),
#  ('hawaiiangardens', 'CA'),
#  ('bath', 'NH'),
#  ('atwater', 'CA'),
#  ('atlanticcity', 'NJ'),
#  ('sugarcreek', 'OH'),
#  ('beaverton', 'OR'),
#  ('ashecounty', 'NC'),
#  ('parowan', 'UT'),
#  ('bouldercreek', 'CA'),
#  ('covington', 'GA'),
#  ('olivehurst', 'CA'),
#  ('plantation', 'FL'),
#  ('riverforest', 'IL'),
#  ('casper', 'WY'),
#  ('stonemountain', 'GA'),
#  ('dunsmuir', 'CA'),
#  ('lynn', 'MA'),
#  ('mascotte', 'FL'),
#  ('southington', 'OH'),
#  ('morenovalley', 'CA'),
#  ('wauwatosa', 'WI'),
#  ('homestead', 'FL'),
#  ('chattanooga', 'TN'),
#  ('cheyenne', 'WY'),
#  ('opp', 'AL'),
#  ('seattle', 'WA'),
#  ('needles', 'CA'),
#  ('brownsville', 'TX'),
#  ('fortcollins', 'CO'),
#  ('colby', 'KS'),
#  ('mt.auburn', 'OH'),
#  ('winnie', 'TX'),
#  ('white', 'GA'),
#  ('oaklandpark', 'FL'),
#  ('jesup', 'GA'),
#  ('monroe', 'GA'),
#  ('philadelphia', 'PA'),
#  ('dayton', 'OH'),
#  ('plymouth', 'MN'),
#  ('myrtlebeach', 'SC'),
#  ('meadowvista', 'CA'),
#  ('studiocity', 'CA'),
#  ('pinnacle', 'NC'),
#  ('decatur', 'GA'),
#  ('micanopy', 'FL'),
#  ('shreveport', 'LA'),
#  ('seneca', 'SC'),
#  ('houma', 'LA'),
#  ('boulder', 'CO'),
#  ('manila', 'AR'),
#  ('lascruces', 'NM'),
#  ('logan', 'UT'),
#  ('gardnervilleranchos', 'NV'),
#  ('whittier', 'CA'),
#  ('roswell', 'GA'),
#  ('nitro', 'WV'),
#  ('campbelltown', 'PA'),
#  ('powhatancounty', 'VA'),
#  ('muncie', 'IN'),
#  ('sandiegocounty', 'CA'),
#  ('rantoul', 'IL'),
#  ('greenfield', 'WI'),
#  ('maui', 'HI'),
#  ('richmond', 'VA'),
#  ('elsmere', 'KY'),
#  ('superior', 'MT'),
#  ('greenville', 'NC'),
#  ('brookshire', 'TX'),
#  ('summerville', 'SC'),
#  ('spokane', 'WA'),
#  ('ardmore', 'OK'),
#  ('pittston', 'PA'),
#  ('gilbert', 'AZ'),
#  ('sandpoint', 'ID'),
#  ('waco', 'TX'),
#  ('odessa', 'TX'),
#  ('toledo', 'OH'),
#  ('statenisland', 'NY'),
#  ('boerne', 'TX'),
#  ('districtheights', 'MD'),
#  ('bolton', 'VT'),
#  ('hanover', 'CO'),
#  ('inyokern', 'CA'),
#  ('carsoncity', 'NV'),
#  ('kerrville', 'TX'),
#  ('bloomfieldtownship', 'MI'),
#  ('hunters', 'WA'),
#  ('canton', 'OH'),
#  ('beverly', 'MA'),
#  ('tuscaloosa', 'AL'),
#  ('grapeview', 'WA'),
#  ('northeast', 'MD'),
#  ('cohasset', 'MN'),
#  ('troy', 'MI'),
#  ('kinggeorge', 'VA'),
#  ('arab', 'AL'),
#  ('bricktownship', 'NJ'),
#  ('archdale', 'NC'),
#  ('santafe', 'NM'),
#  ('westchester', 'PA'),
#  ('thonotosassa', 'FL'),
#  ('hendersonville', 'NC'),
#  ('westjordan', 'UT'),
#  ('spanishfork', 'UT'),
#  ('mountvernon', 'NY'),
#  ('cushing', 'OK'),
#  ('loveland', 'CO'),
#  ('bluefield', 'WV'),
#  ('twinsburg', 'OH'),
#  ('artesia', 'CA'),
#  ('prescott', 'AZ'),
#  ('mitchell', 'SD'),
#  ('frenchlick', 'IN'),
#  ('weitchpec', 'CA'),
#  ('springtown', 'TX'),
#  ('merrimack', 'NH'),
#  ('durham', 'NC'),
#  ('virginiabeach', 'VA'),
#  ('littlehavana', 'FL'),
#  ('fairbanks', 'AK'),
#  ('ashwaubenon', 'WI'),
#  ('elmonte', 'CA'),
#  ('potsdam', 'NY'),
#  ('lodi', 'CA'),
#  ('downey', 'CA'),
#  ('chester', 'SC'),
#  ('broomfield', 'CO'),
#  ('sylacauga', 'AL'),
#  ('westknox', 'TN'),
#  ('wellman', 'IA'),
#  ('mcalester', 'OK'),
#  ('clute', 'TX'),
#  ('princeton', 'NJ'),
#  ('barstow', 'CA'),
#  ('chalmette', 'LA'),
#  ('panoramacity', 'CA'),
#  ('alexandria', 'VA'),
#  ('lead', 'SD'),
#  ('brodhead', 'KY'),
#  ('dickson', 'TN'),
#  ('slidell', 'LA'),
#  ('washingtoncounty', 'AL'),
#  ('harrisonburg', 'VA'),
#  ('shelbyville', 'TX'),
#  ('sandcity', 'CA'),
#  ('paris', 'TX'),
#  ('barberville', 'FL'),
#  ('auburndale', 'FL'),
#  ('niceville', 'FL'),
#  ('happyvalley', 'CA'),
#  ('mckinney', 'TX'),
#  ('reisterstown', 'MD'),
#  ('graysoncounty', 'VA'),
#  ('fountain', 'CO'),
#  ('akron', 'OH'),
#  ('wilhoit', 'AZ'),
#  ('lovington', 'NM'),
#  ('rossville', 'GA'),
#  ('ponder', 'TX'),
#  ('sanysidro', 'CA'),
#  ('rapidcity', 'SD'),
#  ('mora', 'MN'),
#  ('beckley', 'WV'),
#  ('sierravista', 'AZ'),
#  ('rialto', 'CA'),
#  ('amarillo', 'TX'),
#  ('vannuys', 'CA'),
#  ('muscleshoals', 'AL'),
#  ('hurst', 'IL'),
#  ('woodbridge', 'VA'),
#  ('midwestcity', 'OK'),
#  ('monterey', 'CA'),
#  ('westpalmbeach', 'FL'),
#  ('aguanga', 'CA'),
#  ('oldsaybrook', 'CT'),
#  ('pinionhills', 'CA'),
#  ('catotownship', 'MI'),
#  ('lisle', 'IL'),
#  ('lakescharles', 'LA'),
#  ('taylors', 'SC'),
#  ('westodessa', 'TX'),
#  ('lawton', 'OK'),
#  ('brookhaven', 'MS'),
#  ('cartersville', 'GA'),
#  ('naples', 'ME'),
#  ('indio', 'CA'),
#  ('seaside', 'OR'),
#  ('monroeville', 'AL'),
#  ('parma', 'OH'),
#  ('kirkland', 'WA'),
#  ('valinda', 'CA'),
#  ('barrowcounty', 'GA'),
#  ('modesto', 'CA'),
#  ('york', 'WI'),
#  ('palmbeachgardens', 'FL'),
#  ('truthorconsequences', 'NM'),
#  ('mandeville', 'LA'),
#  ('cedarrapids', 'IA'),
#  ('calexico', 'CA'),
#  ('westgoshen', 'CA'),
#  ('kentwood', 'MI'),
#  ('carmichael', 'CA'),
#  ('pinetop', 'KY'),
#  ('newpaltz', 'NY'),
#  ('highgrove', 'CA'),
#  ('capecoral', 'FL'),
#  ('cathedralcity', 'CA'),
#  ('zanesville', 'OH'),
#  ('paddocklake', 'WI'),
#  ('kenaipeninsula', 'AK'),
#  ('talkingrock', 'GA'),
#  ('frederick', 'MD'),
#  ('tampa', 'FL'),
#  ('savannah', 'GA'),
#  ('pointloma', 'CA'),
#  ('smithville', 'MS'),
#  ('salem', 'OR'),
#  ('hohenwald', 'TN'),
#  ('oldtown', 'ME'),
#  ('burkesville', 'KY'),
#  ('mesquite', 'TX'),
#  ('norwood', 'OK'),
#  ('coloradosprings', 'CO'),
#  ('opelika', 'AL'),
#  ('eureka', 'CA'),
#  ('council', 'ID'),
#  ('marksville', 'LA'),
#  ('merced', 'CA'),
#  ('pacificbeach', 'CA'),
#  ('hominy', 'OK'),
#  ('lakeshire', 'MO'),
#  ('goosecreek', 'SC'),
#  ('wadesboro', 'NC'),
#  ('northlaredo', 'TX'),
#  ('braxtoncounty', 'WV'),
#  ('chico', 'CA'),
#  ('brighton', 'CO'),
#  ('dillon', 'MT'),
#  ('aiken', 'SC'),
#  ('gibsoncounty', 'TN'),
#  ('jurupavalley', 'CA'),
#  ('eden', 'GA'),
#  ('springlake', 'NC'),
#  ('germantown', 'PA'),
#  ('minneapolis', 'MN'),
#  ('leoncounty', 'TX'),
#  ('whitfieldcounty', 'GA'),
#  ('cayce', 'SC'),
#  ('littleeggharbor', 'NJ'),
#  ('opa-locka', 'FL'),
#  ('bentontownship', 'MI'),
#  ('manatee', 'FL'),
#  ('pauldingcounty', 'GA'),
#  ('colbert', 'OK'),
#  ('reno', 'NV'),
#  ('corpuschristi', 'TX'),
#  ('columbiaheights', 'MN'),
#  ('ozark', 'AR'),
#  ('lampe', 'MO'),
#  ('seagoville', 'TX'),
#  ('celina', 'OH'),
#  ('maysville', 'MO'),
#  ('wink', 'TX'),
#  ('bangor', 'ME'),
#  ('norwalk', 'CA'),
#  ('deming', 'NM'),
#  ('bigsprings', 'NE'),
#  ('mountwashington', 'PA'),
#  ('irving', 'TX'),
#  ('neenah', 'WI'),
#  ('richmondheights', 'OH'),
#  ('laramie', 'WY'),
#  ('yonkers', 'NY'),
#  ('leitchfield', 'KY'),
#  ('pryor', 'OK'),
#  ('marina', 'CA'),
#  ('lynwood', 'CA'),
#  ('healdton', 'OK'),
#  ('eaststroudsburg', 'PA'),
#  ('denton', 'TX'),
#  ('thurstoncounty', 'WA'),
#  ('mountainview', 'CO'),
#  ('middleriver', 'MD'),
#  ('humboldt', 'TN'),
#  ('gilroy', 'CA'),
#  ('mounthope', 'WI'),
#  ('camarillo', 'CA'),
#  ('kent', 'WA'),
#  ('northwood', 'OH'),
#  ('taos', 'NM'),
#  ('concord', 'CA'),
#  ('palmdale', 'CA'),
#  ('douglasville', 'GA'),
#  ('breauxbridge', 'LA'),
#  ('canaantownship', 'PA'),
#  ('smartsville', 'CA'),
#  ('ludlow', 'KY'),
#  ('brooksville', 'FL'),
#  ('dearborn', 'MI'),
#  ('winnsboro', 'LA'),
#  ('pride', 'LA'),
#  ('lansing', 'IL'),
#  ('porterville', 'CA'),
#  ('paloalto', 'CA'),
#  ('homedale', 'ID'),
#  ('lucedale', 'MS'),
#  ('suffolk', 'VA'),
#  ('santanella', 'CA'),
#  ('rosemead', 'CA'),
#  ('rawlins', 'WY'),
#  ('livingston', 'TN'),
#  ('maryneal', 'TX'),
#  ('siouxfalls', 'SD'),
#  ('ragley', 'LA'),
#  ('olympia', 'WA'),
#  ('johnsoncity', 'TN'),
#  ('redding', 'CA'),
#  ('ceres', 'CA'),
#  ('upperdarby', 'PA'),
#  ('carrizozo', 'NM'),
#  ('daviesscounty', 'KY'),
#  ('geneva', 'WI'),
#  ('acworth', 'GA'),
#  ('kelso', 'WA'),
#  ('risingsun', 'MD'),
#  ('sanfernando', 'CA'),
#  ('penntownship', 'PA'),
#  ('spenard', 'AK'),
#  ('norfolk', 'VA'),
#  ('sevierville', 'TN'),
#  ('cleelum', 'WA'),
#  ('santaclarita', 'CA'),
#  ('elkins', 'WV'),
#  ('southfield', 'MI'),
#  ('hollywoodhills', 'CA'),
#  ('elcajon', 'CA'),
#  ('petroleum', 'WV'),
#  ('belleglade', 'FL'),
#  ('northhills', 'CA'),
#  ('rainbowcity', 'AL'),
#  ('unioncity', 'GA'),
#  ('statesville', 'NC'),
#  ('portbarre', 'LA'),
#  ('meridianville', 'AL'),
#  ('eufaula', 'AL'),
#  ('burns', 'OR'),
#  ('mountainpine', 'AR'),
#  ('latta', 'SC'),
#  ('lenoircity', 'TN'),
#  ('cobbcounty', 'GA'),
#  ('clackamascounty', 'OR'),
#  ('phenixcity', 'AL'),
#  ('wilkinsburg', 'PA'),
#  ('immokalee', 'FL'),
#  ('saginaw', 'MI'),
#  ('newark', 'NJ'),
#  ('ranchocordova', 'CA'),
#  ('schulter', 'OK'),
#  ('ocala', 'FL'),
#  ('rosebud', 'SD'),
#  ('perrytownship', 'OH'),
#  ('hilo', 'HI'),
#  ('milton', 'FL'),
#  ('uniongrove', 'NC'),
#  ('manchester', 'NH'),
#  ('abingdon', 'VA'),
#  ('barrow', 'AK'),
#  ('roseville', 'CA'),
#  ('hendersoncounty', 'TX'),
#  ('maiden', 'NC'),
#  ('urbandale', 'IA'),
#  ('beckville', 'TX'),
#  ('arvonia', 'VA'),
#  ('bradenton', 'FL'),
#  ('jal', 'NM'),
#  ('yorbalinda', 'CA'),
#  ('republic', 'MO'),
#  ('mena', 'AR'),
#  ('commerce', 'GA'),
#  ('ogden', 'UT'),
#  ('elizabethton', 'TN'),
#  ('inglewood', 'CA'),
#  ('fairborn', 'OH'),
#  ('ripon', 'CA'),
#  ('bluesprings', 'MO'),
#  ('bailey', 'NC'),
#  ('easttroy', 'WI'),
#  ('montgomery', 'NY'),
#  ('silversprings', 'NV'),
#  ('hesston', 'KS'),
#  ('roanoke', 'VA'),
#  ('rapidvalley', 'SD'),
#  ('ashville', 'AL'),
#  ('raleigh', 'NC'),
#  ('gautier', 'MS'),
#  ('belair', 'MD'),
#  ('johnstown', 'PA'),
#  ('sims', 'AR'),
#  ('eastbernstadt', 'KY'),
#  ('cheektowaga', 'NY'),
#  ('beaumont', 'CA'),
#  ('bismarck', 'ND'),
#  ('rochester', 'NY'),
#  ('carlsbad', 'NM'),
#  ('biloxi', 'MS'),
#  ('coloradocity', 'CO'),
#  ('rosalia', 'KS'),
#  ('clinton', 'TN'),
#  ('greensboro', 'NC'),
#  ('addison', 'TX'),
#  ('piedmont', 'AL'),
#  ('vancouver', 'WA'),
#  ('russellville', 'AR'),
#  ('evansville', 'IN'),
#  ('florence', 'MS'),
#  ('ansoncounty', 'NC'),
#  ('burnsville', 'NC'),
#  ('byron', 'CA'),
#  ('idahofalls', 'ID'),
#  ('whiteplains', 'KY'),
#  ('hopewell', 'VA'),
#  ('fortlittleton', 'PA'),
#  ('gainesville', 'GA'),
#  ('stamford', 'CT'),
#  ('southgreensburg', 'PA'),
#  ('fredericksburg', 'VA'),
#  ('thornton', 'CO'),
#  ('braintree', 'MA'),
#  ('pawtucket', 'RI'),
#  ('redlands', 'CA'),
#  ('pueblooflaguna', 'NM'),
#  ('lowell', 'AR'),
#  ('grundy', 'VA'),
#  ("lee'ssummit", 'MO'),
#  ('kinston', 'NC'),
#  ('splendora', 'TX'),
#  ('clearlakepark', 'CA'),
#  ('aitkin', 'MN'),
#  ('jackson', 'MI'),
#  ('lockhart', 'TX'),
#  ('raceland', 'LA'),
#  ('maconcounty', 'AL'),
#  ('eauclaire', 'WI'),
#  ('westspringfield', 'MA'),
#  ('oakhill', 'OH'),
#  ('gallatin', 'TN'),
#  ('lakehallie', 'WI'),
#  ('newbrunswick', 'NJ'),
#  ('rotterdam', 'NY'),
#  ('benton', 'AR'),
#  ('noma', 'FL'),
#  ('llano', 'TX'),
#  ('sparta', 'NC'),
#  ('mcpherson', 'KS'),
#  ('lakeelsinore', 'CA'),
#  ('cache', 'OK'),
#  ('vineland', 'NJ'),
#  ('greenbelt', 'MD'),
#  ('mableton', 'GA'),
#  ('perryville', 'AR'),
#  ('everett', 'WA'),
#  ('berne', 'NY'),
#  ('antigo', 'WI'),
#  ('fayetteville', 'NC'),
#  ('eastflatrock', 'NC'),
#  ('kingsbury', 'TX'),
#  ('milcreek', 'UT'),
#  ('westminster', 'CA'),
#  ('wausau', 'WI'),
#  ('alamo', 'TN'),
#  ('burien', 'WA'),
#  ('temecula', 'CA'),
#  ('buffalo', 'NY'),
#  ('gretna', 'LA'),
#  ('weirton', 'WV'),
#  ('lakestevens', 'WA'),
#  ('presqueisle', 'ME'),
#  ('st.martin', 'MS'),
#  ('hogvalley', 'FL'),
#  ('nacogdoches', 'TX'),
#  ('taunton', 'MA'),
#  ('byng', 'OK'),
#  ('boyleheights', 'CA'),
#  ('jacksonsville', 'FL'),
#  ('osteen', 'FL'),
#  ('stockbridge', 'GA'),
#  ('shawneenationalforest', 'IL'),
#  ('riverdale', 'GA'),
#  ('siskiyoucounty', 'CA'),
#  ('sullivan', 'IN'),
#  ('fisty', 'KY'),
#  ('chesterfieldcounty', 'SC'),
#  ('oregoncity', 'OR'),
#  ('flagstaff', 'AZ'),
#  ('hallandalebeach', 'FL'),
#  ('oxford', 'AL'),
#  ('gresham', 'OR'),
#  ('harrisonville', 'MO'),
#  ('washingtonpark', 'IL'),
#  ('solvang', 'CA'),
#  ('sneads', 'FL'),
#  ('socorro', 'NM'),
#  ('eastaboga', 'AL'),
#  ('deland', 'FL'),
#  ('stoneville', 'NC'),
#  ('tualatin', 'OR'),
#  ('bend', 'OR'),
#  ('newnan', 'GA'),
#  ('berea', 'KY'),
#  ('wasilla', 'AK'),
#  ('parker', 'CO'),
#  ('yreka', 'CA'),
#  ('wagoner', 'OK'),
#  ('turlock', 'CA'),
#  ('norman', 'OK'),
#  ('portarthur', 'TX'),
#  ('ishpemingtownship', 'MI'),
#  ('somerton', 'AZ'),
#  ('iredellcounty', 'NC'),
#  ('yakima', 'WA'),
#  ('tupelo', 'MS'),
#  ('maywood', 'CA'),
#  ('eaglemountain', 'UT'),
#  ('hiseville', 'KY'),
#  ('schenectady', 'NY'),
#  ('mobile', 'AL'),
#  ('tiverton', 'RI'),
#  ('chulavista', 'CA'),
#  ('pembine', 'WI'),
#  ('butte', 'MT'),
#  ('montpelier', 'VT'),
#  ('fortwaltonbeach', 'FL'),
#  ('hardeeville', 'SC'),
#  ('lakehavasucity', 'AZ'),
#  ('peterborough', 'NH'),
#  ('lawndale', 'IL'),
#  ('wellington', 'UT'),
#  ('walls', 'MS'),
#  ('bellville', 'TX'),
#  ('belleville', 'IL'),
#  ('paterson', 'NJ'),
#  ('farmington', 'NM'),
#  ('fulshear', 'TX'),
#  ('riverview', 'FL'),
#  ('pinellaspark', 'FL'),
#  ('buckeye', 'AZ'),
#  ('columbiatownship', 'MI'),
#  ('thomaston', 'CT'),
#  ('dolton', 'IL'),
#  ('boone', 'IA'),
#  ('cochran', 'GA'),
#  ('lagunapueblo', 'NM'),
#  ('frederica', 'DE'),
#  ('barbourville', 'KY'),
#  ('ouachitaparish', 'LA'),
#  ('fortmadison', 'IA'),
#  ('parkcounty', 'CO'),
#  ('landrum', 'SC'),
#  ('asheville', 'NC'),
#  ('bristol', 'TN'),
#  ('newiberia', 'LA'),
#  ('fullerton', 'CA'),
#  ('rosser', 'TX'),
#  ('yuma', 'AZ'),
#  ('falconheights', 'MN'),
#  ('rushsprings', 'OK'),
#  ('bell', 'CA'),
#  ('clovis', 'NM'),
#  ('selma', 'CA'),
#  ('brokenbow', 'OK'),
#  ('eastst.louis', 'IL'),
#  ('romulus', 'MI'),
#  ('st.joseph', 'MO'),
#  ('middletown', 'DE'),
#  ('peachland', 'NC'),
#  ('lakeasbury', 'FL'),
#  ('littleeggharbortownship', 'NJ'),
#  ('sheboygan', 'WI'),
#  ('buckhannon', 'WV'),
#  ('gallup', 'NM'),
#  ('pineriver', 'WI'),
#  ('estillsprings', 'TN'),
#  ('metairie', 'LA'),
#  ('malta', 'MT'),
#  ('sparks', 'NV'),
#  ('laquinta', 'CA'),
#  ('compton', 'CA'),
#  ('cityterrace', 'CA'),
#  ('pleasanthill', 'NC'),
#  ('phelps', 'KY'),
#  ('wapato', 'WA'),
#  ('edmund', 'SC'),
#  ('stafford', 'VA'),
#  ('lakecity', 'SC'),
#  ('hammett', 'ID'),
#  ('castaic', 'CA'),
#  ('clearfield', 'UT'),
#  ('scottcounty', 'KY'),
#  ('aldie', 'VA'),
#  ('eastpoint', 'GA'),
#  ('santee', 'CA'),
#  ('beaverdam', 'WI'),
#  ('harrisburg', 'PA'),
#  ('littlemountain', 'SC'),
#  ('wilkesboro', 'NC'),
#  ('georgetown', 'KY'),
#  ('circleville', 'OH'),
#  ('plaquemine', 'LA'),
#  ('tukwila', 'WA'),
#  ('vista', 'CA'),
#  ('hayward', 'CA'),
#  ('fallschurch', 'VA'),
#  ('counce', 'TN'),
#  ('rome', 'OH'),
#  ...]

# %%
list(city_state_dic.items())[5]
# Out:
# ('guthrie', 'OK')

# %%
'prep work to add states'
dic_cs_lst=list(city_state_dic.items())
dic_lst=list(dict_x.items())
dic_lst[0][1]
# Out:
# [71]

# %%
'adding states'
def add_state_to_dictionary(lst_of_dic):
    for i in range(len(lst_of_dic)):
        for x in range(len(dic_cs_lst)):
            if lst_of_dic[i][0] is dic_cs_lst[x][0]:
                lst_of_dic[i][1].append(dic_cs_lst[x][1])
    return lst_of_dic
city_kills_state=add_state_to_dictionary(dic_lst)
city_kills_state
# Out:
# [('losangeles', [71, 'CA']),
#  ('phoenix', [69, 'AZ']),
#  ('houston', [47, 'TX']),
#  ('lasvegas', [41, 'NV']),
#  ('sanantonio', [36, 'TX']),
#  ('columbus', [34, 'OH']),
#  ('chicago', [34, 'IL']),
#  ('albuquerque', [31, 'NM']),
#  ('miami', [29, 'FL']),
#  ('st.louis', [29, 'MO']),
#  ('austin', [28, 'TX']),
#  ('jacksonville', [26, 'NC']),
#  ('kansascity', [26, 'KS']),
#  ('denver', [26, 'CO']),
#  ('oklahomacity', [25, 'OK']),
#  ('tucson', [25, 'AZ']),
#  ('bakersfield', [21, 'CA']),
#  ('tulsa', [21, 'OK']),
#  ('louisville', [18, 'KY']),
#  ('atlanta', [18, 'GA']),
#  ('newyork', [18, 'NY']),
#  ('dallas', [17, 'TX']),
#  ('mesa', [17, 'AZ']),
#  ('fresno', [17, 'CA']),
#  ('baltimore', [16, 'MD']),
#  ('sanjose', [16, 'CA']),
#  ('indianapolis', [16, 'IN']),
#  ('portland', [16, 'OR']),
#  ('orlando', [16, 'FL']),
#  ('springfield', [15, 'FL']),
#  ('aurora', [15, 'CO']),
#  ('arlington', [15, 'TX']),
#  ('charlotte', [15, 'NC']),
#  ('sanfrancisco', [15, 'CA']),
#  ('coloradosprings', [15, 'CO']),
#  ('washington', [15, 'DC']),
#  ('fortworth', [14, 'TX']),
#  ('memphis', [14, 'TN']),
#  ('philadelphia', [14, 'PA']),
#  ('longbeach', [14, 'CA']),
#  ('sandiego', [14, 'CA']),
#  ('pueblo', [12, 'CO']),
#  ('elpaso', [11, 'TX']),
#  ('seattle', [11, 'WA']),
#  ('westminster', [11, 'CA']),
#  ('saltlakecity', [11, 'UT']),
#  ('spokane', [11, 'WA']),
#  ('stockton', [11, 'CA']),
#  ('jackson', [11, 'MI']),
#  ('reno', [11, 'NV']),
#  ('milwaukee', [11, 'WI']),
#  ('sacramento', [10, 'CA']),
#  ('omaha', [10, 'NE']),
#  ('richmond', [10, 'VA']),
#  ('tacoma', [10, 'WA']),
#  ('lascruces', [10, 'NM']),
#  ('glendale', [10, 'AZ']),
#  ('batonrouge', [10, 'LA']),
#  ('honolulu', [10, 'HI']),
#  ('greenville', [10, 'NC']),
#  ('santaana', [10, 'CA']),
#  ('sanbernardino', [10, 'CA']),
#  ('neworleans', [9, 'LA']),
#  ('lakewood', [9, 'CO']),
#  ('st.paul', [9, 'MN']),
#  ('wichita', [9, 'KS']),
#  ('fairbanks', [9, 'AK']),
#  ('anaheim', [9, 'CA']),
#  ('shreveport', [9, 'LA']),
#  ('newark', [9, 'NJ']),
#  ('oakland', [9, 'CA']),
#  ('flagstaff', [9, 'AZ']),
#  ('huntsville', [9, 'AL']),
#  ('amarillo', [9, 'TX']),
#  ('tampa', [9, 'FL']),
#  ('clinton', [9, 'TN']),
#  ('billings', [9, 'MT']),
#  ('anchorage', [9, 'AK']),
#  ('detroit', [9, 'MI']),
#  ('birmingham', [8, 'AL']),
#  ('modesto', [8, 'CA']),
#  ('longview', [8, 'TX']),
#  ('redding', [8, 'CA']),
#  ('wilmington', [8, 'DE']),
#  ('vancouver', [8, 'WA']),
#  ('boston', [8, 'MA']),
#  ('tempe', [8, 'AZ']),
#  ('lancaster', [8, 'PA']),
#  ('clarksville', [7, 'IN']),
#  ('charleston', [7, 'WV']),
#  ('cincinnati', [7, 'OH']),
#  ('boise', [7, 'ID']),
#  ('nashville', [7, 'TN']),
#  ('odessa', [7, 'TX']),
#  ('hemet', [7, 'CA']),
#  ('littlerock', [7, 'AR']),
#  ('durham', [7, 'NC']),
#  ('norfolk', [7, 'VA']),
#  ('lakeland', [7, 'FL']),
#  ('ontario', [6, 'CA']),
#  ('ogden', [6, 'UT']),
#  ('auburn', [6, 'WA']),
#  ('brooklyn', [6, 'OH']),
#  ('garland', [6, 'TX']),
#  ('minneapolis', [6, 'MN']),
#  ('desmoines', [6, 'IA']),
#  ('antioch', [6, 'CA']),
#  ('cleveland', [6, 'OH']),
#  ('scottsdale', [6, 'AZ']),
#  ('kent', [6, 'WA']),
#  ('kingman', [6, 'AZ']),
#  ('akron', [6, 'OH']),
#  ('midland', [6, 'TX']),
#  ('knoxville', [6, 'TN']),
#  ('florence', [6, 'MS']),
#  ('fontana', [5, 'CA']),
#  ('henderson', [5, 'NV']),
#  ('beaumont', [5, 'CA']),
#  ('centennial', [5, 'CO']),
#  ('monroe', [5, 'GA']),
#  ('franklin', [5, 'NC']),
#  ('montgomery', [5, 'NY']),
#  ('fortpierce', [5, 'FL']),
#  ('york', [5, 'WI']),
#  ('westjordan', [5, 'UT']),
#  ('toledo', [5, 'OH']),
#  ('casper', [5, 'WY']),
#  ('fairfield', [5, 'TX']),
#  ('greeley', [5, 'CO']),
#  ('gainesville', [5, 'GA']),
#  ('chester', [5, 'SC']),
#  ('fayetteville', [5, 'NC']),
#  ('jurupavalley', [5, 'CA']),
#  ('eugene', [5, 'OR']),
#  ('riverside', [5, 'CA']),
#  ('vannuys', [5, 'CA']),
#  ('sparks', [5, 'NV']),
#  ('burlington', [5, 'IA']),
#  ('gary', [5, 'IN']),
#  ('irving', [5, 'TX']),
#  ('dayton', [5, 'OH']),
#  ('shelbyville', [5, 'TX']),
#  ('fremont', [5, 'CA']),
#  ('chattanooga', [5, 'TN']),
#  ('columbia', [5, 'MO']),
#  ('northlasvegas', [4, 'NV']),
#  ('sugarcreek', [4, 'OH']),
#  ('pittsburgh', [4, 'PA']),
#  ('azusa', [4, 'CA']),
#  ('hilo', [4, 'HI']),
#  ('savannah', [4, 'GA']),
#  ('lincoln', [4, 'CA']),
#  ('carrollton', [4, 'TX']),
#  ('smyrna', [4, 'TN']),
#  ('deland', [4, 'FL']),
#  ('citrusheights', [4, 'CA']),
#  ('inglewood', [4, 'CA']),
#  ('beaverton', [4, 'OR']),
#  ('phenixcity', [4, 'AL']),
#  ('westmemphis', [4, 'AR']),
#  ('deltona', [4, 'FL']),
#  ('rapidcity', [4, 'SD']),
#  ('terrehaute', [4, 'IN']),
#  ('virginiabeach', [4, 'VA']),
#  ('chickasha', [4, 'OK']),
#  ('lynn', [4, 'MA']),
#  ('corpuschristi', [4, 'TX']),
#  ('farmington', [4, 'NM']),
#  ('raleigh', [4, 'NC']),
#  ('federalway', [4, 'WA']),
#  ('evansville', [4, 'IN']),
#  ('kirkland', [4, 'WA']),
#  ('princeton', [4, 'NJ']),
#  ('grandjunction', [4, 'CO']),
#  ('brownsville', [4, 'TX']),
#  ('trenton', [4, 'NJ']),
#  ('augusta', [4, 'GA']),
#  ('gilbert', [4, 'AZ']),
#  ('waco', [4, 'TX']),
#  ('newcastle', [4, 'IN']),
#  ('fortcollins', [4, 'CO']),
#  ('englewood', [4, 'FL']),
#  ('syracuse', [4, 'NY']),
#  ('homewood', [4, 'AL']),
#  ('weatherford', [4, 'TX']),
#  ('brooksville', [4, 'FL']),
#  ('northcharleston', [4, 'SC']),
#  ('piedmont', [4, 'AL']),
#  ('hamilton', [4, 'AL']),
#  ('vineland', [4, 'NJ']),
#  ('sunnyvale', [4, 'CA']),
#  ('boulder', [4, 'CO']),
#  ('alexandria', [4, 'VA']),
#  ('vallejo', [4, 'CA']),
#  ('visalia', [4, 'CA']),
#  ('fortwayne', [4, 'IN']),
#  ('northglenn', [4, 'CO']),
#  ('harrisburg', [4, 'PA']),
#  ('buffalo', [4, 'NY']),
#  ('miamigardens', [4, 'FL']),
#  ('peoria', [4, 'AZ']),
#  ('buckeye', [4, 'AZ']),
#  ('medford', [4, 'OR']),
#  ('mission', [4, 'TX']),
#  ('chico', [4, 'CA']),
#  ('laredo', [4, 'TX']),
#  ('palmdale', [4, 'CA']),
#  ('yakima', [4, 'WA']),
#  ('indio', [4, 'CA']),
#  ('barstow', [4, 'CA']),
#  ('salem', [4, 'OR']),
#  ('torrance', [4, 'CA']),
#  ('bronx', [4, 'NY']),
#  ('napa', [4, 'CA']),
#  ('morgantown', [4, 'WV']),
#  ('topeka', [4, 'KS']),
#  ('gulfport', [4, 'MS']),
#  ('pasadena', [4, 'CA']),
#  ('eauclaire', [4, 'WI']),
#  ('st.joseph', [4, 'MO']),
#  ('douglas', [4, 'AZ']),
#  ('danville', [4, 'CA']),
#  ('hollywood', [4, 'FL']),
#  ('southgate', [4, 'CA']),
#  ('roswell', [4, 'GA']),
#  ('marana', [3, 'AZ']),
#  ('camden', [3, 'NJ']),
#  ('elkton', [3, 'MD']),
#  ('rossville', [3, 'GA']),
#  ('landover', [3, 'MD']),
#  ('paterson', [3, 'NJ']),
#  ('bradenton', [3, 'FL']),
#  ('mansfield', [3, 'OH']),
#  ('wasilla', [3, 'AK']),
#  ('troy', [3, 'MI']),
#  ('kerrville', [3, 'TX']),
#  ('belton', [3, 'SC']),
#  ('montpelier', [3, 'VT']),
#  ('newton', [3, 'KS']),
#  ('homestead', [3, 'FL']),
#  ('fairview', [3, 'TN']),
#  ('rosebud', [3, 'SD']),
#  ('meridian', [3, 'ID']),
#  ('manchester', [3, 'NH']),
#  ('silverspring', [3, 'MD']),
#  ('allentown', [3, 'PA']),
#  ('conroe', [3, 'TX']),
#  ('carsoncity', [3, 'NV']),
#  ('sparta', [3, 'NC']),
#  ('hutchinson', [3, 'KS']),
#  ('muncie', [3, 'IN']),
#  ('lexington', [3, 'NC']),
#  ('bend', [3, 'OR']),
#  ('delano', [3, 'CA']),
#  ('santafe', [3, 'NM']),
#  ('reading', [3, 'MA']),
#  ('newportnews', [3, 'VA']),
#  ('sallisaw', [3, 'OK']),
#  ('clearwater', [3, 'FL']),
#  ('idahofalls', [3, 'ID']),
#  ('covington', [3, 'GA']),
#  ('colton', [3, 'CA']),
#  ('atwater', [3, 'CA']),
#  ('gardena', [3, 'CA']),
#  ('spartanburg', [3, 'SC']),
#  ('greatfalls', [3, 'MT']),
#  ('stillwater', [3, 'MN']),
#  ('pensacola', [3, 'FL']),
#  ('santaclara', [3, 'CA']),
#  ('madison', [3, 'ME']),
#  ('edinburg', [3, 'TX']),
#  ('cottonwood', [3, 'CA']),
#  ('eastpoint', [3, 'GA']),
#  ('marion', [3, 'AR']),
#  ('southbend', [3, 'IN']),
#  ('palmbay', [3, 'FL']),
#  ('hanover', [3, 'CO']),
#  ('loslunas', [3, 'NM']),
#  ('portst.lucie', [3, 'FL']),
#  ('jonesboro', [3, 'AR']),
#  ('lawton', [3, 'OK']),
#  ('huntingtonbeach', [3, 'CA']),
#  ('orange', [3, 'NJ']),
#  ('athens', [3, 'GA']),
#  ('st.augustine', [3, 'FL']),
#  ('compton', [3, 'CA']),
#  ('unioncity', [3, 'GA']),
#  ('loveland', [3, 'CO']),
#  ('lakeelsinore', [3, 'CA']),
#  ('suncity', [3, 'SC']),
#  ('valdosta', [3, 'GA']),
#  ('mobile', [3, 'AL']),
#  ('independence', [3, 'MO']),
#  ('bristol', [3, 'TN']),
#  ('ceres', [3, 'CA']),
#  ('rockford', [3, 'IL']),
#  ('victorville', [3, 'CA']),
#  ('killeen', [3, 'TX']),
#  ('ruidoso', [3, 'NM']),
#  ('belleville', [3, 'IL']),
#  ('harvey', [3, 'IL']),
#  ('atlanticcity', [3, 'NJ']),
#  ('eagar', [3, 'AZ']),
#  ('hallandalebeach', [3, 'FL']),
#  ('hampton', [3, 'VA']),
#  ('st.petersburg', [3, 'FL']),
#  ('rochester', [3, 'NY']),
#  ('baytown', [3, 'TX']),
#  ('springdale', [3, 'AR']),
#  ('myrtlebeach', [3, 'SC']),
#  ('parker', [3, 'CO']),
#  ('cathedralcity', [3, 'CA']),
#  ('fullerton', [3, 'CA']),
#  ('paris', [3, 'TX']),
#  ('whittier', [3, 'CA']),
#  ('chandler', [3, 'AZ']),
#  ('lowell', [3, 'AR']),
#  ('yuma', [3, 'AZ']),
#  ('redlands', [3, 'CA']),
#  ('portsmouth', [3, 'VA']),
#  ('bexarcounty', [3, 'TX']),
#  ('burnsville', [3, 'NC']),
#  ('hayward', [3, 'CA']),
#  ('madera', [3, 'CA']),
#  ('temecula', [3, 'CA']),
#  ('avondale', [3, 'AZ']),
#  ('seaside', [3, 'OR']),
#  ('hobbs', [3, 'NM']),
#  ('salisbury', [3, 'NC']),
#  ('metairie', [3, 'LA']),
#  ('artesia', [3, 'CA']),
#  ('marietta', [3, 'GA']),
#  ('benton', [3, 'AR']),
#  ('elizabethtown', [3, 'KY']),
#  ('santamaria', [3, 'CA']),
#  ('gastonia', [3, 'NC']),
#  ('adamscounty', [3, 'CO']),
#  ('chino', [3, 'CA']),
#  ('cumming', [3, 'GA']),
#  ('houma', [3, 'LA']),
#  ('clanton', [2, 'AL']),
#  ('bolton', [2, 'VT']),
#  ('boerne', [2, 'TX']),
#  ('st.cloud', [2, 'FL']),
#  ('pompanobeach', [2, 'FL']),
#  ('hendersonville', [2, 'NC']),
#  ('bartlesville', [2, 'OK']),
#  ('spanishfork', [2, 'UT']),
#  ('roy', [2, 'UT']),
#  ('highland', [2, 'CA']),
#  ('henrycounty', [2, 'IN']),
#  ('southaven', [2, 'MS']),
#  ('georgetown', [2, 'KY']),
#  ('timberville', [2, 'VA']),
#  ('sanfernando', [2, 'CA']),
#  ('yubacity', [2, 'CA']),
#  ('montebello', [2, 'CA']),
#  ('ranchomirage', [2, 'CA']),
#  ('springhill', [2, 'FL']),
#  ('parma', [2, 'OH']),
#  ('hays', [2, 'KS']),
#  ('hardeeville', [2, 'SC']),
#  ('oakcliff', [2, 'TX']),
#  ('whitehaven', [2, 'TN']),
#  ('norwich', [2, 'CT']),
#  ('floydcounty', [2, 'GA']),
#  ('quartzsite', [2, 'AZ']),
#  ('southsaltlake', [2, 'UT']),
#  ('fairoaks', [2, 'CA']),
#  ('roanoke', [2, 'VA']),
#  ('cobbcounty', [2, 'GA']),
#  ('lompoc', [2, 'CA']),
#  ('flint', [2, 'MI']),
#  ('lenoir', [2, 'NC']),
#  ('mcminnville', [2, 'TN']),
#  ('easthartford', [2, 'CT']),
#  ('churchhill', [2, 'TN']),
#  ('sanford', [2, 'NC']),
#  ('abingdon', [2, 'VA']),
#  ('temple', [2, 'TX']),
#  ('nashua', [2, 'IA']),
#  ('magnolia', [2, 'AR']),
#  ('lealman', [2, 'FL']),
#  ('aiken', [2, 'SC']),
#  ('taylors', [2, 'SC']),
#  ('morris', [2, 'AL']),
#  ('pulaski', [2, 'VA']),
#  ('chesapeake', [2, 'VA']),
#  ('greensboro', [2, 'NC']),
#  ('clovis', [2, 'NM']),
#  ('hesperia', [2, 'CA']),
#  ('azle', [2, 'TX']),
#  ('ripon', [2, 'CA']),
#  ('aberdeen', [2, 'WA']),
#  ('burbank', [2, 'CA']),
#  ('sandcity', [2, 'CA']),
#  ('thornton', [2, 'CO']),
#  ('shelbytownship', [2, 'MI']),
#  ('sullivan', [2, 'IN']),
#  ('fortwaltonbeach', [2, 'FL']),
#  ('dunsmuir', [2, 'CA']),
#  ('selma', [2, 'CA']),
#  ('llano', [2, 'TX']),
#  ('capecoral', [2, 'FL']),
#  ('oceanside', [2, 'CA']),
#  ('redwoodcity', [2, 'CA']),
#  ('greenvillecounty', [2, 'SC']),
#  ('thomasville', [2, 'NC']),
#  ('emeryville', [2, 'CA']),
#  ('edmond', [2, 'OK']),
#  ('alamosa', [2, 'CO']),
#  ('pleasanton', [2, 'CA']),
#  ('shirley', [2, 'AR']),
#  ('fortlauderdale', [2, 'FL']),
#  ('salinas', [2, 'CA']),
#  ('hattiesburg', [2, 'MS']),
#  ('fairfax', [2, 'VA']),
#  ('risingsun', [2, 'MD']),
#  ('eastbatonrouge', [2, 'LA']),
#  ('portarthur', [2, 'TX']),
#  ('johnsoncity', [2, 'TN']),
#  ('lexingtoncounty', [2, 'SC']),
#  ('ashland', [2, 'WI']),
#  ('bluesprings', [2, 'MO']),
#  ('lansing', [2, 'IL']),
#  ('hollywoodhills', [2, 'CA']),
#  ('buford', [2, 'GA']),
#  ('brockton', [2, 'MA']),
#  ('wakeforest', [2, 'NC']),
#  ('livingston', [2, 'TN']),
#  ('bailey', [2, 'NC']),
#  ('waterfordtownship', [2, 'MI']),
#  ('hallcounty', [2, 'GA']),
#  ('klamathfalls', [2, 'OR']),
#  ('deerpark', [2, 'WA']),
#  ('palmbeachgardens', [2, 'FL']),
#  ('austell', [2, 'GA']),
#  ('picorivera', [2, 'CA']),
#  ('tolleson', [2, 'AZ']),
#  ('ranchocordova', [2, 'CA']),
#  ('soddy-daisy', [2, 'TN']),
#  ('fountaininn', [2, 'SC']),
#  ('kettering', [2, 'OH']),
#  ('carmichael', [2, 'CA']),
#  ('hackensack', [2, 'NJ']),
#  ('royaloak', [2, 'MI']),
#  ('carlsbad', [2, 'NM']),
#  ('harmony', [2, 'TX']),
#  ('leitchfield', [2, 'KY']),
#  ('muskogee', [2, 'OK']),
#  ('wagoner', [2, 'OK']),
#  ('owensboro', [2, 'KY']),
#  ('randallstown', [2, 'MD']),
#  ('elmonte', [2, 'CA']),
#  ('yonkers', [2, 'NY']),
#  ('millville', [2, 'NJ']),
#  ('lakestevens', [2, 'WA']),
#  ('pearland', [2, 'TX']),
#  ('hopewell', [2, 'VA']),
#  ('stonecounty', [2, 'AR']),
#  ('quincy', [2, 'FL']),
#  ('sylacauga', [2, 'AL']),
#  ('yorkcounty', [2, 'PA']),
#  ('olathe', [2, 'KS']),
#  ('kelso', [2, 'WA']),
#  ('dover', [2, 'DE']),
#  ('ozark', [2, 'AR']),
#  ('joplin', [2, 'MO']),
#  ('laramie', [2, 'WY']),
#  ('woodbridge', [2, 'VA']),
#  ('apachejunction', [2, 'AZ']),
#  ('appleton', [2, 'WI']),
#  ('flatwoods', [2, 'KY']),
#  ('allen', [2, 'TX']),
#  ('gresham', [2, 'OR']),
#  ('puna', [2, 'HI']),
#  ('lagrange', [2, 'GA']),
#  ('pointloma', [2, 'CA']),
#  ('sylmar', [2, 'CA']),
#  ('eustis', [2, 'FL']),
#  ('douglasville', [2, 'GA']),
#  ('metropolis', [2, 'IL']),
#  ('aloha', [2, 'OR']),
#  ('newiberia', [2, 'LA']),
#  ('apex', [2, 'NC']),
#  ('madisontownship', [2, 'OH']),
#  ('plano', [2, 'TX']),
#  ('iuka', [2, 'MS']),
#  ('crandon', [2, 'WI']),
#  ('pittsburg', [2, 'CA']),
#  ('winslow', [2, 'AZ']),
#  ('brookville', [2, 'IN']),
#  ('alamo', [2, 'TN']),
#  ('racine', [2, 'WI']),
#  ('loganville', [2, 'GA']),
#  ('cartersville', [2, 'GA']),
#  ('abilene', [2, 'TX']),
#  ('franklincounty', [2, 'OH']),
#  ('plymouthtownship', [2, 'MI']),
#  ('pomona', [2, 'CA']),
#  ('olivehurst', [2, 'CA']),
#  ('lawrenceburg', [2, 'TN']),
#  ('okmulgee', [2, 'OK']),
#  ('vacaville', [2, 'CA']),
#  ('kalamazoo', [2, 'MI']),
#  ('sandsprings', [2, 'OK']),
#  ('redbluff', [2, 'CA']),
#  ('hoover', [2, 'AL']),
#  ('pahrump', [2, 'NV']),
#  ('largo', [2, 'FL']),
#  ('woodville', [2, 'CA']),
#  ('mountainhome', [2, 'ID']),
#  ('winchester', [2, 'CA']),
#  ('rockville', [2, 'MD']),
#  ('catoosa', [2, 'OK']),
#  ('spencer', [2, 'MA']),
#  ('portage', [2, 'IN']),
#  ('tulare', [2, 'CA']),
#  ('clackamascounty', [2, 'OR']),
#  ('burien', [2, 'WA']),
#  ('anderson', [2, 'CA']),
#  ('liberty', [2, 'MO']),
#  ('spring', [2, 'TX']),
#  ('grandforks', [2, 'ND']),
#  ('tallahassee', [2, 'FL']),
#  ('tarboro', [2, 'NC']),
#  ('wauwatosa', [2, 'WI']),
#  ('mableton', [2, 'GA']),
#  ('biloxi', [2, 'MS']),
#  ('chulavista', [2, 'CA']),
#  ('riverview', [2, 'FL']),
#  ('hardwick', [2, 'NJ']),
#  ('denton', [2, 'TX']),
#  ('greece', [2, 'NY']),
#  ('mounthope', [2, 'WI']),
#  ('cincoranch', [2, 'TX']),
#  ('alpine', [2, 'CA']),
#  ('lodi', [2, 'CA']),
#  ('prescott', [2, 'AZ']),
#  ('milton', [2, 'FL']),
#  ('elcajon', [2, 'CA']),
#  ('davenport', [2, 'IA']),
#  ('lakejackson', [2, 'TX']),
#  ('walnutcreek', [2, 'CA']),
#  ('corning', [2, 'WI']),
#  ('roseville', [2, 'CA']),
#  ('archdale', [2, 'NC']),
#  ('stockbridge', [2, 'GA']),
#  ('missoula', [2, 'MT']),
#  ('trinidad', [2, 'CO']),
#  ('losbanos', [2, 'CA']),
#  ('overlandpark', [2, 'KS']),
#  ('huntersville', [2, 'NC']),
#  ('southlaketahoe', [2, 'CA']),
#  ('hudson', [2, 'NC']),
#  ('nacogdoches', [2, 'TX']),
#  ('hillsboro', [2, 'OR']),
#  ('alton', [2, 'IL']),
#  ('pawtucket', [2, 'RI']),
#  ('morenovalley', [2, 'CA']),
#  ('alamogordo', [2, 'NM']),
#  ('wellington', [2, 'UT']),
#  ('hickory', [2, 'NC']),
#  ('clermont', [2, 'FL']),
#  ('russellville', [2, 'AR']),
#  ('saginaw', [2, 'MI']),
#  ('lawndale', [2, 'IL']),
#  ('palatka', [2, 'FL']),
#  ('scottcounty', [2, 'KY']),
#  ('cerritos', [2, 'CA']),
#  ('vista', [2, 'CA']),
#  ('cocoa', [2, 'FL']),
#  ('nampa', [2, 'ID']),
#  ('lumberton', [2, 'MS']),
#  ('cache', [2, 'OK']),
#  ('naples', [2, 'ME']),
#  ('bernalillo', [2, 'NM']),
#  ('coloradocity', [2, 'CO']),
#  ('marysville', [2, 'WA']),
#  ('hohenwald', [2, 'TN']),
#  ('fairmont', [2, 'MN']),
#  ('albany', [2, 'NY']),
#  ('kokomo', [2, 'IN']),
#  ('lemongrove', [2, 'CA']),
#  ('uniontownship', [2, 'MI']),
#  ('everett', [2, 'WA']),
#  ('fortsmith', [2, 'AR']),
#  ('vassalboro', [2, 'ME']),
#  ('santaclarita', [2, 'CA']),
#  ('portorange', [2, 'FL']),
#  ('denhamsprings', [2, 'LA']),
#  ('hurst', [2, 'IL']),
#  ('lafollette', [2, 'TN']),
#  ('sandpoint', [2, 'ID']),
#  ("coeurd'alene", [2, 'ID']),
#  ('deserthotsprings', [2, 'CA']),
#  ('pinellaspark', [2, 'FL']),
#  ('parkville', [2, 'MD']),
#  ('sanysidro', [2, 'CA']),
#  ('darlingtoncounty', [2, 'SC']),
#  ('floralcity', [2, 'FL']),
#  ('irmo', [2, 'SC']),
#  ('dearborn', [2, 'MI']),
#  ('jacksoncounty', [2, 'KY']),
#  ('helena', [2, 'AR']),
#  ('westvalleycity', [2, 'UT']),
#  ('millbrook', [2, 'AL']),
#  ('eufaula', [2, 'AL']),
#  ('norman', [2, 'OK']),
#  ('elkhart', [2, 'IN']),
#  ('watervalley', [2, 'MS']),
#  ('delraybeach', [2, 'FL']),
#  ('monroecounty', [2, 'MS']),
#  ('orangepark', [2, 'FL']),
#  ('stonemountain', [2, 'GA']),
#  ('surprise', [2, 'AZ']),
#  ('ocala', [2, 'FL']),
#  ('waukesha', [2, 'WI']),
#  ('katy', [2, 'TX']),
#  ('forestpark', [2, 'GA']),
#  ('sanmarcos', [2, 'TX']),
#  ('lenoircity', [2, 'TN']),
#  ('evans', [2, 'CO']),
#  ('winnparish', [2, 'LA']),
#  ('manchestertownship', [2, 'PA']),
#  ('morristown', [2, 'TN']),
#  ('mcalester', [2, 'OK']),
#  ('casagrande', [2, 'AZ']),
#  ('cheyenne', [2, 'WY']),
#  ('webster', [2, 'TX']),
#  ('elliscounty', [2, 'TX']),
#  ('sedalia', [2, 'CO']),
#  ('kentwood', [2, 'MI']),
#  ('pinebluff', [2, 'AR']),
#  ('zion', [2, 'IL']),
#  ('wyoming', [2, 'MI']),
#  ('leaguecity', [2, 'TX']),
#  ('geneva', [2, 'WI']),
#  ('stlouis', [2, 'MO']),
#  ('cedarrapids', [2, 'IA']),
#  ('guthrie', [2, 'OK']),
#  ('spanaway', [2, 'WA']),
#  ('elkgrove', [2, 'CA']),
#  ('canton', [2, 'OH']),
#  ('boone', [2, 'IA']),
#  ('lakewales', [2, 'FL']),
#  ('presqueisle', [2, 'ME']),
#  ('crescentcity', [2, 'CA']),
#  ('tahlequah', [2, 'OK']),
#  ('oxford', [2, 'AL']),
#  ('harrisonburg', [2, 'VA']),
#  ('arvada', [2, 'CO']),
#  ('tupelo', [2, 'MS']),
#  ('rialto', [2, 'CA']),
#  ('london', [2, 'KY']),
#  ('bassett', [2, 'VA']),
#  ('queens', [2, 'NY']),
#  ('schertz', [2, 'TX']),
#  ('concord', [2, 'CA']),
#  ('lemoore', [2, 'CA']),
#  ('southelmonte', [2, 'CA']),
#  ('pineville', [2, 'LA']),
#  ('walton', [2, 'WV']),
#  ('euless', [2, 'TX']),
#  ('eagan', [2, 'MN']),
#  ('terrytown', [2, 'LA']),
#  ('kennewick', [2, 'WA']),
#  ('beverly', [2, 'MA']),
#  ('oldtown', [2, 'ME']),
#  ('middletown', [2, 'DE']),
#  ('tamarac', [2, 'FL']),
#  ('edgewood', [1, 'NM']),
#  ('stutsmancounty', [1, 'ND']),
#  ('peterborough', [1, 'NH']),
#  ('pahoa', [1, 'HI']),
#  ('arvonia', [1, 'VA']),
#  ('bardstown', [1, 'KY']),
#  ('applevalley', [1, 'CA']),
#  ('ragley', [1, 'LA']),
#  ('charlottte', [1, 'NC']),
#  ('westover', [1, 'AL']),
#  ('chesterfieldcounty', [1, 'SC']),
#  ('ouachitaparish', [1, 'LA']),
#  ('chanhassen', [1, 'MN']),
#  ('springtown', [1, 'TX']),
#  ('newtongrove', [1, 'NC']),
#  ('winters', [1, 'TX']),
#  ('rocklin', [1, 'CA']),
#  ('colby', [1, 'KS']),
#  ('richmondheights', [1, 'OH']),
#  ('rotterdam', [1, 'NY']),
#  ('provo', [1, 'UT']),
#  ('macoupincounty', [1, 'IL']),
#  ('pemberton', [1, 'NJ']),
#  ('ramseur', [1, 'NC']),
#  ('potsdam', [1, 'NY']),
#  ('hindscounty', [1, 'MS']),
#  ('navarre', [1, 'FL']),
#  ('pikecounty', [1, 'OH']),
#  ('washingtoncounty', [1, 'AL']),
#  ('nocona', [1, 'TX']),
#  ('belleglade', [1, 'FL']),
#  ('fortsumner', [1, 'NM']),
#  ('frametown', [1, 'WV']),
#  ('batesville', [1, 'AR']),
#  ('chathamcounty', [1, 'GA']),
#  ('neenah', [1, 'WI']),
#  ('carson', [1, 'CA']),
#  ('spenard', [1, 'AK']),
#  ('freeport', [1, 'TX']),
#  ('dalton', [1, 'IL']),
#  ('immokalee', [1, 'FL']),
#  ('dentoncounty', [1, 'TX']),
#  ('homer', [1, 'LA']),
#  ('winterhaven', [1, 'FL']),
#  ('northshore', [1, 'HI']),
#  ('ventnor', [1, 'NJ']),
#  ('gallatin', [1, 'TN']),
#  ('holiday', [1, 'FL']),
#  ('meadtownship', [1, 'PA']),
#  ('byron', [1, 'CA']),
#  ('callahan', [1, 'FL']),
#  ('byars', [1, 'OK']),
#  ('bloomfieldtownship', [1, 'MI']),
#  ('claibornecounty', [1, 'TN']),
#  ('bushnell', [1, 'FL']),
#  ('miltona', [1, 'MN']),
#  ('ladylake', [1, 'FL']),
#  ('laquinta', [1, 'CA']),
#  ('ronda', [1, 'NC']),
#  ('elkridge', [1, 'MD']),
#  ('poultney', [1, 'VT']),
#  ('brooklyncenter', [1, 'MN']),
#  ('bullshoals', [1, 'AR']),
#  ('lockhart', [1, 'TX']),
#  ('sanrafael', [1, 'NM']),
#  ('frenchlick', [1, 'IN']),
#  ('twinsburg', [1, 'OH']),
#  ('tishomingo', [1, 'OK']),
#  ('portwentworth', [1, 'GA']),
#  ('golden', [1, 'CO']),
#  ('lacombe', [1, 'LA']),
#  ('waukegan', [1, 'IL']),
#  ('soddydaisy', [1, 'TN']),
#  ('hurricane', [1, 'WV']),
#  ('vadnaisheights', [1, 'MN']),
#  ('portallen', [1, 'LA']),
#  ('st.tammanyparish', [1, 'LA']),
#  ('jesup', [1, 'GA']),
#  ('tomball', [1, 'TX']),
#  ('monckscorner', [1, 'SC']),
#  ('greenbelt', [1, 'MD']),
#  ('pattison', [1, 'TX']),
#  ('mannford', [1, 'OK']),
#  ('westouachita', [1, 'LA']),
#  ('lebanon', [1, 'MO']),
#  ('pima', [1, 'AZ']),
#  ('macon', [1, 'GA']),
#  ('reynoldsville', [1, 'WV']),
#  ('pacificbeach', [1, 'CA']),
#  ('brawley', [1, 'CA']),
#  ('laporte', [1, 'TX']),
#  ('welch', [1, 'WV']),
#  ('capecanaveral', [1, 'FL']),
#  ('cayce', [1, 'SC']),
#  ('swansea', [1, 'SC']),
#  ('mauriceriver', [1, 'NJ']),
#  ("lee'ssummit", [1, 'MO']),
#  ('blackfoot', [1, 'ID']),
#  ('ft.lauderdale', [1, 'FL']),
#  ('huron', [1, 'CA']),
#  ('sunridge', [1, 'NV']),
#  ('lincolnparish', [1, 'LA']),
#  ('southhaven', [1, 'IN']),
#  ('harriscounty', [1, 'TX']),
#  ('jeffersoncounty', [1, 'ID']),
#  ('rowe', [1, 'NM']),
#  ('delrio', [1, 'TX']),
#  ('peachtreecity', [1, 'GA']),
#  ('ashtabula', [1, 'OH']),
#  ('irvington', [1, 'NJ']),
#  ('anniston', [1, 'AL']),
#  ('perryville', [1, 'AR']),
#  ('northfortcollins', [1, 'CO']),
#  ('hensley', [1, 'WV']),
#  ('charlestonview', [1, 'CA']),
#  ('campbelltown', [1, 'PA']),
#  ('leedey', [1, 'OK']),
#  ('mountaingrove', [1, 'MO']),
#  ('petroleum', [1, 'WV']),
#  ('breauxbridge', [1, 'LA']),
#  ('sierrablanca', [1, 'TX']),
#  ('300blockofstatelineroad', [1, 'TN']),
#  ('trosper', [1, 'KY']),
#  ('tunbridge', [1, 'VT']),
#  ('santee', [1, 'CA']),
#  ('bloomington', [1, 'MN']),
#  ('glenvalley', [1, 'CA']),
#  ('poncacity', [1, 'OK']),
#  ('chalmette', [1, 'LA']),
#  ('pocatello', [1, 'ID']),
#  ('sunrise', [1, 'FL']),
#  ('dearbornheights', [1, 'MI']),
#  ('keaau', [1, 'HI']),
#  ('bangor', [1, 'ME']),
#  ('rainbowcity', [1, 'AL']),
#  ('campo', [1, 'CA']),
#  ('uniontown', [1, 'OH']),
#  ('boring', [1, 'OR']),
#  ('hummelstown', [1, 'PA']),
#  ('sims', [1, 'AR']),
#  ('graysoncounty', [1, 'VA']),
#  ('newbrunswick', [1, 'NJ']),
#  ('hawaiiangardens', [1, 'CA']),
#  ('elizabethon', [1, 'TN']),
#  ('morenci', [1, 'AZ']),
#  ('culpeper', [1, 'VA']),
#  ('cochrancounty', [1, 'TX']),
#  ('tatecounty', [1, 'MS']),
#  ('fonddulac', [1, 'WI']),
#  ('strabantownship', [1, 'PA']),
#  ('cheney', [1, 'WA']),
#  ('randolphcounty', [1, 'NC']),
#  ('orcutt', [1, 'CA']),
#  ('goodyear', [1, 'AZ']),
#  ('littlehavana', [1, 'FL']),
#  ('lakeview', [1, 'SC']),
#  ('deridder', [1, 'LA']),
#  ('emporia', [1, 'VA']),
#  ('wales', [1, 'ME']),
#  ('penasco', [1, 'NM']),
#  ('applecreek', [1, 'OH']),
#  ('talladega', [1, 'AL']),
#  ('martinez', [1, 'CA']),
#  ('cochran', [1, 'GA']),
#  ('chinohills', [1, 'CA']),
#  ('lakescharles', [1, 'LA']),
#  ('longmont', [1, 'CO']),
#  ('helena-westhelena', [1, 'AR']),
#  ('mosspoint', [1, 'MS']),
#  ('bonaire', [1, 'GA']),
#  ('decatur', [1, 'GA']),
#  ('pinetop-lakeside', [1, 'AZ']),
#  ('showlow', [1, 'AZ']),
#  ('kirkwood', [1, 'NY']),
#  ('irvine', [1, 'CA']),
#  ('morehead', [1, 'KY']),
#  ('bunch', [1, 'OK']),
#  ('wapato', [1, 'WA']),
#  ('eatonrapidstownship', [1, 'MI']),
#  ('unioncounty', [1, 'SC']),
#  ('whitehall', [1, 'OH']),
#  ('plantation', [1, 'FL']),
#  ('millerton', [1, 'OK']),
#  ('islip', [1, 'NY']),
#  ('hixson', [1, 'TN']),
#  ('watsonville', [1, 'CA']),
#  ('vandalia', [1, 'OH']),
#  ('quinlan', [1, 'TX']),
#  ('spokanevalley', [1, 'WA']),
#  ('leavenworth', [1, 'KS']),
#  ('dakotacity', [1, 'IA']),
#  ('mannington', [1, 'WV']),
#  ('childress', [1, 'TX']),
#  ('columbiaheights', [1, 'MN']),
#  ('jeffersonville', [1, 'OH']),
#  ('tukwila', [1, 'WA']),
#  ('downey', [1, 'CA']),
#  ('westmonroe', [1, 'LA']),
#  ('mountainpine', [1, 'AR']),
#  ('gunlock', [1, 'KY']),
#  ('kahuku', [1, 'HI']),
#  ('buttecounty', [1, 'CA']),
#  ('lodgegrass', [1, 'MT']),
#  ('nicholasville', [1, 'KY']),
#  ('watagua', [1, 'TX']),
#  ('paloalto', [1, 'CA']),
#  ('glenwood', [1, 'GA']),
#  ('parowan', [1, 'UT']),
#  ('ansoncounty', [1, 'NC']),
#  ('tewksbury', [1, 'MA']),
#  ('portst.joe', [1, 'FL']),
#  ('beckley', [1, 'WV']),
#  ('oldsaybrook', [1, 'CT']),
#  ('humboldt', [1, 'TN']),
#  ('jamaica', [1, 'NY']),
#  ('osteen', [1, 'FL']),
#  ('charlottesville', [1, 'VA']),
#  ('northeast', [1, 'MD']),
#  ('wimberley', [1, 'TX']),
#  ('polkcounty', [1, 'OR']),
#  ('villapark', [1, 'IL']),
#  ('newlondon', [1, 'WI']),
#  ('kendalelakes', [1, 'FL']),
#  ('peachland', [1, 'NC']),
#  ('richtonpark', [1, 'IL']),
#  ('anadarko', [1, 'OK']),
#  ('eclectic', [1, 'AL']),
#  ('mckinney', [1, 'TX']),
#  ('aguanga', [1, 'CA']),
#  ('maricopa', [1, 'AZ']),
#  ('elko', [1, 'NV']),
#  ('venice', [1, 'CA']),
#  ('brownstown', [1, 'IN']),
#  ('blackriverfalls', [1, 'WI']),
#  ('barbourville', [1, 'KY']),
#  ('dundalk', [1, 'MD']),
#  ('bisbee', [1, 'AZ']),
#  ('myra', [1, 'TX']),
#  ('waynecounty', [1, 'KY']),
#  ('manatee', [1, 'FL']),
#  ('fallschurch', [1, 'VA']),
#  ('wilderville', [1, 'OR']),
#  ('waldoboro', [1, 'ME']),
#  ('chinle', [1, 'AZ']),
#  ('nikolaevsk', [1, 'AK']),
#  ('bossiercity', [1, 'LA']),
#  ('grandprairie', [1, 'TX']),
#  ('monahans', [1, 'TX']),
#  ('gunnisoncounty', [1, 'CO']),
#  ('sneads', [1, 'FL']),
#  ('jasper', [1, 'OH']),
#  ('horseheads', [1, 'NY']),
#  ('chestertown', [1, 'MD']),
#  ('indiantown', [1, 'FL']),
#  ('larimercounty', [1, 'CO']),
#  ('pittsfield', [1, 'MA']),
#  ('sanger', [1, 'TX']),
#  ('wasco', [1, 'CA']),
#  ('weymouth', [1, 'MA']),
#  ('rector', [1, 'AR']),
#  ('hopkinscounty', [1, 'TX']),
#  ('mercury', [1, 'NV']),
#  ('belgrade', [1, 'ME']),
#  ('palermo', [1, 'CA']),
#  ('rockledge', [1, 'FL']),
#  ('dearborncounty', [1, 'IN']),
#  ('pocahontascounty', [1, 'WV']),
#  ('newpaltz', [1, 'NY']),
#  ('eaststroudsburg', [1, 'PA']),
#  ('lauderhill', [1, 'FL']),
#  ('panoramacity', [1, 'CA']),
#  ('blackmantownship', [1, 'MI']),
#  ('christiancounty', [1, 'KY']),
#  ('grenada', [1, 'MS']),
#  ('catotownship', [1, 'MI']),
#  ('olympia', [1, 'WA']),
#  ('aragonite', [1, 'UT']),
#  ('elsereno', [1, 'CA']),
#  ('lawtey', [1, 'FL']),
#  ('simpsonville', [1, 'SC']),
#  ('fairborn', [1, 'OH']),
#  ('uniongrove', [1, 'NC']),
#  ('oneida', [1, 'TN']),
#  ('wausau', [1, 'WI']),
#  ('orangecity', [1, 'FL']),
#  ('lyndhurst', [1, 'NJ']),
#  ('sancarlospark', [1, 'FL']),
#  ('tremont', [1, 'NY']),
#  ('tustin', [1, 'CA']),
#  ('tehachapi', [1, 'CA']),
#  ('overlea', [1, 'MD']),
#  ('formosa', [1, 'AR']),
#  ('idealbeach', [1, 'NJ']),
#  ('bellville', [1, 'TX']),
#  ('easthollywood', [1, 'CA']),
#  ('rangley', [1, 'CO']),
#  ('coralsprings', [1, 'FL']),
#  ('wythecounty', [1, 'VA']),
#  ('greenecounty', [1, 'MO']),
#  ('kinston', [1, 'NC']),
#  ('paulden', [1, 'AZ']),
#  ('farmersbranch', [1, 'TX']),
#  ('scarbo', [1, 'WV']),
#  ('taunton', [1, 'MA']),
#  ('burnet', [1, 'TX']),
#  ('ohatchee', [1, 'AL']),
#  ('rifle', [1, 'CO']),
#  ('amity', [1, 'OR']),
#  ('oilsprings', [1, 'KY']),
#  ('oaks', [1, 'OK']),
#  ('kingsland', [1, 'GA']),
#  ('coalcounty', [1, 'OK']),
#  ('lynchburg', [1, 'VA']),
#  ('enoree', [1, 'SC']),
#  ('gilroy', [1, 'CA']),
#  ('poplarbluff', [1, 'MO']),
#  ('dadeville', [1, 'AL']),
#  ('mandeville', [1, 'LA']),
#  ('hammond', [1, 'LA']),
#  ('newalbany', [1, 'IN']),
#  ('wilhoit', [1, 'AZ']),
#  ('eatoncounty', [1, 'MI']),
#  ('lewistown', [1, 'PA']),
#  ('wallawalla', [1, 'WA']),
#  ('gonzalescounty', [1, 'TX']),
#  ('oldbridge', [1, 'NJ']),
#  ('windsor', [1, 'CA']),
#  ('camarillo', [1, 'CA']),
#  ('grandprarie', [1, 'TX']),
#  ...]

# %%
len(x)
# Out:
# 2208

# %%
'prepping pop->per capita using data from census'
city_kills_state_list=list(city_kills_state)
city_pop_dic={}
for i in range(len(city_population)):
    city_pop_dic[city_population['City'][i]]=[city_population['Population'][i],city_population['Geographic Area'][i]]
print(len(city_pop_dic))
city_pop_dic_lst=list(city_pop_dic.items())
city_pop_dic_lst
# Out:
# 22748
# [('abanda', [192, 'AL']),
#  ('abbeville', [5237, 'SC']),
#  ('adamsville', [67, 'PA']),
#  ('addisontown', [776, 'WV']),
#  ('akrontown', [1167, 'IN']),
#  ('alabaster', [30352, 'AL']),
#  ('albertville', [7044, 'MN']),
#  ('alexandercity', [14875, 'AL']),
#  ('alexandria', [139966, 'VA']),
#  ('aliceville', [2486, 'AL']),
#  ('allgoodtown', [622, 'AL']),
#  ('altoonatown', [933, 'AL']),
#  ('andalusia', [9015, 'AL']),
#  ('andersontown', [282, 'AL']),
#  ('anniston', [23106, 'AL']),
#  ('arab', [8050, 'AL']),
#  ('ardmoretown', [1194, 'AL']),
#  ('argotown', [4071, 'AL']),
#  ('aritontown', [764, 'AL']),
#  ('arleytown', [357, 'AL']),
#  ('ashfordtown', [2148, 'AL']),
#  ('ashlandtown', [7225, 'VA']),
#  ('ashville', [2212, 'AL']),
#  ('athens', [12710, 'TX']),
#  ('atmore', [10194, 'AL']),
#  ('attalla', [6048, 'AL']),
#  ('auburn', [328, 'WY']),
#  ('autaugavilletown', [870, 'AL']),
#  ('avontown', [12446, 'IN']),
#  ('axis', [757, 'AL']),
#  ('babbietown', [603, 'AL']),
#  ('baileytontown', [431, 'TN']),
#  ('bakerhilltown', [279, 'AL']),
#  ('ballplay', [1580, 'AL']),
#  ('bankstown', [124, 'AR']),
#  ('bayminette', [8044, 'AL']),
#  ('bayoulabatre', [2558, 'AL']),
#  ('bearcreektown', [79, 'MT']),
#  ('beatricetown', [301, 'AL']),
#  ('beavertontown', [201, 'AL']),
#  ('belgreen', [129, 'AL']),
#  ('belktown', [215, 'AL']),
#  ('bellamy', [543, 'AL']),
#  ('bellefontaine', [13370, 'OH']),
#  ('bentontown', [1385, 'TN']),
#  ('berrytown', [1148, 'AL']),
#  ('bessemer', [1905, 'MI']),
#  ('billingsleytown', [144, 'AL']),
#  ('birmingham', [20103, 'MI']),
#  ('blacktown', [207, 'AL']),
#  ('blountsvilletown', [134, 'IN']),
#  ('blueridge', [3084, 'VA']),
#  ('bluespringstown', [96, 'AL']),
#  ('boaz', [1297, 'WV']),
#  ('boligeetown', [328, 'AL']),
#  ('bonairtown', [116, 'AL']),
#  ('boykin', [100, 'SC']),
#  ('brantleytown', [809, 'AL']),
#  ('brantleyville', [884, 'AL']),
#  ('brent', [716, 'OK']),
#  ('brewton', [5408, 'AL']),
#  ('bridgeport', [8149, 'WV']),
#  ('brighton', [36609, 'NY']),
#  ('brillianttown', [900, 'AL']),
#  ('bristowcove', [683, 'AL']),
#  ('brookhighland', [6746, 'AL']),
#  ('brooksidetown', [233, 'CO']),
#  ('brookwoodtown', [1828, 'AL']),
#  ('broomtown', [182, 'AL']),
#  ('brundidge', [2076, 'AL']),
#  ('bucks', [32, 'AL']),
#  ('butlertown', [17, 'SD']),
#  ('calera', [11620, 'AL']),
#  ('calvert', [1192, 'TX']),
#  ('camden', [3582, 'TN']),
#  ('camphilltown', [1014, 'AL']),
#  ('carbonhill', [233, 'OH']),
#  ('cardifftown', [55, 'AL']),
#  ('carlisle-rockledge', [2137, 'AL']),
#  ('carlton', [2007, 'OR']),
#  ('carolinatown', [297, 'AL']),
#  ('carrolltontown', [190, 'MS']),
#  ('castleberrytown', [583, 'AL']),
#  ('catherine', [228, 'CO']),
#  ('cedarblufftown', [1137, 'VA']),
#  ('centerpoint', [492, 'LA']),
#  ('centre', [3489, 'AL']),
#  ('centreville', [71135, 'VA']),
#  ('chatomtown', [1288, 'AL']),
#  ('chelsea', [113, 'WI']),
#  ('cherokeetown', [1048, 'AL']),
#  ('chickasaw', [6106, 'AL']),
#  ('childersburg', [5175, 'AL']),
#  ('choccolocco', [2804, 'AL']),
#  ('chunchula', [210, 'AL']),
#  ('citronelle', [3905, 'AL']),
#  ('clanton', [8619, 'AL']),
#  ('clay', [1559, 'PA']),
#  ('clayhatcheetown', [589, 'AL']),
#  ('claytontown', [821, 'OK']),
#  ('clevelandtown', [202, 'VA']),
#  ('clio', [2646, 'MI']),
#  ('coalingtown', [1657, 'AL']),
#  ('coatsbend', [1394, 'AL']),
#  ('coffeespringstown', [228, 'AL']),
#  ('coffeevilletown', [905, 'MS']),
#  ('cokertown', [979, 'AL']),
#  ('collinsvilletown', [1624, 'TX']),
#  ('colonytown', [136, 'OK']),
#  ('columbiatown', [83, 'VA']),
#  ('columbiana', [6384, 'OH']),
#  ('concord', [1458, 'VA']),
#  ('coosadatown', [1224, 'AL']),
#  ('cordova', [1775, 'NC']),
#  ('cottonwoodtown', [9, 'SD']),
#  ('countylinetown', [258, 'AL']),
#  ('courtlandtown', [1284, 'VA']),
#  ('cowartstown', [1871, 'AL']),
#  ('creola', [1926, 'AL']),
#  ('crossvilletown', [1862, 'AL']),
#  ('cubatown', [346, 'AL']),
#  ('cullman', [14775, 'AL']),
#  ('cullomburg', [171, 'AL']),
#  ('cussetatown', [123, 'AL']),
#  ('dadeville', [3230, 'AL']),
#  ('daleville', [2557, 'VA']),
#  ('daphne', [21570, 'AL']),
#  ('dauphinislandtown', [1238, 'AL']),
#  ('davistontown', [214, 'AL']),
#  ('daytontown', [757, 'WY']),
#  ('deatsvilletown', [1154, 'AL']),
#  ('decatur', [6042, 'TX']),
#  ('deerpark', [3652, 'WA']),
#  ('delta', [3436, 'UT']),
#  ('demopolis', [7483, 'AL']),
#  ('detroittown', [732, 'TX']),
#  ('dodgecitytown', [593, 'AL']),
#  ('dora', [2025, 'AL']),
#  ('dothan', [65496, 'AL']),
#  ('doublespringstown', [1083, 'AL']),
#  ('douglastown', [32, 'OK']),
#  ('doziertown', [329, 'AL']),
#  ('dunnavant', [981, 'AL']),
#  ('duttontown', [316, 'MT']),
#  ('eastbrewton', [2478, 'AL']),
#  ('eastpoint', [33712, 'GA']),
#  ('eclectictown', [1001, 'AL']),
#  ('edgewater', [9023, 'MD']),
#  ('edwardsvilletown', [202, 'AL']),
#  ('egypt', [2391, 'PA']),
#  ('elba', [152, 'MN']),
#  ('elbertatown', [1498, 'AL']),
#  ('eldridgetown', [130, 'AL']),
#  ('elkmonttown', [434, 'AL']),
#  ('elmoretown', [1262, 'AL']),
#  ('emelletown', [53, 'AL']),
#  ('emeraldmountain', [2561, 'AL']),
#  ('enterprise', [961, 'WV']),
#  ('epestown', [192, 'AL']),
#  ('ethelsvilletown', [81, 'AL']),
#  ('eufaula', [2813, 'OK']),
#  ('eunola', [243, 'AL']),
#  ('eutawtown', [2934, 'AL']),
#  ('evatown', [519, 'AL']),
#  ('evergreen', [73, 'TX']),
#  ('exceltown', [723, 'AL']),
#  ('fairfield', [2951, 'TX']),
#  ('fairford', [186, 'AL']),
#  ('fairhope', [1151, 'PA']),
#  ('fairviewtown', [408, 'WV']),
#  ('falkvilletown', [1279, 'AL']),
#  ('faunsdaletown', [98, 'AL']),
#  ('fayette', [2688, 'MO']),
#  ('fayetteville', [258, 'TX']),
#  ('fitzpatrick', [83, 'AL']),
#  ('fivepointstown', [141, 'AL']),
#  ('flomatontown', [1440, 'AL']),
#  ('floralatown', [1980, 'AL']),
#  ('florence', [592, 'WI']),
#  ('foley', [161, 'MO']),
#  ('forestdale', [4099, 'MA']),
#  ('forklandtown', [649, 'AL']),
#  ('fortdeposittown', [1344, 'AL']),
#  ('fortpayne', [14012, 'AL']),
#  ('fortrucker', [4636, 'AL']),
#  ('franklintown', [721, 'WV']),
#  ('fredonia', [46, 'ND']),
#  ('friscocitytown', [1309, 'AL']),
#  ('fruitdale', [1177, 'OR']),
#  ('fruithursttown', [284, 'AL']),
#  ('fultontown', [1358, 'TX']),
#  ('fultondale', [8380, 'AL']),
#  ('fyffetown', [1018, 'AL']),
#  ('gadsden', [1632, 'SC']),
#  ('gainesvilletown', [208, 'AL']),
#  ('gallant', [855, 'AL']),
#  ('gantttown', [222, 'AL']),
#  ('gardencitytown', [562, 'UT']),
#  ('gardendale', [1574, 'TX']),
#  ('gaylesvilletown', [144, 'AL']),
#  ('geigertown', [170, 'AL']),
#  ('geneva', [2321, 'WA']),
#  ('georgianatown', [1738, 'AL']),
#  ('geraldinetown', [261, 'MT']),
#  ('gilbertowntown', [215, 'AL']),
#  ('glenallentown', [85, 'MO']),
#  ('glencoe', [310, 'OH']),
#  ('glenwoodtown', [464, 'UT']),
#  ('goldvilletown', [55, 'AL']),
#  ('goodhopetown', [2264, 'AL']),
#  ('goodwatertown', [1475, 'AL']),
#  ('gordotown', [1750, 'AL']),
#  ('gordontown', [332, 'AL']),
#  ('gordonvilletown', [326, 'AL']),
#  ('goshentown', [361, 'VA']),
#  ('graham', [23491, 'WA']),
#  ('grandbay', [3672, 'AL']),
#  ('granttown', [896, 'AL']),
#  ('graysonvalley', [5736, 'AL']),
#  ('graysville', [2165, 'AL']),
#  ('greensboro', [109, 'VT']),
#  ('greenville', [832, 'VA']),
#  ('grimestown', [558, 'AL']),
#  ('grovehilltown', [1570, 'AL']),
#  ('guin', [2376, 'AL']),
#  ('gulfcrest', [161, 'AL']),
#  ('gulfshores', [9741, 'AL']),
#  ('guntersville', [8197, 'AL']),
#  ('gurleytown', [801, 'AL']),
#  ('gu-wintown', [176, 'AL']),
#  ('hackleburgtown', [1516, 'AL']),
#  ('hackneyville', [347, 'AL']),
#  ('haleburgtown', [103, 'AL']),
#  ('haleyville', [4173, 'AL']),
#  ('hamilton', [3095, 'TX']),
#  ('hammondvilletown', [488, 'AL']),
#  ('hanceville', [2982, 'AL']),
#  ('harpersvilletown', [1637, 'AL']),
#  ('hartford', [14223, 'WI']),
#  ('hartselle', [14255, 'AL']),
#  ('harvest', [5281, 'AL']),
#  ('hatton', [777, 'ND']),
#  ('haydentown', [1810, 'CO']),
#  ('haynevilletown', [932, 'AL']),
#  ('hazelgreen', [228, 'KY']),
#  ('headland', [4510, 'AL']),
#  ('heathtown', [254, 'AL']),
#  ('heflin', [3480, 'AL']),
#  ('helena', [28190, 'MT']),
#  ('henagar', [2344, 'AL']),
#  ('highlandlaketown', [412, 'AL']),
#  ('highlandlakes', [3926, 'AL']),
#  ('hillsborotown', [260, 'WV']),
#  ('hissop', [658, 'AL']),
#  ('hobson', [215, 'MT']),
#  ('hobsoncitytown', [771, 'AL']),
#  ('hodgestown', [155, 'SC']),
#  ('hokesbluff', [4286, 'AL']),
#  ('hollins', [14673, 'VA']),
#  ('holliscrossroads', [608, 'AL']),
#  ('hollypondtown', [798, 'AL']),
#  ('hollywoodtown', [4714, 'SC']),
#  ('holt', [447, 'MO']),
#  ('holtville', [5939, 'CA']),
#  ('homewood', [25167, 'AL']),
#  ('hoover', [81619, 'AL']),
#  ('hornhilltown', [228, 'AL']),
#  ('hueytown', [16105, 'AL']),
#  ('huguley', [2540, 'AL']),
#  ('huntsville', [38548, 'TX']),
#  ('hurtsborotown', [553, 'AL']),
#  ('hytoptown', [354, 'AL']),
#  ('idertown', [723, 'AL']),
#  ('indianspringsvillage', [2363, 'AL']),
#  ('irondale', [445, 'MO']),
#  ('ivalee', [879, 'AL']),
#  ('jackson', [65211, 'TN']),
#  ("jacksons'gaptown", [828, 'AL']),
#  ('jacksonville', [14544, 'TX']),
#  ('jasper', [7590, 'TX']),
#  ('jemison', [2585, 'AL']),
#  ('joppa', [501, 'AL']),
#  ('kansastown', [802, 'OK']),
#  ('kellytontown', [217, 'AL']),
#  ('kennedytown', [447, 'AL']),
#  ('killentown', [1108, 'AL']),
#  ('kimberlytown', [2711, 'AL']),
#  ('kinseytown', [2198, 'AL']),
#  ('kinstontown', [540, 'AL']),
#  ('ladonia', [3142, 'AL']),
#  ('lafayette', [449, 'VA']),
#  ('lakeviewtown', [107, 'TX']),
#  ('lanett', [6468, 'AL']),
#  ('langstontown', [1724, 'OK']),
#  ('leeds', [427, 'ND']),
#  ('leesburgtown', [42616, 'VA']),
#  ('leightontown', [729, 'AL']),
#  ('leroy', [337, 'TX']),
#  ('lestertown', [348, 'WV']),
#  ('levelplainstown', [2085, 'AL']),
#  ('lexingtontown', [1177, 'TX']),
#  ('libertyvilletown', [117, 'AL']),
#  ('lincoln', [2406, 'ND']),
#  ('linden', [1988, 'TX']),
#  ('lineville', [217, 'IA']),
#  ('lipscomb', [37, 'TX']),
#  ('lismantown', [539, 'AL']),
#  ('littlevilletown', [1011, 'AL']),
#  ('livingston', [7044, 'MT']),
#  ('loachapokatown', [180, 'AL']),
#  ('lockharttown', [488, 'SC']),
#  ('locustforktown', [1186, 'AL']),
#  ('lookoutmountain', [1602, 'GA']),
#  ('louisvilletown', [519, 'AL']),
#  ('lowndesborotown', [115, 'AL']),
#  ('loxleytown', [1632, 'AL']),
#  ('luverne', [31, 'ND']),
#  ('lynntown', [1097, 'IN']),
#  ('mcdonaldchapel', [717, 'AL']),
#  ('macedonia', [11188, 'OH']),
#  ('mcintoshtown', [452, 'FL']),
#  ('mckenzietown', [530, 'AL']),
#  ('mcmullentown', [10, 'AL']),
#  ('madison', [233209, 'WI']),
#  ('madridtown', [350, 'AL']),
#  ('magnoliaspringstown', [723, 'AL']),
#  ('malcolm', [187, 'AL']),
#  ('malverntown', [1448, 'AL']),
#  ('maplesvilletown', [708, 'AL']),
#  ('marbury', [1418, 'AL']),
#  ('margarettown', [4428, 'AL']),
#  ('marion', [1260, 'WI']),
#  ('maytowntown', [385, 'AL']),
#  ('meadowbrook', [18312, 'VA']),
#  ('megargel', [62, 'AL']),
#  ('memphistown', [29, 'AL']),
#  ('mentonetown', [1001, 'IN']),
#  ('meridianville', [6021, 'AL']),
#  ('midfield', [5365, 'AL']),
#  ('midlandcitytown', [2344, 'AL']),
#  ('midwaytown', [4679, 'NC']),
#  ('mignon', [1284, 'AL']),
#  ('millbrook', [14640, 'AL']),
#  ('millerville', [106, 'MN']),
#  ('millporttown', [1049, 'AL']),
#  ('millrytown', [546, 'AL']),
#  ('minor', [1094, 'AL']),
#  ('mobile', [195111, 'AL']),
#  ('monroeville', [6519, 'AL']),
#  ('montevallo', [6323, 'AL']),
#  ('montgomery', [1638, 'WV']),
#  ('moody', [1371, 'TX']),
#  ('mooresmill', [5682, 'AL']),
#  ('mooresvilletown', [32711, 'NC']),
#  ('morristown', [29137, 'TN']),
#  ('morrisoncrossroads', [219, 'AL']),
#  ('mossestown', [1029, 'AL']),
#  ('moulton', [605, 'IA']),
#  ('moundvilletown', [124, 'MO']),
#  ('mountainbrook', [20413, 'AL']),
#  ('mountolive', [2099, 'IL']),
#  ('mountvernontown', [2662, 'TX']),
#  ('movico', [305, 'AL']),
#  ('mulgatown', [836, 'AL']),
#  ('munfordtown', [1292, 'AL']),
#  ('muscleshoals', [13146, 'AL']),
#  ('myrtlewoodtown', [130, 'AL']),
#  ('nanafalia', [94, 'AL']),
#  ('nancescreek', [407, 'AL']),
#  ('napierfieldtown', [354, 'AL']),
#  ('naturalbridgetown', [37, 'AL']),
#  ('nauvootown', [221, 'AL']),
#  ('nectartown', [345, 'AL']),
#  ('needhamtown', [94, 'AL']),
#  ('newberntown', [3313, 'TN']),
#  ('newbrocktontown', [1146, 'AL']),
#  ('newhope', [797, 'VA']),
#  ('newmarket', [816, 'PA']),
#  ('newsitetown', [773, 'AL']),
#  ('newtontown', [789, 'UT']),
#  ('newunion', [1431, 'TN']),
#  ('newvilletown', [539, 'AL']),
#  ('northcourtlandtown', [632, 'AL']),
#  ('northjohnstown', [145, 'AL']),
#  ('northport', [491, 'WI']),
#  ('notasulgatown', [965, 'AL']),
#  ('oakgrovetown', [603, 'TX']),
#  ('oakhilltown', [26, 'AL']),
#  ('oakmantown', [789, 'AL']),
#  ('odenvilletown', [3585, 'AL']),
#  ('ohatcheetown', [1170, 'AL']),
#  ('oneonta', [13901, 'NY']),
#  ('onychatown', [184, 'AL']),
#  ('opelika', [26477, 'AL']),
#  ('opp', [6659, 'AL']),
#  ('orangebeach', [5441, 'AL']),
#  ('orrvilletown', [204, 'AL']),
#  ('ourtown', [641, 'AL']),
#  ('owenscrossroadstown', [1521, 'AL']),
#  ('oxford', [21371, 'OH']),
#  ('ozark', [17820, 'MO']),
#  ('paintrocktown', [273, 'TX']),
#  ('panola', [144, 'AL']),
#  ('parrishtown', [982, 'AL']),
#  ('pelham', [403, 'TN']),
#  ('pellcity', [12695, 'AL']),
#  ('penningtontown', [221, 'AL']),
#  ('penton', [201, 'AL']),
#  ('perdidobeachtown', [581, 'AL']),
#  ('peterman', [89, 'AL']),
#  ('petreytown', [58, 'AL']),
#  ('phenixcity', [32822, 'AL']),
#  ('philcampbelltown', [1148, 'AL']),
#  ('pickensvilletown', [608, 'AL']),
#  ('piedmont', [222, 'SD']),
#  ('pikeroadtown', [5406, 'AL']),
#  ('pinckardtown', [647, 'AL']),
#  ('pineappletown', [132, 'AL']),
#  ('pinehilltown', [975, 'AL']),
#  ('pinelevel', [227, 'FL']),
#  ('pineridgetown', [2064, 'SC']),
#  ('pinson', [7163, 'AL']),
#  ('pisgahtown', [722, 'AL']),
#  ('pleasantgrove', [33509, 'UT']),
#  ('pleasantgrovestown', [420, 'AL']),
#  ('pointclear', [2125, 'AL']),
#  ('pollardtown', [137, 'AL']),
#  ('powelltown', [136, 'TX']),
#  ('prattville', [33, 'CA']),
#  ('pricevilletown', [2658, 'AL']),
#  ('prichard', [527, 'WV']),
#  ('providencetown', [223, 'AL']),
#  ('putnam', [7214, 'CT']),
#  ('raglandtown', [1639, 'AL']),
#  ('rainbowcity', [968, 'AZ']),
#  ('rainsville', [4948, 'AL']),
#  ('ranburnetown', [409, 'AL']),
#  ('ray', [592, 'ND']),
#  ('redbay', [3158, 'AL']),
#  ('redland', [1047, 'TX']),
#  ('redleveltown', [487, 'AL']),
#  ('redstonearsenal', [1946, 'AL']),
#  ('reececitytown', [653, 'AL']),
#  ('reeltown', [766, 'AL']),
#  ('reformtown', [1702, 'AL']),
#  ('rehobethtown', [1297, 'AL']),
#  ('reptontown', [282, 'AL']),
#  ('ridgevilletown', [1979, 'SC']),
#  ('riverfallstown', [526, 'AL']),
#  ('riversidetown', [52, 'WY']),
#  ('riverviewtown', [184, 'AL']),
#  ('roanoke', [97032, 'VA']),
#  ('robertsdale', [5276, 'AL']),
#  ('rockcreek', [9316, 'OR']),
#  ('rockfordtown', [470, 'WA']),
#  ('rockmills', [600, 'AL']),
#  ('rockville', [166, 'MO']),
#  ('rogersvilletown', [4420, 'TN']),
#  ('rosatown', [316, 'AL']),
#  ('russellville', [488, 'SC']),
#  ('rutledgetown', [1122, 'TN']),
#  ('st.floriantown', [413, 'AL']),
#  ('st.stephens', [8759, 'NC']),
#  ('saks', [10744, 'AL']),
#  ('samson', [1940, 'AL']),
#  ('sandrocktown', [560, 'AL']),
#  ('sanfordtown', [164, 'TX']),
#  ('saraland', [13405, 'AL']),
#  ('sardiscitytown', [1704, 'AL']),
#  ('satsuma', [6168, 'AL']),
#  ('scottsboro', [14770, 'AL']),
#  ('sectiontown', [770, 'AL']),
#  ('selma', [529, 'VA']),
#  ('selmont-westselmont', [2671, 'AL']),
#  ('sheffield', [1132, 'PA']),
#  ('shelby', [9317, 'OH']),
#  ('shilohtown', [274, 'AL']),
#  ('shoalcreek', [1400, 'AL']),
#  ('shortertown', [474, 'AL']),
#  ('silastown', [452, 'AL']),
#  ('silverhilltown', [706, 'AL']),
#  ('simschapel', [153, 'AL']),
#  ('sipseytown', [437, 'AL']),
#  ('skylinetown', [851, 'AL']),
#  ('slocomb', [1980, 'AL']),
#  ('smithsstation', [4926, 'AL']),
#  ('smokerise', [1825, 'AL']),
#  ('sneadtown', [835, 'AL']),
#  ('somervilletown', [3094, 'TN']),
#  ('southside', [8412, 'AL']),
#  ('southvinemonttown', [749, 'AL']),
#  ('spanishfort', [6798, 'AL']),
#  ('springgarden', [16, 'CA']),
#  ('springville', [1371, 'VA']),
#  ('sprucepine', [222, 'AL']),
#  ('standingrock', [168, 'AL']),
#  ('steeletown', [1043, 'AL']),
#  ('sterrett', [712, 'AL']),
#  ('stevenson', [1465, 'WA']),
#  ('stewartville', [5916, 'MN']),
#  ('sulligent', [1927, 'AL']),
#  ('sumiton', [2520, 'AL']),
#  ('summerdaletown', [862, 'AL']),
#  ('susanmooretown', [763, 'AL']),
#  ('sweetwatertown', [87, 'OK']),
#  ('sylacauga', [12749, 'AL']),
#  ('sylvaniatown', [1837, 'AL']),
#  ('sylvanspringstown', [1542, 'AL']),
#  ('talladega', [15676, 'AL']),
#  ('talladegaspringstown', [166, 'AL']),
#  ('tallassee', [4819, 'AL']),
#  ('tarrant', [6397, 'AL']),
#  ('taylortown', [4112, 'AZ']),
#  ('theodore', [6130, 'AL']),
#  ('thomastontown', [417, 'AL']),
#  ('thomasville', [26757, 'NC']),
#  ('thorsbytown', [1980, 'AL']),
#  ('tibbie', [41, 'AL']),
#  ('tidmorebend', [1245, 'AL']),
#  ('tillmanscorner', [17398, 'AL']),
#  ('towncreektown', [1100, 'AL']),
#  ('toxeytown', [137, 'AL']),
#  ('traffordtown', [646, 'AL']),
#  ('trianatown', [496, 'AL']),
#  ('trinitytown', [2095, 'AL']),
#  ('troy', [243, 'VT']),
#  ('trussville', [19933, 'AL']),
#  ('tuscaloosa', [90468, 'AL']),
#  ('tuscumbia', [8423, 'AL']),
#  ('tuskegee', [9865, 'AL']),
#  ('twintown', [399, 'AL']),
#  ('underwood-petersville', [3247, 'AL']),
#  ('uniontown', [565, 'WV']),
#  ('uniongrovetown', [77, 'AL']),
#  ('unionsprings', [3980, 'AL']),
#  ('uniontowntown', [294, 'WA']),
#  ('uriah', [294, 'AL']),
#  ('valley', [146, 'WA']),
#  ('valleygrande', [4020, 'AL']),
#  ('valleyheadtown', [558, 'AL']),
#  ('vancetown', [170, 'SC']),
#  ('vandiver', [1135, 'AL']),
#  ('vernon', [11002, 'TX']),
#  ('vestaviahills', [34033, 'AL']),
#  ('vinatown', [358, 'AL']),
#  ('vincenttown', [1988, 'AL']),
#  ('vinegarbend', [192, 'AL']),
#  ('vredenburghtown', [312, 'AL']),
#  ('wadleytown', [751, 'AL']),
#  ('waldotown', [283, 'AL']),
#  ('walnutgrovetown', [1911, 'MS']),
#  ('warrior', [3176, 'AL']),
#  ('waterlootown', [166, 'SC']),
#  ('waverlytown', [106, 'WA']),
#  ('weaver', [3038, 'AL']),
#  ('webbtown', [565, 'MS']),
#  ('wedoweetown', [823, 'AL']),
#  ('weogufka', [282, 'AL']),
#  ('westbloctontown', [1240, 'AL']),
#  ('westend-cobbtown', [3465, 'AL']),
#  ('westjeffersontown', [1299, 'NC']),
#  ('westovertown', [1275, 'AL']),
#  ('westpointtown', [3306, 'VA']),
#  ('wetumpka', [6528, 'AL']),
#  ('whatley', [150, 'AL']),
#  ('whitehalltown', [648, 'WV']),
#  ('whiteplains', [1074, 'NC']),
#  ('whitesboro', [3793, 'TX']),
#  ('wilsonvilletown', [1827, 'AL']),
#  ('wiltontown', [687, 'AL']),
#  ('winfield', [524, 'TX']),
#  ('woodlandtown', [809, 'NC']),
#  ('woodstocktown', [5097, 'VA']),
#  ('woodvilletown', [2586, 'TX']),
#  ('yellowblufftown', [188, 'AL']),
#  ('york', [7736, 'SC']),
#  ('adak', [326, 'AK']),
#  ('akhiok', [71, 'AK']),
#  ('akiachak', [627, 'AK']),
#  ('akiak', [346, 'AK']),
#  ('akutan', [1027, 'AK']),
#  ('alakanuk', [677, 'AK']),
#  ('alatna', [37, 'AK']),
#  ('alcanborder', [33, 'AK']),
#  ('aleknagik', [219, 'AK']),
#  ('aleneva', [37, 'AK']),
#  ('allakaket', [105, 'AK']),
#  ('ambler', [258, 'AK']),
#  ('anaktuvukpass', [324, 'AK']),
#  ('anchoragemunicipality', [291826, 'AK']),
#  ('anchorpoint', [1930, 'AK']),
#  ('anderson', [222, 'TX']),
#  ('angoon', [459, 'AK']),
#  ('aniak', [501, 'AK']),
#  ('anvik', [85, 'AK']),
#  ('arcticvillage', [152, 'AK']),
#  ('atka', [61, 'AK']),
#  ('atmautluak', [277, 'AK']),
#  ('atqasuk', [233, 'AK']),
#  ('attustation', [21, 'AK']),
#  ('badger', [375, 'MN']),
#  ('barrow', [4212, 'AK']),
#  ('bearcreek', [1948, 'FL']),
#  ('beaver', [1308, 'WV']),
#  ('beluga', [20, 'AK']),
#  ('bethel', [3713, 'WA']),
#  ('bettles', [12, 'AK']),
#  ('bigdelta', [591, 'AK']),
#  ('biglake', [1835, 'WA']),
#  ('birchcreek', [33, 'AK']),
#  ('brevigmission', [388, 'AK']),
#  ('buckland', [416, 'AK']),
#  ('buffalosoapstone', [855, 'AK']),
#  ('butte', [68, 'ND']),
#  ('cantwell', [219, 'AK']),
#  ('central', [613, 'UT']),
#  ('chalkyitsik', [69, 'AK']),
#  ('chase', [978, 'PA']),
#  ('chefornak', [418, 'AK']),
#  ('chenaridge', [5791, 'AK']),
#  ('chenega', [76, 'AK']),
#  ('chevak', [938, 'AK']),
#  ('chickaloon', [272, 'AK']),
#  ('chicken', [7, 'AK']),
#  ('chignik', [91, 'AK']),
#  ('chigniklagoon', [78, 'AK']),
#  ('chigniklake', [73, 'AK']),
#  ('chiniak', [47, 'AK']),
#  ('chisana', [0, 'AK']),
#  ('chistochina', [93, 'AK']),
#  ('chitina', [126, 'AK']),
#  ('chuathbaluk', [118, 'AK']),
#  ('circle', [104, 'AK']),
#  ('clamgulch', [176, 'AK']),
#  ("clark'spoint", [62, 'AK']),
#  ('coffmancove', [176, 'AK']),
#  ('cohoe', [1364, 'AK']),
#  ('coldbay', [108, 'AK']),
#  ('coldfoot', [10, 'AK']),
#  ('college', [12964, 'AK']),
#  ('cooperlanding', [289, 'AK']),
#  ('coppercenter', [328, 'AK']),
#  ('covenantlife', [86, 'AK']),
#  ('craig', [43, 'MT']),
#  ('crookedcreek', [639, 'GA']),
#  ('crownpoint', [2278, 'NM']),
#  ('deering', [98, 'ND']),
#  ('deltajunction', [958, 'AK']),
#  ('deltana', [2251, 'AK']),
#  ('diamondridge', [1156, 'AK']),
#  ('dillingham', [2329, 'AK']),
#  ('diomede', [115, 'AK']),
#  ('dotlake', [13, 'AK']),
#  ('dotlakevillage', [62, 'AK']),
#  ('drycreek', [227, 'OK']),
#  ('eagle', [19908, 'ID']),
#  ('eaglevillage', [1950, 'WI']),
#  ('ednabay', [42, 'AK']),
#  ('eek', [296, 'AK']),
#  ('egegik', [109, 'AK']),
#  ('eielsonafb', [2647, 'AK']),
#  ('ekwok', [115, 'AK']),
#  ('elfincove', [20, 'AK']),
#  ('elim', [3727, 'PA']),
#  ('emmonak', [762, 'AK']),
#  ('ester', [2422, 'AK']),
#  ('eurekaroadhouse', [29, 'AK']),
#  ('evansville', [5012, 'WI']),
#  ('excursioninlet', [12, 'AK']),
#  ('fairbanks', [31535, 'AK']),
#  ('falsepass', [35, 'AK']),
#  ('farmersloop', [4853, 'AK']),
#  ('farmloop', [1028, 'AK']),
#  ('ferry', [33, 'AK']),
#  ('fishhook', [4679, 'AK']),
#  ('flat', [0, 'AK']),
#  ('fortgreely', [539, 'AK']),
#  ('fortyukon', [583, 'AK']),
#  ('fourmileroad', [43, 'AK']),
#  ('fox', [417, 'AK']),
#  ('foxriver', [685, 'AK']),
#  ('fritzcreek', [1932, 'AK']),
#  ('funnyriver', [877, 'AK']),
#  ('gakona', [218, 'AK']),
#  ('galena', [440, 'MO']),
#  ('gambell', [681, 'AK']),
#  ('gamecreek', [18, 'AK']),
#  ('gateway', [8401, 'FL']),
#  ('glacierview', [234, 'AK']),
#  ('glennallen', [483, 'AK']),
#  ('goldstream', [3557, 'AK']),
#  ('golovin', [156, 'AK']),
#  ('goodnewsbay', [243, 'AK']),
#  ('grayling', [1884, 'MI']),
#  ('gulkana', [119, 'AK']),
#  ('gustavus', [442, 'AK']),
#  ('haines', [416, 'OR']),
#  ('halibutcove', [76, 'AK']),
#  ('happyvalley', [13903, 'OR']),
#  ('harding-birchlakes', [299, 'AK']),
#  ('healy', [234, 'KS']),
#  ('healylake', [13, 'AK']),
#  ('hobartbay', [1, 'AK']),
#  ('hollis', [2060, 'OK']),
#  ('holycross', [374, 'IA']),
#  ('homer', [181, 'MN']),
#  ('hoonah', [760, 'AK']),
#  ('hooperbay', [1093, 'AK']),
#  ('hope', [258, 'ND']),
#  ('houston', [2099451, 'TX']),
#  ('hughes', [1441, 'AR']),
#  ('huslia', [275, 'AK']),
#  ('hydaburg', [376, 'AK']),
#  ('hyder', [87, 'AK']),
#  ('igiugig', [50, 'AK']),
#  ('iliamna', [109, 'AK']),
#  ('ivanofbay', [7, 'AK']),
#  ('juneauandborough', [31275, 'AK']),
#  ('kachemak', [472, 'AK']),
#  ('kake', [557, 'AK']),
#  ('kaktovik', [239, 'AK']),
#  ('kalifornsky', [7850, 'AK']),
#  ('kaltag', [190, 'AK']),
#  ('karluk', [37, 'AK']),
#  ('kasaan', [49, 'AK']),
#  ('kasigluk', [569, 'AK']),
#  ('kasilof', [549, 'AK']),
#  ('kenai', [7100, 'AK']),
#  ('kennylake', [355, 'AK']),
#  ('ketchikan', [8050, 'AK']),
#  ('kiana', [361, 'AK']),
#  ('kingcove', [938, 'AK']),
#  ('kingsalmon', [374, 'AK']),
#  ('kipnuk', [639, 'AK']),
#  ('kivalina', [374, 'AK']),
#  ('klawock', [755, 'AK']),
#  ('klukwan', [95, 'AK']),
#  ('knik-fairview', [14923, 'AK']),
#  ('knikriver', [744, 'AK']),
#  ('kobuk', [151, 'AK']),
#  ('kodiak', [6130, 'AK']),
#  ('kodiakstation', [1301, 'AK']),
#  ('kokhanok', [170, 'AK']),
#  ('koliganek', [209, 'AK']),
#  ('kongiganak', [439, 'AK']),
#  ('kotlik', [577, 'AK']),
#  ('kotzebue', [3201, 'AK']),
#  ('koyuk', [332, 'AK']),
#  ('koyukuk', [96, 'AK']),
#  ('kupreanof', [27, 'AK']),
#  ('kwethluk', [721, 'AK']),
#  ('kwigillingok', [321, 'AK']),
#  ('lakelouise', [46, 'AK']),
#  ('lakeminchumina', [13, 'AK']),
#  ('lakes', [8364, 'AK']),
#  ('larsenbay', [87, 'AK']),
#  ('lazymountain', [1479, 'AK']),
#  ('levelock', [69, 'AK']),
#  ('limevillage', [29, 'AK']),
#  ('livengood', [13, 'AK']),
#  ('loring', [4, 'AK']),
#  ('lowellpoint', [80, 'AK']),
#  ('lowerkalskag', [282, 'AK']),
#  ('lutak', [49, 'AK']),
#  ('mccarthy', [28, 'AK']),
#  ('mcgrath', [80, 'MN']),
#  ('mckinleypark', [185, 'AK']),
#  ('manleyhotsprings', [89, 'AK']),
#  ('manokotak', [442, 'AK']),
#  ('marshall', [1480, 'VA']),
#  ('meadowlakes', [1777, 'TX']),
#  ('mekoryuk', [191, 'AK']),
#  ('mendeltna', [39, 'AK']),
#  ('mentastalake', [112, 'AK']),
#  ('mertarvik', [0, 'AK']),
#  ('metlakatla', [1405, 'AK']),
#  ('minto', [604, 'ND']),
#  ('moosecreek', [747, 'AK']),
#  ('moosepass', [219, 'AK']),
#  ('mosquitolake', [309, 'AK']),
#  ('mountainvillage', [813, 'AK']),
#  ('mudbay', [212, 'AK']),
#  ('nabesna', [5, 'AK']),
#  ('naknek', [544, 'AK']),
#  ('nanwalek', [254, 'AK']),
#  ('napakiak', [354, 'AK']),
#  ('napaskiak', [405, 'AK']),
#  ('naukatibay', [113, 'AK']),
#  ('nelchina', [59, 'AK']),
#  ('nelsonlagoon', [52, 'AK']),
#  ('nenana', [378, 'AK']),
#  ('newallakaket', [66, 'AK']),
#  ('newhalen', [190, 'AK']),
#  ('newstuyahok', [510, 'AK']),
#  ('newtok', [354, 'AK']),
#  ('nightmute', [280, 'AK']),
#  ('nikiski', [4493, 'AK']),
#  ('nikolaevsk', [318, 'AK']),
#  ('nikolai', [94, 'AK']),
#  ('nikolski', [18, 'AK']),
#  ('ninilchik', [883, 'AK']),
#  ('noatak', [514, 'AK']),
#  ('nome', [588, 'TX']),
#  ('nondalton', [164, 'AK']),
#  ('noorvik', [668, 'AK']),
#  ('northpole', [2117, 'AK']),
#  ('northway', [71, 'AK']),
#  ('northwayjunction', [54, 'AK']),
#  ('northwayvillage', [98, 'AK']),
#  ('nuiqsut', [402, 'AK']),
#  ('nulato', [264, 'AK']),
#  ('nunamiqua', [187, 'AK']),
#  ('nunapitchuk', [496, 'AK']),
#  ('oldharbor', [218, 'AK']),
#  ('oscarville', [70, 'AK']),
#  ('ouzinkie', [161, 'AK']),
#  ('palmer', [418, 'MI']),
#  ('paxson', [40, 'AK']),
#  ('pedrobay', [42, 'AK']),
#  ('pelican', [88, 'AK']),
#  ('perryville', [8225, 'MO']),
#  ('petersburg', [2467, 'WV']),
#  ('petersville', [4, 'AK']),
#  ('pilotpoint', [3856, 'TX']),
#  ('pilotstation', [568, 'AK']),
#  ('pitkaspoint', [109, 'AK']),
#  ('platinum', [61, 'AK']),
#  ('pleasantvalley', [3149, 'WV']),
#  ('pointbaker', [2991, 'FL']),
#  ('pointhope', [674, 'AK']),
#  ('pointlay', [189, 'AK']),
#  ('pointmackenzie', [529, 'AK']),
#  ('pointpossession', [3, 'AK']),
#  ('pope-vannoylanding', [6, 'AK']),
#  ('portagecreek', [2, 'AK']),
#  ('portalexander', [52, 'AK']),
#  ('portalsworth', [159, 'AK']),
#  ('portclarence', [24, 'AK']),
#  ('portgraham', [177, 'AK']),
#  ('portheiden', [102, 'AK']),
#  ('portlions', [194, 'AK']),
#  ('portprotection', [48, 'AK']),
#  ('primrose', [78, 'AK']),
#  ('prudhoebay', [2174, 'AK']),
#  ('quinhagak', [669, 'AK']),
#  ('rampart', [24, 'AK']),
#  ('reddevil', [23, 'AK']),
#  ('reddogmine', [309, 'AK']),
#  ('ridgeway', [464, 'MO']),
#  ('ruby', [166, 'AK']),
#  ('russianmission', [312, 'AK']),
#  ('st.george', [72897, 'UT']),
#  ("st.mary's", [283, 'CO']),
#  ('st.michael', [408, 'PA']),
#  ('st.paul', [584, 'TX']),
#  ('salamatof', [980, 'AK']),
#  ('salcha', [1095, 'AK']),
#  ('sandpoint', [7365, 'ID']),
#  ('savoonga', [671, 'AK']),
#  ('saxman', [411, 'AK']),
#  ('scammonbay', [474, 'AK']),
#  ('selawik', [829, 'AK']),
#  ('seldovia', [255, 'AK']),
#  ('seldoviavillage', [165, 'AK']),
#  ('seward', [6964, 'NE']),
#  ('shageluk', [83, 'AK']),
#  ('shaktoolik', [251, 'AK']),
#  ('shishmaref', [563, 'AK']),
#  ('shungnak', [262, 'AK']),
#  ('silversprings', [5296, 'NV']),
#  ('sitkaandborough', [8881, 'AK']),
#  ('skagway', [920, 'AK']),
#  ('skwentna', [37, 'AK']),
#  ('slana', [147, 'AK']),
#  ('sleetmute', [86, 'AK']),
#  ('soldotna', [4163, 'AK']),
#  ('southnaknek', [79, 'AK']),
#  ('southvanhorn', [558, 'AK']),
#  ('stebbins', [556, 'AK']),
#  ('steelecreek', [6662, 'AK']),
#  ('sterling', [27822, 'VA']),
#  ('stevensvillage', [78, 'AK']),
#  ('stonyriver', [54, 'AK']),
#  ('sunrise', [84439, 'FL']),
#  ('susitna', [18, 'AK']),
#  ('susitnanorth', [1260, 'AK']),
#  ('sutton-alpine', [1447, 'AK']),
#  ('takotna', [52, 'AK']),
#  ('talkeetna', [876, 'AK']),
#  ('tanacross', [136, 'AK']),
#  ('tanaina', [8197, 'AK']),
#  ('tanana', [246, 'AK']),
#  ('tatitlek', [88, 'AK']),
#  ('tazlina', [297, 'AK']),
#  ('teller', [229, 'AK']),
#  ('tenakeesprings', [131, 'AK']),
#  ('tetlin', [127, 'AK']),
#  ('thornebay', [471, 'AK']),
#  ('togiak', [817, 'AK']),
#  ('tok', [1258, 'AK']),
#  ('toksookbay', [590, 'AK']),
#  ('tolsona', [30, 'AK']),
#  ('tonsina', [78, 'AK']),
#  ('trappercreek', [481, 'AK']),
#  ('tuluksak', [373, 'AK']),
#  ('tuntutuliak', [408, 'AK']),
#  ('tununak', [327, 'AK']),
#  ('twinhills', [74, 'AK']),
#  ('tworivers', [11712, 'WI']),
#  ('tyonek', [171, 'AK']),
#  ('ugashik', [12, 'AK']),
#  ('unalakleet', [688, 'AK']),
#  ('unalaska', [4376, 'AK']),
#  ('upperkalskag', [210, 'AK']),
#  ('valdez', [47, 'CO']),
#  ('venetie', [166, 'AK']),
#  ('wainwright', [556, 'AK']),
#  ('wales', [31, 'ND']),
#  ('wasilla', [7831, 'AK']),
#  ('whalepass', [31, 'AK']),
#  ('whitemountain', [190, 'AK']),
#  ('whitestone', [97, 'AK']),
#  ('whitestoneloggingcamp', [17, 'AK']),
#  ('whittier', [85331, 'CA']),
#  ('willow', [2102, 'AK']),
#  ('willowcreek', [210, 'MT']),
#  ('wiseman', [14, 'AK']),
#  ('womensbay', [719, 'AK']),
#  ('wrangellandborough', [2369, 'AK']),
#  ('yakutat', [662, 'AK']),
#  ('aguila', [798, 'AZ']),
#  ('ajo', [3304, 'AZ']),
#  ('akchin', [30, 'AZ']),
#  ('ak-chinvillage', [862, 'AZ']),
#  ('alamolake', [25, 'AZ']),
#  ('alichuk', [161, 'AZ']),
#  ('alichukson', [132, 'AZ']),
#  ('alimolina', [71, 'AZ']),
#  ('alpine', [9555, 'UT']),
#  ('amado', [295, 'AZ']),
#  ('anegam', [151, 'AZ']),
#  ('antares', [126, 'AZ']),
#  ('anthem', [21700, 'AZ']),
#  ('apachejunction', [35840, 'AZ']),
#  ('arivaca', [695, 'AZ']),
#  ('arivacajunction', [1090, 'AZ']),
#  ('arizonacity', [10475, 'AZ']),
#  ('arizonavillage', [946, 'AZ']),
#  ('arlington', [25, 'WY']),
#  ('ashfork', [396, 'AZ']),
#  ('avenuebandc', [4176, 'AZ']),
#  ('avondale', [440, 'MO']),
#  ('avravalley', [6050, 'AZ']),
#  ('aztec', [6763, 'NM']),
#  ('bagdad', [3761, 'FL']),
#  ('bearflat', [18, 'AZ']),
#  ('beaverdam', [16214, 'WI']),
#  ('beavervalley', [231, 'AZ']),
#  ('benson', [308, 'VT']),
#  ('beyerville', [177, 'AZ']),
#  ('bisbee', [126, 'ND']),
#  ('bittersprings', [452, 'AZ']),
#  ('blackcanyoncity', [2837, 'AZ']),
#  ('blackwater', [162, 'MO']),
#  ('bluewater', [172, 'CA']),
#  ('bouse', [996, 'AZ']),
#  ('bowie', [5218, 'TX']),
#  ('brenda', [676, 'AZ']),
#  ('bryce', [175, 'AZ']),
#  ('buckeyetown', [50876, 'AZ']),
#  ('buckshot', [153, 'AZ']),
#  ('bullheadcity', [39540, 'AZ']),
#  ('burnside', [611, 'KY']),
#  ('bylas', [1962, 'AZ']),
#  ('cactusflats', [1518, 'AZ']),
#  ('cactusforest', [594, 'AZ']),
#  ('cameron', [946, 'WV']),
#  ('campobonito', [74, 'AZ']),
#  ('campverdetown', [10873, 'AZ']),
#  ('canebeds', [448, 'AZ']),
#  ('canyonday', [1209, 'AZ']),
#  ('carefreetown', [3363, 'AZ']),
#  ('carrizo', [127, 'AZ']),
#  ('casablanca', [54, 'TX']),
#  ('casagrande', [48571, 'AZ']),
#  ('casasadobes', [66795, 'AZ']),
#  ('catalina', [7569, 'AZ']),
#  ('catalinafoothills', [50796, 'AZ']),
#  ('cavecreektown', [5015, 'AZ']),
#  ('cedarcreek', [318, 'AZ']),
#  ('centennialpark', [1264, 'AZ']),
#  ('centralheights-midlandcity', [2534, 'AZ']),
#  ('chandler', [2734, 'TX']),
#  ('charco', [52, 'AZ']),
#  ('chiawulitak', [78, 'AZ']),
#  ('chilchinbito', [506, 'AZ']),
#  ('chinle', [4518, 'AZ']),
#  ('chinovalleytown', [10817, 'AZ']),
#  ('chloride', [271, 'AZ']),
#  ('christophercreek', [156, 'AZ']),
#  ...]

# %%
dict(city_pop_dic_lst)['fresno']
# Out:
# [19069, 'TX']

# %%
city_kills_state_list
# Out:
# [('losangeles', [71, 'CA']),
#  ('phoenix', [69, 'AZ']),
#  ('houston', [47, 'TX']),
#  ('lasvegas', [41, 'NV']),
#  ('sanantonio', [36, 'TX']),
#  ('columbus', [34, 'OH']),
#  ('chicago', [34, 'IL']),
#  ('albuquerque', [31, 'NM']),
#  ('miami', [29, 'FL']),
#  ('st.louis', [29, 'MO']),
#  ('austin', [28, 'TX']),
#  ('jacksonville', [26, 'NC']),
#  ('kansascity', [26, 'KS']),
#  ('denver', [26, 'CO']),
#  ('oklahomacity', [25, 'OK']),
#  ('tucson', [25, 'AZ']),
#  ('bakersfield', [21, 'CA']),
#  ('tulsa', [21, 'OK']),
#  ('louisville', [18, 'KY']),
#  ('atlanta', [18, 'GA']),
#  ('newyork', [18, 'NY']),
#  ('dallas', [17, 'TX']),
#  ('mesa', [17, 'AZ']),
#  ('fresno', [17, 'CA']),
#  ('baltimore', [16, 'MD']),
#  ('sanjose', [16, 'CA']),
#  ('indianapolis', [16, 'IN']),
#  ('portland', [16, 'OR']),
#  ('orlando', [16, 'FL']),
#  ('springfield', [15, 'FL']),
#  ('aurora', [15, 'CO']),
#  ('arlington', [15, 'TX']),
#  ('charlotte', [15, 'NC']),
#  ('sanfrancisco', [15, 'CA']),
#  ('coloradosprings', [15, 'CO']),
#  ('washington', [15, 'DC']),
#  ('fortworth', [14, 'TX']),
#  ('memphis', [14, 'TN']),
#  ('philadelphia', [14, 'PA']),
#  ('longbeach', [14, 'CA']),
#  ('sandiego', [14, 'CA']),
#  ('pueblo', [12, 'CO']),
#  ('elpaso', [11, 'TX']),
#  ('seattle', [11, 'WA']),
#  ('westminster', [11, 'CA']),
#  ('saltlakecity', [11, 'UT']),
#  ('spokane', [11, 'WA']),
#  ('stockton', [11, 'CA']),
#  ('jackson', [11, 'MI']),
#  ('reno', [11, 'NV']),
#  ('milwaukee', [11, 'WI']),
#  ('sacramento', [10, 'CA']),
#  ('omaha', [10, 'NE']),
#  ('richmond', [10, 'VA']),
#  ('tacoma', [10, 'WA']),
#  ('lascruces', [10, 'NM']),
#  ('glendale', [10, 'AZ']),
#  ('batonrouge', [10, 'LA']),
#  ('honolulu', [10, 'HI']),
#  ('greenville', [10, 'NC']),
#  ('santaana', [10, 'CA']),
#  ('sanbernardino', [10, 'CA']),
#  ('neworleans', [9, 'LA']),
#  ('lakewood', [9, 'CO']),
#  ('st.paul', [9, 'MN']),
#  ('wichita', [9, 'KS']),
#  ('fairbanks', [9, 'AK']),
#  ('anaheim', [9, 'CA']),
#  ('shreveport', [9, 'LA']),
#  ('newark', [9, 'NJ']),
#  ('oakland', [9, 'CA']),
#  ('flagstaff', [9, 'AZ']),
#  ('huntsville', [9, 'AL']),
#  ('amarillo', [9, 'TX']),
#  ('tampa', [9, 'FL']),
#  ('clinton', [9, 'TN']),
#  ('billings', [9, 'MT']),
#  ('anchorage', [9, 'AK']),
#  ('detroit', [9, 'MI']),
#  ('birmingham', [8, 'AL']),
#  ('modesto', [8, 'CA']),
#  ('longview', [8, 'TX']),
#  ('redding', [8, 'CA']),
#  ('wilmington', [8, 'DE']),
#  ('vancouver', [8, 'WA']),
#  ('boston', [8, 'MA']),
#  ('tempe', [8, 'AZ']),
#  ('lancaster', [8, 'PA']),
#  ('clarksville', [7, 'IN']),
#  ('charleston', [7, 'WV']),
#  ('cincinnati', [7, 'OH']),
#  ('boise', [7, 'ID']),
#  ('nashville', [7, 'TN']),
#  ('odessa', [7, 'TX']),
#  ('hemet', [7, 'CA']),
#  ('littlerock', [7, 'AR']),
#  ('durham', [7, 'NC']),
#  ('norfolk', [7, 'VA']),
#  ('lakeland', [7, 'FL']),
#  ('ontario', [6, 'CA']),
#  ('ogden', [6, 'UT']),
#  ('auburn', [6, 'WA']),
#  ('brooklyn', [6, 'OH']),
#  ('garland', [6, 'TX']),
#  ('minneapolis', [6, 'MN']),
#  ('desmoines', [6, 'IA']),
#  ('antioch', [6, 'CA']),
#  ('cleveland', [6, 'OH']),
#  ('scottsdale', [6, 'AZ']),
#  ('kent', [6, 'WA']),
#  ('kingman', [6, 'AZ']),
#  ('akron', [6, 'OH']),
#  ('midland', [6, 'TX']),
#  ('knoxville', [6, 'TN']),
#  ('florence', [6, 'MS']),
#  ('fontana', [5, 'CA']),
#  ('henderson', [5, 'NV']),
#  ('beaumont', [5, 'CA']),
#  ('centennial', [5, 'CO']),
#  ('monroe', [5, 'GA']),
#  ('franklin', [5, 'NC']),
#  ('montgomery', [5, 'NY']),
#  ('fortpierce', [5, 'FL']),
#  ('york', [5, 'WI']),
#  ('westjordan', [5, 'UT']),
#  ('toledo', [5, 'OH']),
#  ('casper', [5, 'WY']),
#  ('fairfield', [5, 'TX']),
#  ('greeley', [5, 'CO']),
#  ('gainesville', [5, 'GA']),
#  ('chester', [5, 'SC']),
#  ('fayetteville', [5, 'NC']),
#  ('jurupavalley', [5, 'CA']),
#  ('eugene', [5, 'OR']),
#  ('riverside', [5, 'CA']),
#  ('vannuys', [5, 'CA']),
#  ('sparks', [5, 'NV']),
#  ('burlington', [5, 'IA']),
#  ('gary', [5, 'IN']),
#  ('irving', [5, 'TX']),
#  ('dayton', [5, 'OH']),
#  ('shelbyville', [5, 'TX']),
#  ('fremont', [5, 'CA']),
#  ('chattanooga', [5, 'TN']),
#  ('columbia', [5, 'MO']),
#  ('northlasvegas', [4, 'NV']),
#  ('sugarcreek', [4, 'OH']),
#  ('pittsburgh', [4, 'PA']),
#  ('azusa', [4, 'CA']),
#  ('hilo', [4, 'HI']),
#  ('savannah', [4, 'GA']),
#  ('lincoln', [4, 'CA']),
#  ('carrollton', [4, 'TX']),
#  ('smyrna', [4, 'TN']),
#  ('deland', [4, 'FL']),
#  ('citrusheights', [4, 'CA']),
#  ('inglewood', [4, 'CA']),
#  ('beaverton', [4, 'OR']),
#  ('phenixcity', [4, 'AL']),
#  ('westmemphis', [4, 'AR']),
#  ('deltona', [4, 'FL']),
#  ('rapidcity', [4, 'SD']),
#  ('terrehaute', [4, 'IN']),
#  ('virginiabeach', [4, 'VA']),
#  ('chickasha', [4, 'OK']),
#  ('lynn', [4, 'MA']),
#  ('corpuschristi', [4, 'TX']),
#  ('farmington', [4, 'NM']),
#  ('raleigh', [4, 'NC']),
#  ('federalway', [4, 'WA']),
#  ('evansville', [4, 'IN']),
#  ('kirkland', [4, 'WA']),
#  ('princeton', [4, 'NJ']),
#  ('grandjunction', [4, 'CO']),
#  ('brownsville', [4, 'TX']),
#  ('trenton', [4, 'NJ']),
#  ('augusta', [4, 'GA']),
#  ('gilbert', [4, 'AZ']),
#  ('waco', [4, 'TX']),
#  ('newcastle', [4, 'IN']),
#  ('fortcollins', [4, 'CO']),
#  ('englewood', [4, 'FL']),
#  ('syracuse', [4, 'NY']),
#  ('homewood', [4, 'AL']),
#  ('weatherford', [4, 'TX']),
#  ('brooksville', [4, 'FL']),
#  ('northcharleston', [4, 'SC']),
#  ('piedmont', [4, 'AL']),
#  ('hamilton', [4, 'AL']),
#  ('vineland', [4, 'NJ']),
#  ('sunnyvale', [4, 'CA']),
#  ('boulder', [4, 'CO']),
#  ('alexandria', [4, 'VA']),
#  ('vallejo', [4, 'CA']),
#  ('visalia', [4, 'CA']),
#  ('fortwayne', [4, 'IN']),
#  ('northglenn', [4, 'CO']),
#  ('harrisburg', [4, 'PA']),
#  ('buffalo', [4, 'NY']),
#  ('miamigardens', [4, 'FL']),
#  ('peoria', [4, 'AZ']),
#  ('buckeye', [4, 'AZ']),
#  ('medford', [4, 'OR']),
#  ('mission', [4, 'TX']),
#  ('chico', [4, 'CA']),
#  ('laredo', [4, 'TX']),
#  ('palmdale', [4, 'CA']),
#  ('yakima', [4, 'WA']),
#  ('indio', [4, 'CA']),
#  ('barstow', [4, 'CA']),
#  ('salem', [4, 'OR']),
#  ('torrance', [4, 'CA']),
#  ('bronx', [4, 'NY']),
#  ('napa', [4, 'CA']),
#  ('morgantown', [4, 'WV']),
#  ('topeka', [4, 'KS']),
#  ('gulfport', [4, 'MS']),
#  ('pasadena', [4, 'CA']),
#  ('eauclaire', [4, 'WI']),
#  ('st.joseph', [4, 'MO']),
#  ('douglas', [4, 'AZ']),
#  ('danville', [4, 'CA']),
#  ('hollywood', [4, 'FL']),
#  ('southgate', [4, 'CA']),
#  ('roswell', [4, 'GA']),
#  ('marana', [3, 'AZ']),
#  ('camden', [3, 'NJ']),
#  ('elkton', [3, 'MD']),
#  ('rossville', [3, 'GA']),
#  ('landover', [3, 'MD']),
#  ('paterson', [3, 'NJ']),
#  ('bradenton', [3, 'FL']),
#  ('mansfield', [3, 'OH']),
#  ('wasilla', [3, 'AK']),
#  ('troy', [3, 'MI']),
#  ('kerrville', [3, 'TX']),
#  ('belton', [3, 'SC']),
#  ('montpelier', [3, 'VT']),
#  ('newton', [3, 'KS']),
#  ('homestead', [3, 'FL']),
#  ('fairview', [3, 'TN']),
#  ('rosebud', [3, 'SD']),
#  ('meridian', [3, 'ID']),
#  ('manchester', [3, 'NH']),
#  ('silverspring', [3, 'MD']),
#  ('allentown', [3, 'PA']),
#  ('conroe', [3, 'TX']),
#  ('carsoncity', [3, 'NV']),
#  ('sparta', [3, 'NC']),
#  ('hutchinson', [3, 'KS']),
#  ('muncie', [3, 'IN']),
#  ('lexington', [3, 'NC']),
#  ('bend', [3, 'OR']),
#  ('delano', [3, 'CA']),
#  ('santafe', [3, 'NM']),
#  ('reading', [3, 'MA']),
#  ('newportnews', [3, 'VA']),
#  ('sallisaw', [3, 'OK']),
#  ('clearwater', [3, 'FL']),
#  ('idahofalls', [3, 'ID']),
#  ('covington', [3, 'GA']),
#  ('colton', [3, 'CA']),
#  ('atwater', [3, 'CA']),
#  ('gardena', [3, 'CA']),
#  ('spartanburg', [3, 'SC']),
#  ('greatfalls', [3, 'MT']),
#  ('stillwater', [3, 'MN']),
#  ('pensacola', [3, 'FL']),
#  ('santaclara', [3, 'CA']),
#  ('madison', [3, 'ME']),
#  ('edinburg', [3, 'TX']),
#  ('cottonwood', [3, 'CA']),
#  ('eastpoint', [3, 'GA']),
#  ('marion', [3, 'AR']),
#  ('southbend', [3, 'IN']),
#  ('palmbay', [3, 'FL']),
#  ('hanover', [3, 'CO']),
#  ('loslunas', [3, 'NM']),
#  ('portst.lucie', [3, 'FL']),
#  ('jonesboro', [3, 'AR']),
#  ('lawton', [3, 'OK']),
#  ('huntingtonbeach', [3, 'CA']),
#  ('orange', [3, 'NJ']),
#  ('athens', [3, 'GA']),
#  ('st.augustine', [3, 'FL']),
#  ('compton', [3, 'CA']),
#  ('unioncity', [3, 'GA']),
#  ('loveland', [3, 'CO']),
#  ('lakeelsinore', [3, 'CA']),
#  ('suncity', [3, 'SC']),
#  ('valdosta', [3, 'GA']),
#  ('mobile', [3, 'AL']),
#  ('independence', [3, 'MO']),
#  ('bristol', [3, 'TN']),
#  ('ceres', [3, 'CA']),
#  ('rockford', [3, 'IL']),
#  ('victorville', [3, 'CA']),
#  ('killeen', [3, 'TX']),
#  ('ruidoso', [3, 'NM']),
#  ('belleville', [3, 'IL']),
#  ('harvey', [3, 'IL']),
#  ('atlanticcity', [3, 'NJ']),
#  ('eagar', [3, 'AZ']),
#  ('hallandalebeach', [3, 'FL']),
#  ('hampton', [3, 'VA']),
#  ('st.petersburg', [3, 'FL']),
#  ('rochester', [3, 'NY']),
#  ('baytown', [3, 'TX']),
#  ('springdale', [3, 'AR']),
#  ('myrtlebeach', [3, 'SC']),
#  ('parker', [3, 'CO']),
#  ('cathedralcity', [3, 'CA']),
#  ('fullerton', [3, 'CA']),
#  ('paris', [3, 'TX']),
#  ('whittier', [3, 'CA']),
#  ('chandler', [3, 'AZ']),
#  ('lowell', [3, 'AR']),
#  ('yuma', [3, 'AZ']),
#  ('redlands', [3, 'CA']),
#  ('portsmouth', [3, 'VA']),
#  ('bexarcounty', [3, 'TX']),
#  ('burnsville', [3, 'NC']),
#  ('hayward', [3, 'CA']),
#  ('madera', [3, 'CA']),
#  ('temecula', [3, 'CA']),
#  ('avondale', [3, 'AZ']),
#  ('seaside', [3, 'OR']),
#  ('hobbs', [3, 'NM']),
#  ('salisbury', [3, 'NC']),
#  ('metairie', [3, 'LA']),
#  ('artesia', [3, 'CA']),
#  ('marietta', [3, 'GA']),
#  ('benton', [3, 'AR']),
#  ('elizabethtown', [3, 'KY']),
#  ('santamaria', [3, 'CA']),
#  ('gastonia', [3, 'NC']),
#  ('adamscounty', [3, 'CO']),
#  ('chino', [3, 'CA']),
#  ('cumming', [3, 'GA']),
#  ('houma', [3, 'LA']),
#  ('clanton', [2, 'AL']),
#  ('bolton', [2, 'VT']),
#  ('boerne', [2, 'TX']),
#  ('st.cloud', [2, 'FL']),
#  ('pompanobeach', [2, 'FL']),
#  ('hendersonville', [2, 'NC']),
#  ('bartlesville', [2, 'OK']),
#  ('spanishfork', [2, 'UT']),
#  ('roy', [2, 'UT']),
#  ('highland', [2, 'CA']),
#  ('henrycounty', [2, 'IN']),
#  ('southaven', [2, 'MS']),
#  ('georgetown', [2, 'KY']),
#  ('timberville', [2, 'VA']),
#  ('sanfernando', [2, 'CA']),
#  ('yubacity', [2, 'CA']),
#  ('montebello', [2, 'CA']),
#  ('ranchomirage', [2, 'CA']),
#  ('springhill', [2, 'FL']),
#  ('parma', [2, 'OH']),
#  ('hays', [2, 'KS']),
#  ('hardeeville', [2, 'SC']),
#  ('oakcliff', [2, 'TX']),
#  ('whitehaven', [2, 'TN']),
#  ('norwich', [2, 'CT']),
#  ('floydcounty', [2, 'GA']),
#  ('quartzsite', [2, 'AZ']),
#  ('southsaltlake', [2, 'UT']),
#  ('fairoaks', [2, 'CA']),
#  ('roanoke', [2, 'VA']),
#  ('cobbcounty', [2, 'GA']),
#  ('lompoc', [2, 'CA']),
#  ('flint', [2, 'MI']),
#  ('lenoir', [2, 'NC']),
#  ('mcminnville', [2, 'TN']),
#  ('easthartford', [2, 'CT']),
#  ('churchhill', [2, 'TN']),
#  ('sanford', [2, 'NC']),
#  ('abingdon', [2, 'VA']),
#  ('temple', [2, 'TX']),
#  ('nashua', [2, 'IA']),
#  ('magnolia', [2, 'AR']),
#  ('lealman', [2, 'FL']),
#  ('aiken', [2, 'SC']),
#  ('taylors', [2, 'SC']),
#  ('morris', [2, 'AL']),
#  ('pulaski', [2, 'VA']),
#  ('chesapeake', [2, 'VA']),
#  ('greensboro', [2, 'NC']),
#  ('clovis', [2, 'NM']),
#  ('hesperia', [2, 'CA']),
#  ('azle', [2, 'TX']),
#  ('ripon', [2, 'CA']),
#  ('aberdeen', [2, 'WA']),
#  ('burbank', [2, 'CA']),
#  ('sandcity', [2, 'CA']),
#  ('thornton', [2, 'CO']),
#  ('shelbytownship', [2, 'MI']),
#  ('sullivan', [2, 'IN']),
#  ('fortwaltonbeach', [2, 'FL']),
#  ('dunsmuir', [2, 'CA']),
#  ('selma', [2, 'CA']),
#  ('llano', [2, 'TX']),
#  ('capecoral', [2, 'FL']),
#  ('oceanside', [2, 'CA']),
#  ('redwoodcity', [2, 'CA']),
#  ('greenvillecounty', [2, 'SC']),
#  ('thomasville', [2, 'NC']),
#  ('emeryville', [2, 'CA']),
#  ('edmond', [2, 'OK']),
#  ('alamosa', [2, 'CO']),
#  ('pleasanton', [2, 'CA']),
#  ('shirley', [2, 'AR']),
#  ('fortlauderdale', [2, 'FL']),
#  ('salinas', [2, 'CA']),
#  ('hattiesburg', [2, 'MS']),
#  ('fairfax', [2, 'VA']),
#  ('risingsun', [2, 'MD']),
#  ('eastbatonrouge', [2, 'LA']),
#  ('portarthur', [2, 'TX']),
#  ('johnsoncity', [2, 'TN']),
#  ('lexingtoncounty', [2, 'SC']),
#  ('ashland', [2, 'WI']),
#  ('bluesprings', [2, 'MO']),
#  ('lansing', [2, 'IL']),
#  ('hollywoodhills', [2, 'CA']),
#  ('buford', [2, 'GA']),
#  ('brockton', [2, 'MA']),
#  ('wakeforest', [2, 'NC']),
#  ('livingston', [2, 'TN']),
#  ('bailey', [2, 'NC']),
#  ('waterfordtownship', [2, 'MI']),
#  ('hallcounty', [2, 'GA']),
#  ('klamathfalls', [2, 'OR']),
#  ('deerpark', [2, 'WA']),
#  ('palmbeachgardens', [2, 'FL']),
#  ('austell', [2, 'GA']),
#  ('picorivera', [2, 'CA']),
#  ('tolleson', [2, 'AZ']),
#  ('ranchocordova', [2, 'CA']),
#  ('soddy-daisy', [2, 'TN']),
#  ('fountaininn', [2, 'SC']),
#  ('kettering', [2, 'OH']),
#  ('carmichael', [2, 'CA']),
#  ('hackensack', [2, 'NJ']),
#  ('royaloak', [2, 'MI']),
#  ('carlsbad', [2, 'NM']),
#  ('harmony', [2, 'TX']),
#  ('leitchfield', [2, 'KY']),
#  ('muskogee', [2, 'OK']),
#  ('wagoner', [2, 'OK']),
#  ('owensboro', [2, 'KY']),
#  ('randallstown', [2, 'MD']),
#  ('elmonte', [2, 'CA']),
#  ('yonkers', [2, 'NY']),
#  ('millville', [2, 'NJ']),
#  ('lakestevens', [2, 'WA']),
#  ('pearland', [2, 'TX']),
#  ('hopewell', [2, 'VA']),
#  ('stonecounty', [2, 'AR']),
#  ('quincy', [2, 'FL']),
#  ('sylacauga', [2, 'AL']),
#  ('yorkcounty', [2, 'PA']),
#  ('olathe', [2, 'KS']),
#  ('kelso', [2, 'WA']),
#  ('dover', [2, 'DE']),
#  ('ozark', [2, 'AR']),
#  ('joplin', [2, 'MO']),
#  ('laramie', [2, 'WY']),
#  ('woodbridge', [2, 'VA']),
#  ('apachejunction', [2, 'AZ']),
#  ('appleton', [2, 'WI']),
#  ('flatwoods', [2, 'KY']),
#  ('allen', [2, 'TX']),
#  ('gresham', [2, 'OR']),
#  ('puna', [2, 'HI']),
#  ('lagrange', [2, 'GA']),
#  ('pointloma', [2, 'CA']),
#  ('sylmar', [2, 'CA']),
#  ('eustis', [2, 'FL']),
#  ('douglasville', [2, 'GA']),
#  ('metropolis', [2, 'IL']),
#  ('aloha', [2, 'OR']),
#  ('newiberia', [2, 'LA']),
#  ('apex', [2, 'NC']),
#  ('madisontownship', [2, 'OH']),
#  ('plano', [2, 'TX']),
#  ('iuka', [2, 'MS']),
#  ('crandon', [2, 'WI']),
#  ('pittsburg', [2, 'CA']),
#  ('winslow', [2, 'AZ']),
#  ('brookville', [2, 'IN']),
#  ('alamo', [2, 'TN']),
#  ('racine', [2, 'WI']),
#  ('loganville', [2, 'GA']),
#  ('cartersville', [2, 'GA']),
#  ('abilene', [2, 'TX']),
#  ('franklincounty', [2, 'OH']),
#  ('plymouthtownship', [2, 'MI']),
#  ('pomona', [2, 'CA']),
#  ('olivehurst', [2, 'CA']),
#  ('lawrenceburg', [2, 'TN']),
#  ('okmulgee', [2, 'OK']),
#  ('vacaville', [2, 'CA']),
#  ('kalamazoo', [2, 'MI']),
#  ('sandsprings', [2, 'OK']),
#  ('redbluff', [2, 'CA']),
#  ('hoover', [2, 'AL']),
#  ('pahrump', [2, 'NV']),
#  ('largo', [2, 'FL']),
#  ('woodville', [2, 'CA']),
#  ('mountainhome', [2, 'ID']),
#  ('winchester', [2, 'CA']),
#  ('rockville', [2, 'MD']),
#  ('catoosa', [2, 'OK']),
#  ('spencer', [2, 'MA']),
#  ('portage', [2, 'IN']),
#  ('tulare', [2, 'CA']),
#  ('clackamascounty', [2, 'OR']),
#  ('burien', [2, 'WA']),
#  ('anderson', [2, 'CA']),
#  ('liberty', [2, 'MO']),
#  ('spring', [2, 'TX']),
#  ('grandforks', [2, 'ND']),
#  ('tallahassee', [2, 'FL']),
#  ('tarboro', [2, 'NC']),
#  ('wauwatosa', [2, 'WI']),
#  ('mableton', [2, 'GA']),
#  ('biloxi', [2, 'MS']),
#  ('chulavista', [2, 'CA']),
#  ('riverview', [2, 'FL']),
#  ('hardwick', [2, 'NJ']),
#  ('denton', [2, 'TX']),
#  ('greece', [2, 'NY']),
#  ('mounthope', [2, 'WI']),
#  ('cincoranch', [2, 'TX']),
#  ('alpine', [2, 'CA']),
#  ('lodi', [2, 'CA']),
#  ('prescott', [2, 'AZ']),
#  ('milton', [2, 'FL']),
#  ('elcajon', [2, 'CA']),
#  ('davenport', [2, 'IA']),
#  ('lakejackson', [2, 'TX']),
#  ('walnutcreek', [2, 'CA']),
#  ('corning', [2, 'WI']),
#  ('roseville', [2, 'CA']),
#  ('archdale', [2, 'NC']),
#  ('stockbridge', [2, 'GA']),
#  ('missoula', [2, 'MT']),
#  ('trinidad', [2, 'CO']),
#  ('losbanos', [2, 'CA']),
#  ('overlandpark', [2, 'KS']),
#  ('huntersville', [2, 'NC']),
#  ('southlaketahoe', [2, 'CA']),
#  ('hudson', [2, 'NC']),
#  ('nacogdoches', [2, 'TX']),
#  ('hillsboro', [2, 'OR']),
#  ('alton', [2, 'IL']),
#  ('pawtucket', [2, 'RI']),
#  ('morenovalley', [2, 'CA']),
#  ('alamogordo', [2, 'NM']),
#  ('wellington', [2, 'UT']),
#  ('hickory', [2, 'NC']),
#  ('clermont', [2, 'FL']),
#  ('russellville', [2, 'AR']),
#  ('saginaw', [2, 'MI']),
#  ('lawndale', [2, 'IL']),
#  ('palatka', [2, 'FL']),
#  ('scottcounty', [2, 'KY']),
#  ('cerritos', [2, 'CA']),
#  ('vista', [2, 'CA']),
#  ('cocoa', [2, 'FL']),
#  ('nampa', [2, 'ID']),
#  ('lumberton', [2, 'MS']),
#  ('cache', [2, 'OK']),
#  ('naples', [2, 'ME']),
#  ('bernalillo', [2, 'NM']),
#  ('coloradocity', [2, 'CO']),
#  ('marysville', [2, 'WA']),
#  ('hohenwald', [2, 'TN']),
#  ('fairmont', [2, 'MN']),
#  ('albany', [2, 'NY']),
#  ('kokomo', [2, 'IN']),
#  ('lemongrove', [2, 'CA']),
#  ('uniontownship', [2, 'MI']),
#  ('everett', [2, 'WA']),
#  ('fortsmith', [2, 'AR']),
#  ('vassalboro', [2, 'ME']),
#  ('santaclarita', [2, 'CA']),
#  ('portorange', [2, 'FL']),
#  ('denhamsprings', [2, 'LA']),
#  ('hurst', [2, 'IL']),
#  ('lafollette', [2, 'TN']),
#  ('sandpoint', [2, 'ID']),
#  ("coeurd'alene", [2, 'ID']),
#  ('deserthotsprings', [2, 'CA']),
#  ('pinellaspark', [2, 'FL']),
#  ('parkville', [2, 'MD']),
#  ('sanysidro', [2, 'CA']),
#  ('darlingtoncounty', [2, 'SC']),
#  ('floralcity', [2, 'FL']),
#  ('irmo', [2, 'SC']),
#  ('dearborn', [2, 'MI']),
#  ('jacksoncounty', [2, 'KY']),
#  ('helena', [2, 'AR']),
#  ('westvalleycity', [2, 'UT']),
#  ('millbrook', [2, 'AL']),
#  ('eufaula', [2, 'AL']),
#  ('norman', [2, 'OK']),
#  ('elkhart', [2, 'IN']),
#  ('watervalley', [2, 'MS']),
#  ('delraybeach', [2, 'FL']),
#  ('monroecounty', [2, 'MS']),
#  ('orangepark', [2, 'FL']),
#  ('stonemountain', [2, 'GA']),
#  ('surprise', [2, 'AZ']),
#  ('ocala', [2, 'FL']),
#  ('waukesha', [2, 'WI']),
#  ('katy', [2, 'TX']),
#  ('forestpark', [2, 'GA']),
#  ('sanmarcos', [2, 'TX']),
#  ('lenoircity', [2, 'TN']),
#  ('evans', [2, 'CO']),
#  ('winnparish', [2, 'LA']),
#  ('manchestertownship', [2, 'PA']),
#  ('morristown', [2, 'TN']),
#  ('mcalester', [2, 'OK']),
#  ('casagrande', [2, 'AZ']),
#  ('cheyenne', [2, 'WY']),
#  ('webster', [2, 'TX']),
#  ('elliscounty', [2, 'TX']),
#  ('sedalia', [2, 'CO']),
#  ('kentwood', [2, 'MI']),
#  ('pinebluff', [2, 'AR']),
#  ('zion', [2, 'IL']),
#  ('wyoming', [2, 'MI']),
#  ('leaguecity', [2, 'TX']),
#  ('geneva', [2, 'WI']),
#  ('stlouis', [2, 'MO']),
#  ('cedarrapids', [2, 'IA']),
#  ('guthrie', [2, 'OK']),
#  ('spanaway', [2, 'WA']),
#  ('elkgrove', [2, 'CA']),
#  ('canton', [2, 'OH']),
#  ('boone', [2, 'IA']),
#  ('lakewales', [2, 'FL']),
#  ('presqueisle', [2, 'ME']),
#  ('crescentcity', [2, 'CA']),
#  ('tahlequah', [2, 'OK']),
#  ('oxford', [2, 'AL']),
#  ('harrisonburg', [2, 'VA']),
#  ('arvada', [2, 'CO']),
#  ('tupelo', [2, 'MS']),
#  ('rialto', [2, 'CA']),
#  ('london', [2, 'KY']),
#  ('bassett', [2, 'VA']),
#  ('queens', [2, 'NY']),
#  ('schertz', [2, 'TX']),
#  ('concord', [2, 'CA']),
#  ('lemoore', [2, 'CA']),
#  ('southelmonte', [2, 'CA']),
#  ('pineville', [2, 'LA']),
#  ('walton', [2, 'WV']),
#  ('euless', [2, 'TX']),
#  ('eagan', [2, 'MN']),
#  ('terrytown', [2, 'LA']),
#  ('kennewick', [2, 'WA']),
#  ('beverly', [2, 'MA']),
#  ('oldtown', [2, 'ME']),
#  ('middletown', [2, 'DE']),
#  ('tamarac', [2, 'FL']),
#  ('edgewood', [1, 'NM']),
#  ('stutsmancounty', [1, 'ND']),
#  ('peterborough', [1, 'NH']),
#  ('pahoa', [1, 'HI']),
#  ('arvonia', [1, 'VA']),
#  ('bardstown', [1, 'KY']),
#  ('applevalley', [1, 'CA']),
#  ('ragley', [1, 'LA']),
#  ('charlottte', [1, 'NC']),
#  ('westover', [1, 'AL']),
#  ('chesterfieldcounty', [1, 'SC']),
#  ('ouachitaparish', [1, 'LA']),
#  ('chanhassen', [1, 'MN']),
#  ('springtown', [1, 'TX']),
#  ('newtongrove', [1, 'NC']),
#  ('winters', [1, 'TX']),
#  ('rocklin', [1, 'CA']),
#  ('colby', [1, 'KS']),
#  ('richmondheights', [1, 'OH']),
#  ('rotterdam', [1, 'NY']),
#  ('provo', [1, 'UT']),
#  ('macoupincounty', [1, 'IL']),
#  ('pemberton', [1, 'NJ']),
#  ('ramseur', [1, 'NC']),
#  ('potsdam', [1, 'NY']),
#  ('hindscounty', [1, 'MS']),
#  ('navarre', [1, 'FL']),
#  ('pikecounty', [1, 'OH']),
#  ('washingtoncounty', [1, 'AL']),
#  ('nocona', [1, 'TX']),
#  ('belleglade', [1, 'FL']),
#  ('fortsumner', [1, 'NM']),
#  ('frametown', [1, 'WV']),
#  ('batesville', [1, 'AR']),
#  ('chathamcounty', [1, 'GA']),
#  ('neenah', [1, 'WI']),
#  ('carson', [1, 'CA']),
#  ('spenard', [1, 'AK']),
#  ('freeport', [1, 'TX']),
#  ('dalton', [1, 'IL']),
#  ('immokalee', [1, 'FL']),
#  ('dentoncounty', [1, 'TX']),
#  ('homer', [1, 'LA']),
#  ('winterhaven', [1, 'FL']),
#  ('northshore', [1, 'HI']),
#  ('ventnor', [1, 'NJ']),
#  ('gallatin', [1, 'TN']),
#  ('holiday', [1, 'FL']),
#  ('meadtownship', [1, 'PA']),
#  ('byron', [1, 'CA']),
#  ('callahan', [1, 'FL']),
#  ('byars', [1, 'OK']),
#  ('bloomfieldtownship', [1, 'MI']),
#  ('claibornecounty', [1, 'TN']),
#  ('bushnell', [1, 'FL']),
#  ('miltona', [1, 'MN']),
#  ('ladylake', [1, 'FL']),
#  ('laquinta', [1, 'CA']),
#  ('ronda', [1, 'NC']),
#  ('elkridge', [1, 'MD']),
#  ('poultney', [1, 'VT']),
#  ('brooklyncenter', [1, 'MN']),
#  ('bullshoals', [1, 'AR']),
#  ('lockhart', [1, 'TX']),
#  ('sanrafael', [1, 'NM']),
#  ('frenchlick', [1, 'IN']),
#  ('twinsburg', [1, 'OH']),
#  ('tishomingo', [1, 'OK']),
#  ('portwentworth', [1, 'GA']),
#  ('golden', [1, 'CO']),
#  ('lacombe', [1, 'LA']),
#  ('waukegan', [1, 'IL']),
#  ('soddydaisy', [1, 'TN']),
#  ('hurricane', [1, 'WV']),
#  ('vadnaisheights', [1, 'MN']),
#  ('portallen', [1, 'LA']),
#  ('st.tammanyparish', [1, 'LA']),
#  ('jesup', [1, 'GA']),
#  ('tomball', [1, 'TX']),
#  ('monckscorner', [1, 'SC']),
#  ('greenbelt', [1, 'MD']),
#  ('pattison', [1, 'TX']),
#  ('mannford', [1, 'OK']),
#  ('westouachita', [1, 'LA']),
#  ('lebanon', [1, 'MO']),
#  ('pima', [1, 'AZ']),
#  ('macon', [1, 'GA']),
#  ('reynoldsville', [1, 'WV']),
#  ('pacificbeach', [1, 'CA']),
#  ('brawley', [1, 'CA']),
#  ('laporte', [1, 'TX']),
#  ('welch', [1, 'WV']),
#  ('capecanaveral', [1, 'FL']),
#  ('cayce', [1, 'SC']),
#  ('swansea', [1, 'SC']),
#  ('mauriceriver', [1, 'NJ']),
#  ("lee'ssummit", [1, 'MO']),
#  ('blackfoot', [1, 'ID']),
#  ('ft.lauderdale', [1, 'FL']),
#  ('huron', [1, 'CA']),
#  ('sunridge', [1, 'NV']),
#  ('lincolnparish', [1, 'LA']),
#  ('southhaven', [1, 'IN']),
#  ('harriscounty', [1, 'TX']),
#  ('jeffersoncounty', [1, 'ID']),
#  ('rowe', [1, 'NM']),
#  ('delrio', [1, 'TX']),
#  ('peachtreecity', [1, 'GA']),
#  ('ashtabula', [1, 'OH']),
#  ('irvington', [1, 'NJ']),
#  ('anniston', [1, 'AL']),
#  ('perryville', [1, 'AR']),
#  ('northfortcollins', [1, 'CO']),
#  ('hensley', [1, 'WV']),
#  ('charlestonview', [1, 'CA']),
#  ('campbelltown', [1, 'PA']),
#  ('leedey', [1, 'OK']),
#  ('mountaingrove', [1, 'MO']),
#  ('petroleum', [1, 'WV']),
#  ('breauxbridge', [1, 'LA']),
#  ('sierrablanca', [1, 'TX']),
#  ('300blockofstatelineroad', [1, 'TN']),
#  ('trosper', [1, 'KY']),
#  ('tunbridge', [1, 'VT']),
#  ('santee', [1, 'CA']),
#  ('bloomington', [1, 'MN']),
#  ('glenvalley', [1, 'CA']),
#  ('poncacity', [1, 'OK']),
#  ('chalmette', [1, 'LA']),
#  ('pocatello', [1, 'ID']),
#  ('sunrise', [1, 'FL']),
#  ('dearbornheights', [1, 'MI']),
#  ('keaau', [1, 'HI']),
#  ('bangor', [1, 'ME']),
#  ('rainbowcity', [1, 'AL']),
#  ('campo', [1, 'CA']),
#  ('uniontown', [1, 'OH']),
#  ('boring', [1, 'OR']),
#  ('hummelstown', [1, 'PA']),
#  ('sims', [1, 'AR']),
#  ('graysoncounty', [1, 'VA']),
#  ('newbrunswick', [1, 'NJ']),
#  ('hawaiiangardens', [1, 'CA']),
#  ('elizabethon', [1, 'TN']),
#  ('morenci', [1, 'AZ']),
#  ('culpeper', [1, 'VA']),
#  ('cochrancounty', [1, 'TX']),
#  ('tatecounty', [1, 'MS']),
#  ('fonddulac', [1, 'WI']),
#  ('strabantownship', [1, 'PA']),
#  ('cheney', [1, 'WA']),
#  ('randolphcounty', [1, 'NC']),
#  ('orcutt', [1, 'CA']),
#  ('goodyear', [1, 'AZ']),
#  ('littlehavana', [1, 'FL']),
#  ('lakeview', [1, 'SC']),
#  ('deridder', [1, 'LA']),
#  ('emporia', [1, 'VA']),
#  ('wales', [1, 'ME']),
#  ('penasco', [1, 'NM']),
#  ('applecreek', [1, 'OH']),
#  ('talladega', [1, 'AL']),
#  ('martinez', [1, 'CA']),
#  ('cochran', [1, 'GA']),
#  ('chinohills', [1, 'CA']),
#  ('lakescharles', [1, 'LA']),
#  ('longmont', [1, 'CO']),
#  ('helena-westhelena', [1, 'AR']),
#  ('mosspoint', [1, 'MS']),
#  ('bonaire', [1, 'GA']),
#  ('decatur', [1, 'GA']),
#  ('pinetop-lakeside', [1, 'AZ']),
#  ('showlow', [1, 'AZ']),
#  ('kirkwood', [1, 'NY']),
#  ('irvine', [1, 'CA']),
#  ('morehead', [1, 'KY']),
#  ('bunch', [1, 'OK']),
#  ('wapato', [1, 'WA']),
#  ('eatonrapidstownship', [1, 'MI']),
#  ('unioncounty', [1, 'SC']),
#  ('whitehall', [1, 'OH']),
#  ('plantation', [1, 'FL']),
#  ('millerton', [1, 'OK']),
#  ('islip', [1, 'NY']),
#  ('hixson', [1, 'TN']),
#  ('watsonville', [1, 'CA']),
#  ('vandalia', [1, 'OH']),
#  ('quinlan', [1, 'TX']),
#  ('spokanevalley', [1, 'WA']),
#  ('leavenworth', [1, 'KS']),
#  ('dakotacity', [1, 'IA']),
#  ('mannington', [1, 'WV']),
#  ('childress', [1, 'TX']),
#  ('columbiaheights', [1, 'MN']),
#  ('jeffersonville', [1, 'OH']),
#  ('tukwila', [1, 'WA']),
#  ('downey', [1, 'CA']),
#  ('westmonroe', [1, 'LA']),
#  ('mountainpine', [1, 'AR']),
#  ('gunlock', [1, 'KY']),
#  ('kahuku', [1, 'HI']),
#  ('buttecounty', [1, 'CA']),
#  ('lodgegrass', [1, 'MT']),
#  ('nicholasville', [1, 'KY']),
#  ('watagua', [1, 'TX']),
#  ('paloalto', [1, 'CA']),
#  ('glenwood', [1, 'GA']),
#  ('parowan', [1, 'UT']),
#  ('ansoncounty', [1, 'NC']),
#  ('tewksbury', [1, 'MA']),
#  ('portst.joe', [1, 'FL']),
#  ('beckley', [1, 'WV']),
#  ('oldsaybrook', [1, 'CT']),
#  ('humboldt', [1, 'TN']),
#  ('jamaica', [1, 'NY']),
#  ('osteen', [1, 'FL']),
#  ('charlottesville', [1, 'VA']),
#  ('northeast', [1, 'MD']),
#  ('wimberley', [1, 'TX']),
#  ('polkcounty', [1, 'OR']),
#  ('villapark', [1, 'IL']),
#  ('newlondon', [1, 'WI']),
#  ('kendalelakes', [1, 'FL']),
#  ('peachland', [1, 'NC']),
#  ('richtonpark', [1, 'IL']),
#  ('anadarko', [1, 'OK']),
#  ('eclectic', [1, 'AL']),
#  ('mckinney', [1, 'TX']),
#  ('aguanga', [1, 'CA']),
#  ('maricopa', [1, 'AZ']),
#  ('elko', [1, 'NV']),
#  ('venice', [1, 'CA']),
#  ('brownstown', [1, 'IN']),
#  ('blackriverfalls', [1, 'WI']),
#  ('barbourville', [1, 'KY']),
#  ('dundalk', [1, 'MD']),
#  ('bisbee', [1, 'AZ']),
#  ('myra', [1, 'TX']),
#  ('waynecounty', [1, 'KY']),
#  ('manatee', [1, 'FL']),
#  ('fallschurch', [1, 'VA']),
#  ('wilderville', [1, 'OR']),
#  ('waldoboro', [1, 'ME']),
#  ('chinle', [1, 'AZ']),
#  ('nikolaevsk', [1, 'AK']),
#  ('bossiercity', [1, 'LA']),
#  ('grandprairie', [1, 'TX']),
#  ('monahans', [1, 'TX']),
#  ('gunnisoncounty', [1, 'CO']),
#  ('sneads', [1, 'FL']),
#  ('jasper', [1, 'OH']),
#  ('horseheads', [1, 'NY']),
#  ('chestertown', [1, 'MD']),
#  ('indiantown', [1, 'FL']),
#  ('larimercounty', [1, 'CO']),
#  ('pittsfield', [1, 'MA']),
#  ('sanger', [1, 'TX']),
#  ('wasco', [1, 'CA']),
#  ('weymouth', [1, 'MA']),
#  ('rector', [1, 'AR']),
#  ('hopkinscounty', [1, 'TX']),
#  ('mercury', [1, 'NV']),
#  ('belgrade', [1, 'ME']),
#  ('palermo', [1, 'CA']),
#  ('rockledge', [1, 'FL']),
#  ('dearborncounty', [1, 'IN']),
#  ('pocahontascounty', [1, 'WV']),
#  ('newpaltz', [1, 'NY']),
#  ('eaststroudsburg', [1, 'PA']),
#  ('lauderhill', [1, 'FL']),
#  ('panoramacity', [1, 'CA']),
#  ('blackmantownship', [1, 'MI']),
#  ('christiancounty', [1, 'KY']),
#  ('grenada', [1, 'MS']),
#  ('catotownship', [1, 'MI']),
#  ('olympia', [1, 'WA']),
#  ('aragonite', [1, 'UT']),
#  ('elsereno', [1, 'CA']),
#  ('lawtey', [1, 'FL']),
#  ('simpsonville', [1, 'SC']),
#  ('fairborn', [1, 'OH']),
#  ('uniongrove', [1, 'NC']),
#  ('oneida', [1, 'TN']),
#  ('wausau', [1, 'WI']),
#  ('orangecity', [1, 'FL']),
#  ('lyndhurst', [1, 'NJ']),
#  ('sancarlospark', [1, 'FL']),
#  ('tremont', [1, 'NY']),
#  ('tustin', [1, 'CA']),
#  ('tehachapi', [1, 'CA']),
#  ('overlea', [1, 'MD']),
#  ('formosa', [1, 'AR']),
#  ('idealbeach', [1, 'NJ']),
#  ('bellville', [1, 'TX']),
#  ('easthollywood', [1, 'CA']),
#  ('rangley', [1, 'CO']),
#  ('coralsprings', [1, 'FL']),
#  ('wythecounty', [1, 'VA']),
#  ('greenecounty', [1, 'MO']),
#  ('kinston', [1, 'NC']),
#  ('paulden', [1, 'AZ']),
#  ('farmersbranch', [1, 'TX']),
#  ('scarbo', [1, 'WV']),
#  ('taunton', [1, 'MA']),
#  ('burnet', [1, 'TX']),
#  ('ohatchee', [1, 'AL']),
#  ('rifle', [1, 'CO']),
#  ('amity', [1, 'OR']),
#  ('oilsprings', [1, 'KY']),
#  ('oaks', [1, 'OK']),
#  ('kingsland', [1, 'GA']),
#  ('coalcounty', [1, 'OK']),
#  ('lynchburg', [1, 'VA']),
#  ('enoree', [1, 'SC']),
#  ('gilroy', [1, 'CA']),
#  ('poplarbluff', [1, 'MO']),
#  ('dadeville', [1, 'AL']),
#  ('mandeville', [1, 'LA']),
#  ('hammond', [1, 'LA']),
#  ('newalbany', [1, 'IN']),
#  ('wilhoit', [1, 'AZ']),
#  ('eatoncounty', [1, 'MI']),
#  ('lewistown', [1, 'PA']),
#  ('wallawalla', [1, 'WA']),
#  ('gonzalescounty', [1, 'TX']),
#  ('oldbridge', [1, 'NJ']),
#  ('windsor', [1, 'CA']),
#  ('camarillo', [1, 'CA']),
#  ('grandprarie', [1, 'TX']),
#  ...]

# %%
city_pop_dic_lst[6][0] in city_kills_state_list[598][0]
# Out:
# False

# %%
city_pop_dic_lst[0][1][1]
# Out:
# 'AL'

# %%
city_kills_state[0][1][0]
# Out:
# 71

# %%
def get_state(lst_of_dic,x):
    return lst_of_dic[x][1][1]
def get_number(lst_of_dic,x):
    return lst_of_dic[x][1][0]

# %%
get_number(city_pop_dic_lst,0)
# Out:
# 192

# %%
get_number(city_kills_state,0)
# Out:
# 71

# %%
def autocorrect(user_word, valid_words, diff_function, limit):
    if user_word in valid_words:
        return user_word
    a=min(valid_words,key=lambda word: diff_function(user_word,word,limit))
    if diff_function(user_word,a,limit)>limit:
            return user_word
    else:
        return a

# %%
'pop->per capita'
asdsadofj=city_kills_state_list
def pop_to_per_capita(lst_of_dic):
    for i in range(len(lst_of_dic)):
        for x in range(len(city_pop_dic_lst)):
            if lst_of_dic[i][0] in city_pop_dic_lst[x][0]:
                if lst_of_dic[i][1][1] == city_pop_dic_lst[x][1][1]:
                    per_capita=(lst_of_dic[i][1][0])/int((city_pop_dic_lst[x][1][0]))
                    lst_of_dic[i][1].append(per_capita)
                # lst_of_dic[i] = (lst_of_dic[i][0], [per_capita, lst_of_dic[i][1][1]])
                elif lst_of_dic[i][1][1] != city_pop_dic_lst[x][1][1]:
                    lst_of_dic[i][1].append('wrong state')
            
    return lst_of_dic

kills_per_capita=pop_to_per_capita(asdsadofj)

print(len(kills_per_capita))

kills_per_capita
# Out:
# C:\Users\larry\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in longlong_scalars
# 2208
# [('losangeles',
#   [71, 'CA', 0.0005612825701998482, 0.005759247242050617, 'wrong state']),
#  ('phoenix',
#   [69, 'AZ', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('houston',
#   [47,
#    'TX',
#    2.2386804931384444e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.00276747335570865]),
#  ('lasvegas', [41, 'NV', 'wrong state', 0.00018897405524495185]),
#  ('sanantonio',
#   [36, 'TX', 'wrong state', 2.7120544038113406e-05, 'wrong state']),
#  ('columbus',
#   [34,
#    'OH',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.015910154422087038,
#    'wrong state']),
#  ('chicago',
#   [34,
#    'IL',
#    1.2613156709568712e-05,
#    0.0011230017175320386,
#    0.0023767913317022022,
#    0.0010437772456560446,
#    0.008214544575984537,
#    0.0012552610204533707,
#    'wrong state',
#    'wrong state']),
#  ('albuquerque', [31, 'NM', 5.679195093175439e-05, 0.005146082337317397]),
#  ('miami',
#   [29,
#    'FL',
#    'wrong state',
#    'wrong state',
#    0.00033037514667517287,
#    0.0002706056901844784,
#    0.0009877047784476005,
#    0.0027637472600781474,
#    0.0021000796581939316,
#    0.0004933147348008029,
#    0.0006984081111673048,
#    0.0024877755854851163,
#    0.0008124159569699686,
#    0.0005246874491143638,
#    0.004861693210393965,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('st.louis',
#   [29,
#    'MO',
#    'wrong state',
#    9.082538350235207e-05,
#    'wrong state',
#    'wrong state',
#    0.0019938123066345825,
#    'wrong state',
#    'wrong state']),
#  ('austin',
#   [28,
#    'TX',
#    3.542554941231544e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('jacksonville',
#   [26, 'NC', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('kansascity',
#   [26, 'KS', 0.0020942408376963353, 'wrong state', 'wrong state']),
#  ('denver',
#   [26,
#    'CO',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('oklahomacity', [25, 'OK', 4.310352259228033e-05]),
#  ('tucson',
#   [25,
#    'AZ',
#    0.004405286343612335,
#    0.004423213021939137,
#    4.806620061678549e-05,
#    0.002050524934383202]),
#  ('bakersfield', [21, 'CA', 6.0434611189612156e-05, 'wrong state']),
#  ('tulsa', [21, 'OK', 5.358427786254867e-05]),
#  ('louisville',
#   [18,
#    'KY',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    3.0133743598672106e-05,
#    'wrong state']),
#  ('atlanta',
#   [18,
#    'GA',
#    'wrong state',
#    0.00044492782281985367,
#    'wrong state',
#    'wrong state']),
#  ('newyork',
#   [18,
#    'NY',
#    'wrong state',
#    'wrong state',
#    2.2017990410675886e-06,
#    0.005410279531109108]),
#  ('dallas',
#   [17,
#    'TX',
#    1.41924970112271e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.0023926812104152007,
#    'wrong state']),
#  ('mesa',
#   [17,
#    'AZ',
#    0.010932475884244373,
#    'wrong state',
#    0.022222222222222223,
#    0.0272,
#    0.035416666666666666,
#    0.017671517671517672,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('fresno', [17, 'CA', 'wrong state', 'wrong state']),
#  ('baltimore',
#   [16,
#    'MD',
#    2.576651351695195e-05,
#    0.0022795269981478843,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('sanjose',
#   [16,
#    'CA',
#    'wrong state',
#    0.0007785509220962483,
#    'wrong state',
#    'wrong state']),
#  ('indianapolis', [16, 'IN', 1.9501611930111097e-05]),
#  ('portland', [16, 'OR', 'wrong state', 'wrong state', 'wrong state']),
#  ('orlando', [16, 'FL', 6.714225765841376e-05, 'wrong state']),
#  ('springfield',
#   [15,
#    'FL',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('aurora',
#   [15,
#    'CO',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('arlington',
#   [15,
#    'TX',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('charlotte',
#   [15,
#    'NC',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('sanfrancisco', [15, 'CA', 1.8628102355213076e-05, 0.00023573045008800603]),
#  ('coloradosprings', [15, 'CO', 3.602071911763646e-05]),
#  ('washington',
#   [15,
#    'DC',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('fortworth', [14, 'TX', 1.888813636155131e-05]),
#  ('memphis',
#   [14, 'TN', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('philadelphia',
#   [14,
#    'PA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.012903225806451613]),
#  ('longbeach', [14, 'CA', 'wrong state', 'wrong state']),
#  ('sandiego',
#   [14, 'CA', 0.0006601282534892493, 'wrong state', 0.0013849045405084578]),
#  ('pueblo',
#   [12,
#    'CO',
#    'wrong state',
#    0.0004048992813037757,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('elpaso', [11, 'TX', 'wrong state', 1.6945993119926795e-05]),
#  ('seattle', [11, 'WA', 1.807248710281602e-05]),
#  ('westminster', [11, 'CA', 'wrong state', 'wrong state', 'wrong state']),
#  ('saltlakecity', [11, 'UT', 5.900021454623471e-05]),
#  ('spokane',
#   [11, 'WA', 5.265274081449004e-05, 'wrong state', 0.0001225558464709487]),
#  ('stockton',
#   [11,
#    'CA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('jackson',
#   [11,
#    'MI',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('reno',
#   [11,
#    'NV',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('milwaukee',
#   [11,
#    'WI',
#    1.84925853138612e-05,
#    0.0005199470599357157,
#    0.002615311459819306]),
#  ('sacramento', [10, 'CA', 'wrong state', 0.00020515345478417857]),
#  ('omaha',
#   [10,
#    'NE',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('richmond',
#   [10,
#    'VA',
#    'wrong state',
#    'wrong state',
#    4.896823920005485e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('tacoma', [10, 'WA', 5.040398796352768e-05]),
#  ('lascruces', [10, 'NM', 0.00010244012374766949]),
#  ('glendale',
#   [10, 'AZ', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('batonrouge', [10, 'LA', 4.3574313813493224e-05]),
#  ('honolulu', [10, 'HI', 0.00020034459269944305, 2.9651066252342433e-05]),
#  ('greenville',
#   [10, 'NC', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('santaana', [10, 'CA', 3.081398215254154e-05, 'wrong state']),
#  ('sanbernardino', [10, 'CA', 4.7636287418303766e-05]),
#  ('neworleans', [9, 'LA', 2.6175802506478512e-05]),
#  ('lakewood',
#   [9,
#    'CO',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('st.paul',
#   [9,
#    'MN',
#    'wrong state',
#    'wrong state',
#    0.0007853403141361257,
#    0.0017048683462777042,
#    0.0004464285714285714,
#    0.00046059365404298874,
#    'wrong state']),
#  ('wichita', [9, 'KS', 2.35375345217173e-05, 'wrong state']),
#  ('fairbanks', [9, 'AK', 0.0002853971777390201, 'wrong state']),
#  ('anaheim', [9, 'CA', 2.6764605296418002e-05]),
#  ('shreveport', [9, 'LA', 4.515556090732574e-05]),
#  ('newark',
#   [9,
#    'NJ',
#    'wrong state',
#    'wrong state',
#    0.003740648379052369,
#    'wrong state']),
#  ('oakland',
#   [9,
#    'CA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('flagstaff', [9, 'AZ', 0.0001366327614999241]),
#  ('huntsville', [9, 'AL', 'wrong state', 'wrong state', 'wrong state']),
#  ('amarillo', [9, 'TX', 'wrong state', 'wrong state', 4.719578384331e-05]),
#  ('tampa', [9, 'FL', 'wrong state']),
#  ('clinton',
#   [9,
#    'TN',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('billings', [9, 'MT', 'wrong state', 8.639723528847077e-05, 'wrong state']),
#  ('anchorage', [9, 'AK', 3.084029524442647e-05, 'wrong state']),
#  ('detroit',
#   [9,
#    'MI',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.004312410158121706,
#    'wrong state']),
#  ('birmingham', [8, 'AL', 'wrong state', 'wrong state', 'wrong state']),
#  ('modesto',
#   [8, 'CA', 3.976834936494917e-05, 0.0014079549454417458, 'wrong state']),
#  ('longview',
#   [8, 'TX', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('redding', [8, 'CA', 'wrong state']),
#  ('wilmington',
#   [8,
#    'DE',
#    'wrong state',
#    0.0010140702243630372,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('vancouver', [8, 'WA', 4.944650814940262e-05]),
#  ('boston',
#   [8,
#    'MA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('tempe', [8, 'AZ', 4.946852256073807e-05, 'wrong state', 'wrong state']),
#  ('lancaster', [8, 'PA', 'wrong state', 'wrong state', 'wrong state']),
#  ('clarksville',
#   [7,
#    'IN',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('charleston',
#   [7,
#    'WV',
#    0.00013618677042801557,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.0005204460966542751]),
#  ('cincinnati', [7, 'OH', 2.3573547785265186e-05]),
#  ('boise', [7, 'ID', 'wrong state']),
#  ('nashville',
#   [7,
#    'TN',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    1.1642953850657494e-05]),
#  ('odessa',
#   [7,
#    'TX',
#    'wrong state',
#    7.004202521512908e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.0003082749812833047]),
#  ('hemet', [7, 'CA', 0.0004018831094270295, 8.89939865491946e-05]),
#  ('littlerock', [7, 'AR', 'wrong state', 0.00011235233692860811]),
#  ('durham', [7, 'NC', 'wrong state', 'wrong state']),
#  ('norfolk', [7, 'VA', 2.882995679625046e-05]),
#  ('lakeland',
#   [7,
#    'FL',
#    'wrong state',
#    'wrong state',
#    0.0006331403762662807,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('ontario', [6, 'CA', 'wrong state', 'wrong state']),
#  ('ogden',
#   [6,
#    'UT',
#    7.244189556293389e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.00034568185746384746,
#    0.00036293249455601257,
#    'wrong state']),
#  ('auburn',
#   [6,
#    'WA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('brooklyn',
#   [6,
#    'OH',
#    0.0005372011818426001,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.0038885288399222295]),
#  ('garland',
#   [6,
#    'TX',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    7.612570892066433e-05,
#    'wrong state']),
#  ('minneapolis', [6, 'MN', 1.568307639226511e-05]),
#  ('desmoines',
#   [6, 'IA', 'wrong state', 0.00010599021357028035, 'wrong state']),
#  ('antioch', [6, 'CA', 5.8609776110655256e-05, 'wrong state']),
#  ('cleveland',
#   [6,
#    'OH',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.00013009258255458468,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('scottsdale', [6, 'AZ', 2.7600800423212272e-05]),
#  ('kent',
#   [6,
#    'WA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    6.49273354903637e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('kingman', [6, 'AZ', 'wrong state', 0.0004944783253667381, 'wrong state']),
#  ('akron',
#   [6,
#    'OH',
#    'wrong state',
#    3.0134096730450506e-05,
#    'wrong state',
#    'wrong state']),
#  ('midland',
#   [6,
#    'TX',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('knoxville',
#   [6,
#    'TN',
#    'wrong state',
#    3.354316446213536e-05,
#    'wrong state',
#    'wrong state']),
#  ('florence',
#   [6,
#    'MS',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('fontana', [5, 'CA', 'wrong state', 'wrong state']),
#  ('henderson',
#   [5,
#    'NV',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('beaumont', [5, 'CA', 'wrong state', 'wrong state']),
#  ('centennial', [5, 'CO', 'wrong state', 'wrong state']),
#  ('monroe',
#   [5,
#    'GA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('franklin',
#   [5,
#    'NC',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.002471576866040534,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.00429553264604811,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('montgomery',
#   [5,
#    'NY',
#    'wrong state',
#    'wrong state',
#    0.0013109596224436288,
#    'wrong state',
#    'wrong state',
#    0.003182686187141948,
#    'wrong state',
#    'wrong state']),
#  ('fortpierce',
#   [5,
#    'FL',
#    0.00012022120702091849,
#    0.0007723200494284832,
#    0.0009877518767285659]),
#  ('york',
#   [5,
#    'WI',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('westjordan', [5, 'UT', 4.821042887997532e-05]),
#  ('toledo', [5, 'OH', 'wrong state', 'wrong state', 'wrong state']),
#  ('casper', [5, 'WY', 9.03897606479138e-05, 0.012468827930174564]),
#  ('fairfield',
#   [5,
#    'TX',
#    0.0016943409013893595,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('greeley',
#   [5,
#    'CO',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('gainesville', [5, 'GA', 'wrong state', 'wrong state', 'wrong state']),
#  ('chester',
#   [5,
#    'SC',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.0033967391304347825,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('fayetteville', [5, 'NC', 'wrong state', 'wrong state', 'wrong state']),
#  ('jurupavalley', [5, 'CA']),
#  ('eugene', [5, 'OR', 3.201331754009668e-05]),
#  ('riverside',
#   [5,
#    'CA',
#    'wrong state',
#    0.004262574595055414,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('vannuys', [5, 'CA']),
#  ('sparks', [5, 'NV', 'wrong state', 'wrong state']),
#  ('burlington',
#   [5,
#    'IA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.0016846361185983828,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('gary',
#   [5, 'IN', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('irving',
#   [5,
#    'TX',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    2.311711128577373e-05,
#    'wrong state']),
#  ('dayton',
#   [5,
#    'OH',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('shelbyville', [5, 'TX', 'wrong state']),
#  ('fremont',
#   [5, 'CA', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('chattanooga',
#   [5, 'TN', 'wrong state', 'wrong state', 2.9819769314264586e-05]),
#  ('columbia',
#   [5,
#    'MO',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('northlasvegas', [4, 'NV', 1.8436493194629448e-05]),
#  ('sugarcreek',
#   [4, 'OH', 'wrong state', 0.0018018018018018018, 'wrong state']),
#  ('pittsburgh',
#   [4,
#    'PA',
#    0.0021953896816684962,
#    1.3084552377463167e-05,
#    0.002544529262086514]),
#  ('azusa', [4, 'CA', 8.627941588835444e-05]),
#  ('hilo',
#   [4,
#    'HI',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    9.245775836164852e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('savannah', [4, 'GA', 'wrong state', 'wrong state', 'wrong state']),
#  ('lincoln',
#   [4,
#    'CA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('carrollton',
#   [4,
#    'TX',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('smyrna',
#   [4,
#    'TN',
#    0.00010006504227748036,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('deland',
#   [4,
#    'FL',
#    0.00014797824719766194,
#    0.0038022813688212928,
#    0.002758620689655172,
#    0.0011315417256011315,
#    'wrong state',
#    'wrong state']),
#  ('citrusheights', [4, 'CA', 4.801863122891682e-05]),
#  ('inglewood', [4, 'CA', 3.647205784468374e-05, 'wrong state', 'wrong state']),
#  ('beaverton', [4, 'OR', 'wrong state', 4.454194180595303e-05]),
#  ('phenixcity', [4, 'AL', 0.00012186947778928768]),
#  ('westmemphis', [4, 'AR', 0.00015240998285387692]),
#  ('deltona', [4, 'FL', 4.6958277570378716e-05]),
#  ('rapidcity', [4, 'SD', 5.8861616339984696e-05]),
#  ('terrehaute',
#   [4,
#    'IN',
#    0.0009291521486643438,
#    6.580570864522498e-05,
#    0.0017889087656529517]),
#  ('virginiabeach', [4, 'VA', 9.132545194683033e-06]),
#  ('chickasha', [4, 'OK', 0.0002494387627837366]),
#  ('lynn',
#   [4,
#    'MA',
#    'wrong state',
#    4.4282567060412495e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.00034494653328734045,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('corpuschristi', [4, 'TX', 1.3105515783955572e-05]),
#  ('farmington',
#   [4, 'NM', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('raleigh',
#   [4, 'NC', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('federalway', [4, 'WA', 4.4789823752043534e-05]),
#  ('evansville', [4, 'IN', 'wrong state', 'wrong state', 'wrong state']),
#  ('kirkland', [4, 'WA', 'wrong state', 8.198905446122942e-05]),
#  ('princeton',
#   [4,
#    'NJ',
#    'wrong state',
#    0.00032501828227837813,
#    0.0016227180527383367,
#    0.00028914269191846175,
#    'wrong state']),
#  ('grandjunction', [4, 'CO', 'wrong state']),
#  ('brownsville',
#   [4,
#    'TX',
#    'wrong state',
#    2.285413917028048e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('trenton',
#   [4,
#    'NJ',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('augusta',
#   [4,
#    'GA',
#    'wrong state',
#    2.0424419435877536e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('gilbert',
#   [4,
#    'AZ',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('waco',
#   [4,
#    'TX',
#    3.204999799687513e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.003418803418803419,
#    'wrong state']),
#  ('newcastle',
#   [4,
#    'IN',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('fortcollins', [4, 'CO', 2.7780478657647272e-05]),
#  ('englewood', [4, 'FL', 'wrong state', 'wrong state', 'wrong state']),
#  ('syracuse',
#   [4,
#    'NY',
#    'wrong state',
#    'wrong state',
#    0.0012970168612191958,
#    0.000588235294117647,
#    'wrong state']),
#  ('homewood',
#   [4,
#    'AL',
#    0.00015893829220805023,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('weatherford', [4, 'TX', 0.00015841584158415842]),
#  ('brooksville',
#   [4,
#    'FL',
#    'wrong state',
#    0.001128668171557562,
#    0.0009982530571499876,
#    'wrong state']),
#  ('northcharleston', [4, 'SC', 4.103784715453827e-05]),
#  ('piedmont', [4, 'AL', 'wrong state', 'wrong state']),
#  ('hamilton',
#   [4,
#    'AL',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('vineland', [4, 'NJ', 6.58718134510243e-05, 'wrong state']),
#  ('sunnyvale', [4, 'CA', 2.8554907517793276e-05, 'wrong state']),
#  ('boulder',
#   [4,
#    'CO',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('alexandria',
#   [4,
#    'VA',
#    2.8578369032479315e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('vallejo', [4, 'CA', 3.450000862500216e-05]),
#  ('visalia', [4, 'CA', 3.2143488532810465e-05]),
#  ('fortwayne', [4, 'IN', 1.5767212869199145e-05]),
#  ('northglenn', [4, 'CO', 0.00011176618514068569]),
#  ('harrisburg', [4, 'PA', 'wrong state', 'wrong state', 'wrong state']),
#  ('buffalo',
#   [4,
#    'NY',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.0006594131223211342,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('miamigardens', [4, 'FL', 3.732492278406599e-05]),
#  ('peoria',
#   [4,
#    'AZ',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('buckeye', [4, 'AZ', 7.862253321802028e-05, 'wrong state', 'wrong state']),
#  ('medford', [4, 'OR', 'wrong state', 'wrong state']),
#  ('mission',
#   [4,
#    'TX',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    5.1908951698720446e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.00010958603873866469,
#    0.037383177570093455]),
#  ('chico',
#   [4,
#    'CA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('laredo', [4, 'TX', 1.6942619583126844e-05, 0.18181818181818182, inf]),
#  ('palmdale', [4, 'CA', 'wrong state']),
#  ('yakima', [4, 'WA', 4.392370452523966e-05]),
#  ('indio',
#   [4,
#    'CA',
#    'wrong state',
#    0.00411522633744856,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('barstow', [4, 'CA', 'wrong state']),
#  ('salem',
#   [4,
#    'OR',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('torrance', [4, 'CA', 2.7503128480864698e-05]),
#  ('bronx', [4, 'NY', 0.0006326111023248458]),
#  ('napa',
#   [4,
#    'CA',
#    'wrong state',
#    'wrong state',
#    4.96709300881659e-05,
#    5.20054605733602e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('morgantown', [4, 'WV', 'wrong state', 0.00013486176668914363]),
#  ('topeka', [4, 'KS', 'wrong state', 'wrong state', 3.137919402540146e-05]),
#  ('gulfport', [4, 'MS', 5.90031419173071e-05, 'wrong state']),
#  ('pasadena',
#   [4,
#    'CA',
#    0.0006510416666666666,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('eauclaire', [4, 'WI', 'wrong state', 'wrong state', 6.071368941912178e-05]),
#  ('st.joseph', [4, 'MO', 'wrong state', 'wrong state', 'wrong state']),
#  ('douglas',
#   [4,
#    'AZ',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('danville',
#   [4, 'CA', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('hollywood',
#   [4,
#    'FL',
#    'wrong state',
#    'wrong state',
#    2.8415548988406457e-05,
#    'wrong state']),
#  ('southgate', [4, 'CA', 'wrong state', 'wrong state']),
#  ('roswell',
#   [4, 'GA', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('marana', [3, 'AZ', 8.58099024627442e-05]),
#  ('camden',
#   [3,
#    'NJ',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('elkton',
#   [3, 'MD', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('rossville',
#   [3,
#    'GA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('landover', [3, 'MD', 0.00012999393361643122, 0.0017783046828689982]),
#  ('paterson', [3, 'NJ', 2.0519976196827612e-05]),
#  ('bradenton',
#   [3,
#    'FL',
#    6.0549792112380414e-05,
#    0.0025619128949615714,
#    0.00013526918567950222,
#    0.0007156488549618321]),
#  ('mansfield',
#   [3,
#    'OH',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.004398826979472141,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('wasilla', [3, 'AK', 0.0003830928361639637]),
#  ('troy',
#   [3,
#    'MI',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.006036217303822937,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('kerrville', [3, 'TX', 0.00013424620754463686]),
#  ('belton', [3, 'SC', 'wrong state']),
#  ('montpelier', [3, 'VT', 0.00038192234245703374, 'wrong state', 0.0375]),
#  ('newton',
#   [3,
#    'KS',
#    'wrong state',
#    'wrong state',
#    0.0017055144968732233,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('homestead',
#   [3,
#    'FL',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.0031120331950207467,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('fairview',
#   [3,
#    'TN',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('rosebud', [3, 'SD', 'wrong state', 'wrong state']),
#  ('meridian',
#   [3,
#    'ID',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('manchester',
#   [3,
#    'NH',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('silverspring',
#   [3,
#    'MD',
#    'wrong state',
#    'wrong state',
#    4.198622851704641e-05,
#    'wrong state']),
#  ('allentown',
#   [3, 'PA', 'wrong state', 2.5416836112240748e-05, 'wrong state']),
#  ('conroe', [3, 'TX', 5.3374134894230254e-05]),
#  ('carsoncity', [3, 'NV', 5.427506603466368e-05]),
#  ('sparta',
#   [3,
#    'NC',
#    'wrong state',
#    'wrong state',
#    0.001694915254237288,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('hutchinson', [3, 'KS', 'wrong state', 'wrong state', 0.001221001221001221]),
#  ('muncie', [3, 'IN', 'wrong state', 4.280516515659556e-05]),
#  ('lexington',
#   [3,
#    'NC',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('bend',
#   [3,
#    'OR',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    3.914456086326805e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('delano', [3, 'CA', 'wrong state']),
#  ('santafe',
#   [3,
#    'NM',
#    'wrong state',
#    'wrong state',
#    0.0004893964110929853,
#    'wrong state']),
#  ('reading', [3, 'MA', 'wrong state', 'wrong state', 'wrong state']),
#  ('newportnews', [3, 'VA', 1.6600357461030662e-05]),
#  ('sallisaw', [3, 'OK', 0.00033783783783783786]),
#  ('clearwater', [3, 'FL', 'wrong state', 'wrong state']),
#  ('idahofalls', [3, 'ID', 5.280481579920089e-05]),
#  ('covington',
#   [3, 'GA', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('colton', [3, 'CA', 'wrong state', 'wrong state']),
#  ('atwater', [3, 'CA', 'wrong state']),
#  ('gardena', [3, 'CA', 'wrong state', 0.00028174305033809165]),
#  ('spartanburg', [3, 'SC', 8.105260313943749e-05]),
#  ('greatfalls', [3, 'MT', 'wrong state', 'wrong state']),
#  ('stillwater',
#   [3, 'MN', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('pensacola',
#   [3, 'FL', 5.777786337461241e-05, 0.00014058765640376775, 'wrong state']),
#  ('santaclara',
#   [3, 'CA', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('madison',
#   [3,
#    'ME',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('edinburg',
#   [3,
#    'TX',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    3.891050583657588e-05,
#    'wrong state']),
#  ('cottonwood',
#   [3,
#    'CA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('eastpoint', [3, 'GA', 8.89890840056953e-05, 'wrong state']),
#  ('marion',
#   [3,
#    'AR',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('southbend', [3, 'IN', 'wrong state', 'wrong state']),
#  ('palmbay', [3, 'FL', 2.9072584552766742e-05]),
#  ('hanover',
#   [3,
#    'CO',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('loslunas', [3, 'NM', 0.00020222446916076846]),
#  ('portst.lucie', [3, 'FL', 1.822567024902341e-05]),
#  ('jonesboro', [3, 'AR', 'wrong state', 'wrong state', 'wrong state']),
#  ('lawton', [3, 'OK', 3.0970299482796e-05, 'wrong state']),
#  ('huntingtonbeach', [3, 'CA', 1.579013853214872e-05]),
#  ('orange',
#   [3,
#    'NJ',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    4.6678076863233236e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('athens',
#   [3,
#    'GA',
#    'wrong state',
#    'wrong state',
#    2.598482486228043e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('st.augustine',
#   [3,
#    'FL',
#    0.00023121387283236994,
#    0.00048575129533678756,
#    0.00040766408479412964,
#    0.0006002400960384153,
#    'wrong state']),
#  ('compton', [3, 'CA', 3.1102586698460425e-05, 'wrong state', 'wrong state']),
#  ('unioncity',
#   [3, 'GA', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('loveland', [3, 'CO', 'wrong state', 'wrong state', 'wrong state']),
#  ('lakeelsinore', [3, 'CA', 5.789158835221242e-05]),
#  ('suncity',
#   [3, 'SC', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('valdosta', [3, 'GA', 5.502769727429473e-05]),
#  ('mobile',
#   [3,
#    'AL',
#    1.537586297030921e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('independence', [3, 'MO', 'wrong state', 'wrong state']),
#  ('bristol',
#   [3, 'TN', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('ceres', [3, 'CA', 6.605456106744171e-05, 'wrong state']),
#  ('rockford',
#   [3,
#    'IL',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('victorville', [3, 'CA', 2.5883713104923946e-05]),
#  ('killeen', [3, 'TX', 2.3451974265366905e-05]),
#  ('ruidoso', [3, 'NM', 0.0003736455349358575, 0.0010657193605683837]),
#  ('belleville', [3, 'IL', 'wrong state', 'wrong state']),
#  ('harvey',
#   [3,
#    'IL',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('atlanticcity', [3, 'NJ', 'wrong state']),
#  ('eagar', [3, 'AZ', 0.0006141248720573184, 'wrong state']),
#  ('hallandalebeach', [3, 'FL', 8.083420903726457e-05]),
#  ('hampton',
#   [3,
#    'VA',
#    2.1828341919147822e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.005067567567567568]),
#  ('st.petersburg', [3, 'FL', 1.2256454044425561e-05, 'wrong state']),
#  ('rochester',
#   [3,
#    'NY',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.0004554425383330803,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('baytown', [3, 'TX', 'wrong state', 4.178156597309267e-05]),
#  ('springdale', [3, 'AR', 'wrong state', 'wrong state', 'wrong state']),
#  ('myrtlebeach', [3, 'SC', 0.00011066435501125088, 0.0002181500872600349]),
#  ('parker',
#   [3,
#    'CO',
#    6.622955162593549e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('cathedralcity', [3, 'CA', 5.859375e-05]),
#  ('fullerton', [3, 'CA', 'wrong state']),
#  ('paris',
#   [3,
#    'TX',
#    0.00011918477613126217,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('whittier',
#   [3,
#    'CA',
#    3.515721132999731e-05,
#    5.248792777661138e-05,
#    0.00011746280344557557]),
#  ('chandler', [3, 'AZ', 'wrong state', 'wrong state', 'wrong state']),
#  ('lowell',
#   [3,
#    'AR',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('yuma', [3, 'AZ', 'wrong state']),
#  ('redlands', [3, 'CA', 'wrong state']),
#  ('portsmouth', [3, 'VA', 3.1402103940964046e-05, 'wrong state']),
#  ('bexarcounty', [3, 'TX']),
#  ('burnsville', [3, 'NC', 'wrong state', 'wrong state']),
#  ('hayward', [3, 'CA', 'wrong state']),
#  ('madera',
#   [3,
#    'CA',
#    0.000350099194771852,
#    0.0003242191721603804,
#    4.8847205939820246e-05,
#    0.00032740368874822657,
#    'wrong state']),
#  ('temecula', [3, 'CA', 2.9970928199646345e-05]),
#  ('avondale', [3, 'AZ', 'wrong state', 'wrong state', 'wrong state']),
#  ('seaside', [3, 'OR', 0.00046461204893913583, 'wrong state', 'wrong state']),
#  ('hobbs', [3, 'NM', 8.791981712678038e-05, 0.0005564830272676684]),
#  ('salisbury',
#   [3,
#    'NC',
#    'wrong state',
#    8.912126433367001e-05,
#    'wrong state',
#    'wrong state']),
#  ('metairie', [3, 'LA', 2.1663621724279866e-05]),
#  ('artesia', [3, 'CA', 'wrong state', 'wrong state', 'wrong state']),
#  ('marietta',
#   [3,
#    'GA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('benton',
#   [3,
#    'AR',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('elizabethtown',
#   [3, 'KY', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('santamaria', [3, 'CA', 'wrong state']),
#  ('gastonia', [3, 'NC', 4.181709203941958e-05]),
#  ('adamscounty', [3, 'CO']),
#  ('chino',
#   [3,
#    'CA',
#    'wrong state',
#    3.846992293192106e-05,
#    4.01074880680223e-05,
#    'wrong state']),
#  ('cumming', [3, 'GA', 'wrong state']),
#  ('houma', [3, 'LA', 8.894950633023987e-05]),
#  ('clanton', [2, 'AL', 0.00023204548091425919]),
#  ('bolton', [2, 'VT', 'wrong state', 'wrong state', 'wrong state']),
#  ('boerne', [2, 'TX', 0.00019100372457262916]),
#  ('st.cloud', [2, 'FL', 'wrong state', 'wrong state']),
#  ('pompanobeach', [2, 'FL', 2.003104812459312e-05]),
#  ('hendersonville', [2, 'NC', 'wrong state']),
#  ('bartlesville', [2, 'OK', 5.5944055944055945e-05]),
#  ('spanishfork', [2, 'UT', 5.765184053500908e-05]),
#  ('roy',
#   [2,
#    'UT',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('highland',
#   [2,
#    'CA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.000847457627118644,
#    0.0004966476285075739,
#    4.6844989928327164e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('henrycounty', [2, 'IN']),
#  ('southaven', [2, 'MS', 4.0831325793148504e-05]),
#  ('georgetown',
#   [2,
#    'KY',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('timberville', [2, 'VA', 0.0007930214115781126]),
#  ('sanfernando', [2, 'CA', 'wrong state']),
#  ('yubacity', [2, 'CA', 3.080477474008471e-05]),
#  ('montebello', [2, 'CA', 3.2e-05, 'wrong state']),
#  ('ranchomirage', [2, 'CA', 0.00011615750958299454]),
#  ('springhill', [2, 'FL', 'wrong state', 'wrong state']),
#  ('parma',
#   [2, 'OH', 2.4509503560005392e-05, 'wrong state', 9.653441451877595e-05]),
#  ('hays',
#   [2,
#    'KS',
#    'wrong state',
#    0.00018474043968224645,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('hardeeville', [2, 'SC', 0.0006775067750677507]),
#  ('oakcliff', [2, 'TX']),
#  ('whitehaven', [2, 'TN', 'wrong state', 'wrong state']),
#  ('norwich', [2, 'CT', 'wrong state', 'wrong state', 'wrong state']),
#  ('floydcounty', [2, 'GA']),
#  ('quartzsite', [2, 'AZ', 0.0005439216752787598]),
#  ('southsaltlake', [2, 'UT', 8.468476097726214e-05]),
#  ('fairoaks',
#   [2,
#    'CA',
#    'wrong state',
#    0.00013617484850548105,
#    'wrong state',
#    'wrong state']),
#  ('roanoke',
#   [2,
#    'VA',
#    2.061175694616209e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('cobbcounty', [2, 'GA']),
#  ('lompoc', [2, 'CA', 4.713201677899797e-05]),
#  ('flint',
#   [2,
#    'MI',
#    'wrong state',
#    'wrong state',
#    1.9524767167151533e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('lenoir', [2, 'NC', 0.00010972130787798991, 'wrong state']),
#  ('mcminnville', [2, 'TN', 0.00014700477765527378]),
#  ('easthartford', [2, 'CT', 3.9022867400296575e-05]),
#  ('churchhill', [2, 'TN', 'wrong state', 0.00029686804215526197]),
#  ('sanford',
#   [2, 'NC', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('abingdon', [2, 'VA', 'wrong state', 0.00024417043096081065]),
#  ('temple',
#   [2,
#    'TX',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    3.0256270612084356e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('nashua', [2, 'IA', 'wrong state', 'wrong state']),
#  ('magnolia',
#   [2,
#    'AR',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('lealman', [2, 'FL', 0.00010060868252930228, 0.00012778736182991502]),
#  ('aiken', [2, 'SC', 6.774149844194554e-05]),
#  ('taylors',
#   [2,
#    'SC',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    9.251977610214184e-05]),
#  ('morris',
#   [2,
#    'AL',
#    'wrong state',
#    0.0091324200913242,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('pulaski',
#   [2,
#    'VA',
#    0.00022011886418666079,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('chesapeake',
#   [2,
#    'VA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    9.000535531864146e-06,
#    'wrong state',
#    'wrong state']),
#  ('greensboro',
#   [2, 'NC', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('clovis', [2, 'NM', 5.294506949040371e-05]),
#  ('hesperia', [2, 'CA', 2.2179588125048518e-05, 'wrong state']),
#  ('azle',
#   [2,
#    'TX',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.00018269845619804512]),
#  ('ripon', [2, 'CA', 'wrong state']),
#  ('aberdeen',
#   [2,
#    'WA',
#    0.00011837121212121212,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.007168458781362007]),
#  ('burbank', [2, 'CA', 'wrong state', 'wrong state', 'wrong state']),
#  ('sandcity', [2, 'CA', 0.005988023952095809]),
#  ('thornton',
#   [2, 'CO', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('shelbytownship', [2, 'MI']),
#  ('sullivan',
#   [2,
#    'IN',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('fortwaltonbeach', [2, 'FL', 0.00010252729789306403]),
#  ('dunsmuir', [2, 'CA', 0.0012121212121212121]),
#  ('selma', [2, 'CA', 'wrong state', 'wrong state', 'wrong state']),
#  ('llano',
#   [2,
#    'TX',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.0006188118811881188,
#    0.0006648936170212766,
#    'wrong state']),
#  ('capecoral', [2, 'FL', 1.2961342795113574e-05]),
#  ('oceanside', [2, 'CA', 'wrong state']),
#  ('redwoodcity', [2, 'CA', 2.6036581396862592e-05]),
#  ('greenvillecounty', [2, 'SC']),
#  ('thomasville', [2, 'NC', 7.474679523115446e-05]),
#  ('emeryville', [2, 'CA', 0.0001984126984126984]),
#  ('edmond',
#   [2,
#    'OK',
#    'wrong state',
#    2.4568515447454087e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('alamosa', [2, 'CO', 0.00022779043280182233, 0.0013717421124828531]),
#  ('pleasanton', [2, 'CA', 'wrong state', 'wrong state']),
#  ('shirley', [2, 'AR', 'wrong state', 'wrong state', 'wrong state']),
#  ('fortlauderdale', [2, 'FL', 1.2083058947203073e-05]),
#  ('salinas',
#   [2,
#    'CA',
#    1.3294248243497451e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('hattiesburg', [2, 'MS', 4.3488660331818475e-05, 0.00033846674564224065]),
#  ('fairfax',
#   [2,
#    'VA',
#    'wrong state',
#    8.863283846665189e-05,
#    'wrong state',
#    0.00016625103906899418]),
#  ('risingsun',
#   [2,
#    'MD',
#    'wrong state',
#    'wrong state',
#    0.000719165767709457,
#    'wrong state']),
#  ('eastbatonrouge', [2, 'LA']),
#  ('portarthur', [2, 'TX', 3.7162287710431455e-05]),
#  ('johnsoncity', [2, 'TN', 'wrong state', 'wrong state']),
#  ('lexingtoncounty', [2, 'SC']),
#  ('ashland',
#   [2,
#    'WI',
#    'wrong state',
#    0.00024342745861733204,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('bluesprings', [2, 'MO', 'wrong state', 'wrong state', 'wrong state']),
#  ('lansing',
#   [2, 'IL', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('hollywoodhills', [2, 'CA']),
#  ('buford', [2, 'GA', 'wrong state']),
#  ('brockton', [2, 'MA', 'wrong state', 2.1319688732544504e-05, 'wrong state']),
#  ('wakeforest', [2, 'NC', 6.640767672742968e-05]),
#  ('livingston',
#   [2,
#    'TN',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('bailey',
#   [2,
#    'NC',
#    'wrong state',
#    'wrong state',
#    0.0035149384885764497,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('waterfordtownship', [2, 'MI']),
#  ('hallcounty', [2, 'GA']),
#  ('klamathfalls', [2, 'OR', 9.596928982725528e-05]),
# ...
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('lacombe', [1, 'LA', 0.00011522064754003918]),
#  ('waukegan', [1, 'IL', 1.1226116437279688e-05]),
#  ('soddydaisy', [1, 'TN']),
#  ('hurricane', [1, 'WV', 0.00015913430935709738]),
#  ('vadnaisheights', [1, 'MN', 8.128759551292472e-05]),
#  ('portallen', [1, 'LA', 0.00019305019305019305]),
#  ('st.tammanyparish', [1, 'LA']),
#  ('jesup', [1, 'GA', 'wrong state', 'wrong state']),
#  ('tomball', [1, 'TX', 9.299730307821073e-05]),
#  ('monckscorner', [1, 'SC', 0.00012682308180088776]),
#  ('greenbelt', [1, 'MD', 4.3350095370209814e-05]),
#  ('pattison', [1, 'TX', 0.00211864406779661]),
#  ('mannford', [1, 'OK', 0.00032509752925877764]),
#  ('westouachita', [1, 'LA']),
#  ('lebanon',
#   [1,
#    'MO',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('pima', [1, 'AZ', 0.00041893590280687055, 0.001466275659824047]),
#  ('macon', [1, 'GA', 'wrong state', 'wrong state']),
#  ('reynoldsville', [1, 'WV', 'wrong state']),
#  ('pacificbeach', [1, 'CA', 'wrong state']),
#  ('brawley', [1, 'CA', 4.00753416422875e-05]),
#  ('laporte', [1, 'TX', 2.9585798816568047e-05, 'wrong state', 'wrong state']),
#  ('welch', [1, 'WV', 'wrong state', 0.00041562759767248546]),
#  ('capecanaveral', [1, 'FL', 0.00010088781275221953]),
#  ('cayce', [1, 'SC', 7.982120051085569e-05]),
#  ('swansea', [1, 'SC', 'wrong state', 0.0012091898428053204]),
#  ('mauriceriver', [1, 'NJ']),
#  ("lee'ssummit", [1, 'MO', 1.0945230068736045e-05]),
#  ('blackfoot', [1, 'ID', 8.404067568703252e-05]),
#  ('ft.lauderdale', [1, 'FL']),
#  ('huron', [1, 'CA', 'wrong state', 'wrong state']),
#  ('sunridge', [1, 'NV']),
#  ('lincolnparish', [1, 'LA']),
#  ('southhaven', [1, 'IN', 'wrong state']),
#  ('harriscounty', [1, 'TX']),
#  ('jeffersoncounty', [1, 'ID', 'wrong state']),
#  ('rowe',
#   [1,
#    'NM',
#    'wrong state',
#    0.0024096385542168677,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('delrio', [1, 'TX', 2.8096990812284005e-05, 0.00819672131147541]),
#  ('peachtreecity', [1, 'GA', 2.910022116168083e-05]),
#  ('ashtabula', [1, 'OH', 5.229031583350764e-05]),
#  ('irvington', [1, 'NJ', 'wrong state', 'wrong state', 'wrong state']),
#  ('anniston', [1, 'AL', 4.327880204275946e-05, 'wrong state']),
#  ('perryville', [1, 'AR', 'wrong state', 'wrong state', 'wrong state']),
#  ('northfortcollins', [1, 'CO']),
#  ('hensley', [1, 'WV', 'wrong state']),
#  ('charlestonview', [1, 'CA']),
#  ('campbelltown', [1, 'PA', 'wrong state', 0.0002765486725663717]),
#  ('leedey', [1, 'OK', 0.0022988505747126436]),
#  ('mountaingrove', [1, 'MO', 0.00020881186051367718]),
#  ('petroleum', [1, 'WV']),
#  ('breauxbridge', [1, 'LA', 0.00012286521685710776]),
#  ('sierrablanca', [1, 'TX', 0.0018083182640144665]),
#  ('300blockofstatelineroad', [1, 'TN']),
#  ('trosper', [1, 'KY']),
#  ('tunbridge', [1, 'VT']),
#  ('santee',
#   [1,
#    'CA',
#    1.8722033961769606e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('bloomington', [1, 'MN', 'wrong state', 'wrong state', 'wrong state']),
#  ('glenvalley', [1, 'CA']),
#  ('poncacity', [1, 'OK', 3.939023909875133e-05]),
#  ('chalmette', [1, 'LA', 5.969792848188168e-05]),
#  ('pocatello', [1, 'ID', 1.84314809694959e-05]),
#  ('sunrise',
#   [1,
#    'FL',
#    1.184286881654212e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('dearbornheights', [1, 'MI', 1.7308824038494823e-05]),
#  ('keaau', [1, 'HI', 0.0004438526409232135]),
#  ('bangor',
#   [1,
#    'ME',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('rainbowcity', [1, 'AL', 'wrong state']),
#  ('campo',
#   [1,
#    'CA',
#    'wrong state',
#    0.002932551319648094,
#    0.00037257824143070045,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('uniontown',
#   [1,
#    'OH',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('boring', [1, 'OR']),
#  ('hummelstown', [1, 'PA', 0.00022036139268400177]),
#  ('sims',
#   [1,
#    'AR',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('graysoncounty', [1, 'VA']),
#  ('newbrunswick', [1, 'NJ', 1.812217973577862e-05]),
#  ('hawaiiangardens', [1, 'CA', 7.015574575557738e-05]),
#  ('elizabethon', [1, 'TN']),
#  ('morenci', [1, 'AZ', 'wrong state', 'wrong state']),
#  ('culpeper', [1, 'VA', 6.105378838756945e-05]),
#  ('cochrancounty', [1, 'TX']),
#  ('tatecounty', [1, 'MS']),
#  ('fonddulac', [1, 'WI', 2.324446200692685e-05, 0.00019944156362185878]),
#  ('strabantownship', [1, 'PA']),
#  ('cheney', [1, 'WA', 9.442870632672332e-05, 'wrong state']),
#  ('randolphcounty', [1, 'NC']),
#  ('orcutt', [1, 'CA', 3.459609064175748e-05]),
#  ('goodyear',
#   [1, 'AZ', 1.5319800842589045e-05, 0.002188183807439825, 'wrong state']),
#  ('littlehavana', [1, 'FL']),
#  ('lakeview',
#   [1,
#    'SC',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('deridder', [1, 'LA', 9.453582907922102e-05]),
#  ('emporia', [1, 'VA', 0.00016871941960519654]),
#  ('wales',
#   [1,
#    'ME',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('penasco', [1, 'NM']),
#  ('applecreek', [1, 'OH', 0.0008525149190110827]),
#  ('talladega', [1, 'AL', 6.379178361826996e-05, 0.006024096385542169]),
#  ('martinez', [1, 'CA', 'wrong state', 'wrong state', 'wrong state']),
#  ('cochran',
#   [1,
#    'GA',
#    0.0001941747572815534,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('chinohills', [1, 'CA', 1.3369162689340766e-05]),
#  ('lakescharles', [1, 'LA']),
#  ('longmont', [1, 'CO', 1.159151501101194e-05]),
#  ('helena-westhelena', [1, 'AR', 8.141996417521577e-05]),
#  ('mosspoint', [1, 'MS', 7.297139521307647e-05]),
#  ('bonaire', [1, 'GA']),
#  ('decatur',
#   [1,
#    'GA',
#    'wrong state',
#    5.9887411666067796e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('pinetop-lakeside', [1, 'AZ', 0.00023353573096683791]),
#  ('showlow', [1, 'AZ', 9.380863039399625e-05]),
#  ('kirkwood', [1, 'NY', 'wrong state', 'wrong state']),
#  ('irvine', [1, 'CA', 'wrong state']),
#  ('morehead', [1, 'KY', 0.00014609203798392987, 'wrong state']),
#  ('bunch', [1, 'OK']),
#  ('wapato', [1, 'WA', 0.00020012007204322593]),
#  ('eatonrapidstownship', [1, 'MI']),
#  ('unioncounty', [1, 'SC']),
#  ('whitehall',
#   [1, 'OH', 'wrong state', 'wrong state', 'wrong state', 'wrong state']),
#  ('plantation',
#   [1,
#    'FL',
#    4.922471080482402e-05,
#    'wrong state',
#    0.006134969325153374,
#    0.0007936507936507937,
#    'wrong state',
#    'wrong state']),
#  ('millerton', [1, 'OK', 'wrong state', 'wrong state', 0.003125]),
#  ('islip',
#   [1,
#    'NY',
#    2.9027576197387517e-05,
#    6.90846286701209e-05,
#    5.350741077639253e-05,
#    0.00018556318426424197,
#    3.529204164460914e-05]),
#  ('hixson', [1, 'TN']),
#  ('watsonville', [1, 'CA', 1.9531631477177287e-05]),
#  ('vandalia', [1, 'OH', 6.559097468188377e-05, 'wrong state']),
#  ('quinlan', [1, 'TX', 0.0007173601147776184]),
#  ('spokanevalley', [1, 'WA', 1.1141440588268062e-05]),
#  ('leavenworth', [1, 'KS', 'wrong state', 'wrong state']),
#  ('dakotacity', [1, 'IA', 'wrong state']),
#  ('mannington', [1, 'WV', 0.0004847309743092584]),
#  ('childress', [1, 'TX', 0.0001638001638001638]),
#  ('columbiaheights', [1, 'MN', 5.1292572835453425e-05]),
#  ('jeffersonville', [1, 'OH', 'wrong state', 'wrong state']),
#  ('tukwila', [1, 'WA', 5.233683990160674e-05]),
#  ('downey', [1, 'CA', 'wrong state']),
#  ('westmonroe', [1, 'LA', 'wrong state']),
#  ('mountainpine', [1, 'AR', 0.0012987012987012987]),
#  ('gunlock', [1, 'KY']),
#  ('kahuku', [1, 'HI', 0.00038255547054322876]),
#  ('buttecounty', [1, 'CA']),
#  ('lodgegrass', [1, 'MT', 0.002336448598130841]),
#  ('nicholasville', [1, 'KY', 3.5695163305372124e-05]),
#  ('watagua', [1, 'TX']),
#  ('paloalto',
#   [1, 'CA', 3.551767004084532e-05, 1.5527226992531405e-05, 'wrong state']),
#  ('glenwood',
#   [1,
#    'GA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('parowan', [1, 'UT', 0.00035842293906810036]),
#  ('ansoncounty', [1, 'NC']),
#  ('tewksbury', [1, 'MA']),
#  ('portst.joe', [1, 'FL', 0.00029027576197387516]),
#  ('beckley', [1, 'WV', 5.677302146020211e-05]),
#  ('oldsaybrook', [1, 'CT', 0.0004904364884747426]),
#  ('humboldt',
#   [1,
#    'TN',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.0001183151916706105,
#    'wrong state',
#    'wrong state']),
#  ('jamaica', [1, 'NY', 'wrong state', 'wrong state']),
#  ('osteen', [1, 'FL']),
#  ('charlottesville', [1, 'VA', 2.3001725129384705e-05]),
#  ('northeast',
#   [1,
#    'MD',
#    0.0002799552071668533,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('wimberley', [1, 'TX', 0.0003808073115003808]),
#  ('polkcounty', [1, 'OR']),
#  ('villapark', [1, 'IL', 'wrong state', 4.565376186997809e-05]),
#  ('newlondon',
#   [1, 'WI', 0.00013708019191226866, 'wrong state', 'wrong state']),
#  ('kendalelakes', [1, 'FL', 1.7810073377502314e-05]),
#  ('peachland', [1, 'NC', 0.002288329519450801]),
#  ('richtonpark', [1, 'IL', 7.328154770628756e-05]),
#  ('anadarko', [1, 'OK', 0.0001478852410529429]),
#  ('eclectic', [1, 'AL', 0.000999000999000999]),
#  ('mckinney', [1, 'TX', 7.626776085480906e-06, 0.001226993865030675]),
#  ('aguanga', [1, 'CA', 0.0008865248226950354]),
#  ('maricopa', [1, 'AZ', 'wrong state', 0.0014104372355430183]),
#  ('elko', [1, 'NV', 'wrong state', 5.465376837732962e-05, 'wrong state']),
#  ('venice', [1, 'CA', 'wrong state', 'wrong state', 'wrong state']),
#  ('brownstown',
#   [1,
#    'IN',
#    'wrong state',
#    0.00033932813030200206,
#    'wrong state',
#    'wrong state']),
#  ('blackriverfalls', [1, 'WI', 0.0002760905577029266]),
#  ('barbourville', [1, 'KY', 0.000315955766192733]),
#  ('dundalk', [1, 'MD', 1.572401213893737e-05]),
#  ('bisbee', [1, 'AZ', 'wrong state']),
#  ('myra',
#   [1,
#    'TX',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('waynecounty', [1, 'KY']),
#  ('manatee', [1, 'FL', 0.000445632798573975]),
#  ('fallschurch', [1, 'VA', 8.10898475510866e-05, 3.42383675146369e-05]),
#  ('wilderville', [1, 'OR']),
#  ('waldoboro', [1, 'ME', 0.0008110300081103001]),
#  ('chinle', [1, 'AZ', 0.0002213368747233289]),
#  ('nikolaevsk', [1, 'AK', 0.0031446540880503146]),
#  ('bossiercity', [1, 'LA', 1.6309222865530456e-05]),
#  ('grandprairie', [1, 'TX', 5.7013842961070946e-06]),
#  ('monahans', [1, 'TX', 0.00014382281029771322]),
#  ('gunnisoncounty', [1, 'CO']),
#  ('sneads', [1, 'FL', 0.0005408328826392645, 'wrong state']),
#  ('jasper', [1, 'OH', 'wrong state', 'wrong state']),
#  ('horseheads', [1, 'NY', 0.00015477480266212662, 0.00035174111853675694]),
#  ('chestertown',
#   [1,
#    'MD',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.0001904036557501904,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('indiantown',
#   [1, 'FL', 0.0001643925694558606, 'wrong state', 'wrong state']),
#  ('larimercounty', [1, 'CO']),
#  ('pittsfield', [1, 'MA', 'wrong state']),
#  ('sanger', [1, 'TX', 0.00014459224985540774, 'wrong state', 'wrong state']),
#  ('wasco', [1, 'CA', 'wrong state']),
#  ('weymouth', [1, 'MA', 1.8607074409690564e-05]),
#  ('rector', [1, 'AR', 0.0005058168942842691]),
#  ('hopkinscounty', [1, 'TX']),
#  ('mercury', [1, 'NV']),
#  ('belgrade', [1, 'ME', 'wrong state', 'wrong state']),
#  ('palermo', [1, 'CA', 'wrong state']),
#  ('rockledge', [1, 'FL', 'wrong state', 4.011875150445318e-05, 'wrong state']),
#  ('dearborncounty', [1, 'IN']),
#  ('pocahontascounty', [1, 'WV']),
#  ('newpaltz', [1, 'NY', 0.00014667057788207686]),
#  ('eaststroudsburg', [1, 'PA', 0.0001016260162601626]),
#  ('lauderhill', [1, 'FL', 1.4950588305649827e-05]),
#  ('panoramacity', [1, 'CA']),
#  ('blackmantownship', [1, 'MI']),
#  ('christiancounty', [1, 'KY']),
#  ('grenada', [1, 'MS', 7.638252367858234e-05]),
#  ('catotownship', [1, 'MI']),
#  ('olympia',
#   [1,
#    'WA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    2.151555574680494e-05]),
#  ('aragonite', [1, 'UT']),
#  ('elsereno', [1, 'CA']),
#  ('lawtey', [1, 'FL', 0.0013698630136986301]),
#  ('simpsonville', [1, 'SC', 5.48305735277991e-05]),
#  ('fairborn', [1, 'OH', 3.0909990108803164e-05]),
#  ('uniongrove', [1, 'NC', 'wrong state', 'wrong state', 'wrong state']),
#  ('oneida', [1, 'TN', 'wrong state', 'wrong state', 0.00026652452025586353]),
#  ('wausau',
#   [1, 'WI', 'wrong state', 2.557152355137319e-05, 0.0017391304347826088]),
#  ('orangecity', [1, 'FL', 'wrong state']),
#  ('lyndhurst', [1, 'NJ', 'wrong state']),
#  ('sancarlospark', [1, 'FL', 5.943889681407513e-05]),
#  ('tremont',
#   [1,
#    'NY',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('tustin', [1, 'CA', 4.013324236465064e-05, 'wrong state', 'wrong state']),
#  ('tehachapi', [1, 'CA', 6.937699458859442e-05]),
#  ('overlea', [1, 'MD', 8.146639511201629e-05, 'wrong state']),
#  ('formosa', [1, 'AR']),
#  ('idealbeach', [1, 'NJ']),
#  ('bellville', [1, 'TX', 0.000244081034903588, 'wrong state']),
#  ('easthollywood', [1, 'CA']),
#  ('rangley', [1, 'CO']),
#  ('coralsprings', [1, 'FL', 8.257911078813503e-06]),
#  ('wythecounty', [1, 'VA']),
#  ('greenecounty', [1, 'MO']),
#  ('kinston', [1, 'NC', 'wrong state', 4.613184481247405e-05]),
#  ('paulden', [1, 'AZ', 0.00019116803670426305]),
#  ('farmersbranch', [1, 'TX', 3.49454850433324e-05]),
#  ('scarbo', [1, 'WV', 'wrong state']),
#  ('taunton', [1, 'MA', 'wrong state', 'wrong state', 'wrong state']),
#  ('burnet',
#   [1,
#    'TX',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    9.249838127832763e-05,
#    0.00016702856188408218,
#    'wrong state']),
#  ('ohatchee', [1, 'AL', 0.0008547008547008547]),
#  ('rifle', [1, 'CO', 0.00010902747492368077]),
#  ('amity',
#   [1,
#    'OR',
#    0.0006195786864931846,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('oilsprings', [1, 'KY']),
#  ('oaks',
#   [1,
#    'OK',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.009708737864077669,
#    0.003472222222222222,
#    0.005050505050505051,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('kingsland', [1, 'GA', 'wrong state']),
#  ('coalcounty', [1, 'OK']),
#  ('lynchburg',
#   [1,
#    'VA',
#    1.3233114545839509e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('enoree', [1, 'SC', 0.0015037593984962407]),
#  ('gilroy', [1, 'CA', 2.048298887773704e-05]),
#  ('poplarbluff', [1, 'MO', 5.8744052164718324e-05]),
#  ('dadeville', [1, 'AL', 0.00030959752321981426, 'wrong state']),
#  ('mandeville', [1, 'LA', 8.650519031141868e-05]),
#  ('hammond',
#   [1,
#    'LA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('newalbany', [1, 'IN', 'wrong state', 'wrong state', 'wrong state']),
#  ('wilhoit', [1, 'AZ', 0.001152073732718894]),
#  ('eatoncounty', [1, 'MI']),
#  ('lewistown',
#   [1,
#    'PA',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    0.00011993283761093787]),
#  ('wallawalla', [1, 'WA', 3.1514922315716493e-05, 0.0005980861244019139]),
#  ('gonzalescounty', [1, 'TX']),
#  ('oldbridge', [1, 'NJ', 4.2099945270071146e-05]),
#  ('windsor',
#   [1,
#    'CA',
#    9.029345372460496e-05,
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state',
#    'wrong state']),
#  ('camarillo', [1, 'CA', 1.5337188079937423e-05]),
#  ('grandprarie', [1, 'TX']),
#  ...]

# %%
"goddammit, it's dividing every time it sees an instance of a city"
# Out:
# "goddammit, it's dividing every time it sees an instance of a city"

# %%
city_population['City'][1201]
# Out:
# 'phoenix'

# %%
 lst_of_dic[i][1].append(autocorrect(lst_of_dic[i][0], city_pop_dic_lst[x][0], lambda w1, w2, limit: abs(len(w2) - len(w1)), 3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-aa1982339738> in <module>
# ----> 1 lst_of_dic[i][1].append(autocorrect(lst_of_dic[i][0], city_pop_dic_lst[x][0], lambda w1, w2, limit: abs(len(w2) - len(w1)), 3))
#
# NameError: name 'lst_of_dic' is not defined

# %%
'suggestions for how to fix this:'
'1, Shave off a bunch of redundant cities in the CityPopulation2000 excel sheet'
"2, ignore cities that don't have enough shootings"
"3, manually do this"
'4, repurpose some code from a cs61a project'

'''
possible additions: 
drop a city if it isn't in the population excel
make it so cities can only be run once
    --combine with repurposed project?

'''
"I don't know if these things will work though"
