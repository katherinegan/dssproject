# %%
import numpy as np
import pandas as pd

# %%
police = pd.read_csv('fatal-police-shootings-data.csv')

police['city'] = police['city'].str.lower()

# %%
police
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# ...

# %%
police.shape
# Out:
# (4612, 14)

# %%
police.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        shelton    WA                     True       attack
# 1      M    W          aloha    OR                    False       attack
# 2      M    H        wichita    KS                    False        other
# 3      M    W  san francisco    CA                     True       attack
# 4      M    H          evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# ...

# %%
police["id"]
# Out:
# 0          3
# 1          4
# 2          5
# 3          8
# 4          9
# 5         11
# 6         13
# 7         15
# 8         16
# 9         17
# 10        19
# 11        21
# 12        22
# 13        25
# 14        27
# 15        29
# 16        32
# 17        36
# 18        37
# 19        38
# 20       325
# 21        42
# 22        43
# 23        45
# 24        46
# 25        48
# 26        49
# 27        50
# 28        51
# 29        52
#         ...
# 4582    5038
# 4583    5041
# 4584    5066
# 4585    5032
# 4586    5034
# 4587    5043
# 4588    5045
# 4589    5044
# 4590    5058
# 4591    5049
# 4592    5050
# 4593    5046
# 4594    5047
# 4595    5048
# 4596    5051
# 4597    5068
# 4598    5069
# 4599    5053
# 4600    5067
# 4601    5052
# 4602    5054
# 4603    5055
# 4604    5057
# 4605    5059
# 4606    5063
# 4607    5065
# 4608    5060
# 4609    5061
# 4610    5062
# 4611    5064
# Name: id, Length: 4612, dtype: int64

# %%
police[police['manner_of_death'].str.contains('shot and Tasered')]
# Out:
#         id                      name        date   manner_of_death  \
# 2        5        John Paul Quintero  2015-01-03  shot and Tasered
# 10      19            Patrick Wetter  2015-01-06  shot and Tasered
# 23      45         Salvador Figueroa  2015-01-11  shot and Tasered
# 38      68             Zaki Shinwary  2015-01-16  shot and Tasered
# 43      83             Carter Castle  2015-01-18  shot and Tasered
# 51     100        Kristiana Coignard  2015-01-22  shot and Tasered
# 69     346               Matautu Nuu  2015-01-28  shot and Tasered
# 75     339     Edward Donnell Bright  2015-01-31  shot and Tasered
# 100    138   Antonio Zambrano-Montes  2015-02-10  shot and Tasered
# 112    150               Lavall Hall  2015-02-15  shot and Tasered
# 131    266            Jerome Nichols  2015-02-23  shot and Tasered
# 132    371              Daniel Elrod  2015-02-23  shot and Tasered
# 137    177            Joseph Biegert  2015-02-24  shot and Tasered
# ...

# %%
police[police['manner_of_death'].str.contains('shot')]
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# ...

# %%
police['gender'].value_counts()
# Out:
# M    4398
# F     210
# Name: gender, dtype: int64

# %%
police['gender'].value_counts('F')
# Out:
# M    0.954427
# F    0.045573
# Name: gender, dtype: float64

# %%
police['manner_of_death'].value_counts()
# Out:
# shot                4382
# shot and Tasered     230
# Name: manner_of_death, dtype: int64

# %%
police['armed'].value_counts()
# Out:
# gun                                 2562
# knife                                689
# unarmed                              294
# undetermined                         189
# toy weapon                           161
# vehicle                               82
# unknown weapon                        60
# machete                               39
# ax                                    23
# Taser                                 19
# gun and knife                         16
# sword                                 16
# baseball bat                          13
# hammer                                12
# metal pipe                            11
# hatchet                               10
# box cutter                            10
# screwdriver                            9
# crossbow                               9
# sharp object                           7
# gun and car                            7
# pipe                                   6
# piece of wood                          5
# ...

# %%
police
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# ...

# %%
police['state'].value_counts()
# Out:
# CA    698
# TX    410
# FL    281
# AZ    223
# CO    159
# GA    151
# OK    138
# OH    134
# WA    127
# NC    127
# TN    120
# MO    114
# LA     96
# IL     95
# PA     95
# NM     91
# AL     88
# VA     84
# IN     82
# NY     80
# KY     80
# NV     79
# WI     73
# SC     72
# MI     72
# OR     72
# AR     68
# MD     67
# NJ     59
# MN     57
# MS     57
# UT     51
# WV     50
# KS     45
# ID     35
# AK     32
# MA     31
# IA     29
# HI     26
# MT     24
# NE     20
# CT     18
# ME     17
# SD     15
# DC     13
# WY     13
# NH     12
# DE     11
# ND      9
# VT      8
# RI      4
# Name: state, dtype: int64

# %%
police
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# ...

# %%
city_population = pd.read_csv('CityPopulation2000.csv', encoding = "ISO-8859-1")

print(city_population.dtypes)

city_population['Population'] = city_population['Population'].str.replace(r'\(r.*\)', '')
city_population['City'] = city_population['City'].str.replace(r'\(.*\)', '')
city_population['City'] = city_population['City'].str.replace(r'CDP', '')
city_population['City'] = city_population['City'].str.replace(r'city', '')
city_population['City'] = city_population['City'].str.lower()
type_dict = {'Geographic Area': 'str', 'City': 'str', 'Population': 'int64'}

city_population = city_population.astype(type_dict)

print(city_population.dtypes)

city_population
# Out:
# Geographic Area    object
# City               object
# Population         object
# dtype: object
# Geographic Area    object
# City               object
# Population          int64
# dtype: object
#       Geographic Area                               City  Population
# 0                  AL                            abanda          192
# 1                  AL                         abbeville         2688
# 2                  AL                        adamsville         4522
# 3                  AL                       addison town         758
# 4                  AL                         akron town         356
# 5                  AL                         alabaster        30352
# 6                  AL                       albertville        21160
# 7                  AL                    alexander city        14875
# 8                  AL                        alexandria         3917
# 9                  AL                        aliceville         2486
# ...

# %%
city_population.dtypes
# Out:
# Geographic Area    object
# City               object
# Population          int64
# dtype: object

# %%
grouped_tbl = police.groupby("city").agg(len)
selected_tbl = grouped_tbl[["id"]]
selected_tbl.rename(columns={'id':'kill counts'})
# Out:
#                               kill counts
# city
# 300 block of state line road            1
# abbeville                               1
# aberdeen                                2
# abilene                                 2
# abingdon                                2
# abington township                       1
# acworth                                 1
# ada                                     1
# adams county                            3
# addison                                 1
# adelanto                                1
# affton                                  1
# aguanga                                 1
# ahwatukee                               1
# aiea                                    1
# aiken                                   2
# aitkin                                  1
# akron                                   6
# alamo                                   2
# alamogordo                              2
# alamosa                                 2
# ...

# %%
police[police['city'].str.contains('300')]
# Out:
#         id              name        date manner_of_death  armed   age gender  \
# 2928  3247  Salvador Byassee  2017-12-26            shot  knife  34.0      M
#
#      race                          city state  signs_of_mental_illness  \
# 2928  NaN  300 block of state line road    TN                    False
#
#      threat_level   flee  body_camera
# 2928        other  Other        False

# %%
x=police['city'].value_counts()
x
# Out:
# los angeles           71
# phoenix               69
# houston               47
# las vegas             41
# san antonio           36
# chicago               34
# columbus              34
# albuquerque           31
# miami                 29
# st. louis             29
# austin                28
# kansas city           26
# denver                26
# jacksonville          26
# oklahoma city         25
# tucson                25
# tulsa                 21
# bakersfield           21
# new york              18
# atlanta               18
# louisville            18
# dallas                17
# mesa                  17
# fresno                17
# indianapolis          16
# orlando               16
# portland              16
# san jose              16
# baltimore             16
# washington            15
#                       ..
# elsmere                1
# indialantic            1
# woodland               1
# bethany                1
# miami beach            1
# manistee               1
# ...

# %%
dict_x=dict(x)

# %%
len(dict_x)
# Out:
# 2210

# %%
next(iter( dict_x.items()))
# Out:
# ('los angeles', 71)

# %%
list(dict_x.items())[0][1]
# Out:
# 71

# %%
'allows me to add states to the kill count'
def change_key_values_to_list(dic):
    dic_lst=list(dic.items())
    for i in range(len(dic_lst)):
        number= dic_lst[i][1]
        lst_with_number=[number]
        dic[dic_lst[i][0]]=lst_with_number

change_key_values_to_list(dict_x)

print(len(dict_x))

dict_x.items()
# Out:
# 2210
# ...

# %%
'prepping to add the associated state to the city'
city_state=police[['city','state']]
print(len(city_state))
city_state['city'][0]
city_state_dic={}
for i in range(len(city_state)):
    city_state_dic[city_state['city'][i]]=city_state['state'][i]
print(len(city_state_dic))
list(city_state_dic.items())
# Out:
# 4612
# 2210
# [('shelton', 'WA'),
#  ('aloha', 'OR'),
#  ('wichita', 'KS'),
#  ('san francisco', 'CA'),
#  ('evans', 'CO'),
#  ('guthrie', 'OK'),
#  ('chandler', 'AZ'),
#  ('assaria', 'KS'),
#  ('burlington', 'IA'),
#  ('knoxville', 'TN'),
#  ('stockton', 'CA'),
#  ('freeport', 'TX'),
#  ('columbus', 'OH'),
#  ('des moines', 'IA'),
#  ('new orleans', 'LA'),
#  ('huntley', 'MT'),
#  ('salt lake city', 'UT'),
#  ('strong', 'AR'),
#  ('syracuse', 'NY'),
#  ('england', 'AR'),
#  ('el paso', 'TX'),
#  ('arcola', 'IL'),
#  ('south gate', 'CA'),
#  ('north las vegas', 'NV'),
#  ('albuquerque', 'NM'),
#  ('jourdanton', 'TX'),
#  ('st. paul', 'MN'),
#  ('franklin county', 'OH'),
#  ('chesapeake', 'VA'),
#  ('old bridge', 'NJ'),
#  ('lake jackson', 'TX'),
#  ('draper', 'UT'),
#  ('indianapolis', 'IN'),
#  ('aurora', 'CO'),
#  ('bloomington', 'MN'),
#  ('fairfield', 'TX'),
#  ('evangeline parish', 'LA'),
#  ('mabank', 'TX'),
#  ('fremont', 'CA'),
#  ('muskogee', 'OK'),
# ...

# %%
list(city_state_dic.items())[5]
# Out:
# ('guthrie', 'OK')

# %%
'prepping to add states'
dic_cs_lst=list(city_state_dic.items())
dic_lst=list(dict_x.items())
dic_lst[0][1]
# Out:
# [71]

# %%
'adding states'
def add_state_to_dictionary(lst_of_dic):
    for i in range(len(lst_of_dic)):
        for x in range(len(dic_cs_lst)):
            if lst_of_dic[i][0] is dic_cs_lst[x][0]:
                lst_of_dic[i][1].append(dic_cs_lst[x][1])
    return lst_of_dic
city_kills_state=add_state_to_dictionary(dic_lst)
city_kills_state
# Out:
# [('los angeles', [71, 'CA']),
#  ('phoenix', [69, 'AZ']),
#  ('houston', [47, 'TX']),
#  ('las vegas', [41, 'NV']),
#  ('san antonio', [36, 'TX']),
#  ('chicago', [34, 'IL']),
#  ('columbus', [34, 'OH']),
#  ('albuquerque', [31, 'NM']),
#  ('miami', [29, 'FL']),
#  ('st. louis', [29, 'MO']),
#  ('austin', [28, 'TX']),
#  ('kansas city', [26, 'KS']),
#  ('denver', [26, 'CO']),
#  ('jacksonville', [26, 'NC']),
#  ('oklahoma city', [25, 'OK']),
#  ('tucson', [25, 'AZ']),
#  ('tulsa', [21, 'OK']),
#  ('bakersfield', [21, 'CA']),
#  ('new york', [18, 'NY']),
#  ('atlanta', [18, 'GA']),
#  ('louisville', [18, 'KY']),
#  ('dallas', [17, 'TX']),
#  ('mesa', [17, 'AZ']),
#  ('fresno', [17, 'CA']),
#  ('indianapolis', [16, 'IN']),
#  ('orlando', [16, 'FL']),
#  ('portland', [16, 'OR']),
#  ('san jose', [16, 'CA']),
#  ('baltimore', [16, 'MD']),
#  ('washington', [15, 'DC']),
#  ('charlotte', [15, 'NC']),
#  ('springfield', [15, 'FL']),
#  ('colorado springs', [15, 'CO']),
# ...

# %%
len(x)
# Out:
# 2210

# %%
'prepping pop->per capita'
city_kills_state_list=list(city_kills_state)
city_pop_dic={}
for i in range(len(city_population)):
    city_pop_dic[city_population['City'][i]]=[city_population['Population'][i],city_population['Geographic Area'][i]]
print(len(city_pop_dic))
city_pop_dic_lst=list(city_pop_dic.items())
city_pop_dic_lst
# Out:
# 22954
# [('abanda ', [192, 'AL']),
#  ('abbeville ', [5237, 'SC']),
#  ('adamsville ', [67, 'PA']),
#  ('addison town', [13056, 'TX']),
#  ('akron town', [1167, 'IN']),
#  ('alabaster ', [30352, 'AL']),
#  ('albertville ', [7044, 'MN']),
#  ('alexander city ', [14875, 'AL']),
#  ('alexandria ', [139966, 'VA']),
#  ('aliceville ', [2486, 'AL']),
#  ('allgood town', [622, 'AL']),
#  ('altoona town', [933, 'AL']),
#  ('andalusia ', [9015, 'AL']),
#  ('anderson town', [282, 'AL']),
#  ('anniston ', [23106, 'AL']),
#  ('arab ', [8050, 'AL']),
#  ('ardmore town', [1194, 'AL']),
#  ('argo town', [4071, 'AL']),
#  ('ariton town', [764, 'AL']),
#  ('arley town', [357, 'AL']),
#  ('ashford town', [2148, 'AL']),
#  ('ashland town', [7225, 'VA']),
#  ('ashville ', [2212, 'AL']),
#  ('athens ', [12710, 'TX']),
#  ('atmore ', [10194, 'AL']),
#  ('attalla ', [6048, 'AL']),
#  ('auburn ', [328, 'WY']),
#  ('autaugaville town', [870, 'AL']),
#  ('avon town', [12446, 'IN']),
# ...

# %%
city_pop_dic_lst[6][0]
# Out:
# 'albertville '

# %%
city_kills_state_list
# Out:
# [('los angeles', [71, 'CA']),
#  ('phoenix', [69, 'AZ']),
#  ('houston', [47, 'TX']),
#  ('las vegas', [41, 'NV']),
#  ('san antonio', [36, 'TX']),
#  ('chicago', [34, 'IL']),
#  ('columbus', [34, 'OH']),
#  ('albuquerque', [31, 'NM']),
#  ('miami', [29, 'FL']),
#  ('st. louis', [29, 'MO']),
#  ('austin', [28, 'TX']),
#  ('kansas city', [26, 'KS']),
#  ('denver', [26, 'CO']),
#  ('jacksonville', [26, 'NC']),
#  ('oklahoma city', [25, 'OK']),
#  ('tucson', [25, 'AZ']),
#  ('tulsa', [21, 'OK']),
#  ('bakersfield', [21, 'CA']),
#  ('new york', [18, 'NY']),
#  ('atlanta', [18, 'GA']),
#  ('louisville', [18, 'KY']),
#  ('dallas', [17, 'TX']),
#  ('mesa', [17, 'AZ']),
#  ('fresno', [17, 'CA']),
#  ('indianapolis', [16, 'IN']),
#  ('orlando', [16, 'FL']),
#  ('portland', [16, 'OR']),
#  ('san jose', [16, 'CA']),
#  ('baltimore', [16, 'MD']),
#  ('washington', [15, 'DC']),
#  ('charlotte', [15, 'NC']),
#  ('springfield', [15, 'FL']),
#  ('colorado springs', [15, 'CO']),
# ...

# %%
city_pop_dic_lst[6][0] in city_kills_state_list[598][0]
# Out:
# False

# %%
city_pop_dic_lst[0][1][1]
# Out:
# 'AL'

# %%
city_kills_state[0][1][0]
# Out:
# 71

# %%
def get_state(lst_of_dic,x):
    return lst_of_dic[x][1][1]
def get_number(lst_of_dic,x):
    return lst_of_dic[x][1][0]

# %%
get_number(city_pop_dic_lst,0)
# Out:
# 192

# %%
get_number(city_kills_state,0)
# Out:
# 71

# %%
'pop->per capita'
asdsadofj=city_kills_state_list
def pop_to_per_capita(lst_of_dic):
    for i in range(len(lst_of_dic))[0:100]:
        for x in range(len(city_pop_dic_lst)):
            if lst_of_dic[i][0] in city_pop_dic_lst[x][0]:
                if lst_of_dic[i][1][1] == city_pop_dic_lst[x][1][1]:
                    per_capita=(lst_of_dic[i][1][0])/int((city_pop_dic_lst[x][1][0]))
                    lst_of_dic[i] = (lst_of_dic[i][0], [per_capita, lst_of_dic[i][1][1]])
    return lst_of_dic

kills_per_capita=pop_to_per_capita(asdsadofj)

print(len(kills_per_capita))

kills_per_capita
# Out:
# 2210
# [('los angeles', [4.552908583710644e-08, 'CA']),
#  ('phoenix', [69, 'AZ']),
#  ('houston', [1.3181890673841161e-09, 'TX']),
#  ('las vegas', [0.00018897405524495185, 'NV']),
#  ('san antonio', [2.7120544038113406e-05, 'TX']),
#  ('chicago', [7.974914585572336e-27, 'IL']),
#  ('columbus', [0.015910154422087038, 'OH']),
#  ('albuquerque', [9.427614696506373e-09, 'NM']),
#  ('miami', [2.1638980560620826e-48, 'FL']),
#  ('st. louis', [6.244440254544659e-09, 'MO']),
#  ('austin', [3.542554941231544e-05, 'TX']),
#  ('kansas city', [0.0020942408376963353, 'KS']),
#  ('denver', [26, 'CO']),
#  ('jacksonville', [26, 'NC']),
#  ('oklahoma city', [4.310352259228033e-05, 'OK']),
#  ('tucson', [1.2291271779764852e-16, 'AZ']),
#  ('tulsa', [5.358427786254867e-05, 'OK']),
#  ('bakersfield', [6.0434611189612156e-05, 'CA']),
#  ('new york', [6.617971268613131e-10, 'NY']),
#  ('atlanta', [0.00044492782281985367, 'GA']),
#  ('louisville', [4.0661052817276176e-11, 'KY']),
# ...

# %%
"goddammit, it's dividing every time it sees an instance of a city"
city_kills_state_list
# Out:
# [('los angeles', [4.552908583710644e-08, 'CA']),
#  ('phoenix', [69, 'AZ']),
#  ('houston', [1.3181890673841161e-09, 'TX']),
#  ('las vegas', [0.00018897405524495185, 'NV']),
#  ('san antonio', [2.7120544038113406e-05, 'TX']),
#  ('chicago', [7.974914585572336e-27, 'IL']),
#  ('columbus', [0.015910154422087038, 'OH']),
#  ('albuquerque', [9.427614696506373e-09, 'NM']),
#  ('miami', [2.1638980560620826e-48, 'FL']),
#  ('st. louis', [6.244440254544659e-09, 'MO']),
#  ('austin', [3.542554941231544e-05, 'TX']),
#  ('kansas city', [0.0020942408376963353, 'KS']),
#  ('denver', [26, 'CO']),
#  ('jacksonville', [26, 'NC']),
#  ('oklahoma city', [4.310352259228033e-05, 'OK']),
#  ('tucson', [1.2291271779764852e-16, 'AZ']),
#  ('tulsa', [5.358427786254867e-05, 'OK']),
#  ('bakersfield', [6.0434611189612156e-05, 'CA']),
#  ('new york', [6.617971268613131e-10, 'NY']),
#  ('atlanta', [0.00044492782281985367, 'GA']),
#  ('louisville', [4.0661052817276176e-11, 'KY']),
# ...

# %%
city_population['City'][1201]
# Out:
# 'phoenix '

# %%
'suggestions for how to fix this:'
'1, Shave off a bunch of redundant cities in the CityPopulation2000 excel sheet'
"2, ignore cities that don't have enough shootings"
"3, manually do this"


"I don't know if these things will work though"
