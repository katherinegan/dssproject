# %%
import numpy as np
import pandas as pd

# %%
police = pd.read_csv('fatal-police-shootings-data.csv')
police['city'] = police['city'].str.replace(r' city', '') #removes anything with a lower-cased ' city', done to try to clean up data
#police['city'] = police['city'].str.lower() #makes everything lower case, done to try to clean up data
police['city'] = police['city'].str.replace(r'\s', '')
police
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11      21                         Ron Sneed  2015-01-07              shot
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 13      25            Nicholas Ryan Brickman  2015-01-07              shot
# 14      27  Omarr Julian Maximillian Jackson  2015-01-07              shot
# 15      29                     Loren Simpson  2015-01-08              shot
# 16      32               James Dudley Barker  2015-01-08              shot
# 17      36               Artago Damon Howard  2015-01-08              shot
# 18      37                      Thomas Hamby  2015-01-08              shot
# 19      38                     Jimmy Foreman  2015-01-09              shot
# 20     325                     Andy Martinez  2015-01-09              shot
# 21      42                       Tommy Smith  2015-01-11              shot
# 22      43                    Brian  Barbosa  2015-01-11              shot
# 23      45                 Salvador Figueroa  2015-01-11  shot and Tasered
# 24      46               John Edward O'Keefe  2015-01-13              shot
# 25      48                 Richard McClendon  2015-01-13              shot
# 26      49                     Marcus Golden  2015-01-14              shot
# 27      50                    Michael Goebel  2015-01-14              shot
# 28      51                      Mario Jordan  2015-01-14              shot
# 29      52                  Talbot Schroeder  2015-01-14              shot
# ...    ...                               ...         ...               ...
# 4582  5038            Jeffrey Michael Gibble  2019-09-16              shot
# 4583  5041                  Kristopher Adams  2019-09-16              shot
# 4584  5066                             TK TK  2019-09-16              shot
# 4585  5032                   Gay Ellen Plack  2019-09-17              shot
# 4586  5034                             TK TK  2019-09-17              shot
# 4587  5043            Scott Gabriel Spangler  2019-09-18              shot
# 4588  5045                 John Emory Sawyer  2019-09-19              shot
# 4589  5044            Jordan Michael Griffin  2019-09-20              shot
# 4590  5058                 Adam Paul English  2019-09-20              shot
# 4591  5049                  Jeffrey Peterson  2019-09-21              shot
# 4592  5050                             TK TK  2019-09-22              shot
# 4593  5046                             TK TK  2019-09-23              shot
# 4594  5047              Jeffery Tyler Aycock  2019-09-23              shot
# 4595  5048                    Charles Nation  2019-09-23              shot
# 4596  5051                   Jarod Lee Smith  2019-09-24              shot
# 4597  5068                    Haywood Cannon  2019-09-24              shot
# 4598  5069            Ronald Michael McCrary  2019-09-24              shot
# 4599  5053                  Daryl Strickland  2019-09-25              shot
# 4600  5067                  Kevin Dudenhefer  2019-09-25  shot and Tasered
# 4601  5052                     Leonard Shand  2019-09-26              shot
# 4602  5054               Chad Willis Huggins  2019-09-26              shot
# 4603  5055                             TK TK  2019-09-26              shot
# 4604  5057                             TK TK  2019-09-26              shot
# 4605  5059                    Haywood Cannon  2019-09-26              shot
# 4606  5063              Jamaal Ramone Taylor  2019-09-28              shot
# 4607  5065                             TK TK  2019-09-28              shot
# 4608  5060                    Dewayne Morgan  2019-09-29  shot and Tasered
# 4609  5061                             TK TK  2019-09-29              shot
# 4610  5062                   Richard Cabrera  2019-09-29              shot
# 4611  5064                  Antonio Williams  2019-09-29              shot
#
#                armed   age gender race             city state  \
# 0                gun  53.0      M    A          Shelton    WA
# 1                gun  47.0      M    W            Aloha    OR
# 2            unarmed  23.0      M    H          Wichita    KS
# 3         toy weapon  32.0      M    W     SanFrancisco    CA
# 4           nail gun  39.0      M    H            Evans    CO
# 5                gun  18.0      M    W          Guthrie    OK
# 6                gun  22.0      M    H         Chandler    AZ
# 7                gun  35.0      M    W          Assaria    KS
# 8            unarmed  34.0      F    W       Burlington    IA
# 9         toy weapon  47.0      M    B        Knoxville    PA
# 10             knife  25.0      M    W         Stockton    CA
# 11               gun  31.0      M    B         Freeport    TX
# 12             knife  41.0      M    B         Columbus    OH
# 13               gun  30.0      M    W        DesMoines    IA
# 14               gun  37.0      M    B       NewOrleans    LA
# 15               NaN  28.0      M    W          Huntley    MT
# 16            shovel  42.0      M    W     SaltLakeCity    UT
# 17           unarmed  36.0      M    B           Strong    AR
# 18               gun  49.0      M    W         Syracuse    UT
# 19               gun  71.0      M    W          England    AR
# 20               gun  33.0      M    H           ElPaso    TX
# 21               gun  39.0      M    W           Arcola    IL
# 22               gun  23.0      M    H        SouthGate    CA
# 23               gun  29.0      M    H    NorthLasVegas    NV
# 24               gun  34.0      M    W      Albuquerque    NM
# 25             knife  43.0      M    W       Jourdanton    TX
# 26               NaN  24.0      M    B          St.Paul    MN
# 27               NaN  29.0      M    W   FranklinCounty    MO
# 28               gun  34.0      M    B       Chesapeake    VA
# 29             knife  75.0      M    W        OldBridge    NJ
# ...              ...   ...    ...  ...              ...   ...
# 4582             gun  33.0      M    W      Elizabethon    TN
# 4583             gun  37.0      M  NaN           Sanger    TX
# 4584             gun   NaN      M  NaN          Houston    TX
# 4585         hatchet  57.0      F    W         Richmond    VA
# 4586         vehicle   NaN      M  NaN           Milton    FL
# 4587    undetermined  43.0      M  NaN            Salem    OR
# 4588  unknown weapon  74.0      M  NaN       SoddyDaisy    TN
# 4589      pellet gun  18.0      M  NaN        LongBeach    CA
# 4590             gun  21.0      M  NaN      Gainesville    GA
# 4591    undetermined  29.0      M  NaN              Ada    OK
# 4592             gun  74.0      M    W           Austin    TX
# 4593             gun   NaN      M    H       LosAngeles    CA
# 4594             gun  28.0      M    W      FloydCounty    GA
# 4595  unknown weapon  31.0      M  NaN           Lowell    AR
# 4596             gun  41.0      M  NaN       Huntington    WV
# 4597             gun  67.0      M  NaN        Richlands    NC
# 4598           knife  63.0      M  NaN          Sanford    NC
# 4599             gun  64.0      M  NaN       Hartsville    SC
# 4600             gun  32.0      M    W          Lacombe    LA
# 4601           knife  49.0      M    B      Hyattsville    MD
# 4602             gun  28.0      M    W  LexingtonCounty    SC
# 4603         vehicle   NaN      M  NaN          LaHabra    CA
# 4604             gun   NaN      M  NaN           Dallas    TX
# 4605             gun  67.0      M  NaN     Jacksonville    NC
# 4606           knife  31.0      M  NaN        Baltimore    MD
# 4607             gun   NaN      M  NaN           Boston    MA
# 4608             NaN  37.0      M    W         Longview    TX
# 4609    undetermined   NaN      M  NaN         Monument    CO
# 4610             gun  38.0      M  NaN            Miami    FL
# 4611             gun  27.0      M  NaN          NewYork    NY
#
#       signs_of_mental_illness  threat_level         flee  body_camera
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# 5                       False        attack  Not fleeing        False
# 6                       False        attack          Car        False
# 7                       False        attack  Not fleeing        False
# 8                       False         other  Not fleeing         True
# 9                       False        attack  Not fleeing        False
# 10                      False        attack  Not fleeing        False
# 11                      False        attack  Not fleeing        False
# 12                       True         other  Not fleeing        False
# 13                      False        attack          Car        False
# 14                      False        attack         Foot         True
# 15                      False  undetermined  Not fleeing        False
# 16                      False        attack  Not fleeing         True
# 17                      False        attack  Not fleeing        False
# 18                      False        attack  Not fleeing         True
# 19                      False        attack  Not fleeing        False
# 20                      False        attack  Not fleeing        False
# 21                       True        attack  Not fleeing        False
# 22                      False        attack  Not fleeing        False
# 23                      False        attack         Foot        False
# 24                      False        attack         Foot         True
# 25                       True         other  Not fleeing        False
# 26                      False        attack  Not fleeing        False
# 27                      False        attack  Not fleeing        False
# 28                       True        attack  Not fleeing        False
# 29                      False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 4582                    False        attack         Foot        False
# 4583                    False        attack         Foot        False
# 4584                    False        attack         Foot        False
# 4585                     True        attack  Not fleeing         True
# 4586                    False        attack          Car        False
# 4587                    False        attack  Not fleeing        False
# 4588                     True         other  Not fleeing        False
# 4589                    False        attack  Not fleeing        False
# 4590                    False        attack  Not fleeing         True
# 4591                    False        attack  Not fleeing        False
# 4592                    False        attack  Not fleeing        False
# 4593                    False         other          NaN        False
# 4594                    False        attack         Foot        False
# 4595                    False         other  Not fleeing        False
# 4596                    False        attack  Not fleeing        False
# 4597                    False        attack          Car        False
# 4598                    False         other          NaN        False
# 4599                    False        attack  Not fleeing        False
# 4600                     True        attack  Not fleeing        False
# 4601                    False        attack  Not fleeing        False
# 4602                    False        attack        Other        False
# 4603                    False        attack          Car        False
# 4604                    False        attack  Not fleeing        False
# 4605                    False        attack  Not fleeing        False
# 4606                    False        attack         Foot        False
# 4607                    False        attack         Foot        False
# 4608                    False        attack         Foot        False
# 4609                    False        attack  Not fleeing        False
# 4610                    False        attack          NaN        False
# 4611                    False        attack  Not fleeing        False
#
# [4612 rows x 14 columns]

# %%
city_population = pd.read_csv('CityPopulation2000.csv', encoding = "ISO-8859-1")

print(city_population.dtypes) #shows the type of data contained in cells

city_population['Population'] = city_population['Population'].str.replace(r'\(r.*\)', '')#removes anything that has a (r) in it, done to try to clean up data
city_population['City'] = city_population['City'].str.replace(r'\(.*\)', '')#removes anything that has a parenthesis in it, done to try to clean up data
city_population['City'] = city_population['City'].str.replace(r'CDP', '')#removes anything that has a 'CDP' in it, done to try to clean up data
city_population['City'] = city_population['City'].str.replace(r' city', '')#removes anything that has a lowercase spelling of 'city' in it, done to try to clean up data
city_population['City'] = city_population['City'].str.replace(r'\s', '')#gets rid of spaces
#city_population['City'] = city_population['City'].str.lower()#makes everthing lowercase, done to try to clean up data
type_dict = {'Geographic Area': 'str', 'City': 'str', 'Population': 'int64'}#done to change population values into an integer
city_population = city_population.astype(type_dict)#done to change population values into an integer

print(city_population.dtypes)
print(len(city_population))
#city_population=city_population[city_population.Population != 0], old attempt to get rid of zeros, it broke everything so i'm not doing it
#print(len(city_population))
city_population
# Out:
# Geographic Area    object
# City               object
# Population         object
# dtype: object
# Geographic Area    object
# City               object
# Population          int64
# dtype: object
# 29523
#       Geographic Area                            City  Population
# 0                  AL                          Abanda         192
# 1                  AL                       Abbeville        2688
# 2                  AL                      Adamsville        4522
# 3                  AL                     Addisontown         758
# 4                  AL                       Akrontown         356
# 5                  AL                       Alabaster       30352
# 6                  AL                     Albertville       21160
# 7                  AL                   AlexanderCity       14875
# 8                  AL                      Alexandria        3917
# 9                  AL                      Aliceville        2486
# 10                 AL                     Allgoodtown         622
# 11                 AL                     Altoonatown         933
# 12                 AL                       Andalusia        9015
# 13                 AL                    Andersontown         282
# 14                 AL                        Anniston       23106
# 15                 AL                            Arab        8050
# 16                 AL                     Ardmoretown        1194
# 17                 AL                        Argotown        4071
# 18                 AL                      Aritontown         764
# 19                 AL                       Arleytown         357
# 20                 AL                     Ashfordtown        2148
# 21                 AL                     Ashlandtown        2037
# 22                 AL                        Ashville        2212
# 23                 AL                          Athens       21897
# 24                 AL                          Atmore       10194
# 25                 AL                         Attalla        6048
# 26                 AL                          Auburn       53380
# 27                 AL                Autaugavilletown         870
# 28                 AL                        Avontown         543
# 29                 AL                            Axis         757
# ...               ...                             ...         ...
# 29493     Puerto Rico              SanIsidrocomunidad        6828
# 29494     Puerto Rico                SanJosécomunidad        2900
# 29495     Puerto Rico               SanJuanzonaurbana      381931
# 29496     Puerto Rico            SanLorenzozonaurbana        8037
# 29497     Puerto Rico          SanSebastiánzonaurbana        9622
# 29498     Puerto Rico           SantaBárbaracomunidad        4622
# 29499     Puerto Rico             SantaClaracomunidad         982
# 29500     Puerto Rico           SantaIsabelzonaurbana        5976
# 29501     Puerto Rico           SantoDomingocomunidad        3156
# 29502     Puerto Rico                 Stellacomunidad        1088
# 29503     Puerto Rico                 Suárezcomunidad        1931
# 29504     Puerto Rico               Tallaboacomunidad         925
# 29505     Puerto Rico           TallaboaAltacomunidad        1816
# 29506     Puerto Rico                  Tibescomunidad         362
# 29507     Puerto Rico              Tiburonescomunidad        1616
# 29508     Puerto Rico  TierrasNuevasPonientecomunidad        3228
# 29509     Puerto Rico               ToaAltazonaurbana        3713
# 29510     Puerto Rico               ToaBajazonaurbana        1513
# 29511     Puerto Rico          TrujilloAltozonaurbana       48437
# 29512     Puerto Rico                Utuadozonaurbana        8397
# 29513     Puerto Rico                  Vayascomunidad         528
# 29514     Puerto Rico                Vázquezcomunidad        1890
# 29515     Puerto Rico              VegaAltazonaurbana       10266
# 29516     Puerto Rico              VegaBajazonaurbana       25905
# 29517     Puerto Rico                Viequescomunidad        3316
# 29518     Puerto Rico               Viequeszonaurbana        1938
# 29519     Puerto Rico              Villalbazonaurbana        3384
# 29520     Puerto Rico               Yabucoazonaurbana        6047
# 29521     Puerto Rico                 Yaucozonaurbana       17186
# 29522     Puerto Rico                 Yaurelcomunidad        1050
#
# [29523 rows x 3 columns]

# %%
'getting number of shootings per city'
csk=police.groupby(["city", "state"]).size() #Fuck yeah
print(len(csk))
lst_csk = list(csk)
print(lst_csk[0])
csk
# Out:
# 2473
# 1
# city                     state
# 300blockofStateLineRoad  TN        1
# Abbeville                AL        1
# Aberdeen                 NC        1
#                          WA        1
# Abilene                  TX        2
# Abingdon                 MD        1
#                          VA        1
# AbingtonTownship         PA        1
# Acworth                  GA        1
# Ada                      OK        1
# AdamsCounty              CO        3
# Addison                  TX        1
# Adelanto                 CA        1
# Affton                   MO        1
# Aguanga                  CA        1
# Ahwatukee                AZ        1
# Aiea                     HI        1
# Aiken                    SC        2
# Aitkin                   MN        1
# Akron                    OH        6
# Alamo                    TN        2
# Alamogordo               NM        2
# Alamosa                  CO        2
# Albany                   GA        1
#                          NY        1
# AlbertLea                MN        1
# Albuquerque              NM       31
# AlderwoodManor           WA        1
# Aldie                    VA        1
# Alexandria               LA        2
#                                   ..
# WoodLake                 ND        1
# Woodbridge               NJ        1
#                          VA        1
# Woodford                 VA        1
# Woodland                 WA        1
# Woodlawn                 MD        1
# Woodstock                GA        1
# Woodville                CA        1
#                          GA        1
# Wyoming                  MI        2
# WytheCounty              VA        1
# Wytheville               VA        1
# Yakima                   WA        4
# Yellville                AR        1
# Yonkers                  NY        2
# YorbaLinda               CA        1
# York                     NE        1
#                          PA        2
#                          SC        1
#                          WI        1
# YorkCounty               PA        1
#                          VA        1
# Youngtown                AZ        1
# Yreka                    CA        1
# YubaCity                 CA        2
# YuccaValley              CA        1
# Yulee                    FL        1
# Yuma                     AZ        3
# Zanesville               OH        1
# Zion                     IL        2
# Length: 2473, dtype: int64

# %%
'converting to a list'
csk_dict=dict(csk)
print(len(csk_dict))
lst_csk_dict=list(csk_dict)
lst_csk_dict
# Out:
# 2473
# [('300blockofStateLineRoad', 'TN'),
#  ('Abbeville', 'AL'),
#  ('Aberdeen', 'NC'),
#  ('Aberdeen', 'WA'),
#  ('Abilene', 'TX'),
#  ('Abingdon', 'MD'),
#  ('Abingdon', 'VA'),
#  ('AbingtonTownship', 'PA'),
#  ('Acworth', 'GA'),
#  ('Ada', 'OK'),
#  ('AdamsCounty', 'CO'),
#  ('Addison', 'TX'),
#  ('Adelanto', 'CA'),
#  ('Affton', 'MO'),
#  ('Aguanga', 'CA'),
#  ('Ahwatukee', 'AZ'),
#  ('Aiea', 'HI'),
#  ('Aiken', 'SC'),
#  ('Aitkin', 'MN'),
#  ('Akron', 'OH'),
#  ('Alamo', 'TN'),
#  ('Alamogordo', 'NM'),
#  ('Alamosa', 'CO'),
#  ('Albany', 'GA'),
#  ('Albany', 'NY'),
#  ('AlbertLea', 'MN'),
#  ('Albuquerque', 'NM'),
#  ('AlderwoodManor', 'WA'),
#  ('Aldie', 'VA'),
#  ('Alexandria', 'LA'),
#  ('Alexandria', 'MN'),
#  ('Alexandria', 'VA'),
#  ('AlgomaTownship', 'MI'),
#  ('Alhambra', 'CA'),
#  ('Aliceville', 'CA'),
#  ('Allen', 'TX'),
#  ('Allentown', 'PA'),
#  ('Aloha', 'OR'),
#  ('Alpine', 'CA'),
#  ('Alton', 'IL'),
#  ('Altoona', 'IA'),
#  ('Alvin', 'TX'),
#  ('Amarillo', 'TX'),
#  ('AmeliaIsland', 'FL'),
#  ('Amite', 'LA'),
#  ('Amity', 'OR'),
#  ('Anadarko', 'OK'),
#  ('Anaheim', 'CA'),
#  ('Anchorage', 'AK'),
#  ('Anderson', 'CA'),
#  ('AngelFire', 'NM'),
#  ('Ankeny', 'IA'),
#  ('Anniston', 'AL'),
#  ('AnsonCounty', 'NC'),
#  ('Antelope', 'CA'),
#  ('Antigo', 'WI'),
#  ('Antioch', 'CA'),
#  ('Antioch', 'IL'),
#  ('Antioch', 'TN'),
#  ('ApacheJunction', 'AZ'),
#  ('Apex', 'NC'),
#  ('Apopka', 'FL'),
#  ('AppleCreek', 'OH'),
#  ('AppleValley', 'CA'),
#  ('Appleton', 'WI'),
#  ('Arab', 'AL'),
#  ('Aragonite', 'UT'),
#  ('Arcata', 'CA'),
#  ('Archdale', 'NC'),
#  ('Arcola', 'IL'),
#  ('Ardmore', 'OK'),
#  ('Ardsley', 'NY'),
#  ('Arlington', 'GA'),
#  ('Arlington', 'TN'),
#  ('Arlington', 'TX'),
#  ('Arlington', 'VA'),
#  ('Arpin', 'WI'),
#  ('Artesia', 'CA'),
#  ('Artesia', 'NM'),
#  ('Arundel', 'ME'),
#  ('Arvada', 'CO'),
#  ('Arvonia', 'VA'),
#  ('AsburyPark', 'NJ'),
#  ('AsheCounty', 'NC'),
#  ('Asheville', 'NC'),
#  ('Ashland', 'CA'),
#  ('Ashland', 'WI'),
#  ('Ashtabula', 'OH'),
#  ('Ashville', 'AL'),
#  ('Ashwaubenon', 'WI'),
#  ('Aspers', 'PA'),
#  ('Assaria', 'KS'),
#  ('Atascadero', 'CA'),
#  ('Athens', 'GA'),
#  ('Atlanta', 'GA'),
#  ('AtlanticCity', 'NJ'),
#  ('Atwater', 'CA'),
#  ('Auburn', 'CA'),
#  ('Auburn', 'MA'),
#  ('Auburn', 'WA'),
#  ('Auburndale', 'FL'),
#  ('Augusta', 'GA'),
#  ('Augusta', 'WV'),
#  ('Aurora', 'CO'),
#  ('Aurora', 'IL'),
#  ('Aurora', 'MO'),
#  ('Austell', 'GA'),
#  ('Austin', 'AR'),
#  ('Austin', 'MN'),
#  ('Austin', 'TX'),
#  ('Avella', 'PA'),
#  ('Avenal', 'CA'),
#  ('Avon', 'IN'),
#  ('Avondale', 'AZ'),
#  ('Azle', 'TX'),
#  ('Azusa', 'CA'),
#  ('BagleyTownship', 'MI'),
#  ('Bailey', 'CO'),
#  ('Bailey', 'NC'),
#  ('BainbridgeIsland', 'WA'),
#  ('Bakersfield', 'CA'),
#  ('BalchSprings', 'TX'),
#  ('BaldwinCounty', 'AL'),
#  ('BaldwinHills', 'CA'),
#  ('Baltimore', 'MD'),
#  ('Bandon', 'OR'),
#  ('Bangor', 'ME'),
#  ('Banning', 'CA'),
#  ('Barberton', 'OH'),
#  ('Barberville', 'FL'),
#  ('Barbourville', 'KY'),
#  ('Bardstown', 'KY'),
#  ('Barnwell', 'AL'),
#  ('BaronaIndianReservation', 'CA'),
#  ('Barrow', 'AK'),
#  ('BarrowCounty', 'GA'),
#  ('Barstow', 'CA'),
#  ('Bartlesville', 'OK'),
#  ('Bartlett', 'TN'),
#  ('Barton', 'MS'),
#  ('Bassett', 'CA'),
#  ('Bassett', 'VA'),
#  ('Bastrop', 'LA'),
#  ('Batesville', 'AR'),
#  ('Bath', 'NH'),
#  ('BatonRouge', 'LA'),
#  ('BattleCreek', 'MI'),
#  ('Baxter', 'KY'),
#  ('BayCity', 'MI'),
#  ('BayMinette', 'AL'),
#  ('Baytown', 'TX'),
#  ('Beacon', 'NY'),
#  ('Beaumont', 'CA'),
#  ('Beaumont', 'TX'),
#  ('Beaver', 'WA'),
#  ('BeaverDam', 'WI'),
#  ('Beaverton', 'MI'),
#  ('Beaverton', 'OR'),
#  ('Beckley', 'WV'),
#  ('Beckville', 'TX'),
#  ('Bedford', 'TX'),
#  ('BeechGrove', 'IN'),
#  ('BelAir', 'MD'),
#  ('Belgrade', 'ME'),
#  ('Bell', 'CA'),
#  ('BellGardens', 'CA'),
#  ('BelleGlade', 'FL'),
#  ('Belleville', 'IL'),
#  ('Belleville', 'MI'),
#  ('Bellflower', 'CA'),
#  ('Bellingham', 'WA'),
#  ('Bellville', 'TX'),
#  ('Belmont', 'NH'),
#  ('Belton', 'MO'),
#  ('Belton', 'SC'),
#  ('Bemidji', 'MN'),
#  ('Bend', 'OR'),
#  ('Benton', 'AR'),
#  ('Benton', 'IL'),
#  ('BentonCity', 'WA'),
#  ('BentonHarbor', 'MI'),
#  ('BentonTownship', 'MI'),
#  ('Berea', 'KY'),
#  ('Bernalillo', 'NM'),
#  ('Berne', 'NY'),
#  ('Bernice', 'LA'),
#  ('Bethany', 'OK'),
#  ('Beverly', 'MA'),
#  ('Beverly', 'OH'),
#  ('BeverlyHills', 'FL'),
#  ('BexarCounty', 'TX'),
#  ('BibbCounty', 'GA'),
#  ('BigBear', 'MO'),
#  ('BigLake', 'AK'),
#  ('BigSprings', 'NE'),
#  ('BigSur', 'CA'),
#  ('Billings', 'MT'),
#  ('Biloxi', 'MS'),
#  ('Birmingham', 'AL'),
#  ('Bisbee', 'AZ'),
#  ('Bismarck', 'ND'),
#  ('Bixby', 'OK'),
#  ('BlackRiverFalls', 'WI'),
#  ('Blackfoot', 'ID'),
#  ('BlackmanTownship', 'MI'),
#  ('Blacksburg', 'SC'),
#  ('Blackwell', 'OK'),
#  ('Bloomfield', 'NJ'),
#  ('BloomfieldTownship', 'MI'),
#  ('Bloomingdale', 'IL'),
#  ('Bloomington', 'MN'),
#  ('Bloomsburg', 'PA'),
#  ('Blountville', 'TN'),
#  ('BlueSprings', 'MO'),
#  ('BlueSummit', 'MO'),
#  ('Bluefield', 'WV'),
#  ('BluffCity', 'TN'),
#  ('Blytheville', 'AR'),
#  ('Boerne', 'TX'),
#  ('Bogalusa', 'LA'),
#  ('BoilingSprings', 'SC'),
#  ('Boise', 'ID'),
#  ('Bolton', 'CT'),
#  ('Bolton', 'VT'),
#  ('BonAqua', 'TN'),
#  ('Bonaire', 'GA'),
#  ('Boone', 'IA'),
#  ('Booneville', 'KY'),
#  ('Boonville', 'IN'),
#  ('Boring', 'OR'),
#  ('BossierCity', 'LA'),
#  ('Boston', 'MA'),
#  ('Boswell', 'OK'),
#  ('Boulder', 'CO'),
#  ('BoulderCity', 'NV'),
#  ('BoulderCreek', 'CA'),
#  ('BowlingGreen', 'KY'),
#  ('BoxElder', 'SD'),
#  ('BoyleHeights', 'CA'),
#  ('BoyntonBeach', 'FL'),
#  ('BoytonBeach', 'FL'),
#  ('Bozeman', 'MT'),
#  ('Bradenton', 'FL'),
#  ('BradleyCounty', 'TN'),
#  ('Braintree', 'MA'),
#  ('Brandywine', 'WV'),
#  ('Brawley', 'CA'),
#  ('Braxton', 'MS'),
#  ('BraxtonCounty', 'WV'),
#  ('BreauxBridge', 'LA'),
#  ('Bremen', 'KY'),
#  ('Bremerton', 'WA'),
#  ('Brevard', 'NC'),
#  ('Brick', 'NJ'),
#  ('BrickTownship', 'NJ'),
#  ('Bridgeport', 'CT'),
#  ('Bridgeton', 'NJ'),
#  ('Brighton', 'CO'),
#  ('BrightonTownship', 'MI'),
#  ('Bristol', 'TN'),
#  ('Bristol', 'VA'),
#  ('BristolTownship', 'PA'),
#  ('Brockton', 'MA'),
#  ('Brodhead', 'KY'),
#  ('BrokenBow', 'OK'),
#  ('Bronx', 'NY'),
#  ('Brookhaven', 'MS'),
#  ('Brooklet', 'GA'),
#  ('Brooklyn', 'NY'),
#  ('Brooklyn', 'OH'),
#  ('BrooklynCenter', 'MN'),
#  ('Brookshire', 'TX'),
#  ('Brooksville', 'AL'),
#  ('Brooksville', 'FL'),
#  ('Brookville', 'IN'),
#  ('Brookville', 'OH'),
#  ('Broomfield', 'CO'),
#  ('Brownstown', 'IN'),
#  ('Brownsville', 'TX'),
#  ('Bruce', 'FL'),
#  ('Buckeye', 'AZ'),
#  ('Buckhannon', 'WV'),
#  ('Buffalo', 'MO'),
#  ('Buffalo', 'NY'),
#  ('Buford', 'GA'),
#  ('BullShoals', 'AR'),
#  ('BullheadCity', 'AZ'),
#  ('Bunch', 'OK'),
#  ('Burbank', 'CA'),
#  ('Burien', 'WA'),
#  ('Burkesville', 'KY'),
#  ('Burlington', 'IA'),
#  ('Burlington', 'NC'),
#  ('Burlington', 'VT'),
#  ('Burnet', 'TX'),
#  ('Burns', 'OR'),
#  ('BurnsFlat', 'OK'),
#  ('Burnsville', 'MN'),
#  ('Burnsville', 'NC'),
#  ('Bushnell', 'FL'),
#  ('Butte', 'MT'),
#  ('ButteCounty', 'CA'),
#  ('Byars', 'OK'),
#  ('Byng', 'OK'),
#  ('Byram', 'NJ'),
#  ('Byron', 'CA'),
#  ('Cabazon', 'CA'),
#  ('Cabot', 'AR'),
#  ('Cache', 'OK'),
#  ('Cade', 'LA'),
#  ('Calabasas', 'CA'),
#  ('CalaverasCounty', 'CA'),
#  ('Caldwell', 'ID'),
#  ('Caledonia', 'WI'),
#  ('Calexico', 'CA'),
#  ('Calhoun', 'GA'),
#  ('Calimesa', 'CA'),
#  ('Callahan', 'FL'),
#  ('Camarillo', 'CA'),
#  ('Camden', 'NJ'),
#  ('CampCroft', 'SC'),
#  ('CampWood', 'TX'),
#  ('Campbellton', 'TX'),
#  ('Campbelltown', 'PA'),
#  ('Campo', 'CA'),
#  ('Campobello', 'SC'),
#  ('Canaan', 'NH'),
#  ('CanaanTownship', 'PA'),
#  ('Canandaigua', 'NY'),
#  ('Canton', 'NC'),
#  ('Canton', 'OH'),
#  ('CantonTownship', 'PA'),
#  ('Cantonment', 'FL'),
#  ('Canutillo', 'TX'),
#  ('CapeCanaveral', 'FL'),
#  ('CapeCoral', 'FL'),
#  ('CapeGirardeau', 'MO'),
#  ('CapitolHeights', 'MD'),
#  ('Carlsbad', 'NM'),
#  ('Carmichael', 'CA'),
#  ('Carnesville', 'GA'),
#  ('Carollwood', 'FL'),
#  ('Carrizozo', 'NM'),
#  ('CarrollCounty', 'GA'),
#  ('Carrollton', 'GA'),
#  ('Carrollton', 'TX'),
#  ('Carson', 'CA'),
#  ('CarsonCity', 'NV'),
#  ('CarterCounty', 'KY'),
#  ('Cartersville', 'GA'),
#  ('Carthage', 'TN'),
#  ('Cary', 'NC'),
#  ('CasaGrande', 'AZ'),
#  ('Casper', 'WY'),
#  ('Casselberry', 'FL'),
#  ('Castaic', 'CA'),
#  ('CathedralCity', 'CA'),
#  ('CatoTownship', 'MI'),
#  ('Catoosa', 'OK'),
#  ('CaveJunction', 'OR'),
#  ('Cayce', 'SC'),
#  ('CañonCity', 'CO'),
#  ('CedarHill', 'TX'),
#  ('CedarLake', 'TX'),
#  ('CedarRapids', 'IA'),
#  ('Cedartown', 'GA'),
#  ('Celina', 'OH'),
#  ('Centennial', 'CO'),
#  ('Centerville', 'UT'),
#  ('Centralia', 'WA'),
#  ('Ceres', 'CA'),
#  ('Cerritos', 'CA'),
#  ('Chalmette', 'LA'),
#  ('Chambersburg', 'PA'),
#  ('Chamblee', 'GA'),
#  ('Chandler', 'AZ'),
#  ('Chanhassen', 'MN'),
#  ('Channelview', 'TX'),
#  ('Chapeno', 'TX'),
#  ('Charleston', 'SC'),
#  ('Charleston', 'TN'),
#  ('Charleston', 'WV'),
#  ('CharlestonView', 'CA'),
#  ('Charlotte', 'NC'),
#  ('Charlottesville', 'VA'),
#  ('Charlottte', 'NC'),
#  ('ChathamCounty', 'GA'),
#  ('Chatsworth', 'CA'),
#  ('Chattanooga', 'TN'),
#  ('Chavies', 'KY'),
#  ('CheathamCounty', 'TN'),
#  ('Cheektowaga', 'NY'),
#  ('Cheney', 'WA'),
#  ('Chesapeake', 'VA'),
#  ('Chester', 'PA'),
#  ('Chester', 'SC'),
#  ('Chester', 'VA'),
#  ('ChesterfieldCounty', 'SC'),
#  ('Chestertown', 'MD'),
#  ('Chetopa', 'KS'),
#  ('Cheyenne', 'WY'),
#  ('Chicago', 'IL'),
#  ('Chickasha', 'OK'),
#  ('Chico', 'CA'),
#  ('Childress', 'TX'),
#  ('Chinle', 'AZ'),
#  ('Chino', 'CA'),
#  ('ChinoHills', 'CA'),
#  ('Chowchilla', 'CA'),
#  ('ChristianCounty', 'KY'),
#  ('ChulaVista', 'CA'),
#  ('ChurchHill', 'TN'),
#  ('Cincinnati', 'OH'),
#  ('CincoRanch', 'TX'),
#  ('Circleville', 'OH'),
#  ('Cisco', 'TX'),
#  ('Citra', 'FL'),
#  ('Citronelle', 'AL'),
#  ('CitrusHeights', 'CA'),
#  ('CityTerrace', 'CA'),
#  ('ClackamasCounty', 'OR'),
#  ('ClaiborneCounty', 'TN'),
#  ('Clanton', 'AL'),
#  ('Claremont', 'NH'),
#  ('Clarendon', 'NY'),
#  ('ClarkCounty', 'WI'),
#  ('Clarkesville', 'GA'),
#  ('Clarksburg', 'WV'),
#  ('Clarksdale', 'MS'),
#  ('Clarksville', 'AR'),
#  ('Clarksville', 'IN'),
#  ('Clarksville', 'TN'),
#  ('Clarksville', 'TX'),
#  ('Clay', 'AL'),
#  ('Claymont', 'DE'),
#  ('Clayton', 'GA'),
#  ('CleElum', 'WA'),
#  ('ClearCreekCanyon', 'CO'),
#  ('Clearfield', 'UT'),
#  ('ClearlakePark', 'CA'),
#  ('Clearwater', 'FL'),
#  ('Clendenin', 'WV'),
#  ('Clermont', 'FL'),
#  ('Cleveland', 'OH'),
#  ('Clinton', 'IL'),
#  ('Clinton', 'LA'),
#  ('Clinton', 'MD'),
#  ('Clinton', 'MO'),
#  ('Clinton', 'MS'),
#  ('Clinton', 'NC'),
#  ('Clinton', 'TN'),
#  ('Clinton', 'UT'),
#  ('Cloverdale', 'CA'),
#  ('Clovis', 'CA'),
#  ('Clovis', 'NM'),
#  ('Clute', 'TX'),
#  ('CoalCounty', 'OK'),
#  ('Coalinga', 'CA'),
#  ('CobbCounty', 'GA'),
#  ('Cochran', 'GA'),
#  ('CochranCounty', 'TX'),
#  ('CockeCounty', 'TN'),
#  ('Cocoa', 'FL'),
#  ('CocoaBeach', 'FL'),
#  ("Coeurd'Alene", 'ID'),
#  ('Cofield', 'NC'),
#  ('Cohasset', 'MN'),
#  ('Colbert', 'OK'),
#  ('Colby', 'KS'),
#  ('ColebrookTownship', 'OH'),
#  ('Coleman', 'FL'),
#  ('Collierville', 'TN'),
#  ('ColoradoCity', 'CO'),
#  ('ColoradoSprings', 'CO'),
#  ('Colton', 'CA'),
#  ('Colton', 'OR'),
#  ('Columbia', 'MD'),
#  ('Columbia', 'MO'),
#  ('Columbia', 'TN'),
#  ('ColumbiaHeights', 'MN'),
#  ('ColumbiaTownship', 'MI'),
#  ('Columbua', 'IN'),
#  ('Columbus', 'GA'),
#  ('Columbus', 'MS'),
#  ('Columbus', 'OH'),
#  ('Commerce', 'GA'),
#  ('CommerceCity', 'CO'),
#  ('Compton', 'CA'),
#  ('Concord', 'CA'),
#  ('Concord', 'VA'),
#  ('ConeyIsland', 'NY'),
#  ('Conroe', 'TX'),
#  ('Constantia', 'NY'),
#  ('Converse', 'LA'),
#  ('Coolin', 'ID'),
#  ('CoonRapids', 'MN'),
#  ('CoosBay', 'OR'),
#  ('CopperCenter', 'AK'),
#  ('CoralSprings', 'FL'),
#  ('Corning', 'CA'),
#  ('Corning', 'WI'),
#  ('Corona', 'CA'),
#  ('CorpusChristi', 'TX'),
#  ('Cosby', 'TN'),
#  ('Cottonwood', 'AZ'),
#  ('Cottonwood', 'CA'),
#  ('CottonwoodHeights', 'UT'),
#  ('Counce', 'TN'),
#  ('Council', 'ID'),
#  ('CouncilBluffs', 'IA'),
#  ('Coushatta', 'LA'),
#  ('Covina', 'CA'),
#  ('Covington', 'GA'),
#  ('Covington', 'LA'),
#  ('CranburyTownship', 'NJ'),
#  ('Crandon', 'WI'),
#  ('CrawfordCounty', 'OH'),
#  ('Crawfordsville', 'IN'),
#  ('CrenshawCounty', 'AL'),
#  ('CrescentCity', 'CA'),
#  ('CrescentCity', 'FL'),
#  ('Creston', 'IA'),
#  ('Crestwood', 'KY'),
#  ('Crowell', 'TX'),
#  ('Crowley', 'LA'),
#  ('Crownpoint', 'NM'),
#  ('Crystal', 'MN'),
#  ('CrystalSprings', 'FL'),
#  ('Culpeper', 'VA'),
#  ('CumberlandCounty', 'KY'),
#  ('Cumming', 'GA'),
#  ('Cushing', 'OK'),
#  ('DadeCity', 'FL'),
#  ('Dadeville', 'AL'),
#  ('DakotaCity', 'IA'),
#  ('Dalhart', 'TX'),
#  ('Dallas', 'NC'),
#  ('Dallas', 'OR'),
#  ('Dallas', 'TX'),
#  ('Dalton', 'IL'),
#  ('Danbury', 'CT'),
#  ('Danville', 'CA'),
#  ('Danville', 'IL'),
#  ('Danville', 'VA'),
#  ('DarlingtonCounty', 'SC'),
#  ('Davenport', 'IA'),
#  ('DavidsonCounty', 'NC'),
#  ('Davidsonville', 'MD'),
#  ('Davie', 'FL'),
#  ('DaviessCounty', 'KY'),
#  ('Dayton', 'OH'),
#  ('DeKalbCounty', 'GA'),
#  ('DeLand', 'FL'),
#  ('DeRidder', 'LA'),
#  ('DeSoto', 'TX'),
#  ('Dearborn', 'MI'),
#  ('DearbornCounty', 'IN'),
#  ('DearbornHeights', 'MI'),
#  ('Decatur', 'GA'),
#  ('DecaturCounty', 'TN'),
#  ('DeerPark', 'AL'),
#  ('DeerPark', 'WA'),
#  ('Deerfield', 'IL'),
#  ('Defiance', 'OH'),
#  ('DelCity', 'OK'),
#  ('DelMar', 'CA'),
#  ('DelRio', 'TX'),
#  ('Deland', 'FL'),
#  ('Delano', 'CA'),
#  ('Delaware', 'OH'),
#  ('Delhi', 'CA'),
#  ('DelrayBeach', 'FL'),
#  ('Deltona', 'FL'),
#  ('Deming', 'NM'),
#  ('Demopolis', 'AL'),
#  ('DenhamSprings', 'LA'),
#  ('Denton', 'TX'),
#  ('DentonCounty', 'TX'),
#  ('Denver', 'CO'),
#  ('Deptford', 'NJ'),
#  ('Derry', 'NH'),
#  ('DesMoines', 'IA'),
#  ('DesMoines', 'WA'),
#  ('DesertHotSprings', 'CA'),
#  ('Desha', 'AR'),
#  ('Detroit', 'MI'),
#  ("Devil'sLake", 'ND'),
#  ('Dickson', 'TN'),
#  ('Dilley', 'TX'),
#  ('Dillon', 'MT'),
#  ('Dinosaur', 'CO'),
#  ('Dinuba', 'CA'),
#  ('DistrictHeights', 'MD'),
#  ('Dolton', 'IL'),
#  ('Douglas', 'AZ'),
#  ('Douglas', 'GA'),
#  ('Douglas', 'WY'),
#  ('DouglasCity', 'CA'),
#  ('Douglasville', 'GA'),
#  ('Dover', 'AR'),
#  ('Dover', 'DE'),
#  ('DoverTownship', 'PA'),
#  ('Downey', 'CA'),
#  ('Draper', 'UT'),
#  ('Duarte', 'CA'),
#  ('Dublin', 'NC'),
#  ('Dumas', 'TX'),
#  ('Dundalk', 'MD'),
#  ('Dundee', 'FL'),
#  ('Dunsmuir', 'CA'),
#  ('Dunwoody', 'GA'),
#  ('Durham', 'CA'),
#  ('Durham', 'NC'),
#  ('Dyer', 'IN'),
#  ('Dyersburg', 'TN'),
#  ('Eagan', 'MN'),
#  ('Eagar', 'AZ'),
#  ('EagleMountain', 'UT'),
#  ('EastBatonRouge', 'LA'),
#  ('EastBernstadt', 'KY'),
#  ('EastFlatRock', 'NC'),
#  ('EastHartford', 'CT'),
#  ('EastHollywood', 'CA'),
#  ('EastLosAngeles', 'CA'),
#  ('EastPoint', 'GA'),
#  ('EastRidge', 'TN'),
#  ('EastSt.Louis', 'IL'),
#  ('EastStroudsburg', 'PA'),
#  ('EastTroy', 'WI'),
#  ('EastWenatchee', 'WA'),
#  ('Eastaboga', 'AL'),
#  ('EatonCounty', 'MI'),
#  ('EatonRapidsTownship', 'MI'),
#  ('EauClaire', 'WI'),
#  ('EbeyIsland', 'WA'),
#  ('Eclectic', 'AL'),
#  ('Eden', 'GA'),
#  ('Edgewater', 'FL'),
#  ('Edgewood', 'NM'),
#  ('Edinburg', 'NY'),
#  ('Edinburg', 'TX'),
#  ('Edmond', 'OK'),
#  ('Edmonton', 'KY'),
#  ('Edmund', 'SC'),
#  ('Efland', 'NC'),
#  ('Ehrenberg', 'AZ'),
#  ('ElCajon', 'CA'),
#  ('ElCerrito', 'CA'),
#  ('ElMonte', 'CA'),
#  ('ElPaso', 'TX'),
#  ('ElSereno', 'CA'),
#  ('Elberton', 'GA'),
#  ('Eldorado', 'NM'),
#  ('EldoradoSprings', 'CO'),
#  ('Elgin', 'IL'),
#  ('Elizabethon', 'TN'),
#  ('Elizabethton', 'TN'),
#  ('Elizabethtown', 'KY'),
#  ('ElkGrove', 'CA'),
#  ('ElkPlain', 'WA'),
#  ('Elkhart', 'IN'),
#  ('Elkhorn', 'WI'),
#  ('Elkins', 'WV'),
#  ('Elko', 'NV'),
#  ('Elkridge', 'MD'),
#  ('Elkton', 'MD'),
#  ('EllisCounty', 'TX'),
#  ('Elmira', 'NY'),
#  ('Elsmere', 'KY'),
#  ('Elyria', 'OH'),
#  ('Emeryville', 'CA'),
#  ('Emporia', 'VA'),
#  ('Encinitas', 'CA'),
#  ('England', 'AR'),
#  ('Englewood', 'CO'),
#  ('Englewood', 'FL'),
#  ('Englewood', 'OH'),
#  ('English', 'IN'),
#  ('Enid', 'OK'),
#  ('Enoree', 'SC'),
#  ('Epping', 'NH'),
#  ('Erie', 'PA'),
#  ('Ernul', 'NC'),
#  ('Escalon', 'CA'),
#  ('Escondido', 'CA'),
#  ('Essex', 'MD'),
#  ('EstillSprings', 'TN'),
#  ('Euclid', 'OH'),
#  ('Eufaula', 'AL'),
#  ('Eufaula', 'OK'),
#  ('Eugene', 'OR'),
#  ('Euless', 'TX'),
#  ('Eureka', 'CA'),
#  ('Eustis', 'FL'),
#  ('EvangelineParish', 'LA'),
#  ('Evans', 'CO'),
#  ('Evansville', 'IN'),
#  ('Everett', 'MA'),
#  ('Everett', 'WA'),
#  ('Everton', 'MO'),
#  ('FairOaks', 'CA'),
#  ('Fairbanks', 'AK'),
#  ('Fairborn', 'OH'),
#  ('Fairchance', 'PA'),
#  ('Fairchild', 'WI'),
#  ('Fairfax', 'OK'),
#  ('Fairfax', 'VA'),
#  ('Fairfield', 'CA'),
#  ('Fairfield', 'CT'),
#  ('Fairfield', 'OH'),
#  ('Fairfield', 'TX'),
#  ('Fairhope', 'AL'),
#  ('Fairland', 'OK'),
#  ('Fairmont', 'MN'),
#  ('Fairmont', 'WV'),
#  ('Fairview', 'OH'),
#  ('Fairview', 'TN'),
#  ('FalconHeights', 'MN'),
#  ('FallRiver', 'MA'),
#  ('FallsChurch', 'VA'),
#  ('FarmersBranch', 'TX'),
#  ('Farmington', 'AR'),
#  ('Farmington', 'NM'),
#  ('Farmville', 'VA'),
#  ('Fayetteville', 'AR'),
#  ('Fayetteville', 'NC'),
#  ('FederalHeights', 'CO'),
#  ('FederalWay', 'WA'),
#  ('Fife', 'WA'),
#  ('Findlay', 'OH'),
#  ('FinneyCounty', 'KS'),
#  ('Fishers', 'IN'),
#  ('Fisty', 'KY'),
#  ('Flagstaff', 'AZ'),
#  ('Flatwoods', 'KY'),
#  ('Fletcher', 'NC'),
#  ('Flint', 'MI'),
#  ('FloralCity', 'FL'),
#  ('Florence', 'AZ'),
#  ('Florence', 'CA'),
#  ('Florence', 'MS'),
#  ('Florence', 'OR'),
#  ('Florence', 'SC'),
#  ('FloridaCity', 'FL'),
#  ('Florissant', 'MO'),
#  ('FloydCounty', 'GA'),
#  ('Follansbee', 'WV'),
#  ('FondduLac', 'WI'),
#  ('Fontana', 'CA'),
#  ('ForestPark', 'GA'),
#  ('ForestPark', 'IL'),
#  ('Foresthill', 'CA'),
#  ('ForksTownship', 'PA'),
#  ('Formosa', 'AR'),
#  ('FortAshby', 'WV'),
#  ('FortCollins', 'CO'),
#  ('FortDodge', 'IA'),
#  ('FortLauderdale', 'FL'),
#  ('FortLittleton', 'PA'),
#  ('FortLupton', 'CO'),
#  ('FortMadison', 'IA'),
#  ('FortMeade', 'MD'),
#  ('FortMorgan', 'CO'),
#  ('FortMyers', 'FL'),
#  ('FortPierce', 'FL'),
#  ('FortSmith', 'AR'),
#  ('FortSmith', 'OK'),
#  ('FortStockton', 'TX'),
#  ('FortSumner', 'NM'),
#  ('FortValley', 'GA'),
#  ('FortWaltonBeach', 'FL'),
#  ('FortWashington', 'MD'),
#  ('FortWayne', 'IN'),
#  ('FortWorth', 'TX'),
#  ('Fountain', 'CO'),
#  ('FountainInn', 'SC'),
#  ('FountainValley', 'CA'),
#  ('FoxCrossing', 'WI'),
#  ('Frametown', 'WV'),
#  ('Franklin', 'LA'),
#  ('Franklin', 'NC'),
#  ('Franklin', 'TN'),
#  ('Franklin', 'WI'),
#  ('FranklinCounty', 'MO'),
#  ('FranklinCounty', 'OH'),
#  ('FranklinTownship', 'PA'),
#  ('Franklinton', 'OH'),
#  ('Frederica', 'DE'),
#  ('Frederick', 'MD'),
#  ('Fredericksburg', 'VA'),
#  ('Frederickstown', 'WA'),
#  ('Fredonia', 'NY'),
#  ('Freeport', 'TX'),
#  ('Fremont', 'CA'),
#  ('FrenchLick', 'IN'),
#  ('Fresno', 'CA'),
#  ('Fridley', 'MN'),
#  ('FriendlyHills', 'CO'),
#  ('Friendswood', 'TX'),
#  ('Fritch', 'TX'),
#  ('FruitlandPark', 'FL'),
#  ('Ft.Lauderdale', 'FL'),
#  ('Fullerton', 'CA'),
#  ('Fulshear', 'TX'),
#  ('Fulton', 'KY'),
#  ('Fuqua', 'TX'),
#  ('Gadsden', 'AL'),
#  ('Gainesville', 'FL'),
#  ('Gainesville', 'GA'),
#  ('Gallatin', 'TN'),
#  ('Gallup', 'NM'),
#  ('Galveston', 'TX'),
#  ('GardenCity', 'ID'),
#  ('GardenGrove', 'CA'),
#  ('Gardena', 'CA'),
#  ('Gardner', 'KS'),
#  ('GardnervilleRanchos', 'NV'),
#  ('Garland', 'TX'),
#  ('Gary', 'IN'),
#  ('GastonCounty', 'NC'),
#  ('Gastonia', 'NC'),
#  ('Gautier', 'MS'),
#  ('GeneseeTownship', 'MI'),
#  ('Geneva', 'WI'),
#  ('GenevaTownship', 'OH'),
#  ('Georgetown', 'KY'),
#  ('Germantown', 'PA'),
#  ('Gerrardstown', 'WV'),
#  ('Gibson', 'LA'),
#  ('GibsonCounty', 'TN'),
#  ('Gifford', 'FL'),
#  ('Gilbert', 'AZ'),
#  ('Gilbert', 'MN'),
#  ('Gillette', 'WY'),
#  ('Gilmer', 'TX'),
#  ('Gilroy', 'CA'),
#  ('Girard', 'OH'),
#  ('GladeSpring', 'VA'),
#  ('Gladewater', 'TX'),
#  ('GlenBurnie', 'MD'),
#  ('GlenValley', 'CA'),
#  ('Glendale', 'AZ'),
#  ('Glendale', 'CA'),
#  ('Glendora', 'CA'),
#  ('Glennville', 'GA'),
#  ('Glenoma', 'WA'),
#  ('Glenville', 'NY'),
#  ('Glenwood', 'GA'),
#  ('Golden', 'CO'),
#  ('GoldenShores', 'AZ'),
#  ('GoldenValley', 'AZ'),
#  ('Goleta', 'CA'),
#  ('Gonic', 'NH'),
#  ('GonzalesCounty', 'TX'),
#  ('Goodbee', 'LA'),
#  ('Gooding', 'ID'),
#  ('Goodyear', 'AZ'),
#  ('GooseCreek', 'SC'),
#  ('Gordo', 'AL'),
#  ('Gorham', 'ME'),
#  ('Goshen', 'IN'),
#  ('Grafton', 'WV'),
#  ('Graham', 'WA'),
#  ('GrandCanyonCaverns', 'AZ'),
#  ('GrandForks', 'ND'),
#  ('GrandIsland', 'NE'),
#  ('GrandJunction', 'CO'),
#  ('GrandPrairie', 'TX'),
#  ('GrandPrarie', 'TX'),
#  ('GrandRapids', 'MI'),
#  ('GrandTerrace', 'CA'),
#  ('Grandview', 'MO'),
#  ('GraniteFalls', 'NC'),
#  ('Grant', 'OK'),
#  ('Grant-Valkaria', 'FL'),
#  ('GrantsPass', 'OR'),
#  ('Grapeview', 'WA'),
#  ('GrassValley', 'CA'),
#  ('Gray', 'TN'),
#  ('GraysonCounty', 'VA'),
#  ('GreatFalls', 'MT'),
#  ('Greece', 'NY'),
#  ('Greeley', 'CO'),
#  ('Green', 'OH'),
#  ('GreenBay', 'WI'),
#  ('Greenback', 'TN'),
#  ('Greenbelt', 'MD'),
#  ('GreeneCounty', 'MO'),
#  ('Greeneville', 'TN'),
#  ('Greenfield', 'WI'),
#  ('Greenport', 'NY'),
#  ('Greensboro', 'NC'),
#  ('Greensburg', 'PA'),
#  ('Greenspoint', 'TX'),
#  ('Greenville', 'MS'),
#  ('Greenville', 'NC'),
#  ('Greenville', 'SC'),
#  ('GreenvilleCounty', 'SC'),
#  ('Greenwood', 'IN'),
#  ('Grenada', 'MS'),
#  ('Gresham', 'OR'),
#  ('Gretna', 'LA'),
#  ('Griffin', 'GA'),
#  ('GroverBeach', 'CA'),
#  ('Groveton', 'TX'),
#  ('Grundy', 'VA'),
#  ('GuadalupeCounty', 'TX'),
#  ('Gulfport', 'MS'),
#  ('Gunlock', 'KY'),
#  ('GunnisonCounty', 'CO'),
#  ('Gurnee', 'IL'),
#  ('Guthrie', 'OK'),
#  ('Habersham', 'GA'),
#  ('HaciendaHeights', 'CA'),
#  ('Hackensack', 'NJ'),
#  ('Hackett', 'AR'),
#  ('HallCounty', 'GA'),
#  ('HallandaleBeach', 'FL'),
#  ('Hamilton', 'AL'),
#  ('Hamilton', 'NJ'),
#  ('Hamilton', 'OH'),
#  ('HamiltonCounty', 'TN'),
#  ('Hammett', 'ID'),
#  ('Hammond', 'LA'),
#  ('Hampton', 'GA'),
#  ('Hampton', 'NH'),
#  ('Hampton', 'VA'),
#  ('Hanceville', 'AL'),
#  ('HancockCounty', 'MS'),
#  ('Hanford', 'CA'),
#  ('Hanover', 'CO'),
#  ('Hanover', 'IN'),
#  ('Hanover', 'NM'),
#  ('HappyValley', 'CA'),
#  ('Hardeeville', 'SC'),
#  ('Hardwick', 'NJ'),
#  ('HarkerHeights', 'TX'),
#  ('Harmony', 'IN'),
#  ('Harmony', 'TX'),
#  ('HarrisCounty', 'TX'),
#  ('Harrisburg', 'PA'),
#  ('Harrisonburg', 'VA'),
#  ('Harrisonville', 'MO'),
#  ('Hartford', 'CT'),
#  ('Hartsville', 'SC'),
#  ('Harvey', 'IL'),
#  ('Harvey', 'LA'),
#  ('Hastings', 'MN'),
#  ('Hattiesburg', 'MS'),
#  ('Haughton', 'LA'),
#  ('Havasu', 'AZ'),
#  ('HavredeGrace', 'MD'),
#  ('HawaiianGardens', 'CA'),
#  ('Hawkins', 'WI'),
#  ('Hawthorne', 'CA'),
#  ('Haymarket', 'VA'),
#  ('Haynesville', 'AL'),
#  ('Hays', 'KS'),
#  ('Hayti', 'MO'),
#  ('Hayward', 'CA'),
#  ('Healdton', 'OK'),
#  ('Helena', 'AR'),
#  ('Helena', 'MT'),
#  ('Helena-WestHelena', 'AR'),
#  ('Hemet', 'CA'),
#  ('Henderson', 'NC'),
#  ('Henderson', 'NV'),
#  ('HendersonCounty', 'TX'),
#  ('Hendersonville', 'NC'),
#  ('Hendersonville', 'TN'),
#  ('Henrico', 'VA'),
#  ('HenryCounty', 'GA'),
#  ('HenryCounty', 'IN'),
#  ('Hensley', 'WV'),
#  ('Hereford', 'TX'),
#  ('Hermantown', 'MN'),
#  ('Hernando', 'FL'),
#  ('Herndon', 'VA'),
#  ('Hesperia', 'CA'),
#  ('Hessel', 'MI'),
#  ('Hesston', 'KS'),
#  ('Hialeah', 'FL'),
#  ('Hickory', 'NC'),
#  ('Highgrove', 'CA'),
#  ('Highland', 'CA'),
#  ('HighlandsRanch', 'CO'),
#  ('Hillsboro', 'OR'),
#  ('Hilltop', 'OH'),
#  ('Hillyard', 'WA'),
#  ('Hilo', 'HI'),
#  ('Hiltons', 'VA'),
#  ('HindsCounty', 'MS'),
#  ('Hiram', 'GA'),
#  ('Hiseville', 'KY'),
#  ('Hixson', 'TN'),
#  ('Hobbs', 'NM'),
#  ('HogValley', 'FL'),
#  ('Hohenwald', 'TN'),
#  ('Holiday', 'FL'),
#  ('HollandTownship', 'MI'),
#  ...]

# %%
'create list with city, police shootings, and kill count'
def make_list_of_city_kill_state(kill_count,city_state):
    lst=[]
    for i in range(len(kill_count)):
        lst.append([city_state[i][0],kill_count[i],city_state[i][1]])
    return lst

city_kill_state = make_list_of_city_kill_state(lst_csk,lst_csk_dict)
print(len(city_kill_state))
city_kill_state
# Out:
# 2473
# [['300blockofStateLineRoad', 1, 'TN'],
#  ['Abbeville', 1, 'AL'],
#  ['Aberdeen', 1, 'NC'],
#  ['Aberdeen', 1, 'WA'],
#  ['Abilene', 2, 'TX'],
#  ['Abingdon', 1, 'MD'],
#  ['Abingdon', 1, 'VA'],
#  ['AbingtonTownship', 1, 'PA'],
#  ['Acworth', 1, 'GA'],
#  ['Ada', 1, 'OK'],
#  ['AdamsCounty', 3, 'CO'],
#  ['Addison', 1, 'TX'],
#  ['Adelanto', 1, 'CA'],
#  ['Affton', 1, 'MO'],
#  ['Aguanga', 1, 'CA'],
#  ['Ahwatukee', 1, 'AZ'],
#  ['Aiea', 1, 'HI'],
#  ['Aiken', 2, 'SC'],
#  ['Aitkin', 1, 'MN'],
#  ['Akron', 6, 'OH'],
#  ['Alamo', 2, 'TN'],
#  ['Alamogordo', 2, 'NM'],
#  ['Alamosa', 2, 'CO'],
#  ['Albany', 1, 'GA'],
#  ['Albany', 1, 'NY'],
#  ['AlbertLea', 1, 'MN'],
#  ['Albuquerque', 31, 'NM'],
#  ['AlderwoodManor', 1, 'WA'],
#  ['Aldie', 1, 'VA'],
#  ['Alexandria', 2, 'LA'],
#  ['Alexandria', 1, 'MN'],
#  ['Alexandria', 1, 'VA'],
#  ['AlgomaTownship', 1, 'MI'],
#  ['Alhambra', 1, 'CA'],
#  ['Aliceville', 1, 'CA'],
#  ['Allen', 2, 'TX'],
#  ['Allentown', 3, 'PA'],
#  ['Aloha', 2, 'OR'],
#  ['Alpine', 2, 'CA'],
#  ['Alton', 2, 'IL'],
#  ['Altoona', 1, 'IA'],
#  ['Alvin', 1, 'TX'],
#  ['Amarillo', 9, 'TX'],
#  ['AmeliaIsland', 1, 'FL'],
#  ['Amite', 1, 'LA'],
#  ['Amity', 1, 'OR'],
#  ['Anadarko', 1, 'OK'],
#  ['Anaheim', 9, 'CA'],
#  ['Anchorage', 9, 'AK'],
#  ['Anderson', 2, 'CA'],
#  ['AngelFire', 1, 'NM'],
#  ['Ankeny', 1, 'IA'],
#  ['Anniston', 1, 'AL'],
#  ['AnsonCounty', 1, 'NC'],
#  ['Antelope', 1, 'CA'],
#  ['Antigo', 1, 'WI'],
#  ['Antioch', 4, 'CA'],
#  ['Antioch', 1, 'IL'],
#  ['Antioch', 1, 'TN'],
#  ['ApacheJunction', 2, 'AZ'],
#  ['Apex', 2, 'NC'],
#  ['Apopka', 1, 'FL'],
#  ['AppleCreek', 1, 'OH'],
#  ['AppleValley', 1, 'CA'],
#  ['Appleton', 2, 'WI'],
#  ['Arab', 1, 'AL'],
#  ['Aragonite', 1, 'UT'],
#  ['Arcata', 1, 'CA'],
#  ['Archdale', 2, 'NC'],
#  ['Arcola', 1, 'IL'],
#  ['Ardmore', 1, 'OK'],
#  ['Ardsley', 1, 'NY'],
#  ['Arlington', 1, 'GA'],
#  ['Arlington', 1, 'TN'],
#  ['Arlington', 11, 'TX'],
#  ['Arlington', 2, 'VA'],
#  ['Arpin', 1, 'WI'],
#  ['Artesia', 1, 'CA'],
#  ['Artesia', 2, 'NM'],
#  ['Arundel', 1, 'ME'],
#  ['Arvada', 2, 'CO'],
#  ['Arvonia', 1, 'VA'],
#  ['AsburyPark', 1, 'NJ'],
#  ['AsheCounty', 1, 'NC'],
#  ['Asheville', 1, 'NC'],
#  ['Ashland', 1, 'CA'],
#  ['Ashland', 1, 'WI'],
#  ['Ashtabula', 1, 'OH'],
#  ['Ashville', 1, 'AL'],
#  ['Ashwaubenon', 1, 'WI'],
#  ['Aspers', 1, 'PA'],
#  ['Assaria', 1, 'KS'],
#  ['Atascadero', 1, 'CA'],
#  ['Athens', 3, 'GA'],
#  ['Atlanta', 18, 'GA'],
#  ['AtlanticCity', 3, 'NJ'],
#  ['Atwater', 3, 'CA'],
#  ['Auburn', 1, 'CA'],
#  ['Auburn', 1, 'MA'],
#  ['Auburn', 4, 'WA'],
#  ['Auburndale', 1, 'FL'],
#  ['Augusta', 3, 'GA'],
#  ['Augusta', 1, 'WV'],
#  ['Aurora', 12, 'CO'],
#  ['Aurora', 2, 'IL'],
#  ['Aurora', 1, 'MO'],
#  ['Austell', 2, 'GA'],
#  ['Austin', 1, 'AR'],
#  ['Austin', 1, 'MN'],
#  ['Austin', 26, 'TX'],
#  ['Avella', 1, 'PA'],
#  ['Avenal', 1, 'CA'],
#  ['Avon', 1, 'IN'],
#  ['Avondale', 3, 'AZ'],
#  ['Azle', 2, 'TX'],
#  ['Azusa', 4, 'CA'],
#  ['BagleyTownship', 1, 'MI'],
#  ['Bailey', 1, 'CO'],
#  ['Bailey', 1, 'NC'],
#  ['BainbridgeIsland', 1, 'WA'],
#  ['Bakersfield', 21, 'CA'],
#  ['BalchSprings', 1, 'TX'],
#  ['BaldwinCounty', 1, 'AL'],
#  ['BaldwinHills', 1, 'CA'],
#  ['Baltimore', 16, 'MD'],
#  ['Bandon', 1, 'OR'],
#  ['Bangor', 1, 'ME'],
#  ['Banning', 1, 'CA'],
#  ['Barberton', 1, 'OH'],
#  ['Barberville', 1, 'FL'],
#  ['Barbourville', 1, 'KY'],
#  ['Bardstown', 1, 'KY'],
#  ['Barnwell', 1, 'AL'],
#  ['BaronaIndianReservation', 1, 'CA'],
#  ['Barrow', 1, 'AK'],
#  ['BarrowCounty', 1, 'GA'],
#  ['Barstow', 4, 'CA'],
#  ['Bartlesville', 2, 'OK'],
#  ['Bartlett', 1, 'TN'],
#  ['Barton', 1, 'MS'],
#  ['Bassett', 1, 'CA'],
#  ['Bassett', 1, 'VA'],
#  ['Bastrop', 1, 'LA'],
#  ['Batesville', 1, 'AR'],
#  ['Bath', 1, 'NH'],
#  ['BatonRouge', 10, 'LA'],
#  ['BattleCreek', 1, 'MI'],
#  ['Baxter', 1, 'KY'],
#  ['BayCity', 1, 'MI'],
#  ['BayMinette', 1, 'AL'],
#  ['Baytown', 3, 'TX'],
#  ['Beacon', 1, 'NY'],
#  ['Beaumont', 3, 'CA'],
#  ['Beaumont', 2, 'TX'],
#  ['Beaver', 1, 'WA'],
#  ['BeaverDam', 1, 'WI'],
#  ['Beaverton', 1, 'MI'],
#  ['Beaverton', 3, 'OR'],
#  ['Beckley', 1, 'WV'],
#  ['Beckville', 1, 'TX'],
#  ['Bedford', 1, 'TX'],
#  ['BeechGrove', 1, 'IN'],
#  ['BelAir', 1, 'MD'],
#  ['Belgrade', 1, 'ME'],
#  ['Bell', 1, 'CA'],
#  ['BellGardens', 1, 'CA'],
#  ['BelleGlade', 1, 'FL'],
#  ['Belleville', 2, 'IL'],
#  ['Belleville', 1, 'MI'],
#  ['Bellflower', 1, 'CA'],
#  ['Bellingham', 1, 'WA'],
#  ['Bellville', 1, 'TX'],
#  ['Belmont', 1, 'NH'],
#  ['Belton', 2, 'MO'],
#  ['Belton', 1, 'SC'],
#  ['Bemidji', 1, 'MN'],
#  ['Bend', 3, 'OR'],
#  ['Benton', 2, 'AR'],
#  ['Benton', 1, 'IL'],
#  ['BentonCity', 1, 'WA'],
#  ['BentonHarbor', 1, 'MI'],
#  ['BentonTownship', 1, 'MI'],
#  ['Berea', 1, 'KY'],
#  ['Bernalillo', 2, 'NM'],
#  ['Berne', 1, 'NY'],
#  ['Bernice', 1, 'LA'],
#  ['Bethany', 1, 'OK'],
#  ['Beverly', 1, 'MA'],
#  ['Beverly', 1, 'OH'],
#  ['BeverlyHills', 1, 'FL'],
#  ['BexarCounty', 3, 'TX'],
#  ['BibbCounty', 1, 'GA'],
#  ['BigBear', 1, 'MO'],
#  ['BigLake', 1, 'AK'],
#  ['BigSprings', 1, 'NE'],
#  ['BigSur', 1, 'CA'],
#  ['Billings', 9, 'MT'],
#  ['Biloxi', 2, 'MS'],
#  ['Birmingham', 8, 'AL'],
#  ['Bisbee', 1, 'AZ'],
#  ['Bismarck', 1, 'ND'],
#  ['Bixby', 1, 'OK'],
#  ['BlackRiverFalls', 1, 'WI'],
#  ['Blackfoot', 1, 'ID'],
#  ['BlackmanTownship', 1, 'MI'],
#  ['Blacksburg', 1, 'SC'],
#  ['Blackwell', 1, 'OK'],
#  ['Bloomfield', 1, 'NJ'],
#  ['BloomfieldTownship', 1, 'MI'],
#  ['Bloomingdale', 1, 'IL'],
#  ['Bloomington', 1, 'MN'],
#  ['Bloomsburg', 1, 'PA'],
#  ['Blountville', 1, 'TN'],
#  ['BlueSprings', 2, 'MO'],
#  ['BlueSummit', 1, 'MO'],
#  ['Bluefield', 1, 'WV'],
#  ['BluffCity', 1, 'TN'],
#  ['Blytheville', 1, 'AR'],
#  ['Boerne', 2, 'TX'],
#  ['Bogalusa', 1, 'LA'],
#  ['BoilingSprings', 1, 'SC'],
#  ['Boise', 7, 'ID'],
#  ['Bolton', 1, 'CT'],
#  ['Bolton', 1, 'VT'],
#  ['BonAqua', 1, 'TN'],
#  ['Bonaire', 1, 'GA'],
#  ['Boone', 2, 'IA'],
#  ['Booneville', 1, 'KY'],
#  ['Boonville', 1, 'IN'],
#  ['Boring', 1, 'OR'],
#  ['BossierCity', 1, 'LA'],
#  ['Boston', 8, 'MA'],
#  ['Boswell', 1, 'OK'],
#  ['Boulder', 4, 'CO'],
#  ['BoulderCity', 1, 'NV'],
#  ['BoulderCreek', 1, 'CA'],
#  ['BowlingGreen', 1, 'KY'],
#  ['BoxElder', 1, 'SD'],
#  ['BoyleHeights', 1, 'CA'],
#  ['BoyntonBeach', 1, 'FL'],
#  ['BoytonBeach', 1, 'FL'],
#  ['Bozeman', 1, 'MT'],
#  ['Bradenton', 3, 'FL'],
#  ['BradleyCounty', 1, 'TN'],
#  ['Braintree', 1, 'MA'],
#  ['Brandywine', 1, 'WV'],
#  ['Brawley', 1, 'CA'],
#  ['Braxton', 1, 'MS'],
#  ['BraxtonCounty', 1, 'WV'],
#  ['BreauxBridge', 1, 'LA'],
#  ['Bremen', 1, 'KY'],
#  ['Bremerton', 1, 'WA'],
#  ['Brevard', 1, 'NC'],
#  ['Brick', 1, 'NJ'],
#  ['BrickTownship', 1, 'NJ'],
#  ['Bridgeport', 1, 'CT'],
#  ['Bridgeton', 1, 'NJ'],
#  ['Brighton', 1, 'CO'],
#  ['BrightonTownship', 1, 'MI'],
#  ['Bristol', 2, 'TN'],
#  ['Bristol', 1, 'VA'],
#  ['BristolTownship', 1, 'PA'],
#  ['Brockton', 2, 'MA'],
#  ['Brodhead', 1, 'KY'],
#  ['BrokenBow', 1, 'OK'],
#  ['Bronx', 4, 'NY'],
#  ['Brookhaven', 1, 'MS'],
#  ['Brooklet', 1, 'GA'],
#  ['Brooklyn', 5, 'NY'],
#  ['Brooklyn', 1, 'OH'],
#  ['BrooklynCenter', 1, 'MN'],
#  ['Brookshire', 1, 'TX'],
#  ['Brooksville', 1, 'AL'],
#  ['Brooksville', 3, 'FL'],
#  ['Brookville', 1, 'IN'],
#  ['Brookville', 1, 'OH'],
#  ['Broomfield', 1, 'CO'],
#  ['Brownstown', 1, 'IN'],
#  ['Brownsville', 4, 'TX'],
#  ['Bruce', 1, 'FL'],
#  ['Buckeye', 4, 'AZ'],
#  ['Buckhannon', 1, 'WV'],
#  ['Buffalo', 1, 'MO'],
#  ['Buffalo', 3, 'NY'],
#  ['Buford', 2, 'GA'],
#  ['BullShoals', 1, 'AR'],
#  ['BullheadCity', 1, 'AZ'],
#  ['Bunch', 1, 'OK'],
#  ['Burbank', 2, 'CA'],
#  ['Burien', 2, 'WA'],
#  ['Burkesville', 1, 'KY'],
#  ['Burlington', 2, 'IA'],
#  ['Burlington', 1, 'NC'],
#  ['Burlington', 2, 'VT'],
#  ['Burnet', 1, 'TX'],
#  ['Burns', 1, 'OR'],
#  ['BurnsFlat', 1, 'OK'],
#  ['Burnsville', 2, 'MN'],
#  ['Burnsville', 1, 'NC'],
#  ['Bushnell', 1, 'FL'],
#  ['Butte', 1, 'MT'],
#  ['ButteCounty', 1, 'CA'],
#  ['Byars', 1, 'OK'],
#  ['Byng', 1, 'OK'],
#  ['Byram', 1, 'NJ'],
#  ['Byron', 1, 'CA'],
#  ['Cabazon', 1, 'CA'],
#  ['Cabot', 1, 'AR'],
#  ['Cache', 2, 'OK'],
#  ['Cade', 1, 'LA'],
#  ['Calabasas', 1, 'CA'],
#  ['CalaverasCounty', 1, 'CA'],
#  ['Caldwell', 1, 'ID'],
#  ['Caledonia', 1, 'WI'],
#  ['Calexico', 1, 'CA'],
#  ['Calhoun', 1, 'GA'],
#  ['Calimesa', 1, 'CA'],
#  ['Callahan', 1, 'FL'],
#  ['Camarillo', 1, 'CA'],
#  ['Camden', 3, 'NJ'],
#  ['CampCroft', 1, 'SC'],
#  ['CampWood', 1, 'TX'],
#  ['Campbellton', 1, 'TX'],
#  ['Campbelltown', 1, 'PA'],
#  ['Campo', 1, 'CA'],
#  ['Campobello', 1, 'SC'],
#  ['Canaan', 1, 'NH'],
#  ['CanaanTownship', 1, 'PA'],
#  ['Canandaigua', 1, 'NY'],
#  ['Canton', 1, 'NC'],
#  ['Canton', 1, 'OH'],
#  ['CantonTownship', 1, 'PA'],
#  ['Cantonment', 1, 'FL'],
#  ['Canutillo', 1, 'TX'],
#  ['CapeCanaveral', 1, 'FL'],
#  ['CapeCoral', 2, 'FL'],
#  ['CapeGirardeau', 1, 'MO'],
#  ['CapitolHeights', 1, 'MD'],
#  ['Carlsbad', 2, 'NM'],
#  ['Carmichael', 2, 'CA'],
#  ['Carnesville', 1, 'GA'],
#  ['Carollwood', 1, 'FL'],
#  ['Carrizozo', 1, 'NM'],
#  ['CarrollCounty', 1, 'GA'],
#  ['Carrollton', 2, 'GA'],
#  ['Carrollton', 2, 'TX'],
#  ['Carson', 1, 'CA'],
#  ['CarsonCity', 3, 'NV'],
#  ['CarterCounty', 1, 'KY'],
#  ['Cartersville', 2, 'GA'],
#  ['Carthage', 1, 'TN'],
#  ['Cary', 1, 'NC'],
#  ['CasaGrande', 2, 'AZ'],
#  ['Casper', 5, 'WY'],
#  ['Casselberry', 1, 'FL'],
#  ['Castaic', 1, 'CA'],
#  ['CathedralCity', 3, 'CA'],
#  ['CatoTownship', 1, 'MI'],
#  ['Catoosa', 2, 'OK'],
#  ['CaveJunction', 1, 'OR'],
#  ['Cayce', 1, 'SC'],
#  ['CañonCity', 1, 'CO'],
#  ['CedarHill', 1, 'TX'],
#  ['CedarLake', 1, 'TX'],
#  ['CedarRapids', 2, 'IA'],
#  ['Cedartown', 1, 'GA'],
#  ['Celina', 1, 'OH'],
#  ['Centennial', 5, 'CO'],
#  ['Centerville', 1, 'UT'],
#  ['Centralia', 1, 'WA'],
#  ['Ceres', 3, 'CA'],
#  ['Cerritos', 2, 'CA'],
#  ['Chalmette', 1, 'LA'],
#  ['Chambersburg', 1, 'PA'],
#  ['Chamblee', 1, 'GA'],
#  ['Chandler', 3, 'AZ'],
#  ['Chanhassen', 1, 'MN'],
#  ['Channelview', 1, 'TX'],
#  ['Chapeno', 1, 'TX'],
#  ['Charleston', 1, 'SC'],
#  ['Charleston', 1, 'TN'],
#  ['Charleston', 5, 'WV'],
#  ['CharlestonView', 1, 'CA'],
#  ['Charlotte', 15, 'NC'],
#  ['Charlottesville', 1, 'VA'],
#  ['Charlottte', 1, 'NC'],
#  ['ChathamCounty', 1, 'GA'],
#  ['Chatsworth', 1, 'CA'],
#  ['Chattanooga', 5, 'TN'],
#  ['Chavies', 1, 'KY'],
#  ['CheathamCounty', 1, 'TN'],
#  ['Cheektowaga', 1, 'NY'],
#  ['Cheney', 1, 'WA'],
#  ['Chesapeake', 2, 'VA'],
#  ['Chester', 3, 'PA'],
#  ['Chester', 1, 'SC'],
#  ['Chester', 1, 'VA'],
#  ['ChesterfieldCounty', 1, 'SC'],
#  ['Chestertown', 1, 'MD'],
#  ['Chetopa', 1, 'KS'],
#  ['Cheyenne', 2, 'WY'],
#  ['Chicago', 34, 'IL'],
#  ['Chickasha', 4, 'OK'],
#  ['Chico', 4, 'CA'],
#  ['Childress', 1, 'TX'],
#  ['Chinle', 1, 'AZ'],
#  ['Chino', 3, 'CA'],
#  ['ChinoHills', 1, 'CA'],
#  ['Chowchilla', 1, 'CA'],
#  ['ChristianCounty', 1, 'KY'],
#  ['ChulaVista', 2, 'CA'],
#  ['ChurchHill', 2, 'TN'],
#  ['Cincinnati', 7, 'OH'],
#  ['CincoRanch', 2, 'TX'],
#  ['Circleville', 1, 'OH'],
#  ['Cisco', 1, 'TX'],
#  ['Citra', 1, 'FL'],
#  ['Citronelle', 1, 'AL'],
#  ['CitrusHeights', 4, 'CA'],
#  ['CityTerrace', 1, 'CA'],
#  ['ClackamasCounty', 2, 'OR'],
#  ['ClaiborneCounty', 1, 'TN'],
#  ['Clanton', 2, 'AL'],
#  ['Claremont', 1, 'NH'],
#  ['Clarendon', 1, 'NY'],
#  ['ClarkCounty', 1, 'WI'],
#  ['Clarkesville', 1, 'GA'],
#  ['Clarksburg', 1, 'WV'],
#  ['Clarksdale', 1, 'MS'],
#  ['Clarksville', 1, 'AR'],
#  ['Clarksville', 1, 'IN'],
#  ['Clarksville', 4, 'TN'],
#  ['Clarksville', 1, 'TX'],
#  ['Clay', 1, 'AL'],
#  ['Claymont', 1, 'DE'],
#  ['Clayton', 1, 'GA'],
#  ['CleElum', 1, 'WA'],
#  ['ClearCreekCanyon', 1, 'CO'],
#  ['Clearfield', 1, 'UT'],
#  ['ClearlakePark', 1, 'CA'],
#  ['Clearwater', 3, 'FL'],
#  ['Clendenin', 1, 'WV'],
#  ['Clermont', 2, 'FL'],
#  ['Cleveland', 6, 'OH'],
#  ['Clinton', 1, 'IL'],
#  ['Clinton', 1, 'LA'],
#  ['Clinton', 1, 'MD'],
#  ['Clinton', 1, 'MO'],
#  ['Clinton', 1, 'MS'],
#  ['Clinton', 1, 'NC'],
#  ['Clinton', 2, 'TN'],
#  ['Clinton', 1, 'UT'],
#  ['Cloverdale', 1, 'CA'],
#  ['Clovis', 1, 'CA'],
#  ['Clovis', 1, 'NM'],
#  ['Clute', 1, 'TX'],
#  ['CoalCounty', 1, 'OK'],
#  ['Coalinga', 1, 'CA'],
#  ['CobbCounty', 2, 'GA'],
#  ['Cochran', 1, 'GA'],
#  ['CochranCounty', 1, 'TX'],
#  ['CockeCounty', 1, 'TN'],
#  ['Cocoa', 2, 'FL'],
#  ['CocoaBeach', 1, 'FL'],
#  ["Coeurd'Alene", 2, 'ID'],
#  ['Cofield', 1, 'NC'],
#  ['Cohasset', 1, 'MN'],
#  ['Colbert', 1, 'OK'],
#  ['Colby', 1, 'KS'],
#  ['ColebrookTownship', 1, 'OH'],
#  ['Coleman', 1, 'FL'],
#  ['Collierville', 1, 'TN'],
#  ['ColoradoCity', 2, 'CO'],
#  ['ColoradoSprings', 15, 'CO'],
#  ['Colton', 2, 'CA'],
#  ['Colton', 1, 'OR'],
#  ['Columbia', 1, 'MD'],
#  ['Columbia', 3, 'MO'],
#  ['Columbia', 1, 'TN'],
#  ['ColumbiaHeights', 1, 'MN'],
#  ['ColumbiaTownship', 1, 'MI'],
#  ['Columbua', 1, 'IN'],
#  ['Columbus', 3, 'GA'],
#  ['Columbus', 3, 'MS'],
#  ['Columbus', 28, 'OH'],
#  ['Commerce', 1, 'GA'],
#  ['CommerceCity', 1, 'CO'],
#  ['Compton', 3, 'CA'],
#  ['Concord', 1, 'CA'],
#  ['Concord', 1, 'VA'],
#  ['ConeyIsland', 1, 'NY'],
#  ['Conroe', 3, 'TX'],
#  ['Constantia', 1, 'NY'],
#  ['Converse', 1, 'LA'],
#  ['Coolin', 1, 'ID'],
#  ['CoonRapids', 1, 'MN'],
#  ['CoosBay', 1, 'OR'],
#  ['CopperCenter', 1, 'AK'],
#  ['CoralSprings', 1, 'FL'],
#  ['Corning', 1, 'CA'],
#  ['Corning', 1, 'WI'],
#  ['Corona', 1, 'CA'],
#  ['CorpusChristi', 4, 'TX'],
#  ['Cosby', 1, 'TN'],
#  ['Cottonwood', 2, 'AZ'],
#  ['Cottonwood', 1, 'CA'],
#  ['CottonwoodHeights', 1, 'UT'],
#  ['Counce', 1, 'TN'],
#  ['Council', 1, 'ID'],
#  ['CouncilBluffs', 1, 'IA'],
#  ['Coushatta', 1, 'LA'],
#  ['Covina', 1, 'CA'],
#  ['Covington', 2, 'GA'],
#  ['Covington', 1, 'LA'],
#  ['CranburyTownship', 1, 'NJ'],
#  ['Crandon', 2, 'WI'],
#  ['CrawfordCounty', 1, 'OH'],
#  ['Crawfordsville', 1, 'IN'],
#  ['CrenshawCounty', 1, 'AL'],
#  ['CrescentCity', 1, 'CA'],
#  ['CrescentCity', 1, 'FL'],
#  ['Creston', 1, 'IA'],
#  ['Crestwood', 1, 'KY'],
#  ['Crowell', 1, 'TX'],
#  ['Crowley', 1, 'LA'],
#  ['Crownpoint', 1, 'NM'],
#  ['Crystal', 1, 'MN'],
#  ['CrystalSprings', 1, 'FL'],
#  ['Culpeper', 1, 'VA'],
#  ['CumberlandCounty', 1, 'KY'],
#  ['Cumming', 3, 'GA'],
#  ['Cushing', 1, 'OK'],
#  ['DadeCity', 1, 'FL'],
#  ['Dadeville', 1, 'AL'],
#  ['DakotaCity', 1, 'IA'],
#  ['Dalhart', 1, 'TX'],
#  ['Dallas', 1, 'NC'],
#  ['Dallas', 1, 'OR'],
#  ['Dallas', 15, 'TX'],
#  ['Dalton', 1, 'IL'],
#  ['Danbury', 1, 'CT'],
#  ['Danville', 1, 'CA'],
#  ['Danville', 1, 'IL'],
#  ['Danville', 2, 'VA'],
#  ['DarlingtonCounty', 2, 'SC'],
#  ['Davenport', 2, 'IA'],
#  ['DavidsonCounty', 1, 'NC'],
#  ['Davidsonville', 1, 'MD'],
#  ['Davie', 1, 'FL'],
#  ['DaviessCounty', 1, 'KY'],
#  ['Dayton', 5, 'OH'],
#  ['DeKalbCounty', 1, 'GA'],
#  ['DeLand', 3, 'FL'],
#  ['DeRidder', 1, 'LA'],
#  ['DeSoto', 1, 'TX'],
#  ['Dearborn', 2, 'MI'],
#  ['DearbornCounty', 1, 'IN'],
#  ['DearbornHeights', 1, 'MI'],
#  ['Decatur', 1, 'GA'],
#  ['DecaturCounty', 1, 'TN'],
#  ['DeerPark', 1, 'AL'],
#  ['DeerPark', 1, 'WA'],
#  ['Deerfield', 1, 'IL'],
#  ['Defiance', 1, 'OH'],
#  ['DelCity', 1, 'OK'],
#  ['DelMar', 1, 'CA'],
#  ['DelRio', 1, 'TX'],
#  ['Deland', 1, 'FL'],
#  ['Delano', 3, 'CA'],
#  ['Delaware', 1, 'OH'],
#  ['Delhi', 1, 'CA'],
#  ['DelrayBeach', 2, 'FL'],
#  ['Deltona', 4, 'FL'],
#  ['Deming', 1, 'NM'],
#  ['Demopolis', 1, 'AL'],
#  ['DenhamSprings', 2, 'LA'],
#  ['Denton', 2, 'TX'],
#  ['DentonCounty', 1, 'TX'],
#  ['Denver', 26, 'CO'],
#  ['Deptford', 1, 'NJ'],
#  ['Derry', 1, 'NH'],
#  ['DesMoines', 4, 'IA'],
#  ['DesMoines', 2, 'WA'],
#  ['DesertHotSprings', 2, 'CA'],
#  ['Desha', 1, 'AR'],
#  ['Detroit', 9, 'MI'],
#  ["Devil'sLake", 1, 'ND'],
#  ['Dickson', 1, 'TN'],
#  ['Dilley', 1, 'TX'],
#  ['Dillon', 1, 'MT'],
#  ['Dinosaur', 1, 'CO'],
#  ['Dinuba', 1, 'CA'],
#  ['DistrictHeights', 1, 'MD'],
#  ['Dolton', 1, 'IL'],
#  ['Douglas', 1, 'AZ'],
#  ['Douglas', 1, 'GA'],
#  ['Douglas', 2, 'WY'],
#  ['DouglasCity', 1, 'CA'],
#  ['Douglasville', 2, 'GA'],
#  ['Dover', 1, 'AR'],
#  ['Dover', 1, 'DE'],
#  ['DoverTownship', 1, 'PA'],
#  ['Downey', 1, 'CA'],
#  ['Draper', 1, 'UT'],
#  ['Duarte', 1, 'CA'],
#  ['Dublin', 1, 'NC'],
#  ['Dumas', 1, 'TX'],
#  ['Dundalk', 1, 'MD'],
#  ['Dundee', 1, 'FL'],
#  ['Dunsmuir', 2, 'CA'],
#  ['Dunwoody', 1, 'GA'],
#  ['Durham', 1, 'CA'],
#  ['Durham', 6, 'NC'],
#  ['Dyer', 1, 'IN'],
#  ['Dyersburg', 1, 'TN'],
#  ['Eagan', 2, 'MN'],
#  ['Eagar', 3, 'AZ'],
#  ['EagleMountain', 1, 'UT'],
#  ['EastBatonRouge', 2, 'LA'],
#  ['EastBernstadt', 1, 'KY'],
#  ['EastFlatRock', 1, 'NC'],
#  ['EastHartford', 2, 'CT'],
#  ['EastHollywood', 1, 'CA'],
#  ['EastLosAngeles', 1, 'CA'],
#  ['EastPoint', 3, 'GA'],
#  ['EastRidge', 1, 'TN'],
#  ['EastSt.Louis', 1, 'IL'],
#  ['EastStroudsburg', 1, 'PA'],
#  ['EastTroy', 1, 'WI'],
#  ['EastWenatchee', 1, 'WA'],
#  ['Eastaboga', 1, 'AL'],
#  ['EatonCounty', 1, 'MI'],
#  ['EatonRapidsTownship', 1, 'MI'],
#  ['EauClaire', 4, 'WI'],
#  ['EbeyIsland', 1, 'WA'],
#  ['Eclectic', 1, 'AL'],
#  ['Eden', 1, 'GA'],
#  ['Edgewater', 1, 'FL'],
#  ['Edgewood', 1, 'NM'],
#  ['Edinburg', 1, 'NY'],
#  ['Edinburg', 2, 'TX'],
#  ['Edmond', 2, 'OK'],
#  ['Edmonton', 1, 'KY'],
#  ['Edmund', 1, 'SC'],
#  ['Efland', 1, 'NC'],
#  ['Ehrenberg', 1, 'AZ'],
#  ['ElCajon', 2, 'CA'],
#  ['ElCerrito', 1, 'CA'],
#  ['ElMonte', 2, 'CA'],
#  ['ElPaso', 11, 'TX'],
#  ['ElSereno', 1, 'CA'],
#  ['Elberton', 1, 'GA'],
#  ['Eldorado', 1, 'NM'],
#  ['EldoradoSprings', 1, 'CO'],
#  ['Elgin', 1, 'IL'],
#  ['Elizabethon', 1, 'TN'],
#  ['Elizabethton', 1, 'TN'],
#  ['Elizabethtown', 3, 'KY'],
#  ['ElkGrove', 2, 'CA'],
#  ['ElkPlain', 1, 'WA'],
#  ['Elkhart', 2, 'IN'],
#  ['Elkhorn', 1, 'WI'],
#  ['Elkins', 1, 'WV'],
#  ['Elko', 1, 'NV'],
#  ['Elkridge', 1, 'MD'],
#  ['Elkton', 3, 'MD'],
#  ['EllisCounty', 2, 'TX'],
#  ['Elmira', 1, 'NY'],
#  ['Elsmere', 1, 'KY'],
#  ['Elyria', 1, 'OH'],
#  ['Emeryville', 2, 'CA'],
#  ['Emporia', 1, 'VA'],
#  ['Encinitas', 1, 'CA'],
#  ['England', 1, 'AR'],
#  ['Englewood', 1, 'CO'],
#  ['Englewood', 2, 'FL'],
#  ['Englewood', 1, 'OH'],
#  ['English', 1, 'IN'],
#  ['Enid', 1, 'OK'],
#  ['Enoree', 1, 'SC'],
#  ['Epping', 1, 'NH'],
#  ['Erie', 1, 'PA'],
#  ['Ernul', 1, 'NC'],
#  ['Escalon', 1, 'CA'],
#  ['Escondido', 1, 'CA'],
#  ['Essex', 1, 'MD'],
#  ['EstillSprings', 1, 'TN'],
#  ['Euclid', 1, 'OH'],
#  ['Eufaula', 1, 'AL'],
#  ['Eufaula', 1, 'OK'],
#  ['Eugene', 5, 'OR'],
#  ['Euless', 2, 'TX'],
#  ['Eureka', 1, 'CA'],
#  ['Eustis', 2, 'FL'],
#  ['EvangelineParish', 1, 'LA'],
#  ['Evans', 2, 'CO'],
#  ['Evansville', 4, 'IN'],
#  ['Everett', 1, 'MA'],
#  ['Everett', 1, 'WA'],
#  ['Everton', 1, 'MO'],
#  ['FairOaks', 2, 'CA'],
#  ['Fairbanks', 9, 'AK'],
#  ['Fairborn', 1, 'OH'],
#  ['Fairchance', 1, 'PA'],
#  ['Fairchild', 1, 'WI'],
#  ['Fairfax', 1, 'OK'],
#  ['Fairfax', 1, 'VA'],
#  ['Fairfield', 1, 'CA'],
#  ['Fairfield', 1, 'CT'],
#  ['Fairfield', 1, 'OH'],
#  ['Fairfield', 2, 'TX'],
#  ['Fairhope', 1, 'AL'],
#  ['Fairland', 1, 'OK'],
#  ['Fairmont', 1, 'MN'],
#  ['Fairmont', 1, 'WV'],
#  ['Fairview', 1, 'OH'],
#  ['Fairview', 2, 'TN'],
#  ['FalconHeights', 1, 'MN'],
#  ['FallRiver', 1, 'MA'],
#  ['FallsChurch', 1, 'VA'],
#  ['FarmersBranch', 1, 'TX'],
#  ['Farmington', 1, 'AR'],
#  ['Farmington', 3, 'NM'],
#  ['Farmville', 1, 'VA'],
#  ['Fayetteville', 2, 'AR'],
#  ['Fayetteville', 3, 'NC'],
#  ['FederalHeights', 1, 'CO'],
#  ['FederalWay', 4, 'WA'],
#  ['Fife', 1, 'WA'],
#  ['Findlay', 1, 'OH'],
#  ['FinneyCounty', 1, 'KS'],
#  ['Fishers', 1, 'IN'],
#  ['Fisty', 1, 'KY'],
#  ['Flagstaff', 9, 'AZ'],
#  ['Flatwoods', 2, 'KY'],
#  ['Fletcher', 1, 'NC'],
#  ['Flint', 2, 'MI'],
#  ['FloralCity', 2, 'FL'],
#  ['Florence', 1, 'AZ'],
#  ['Florence', 2, 'CA'],
#  ['Florence', 1, 'MS'],
#  ['Florence', 1, 'OR'],
#  ['Florence', 1, 'SC'],
#  ['FloridaCity', 1, 'FL'],
#  ['Florissant', 1, 'MO'],
#  ['FloydCounty', 2, 'GA'],
#  ['Follansbee', 1, 'WV'],
#  ['FondduLac', 1, 'WI'],
#  ['Fontana', 5, 'CA'],
#  ['ForestPark', 1, 'GA'],
#  ['ForestPark', 1, 'IL'],
#  ['Foresthill', 1, 'CA'],
#  ['ForksTownship', 1, 'PA'],
#  ['Formosa', 1, 'AR'],
#  ['FortAshby', 1, 'WV'],
#  ['FortCollins', 4, 'CO'],
#  ['FortDodge', 1, 'IA'],
#  ['FortLauderdale', 2, 'FL'],
#  ['FortLittleton', 1, 'PA'],
#  ['FortLupton', 1, 'CO'],
#  ['FortMadison', 1, 'IA'],
#  ['FortMeade', 1, 'MD'],
#  ['FortMorgan', 1, 'CO'],
#  ['FortMyers', 1, 'FL'],
#  ['FortPierce', 5, 'FL'],
#  ['FortSmith', 1, 'AR'],
#  ['FortSmith', 1, 'OK'],
#  ['FortStockton', 1, 'TX'],
#  ['FortSumner', 1, 'NM'],
#  ['FortValley', 1, 'GA'],
#  ['FortWaltonBeach', 2, 'FL'],
#  ['FortWashington', 1, 'MD'],
#  ['FortWayne', 4, 'IN'],
#  ['FortWorth', 14, 'TX'],
#  ['Fountain', 1, 'CO'],
#  ['FountainInn', 2, 'SC'],
#  ['FountainValley', 1, 'CA'],
#  ['FoxCrossing', 1, 'WI'],
#  ['Frametown', 1, 'WV'],
#  ['Franklin', 1, 'LA'],
#  ['Franklin', 2, 'NC'],
#  ['Franklin', 1, 'TN'],
#  ['Franklin', 1, 'WI'],
#  ['FranklinCounty', 1, 'MO'],
#  ['FranklinCounty', 1, 'OH'],
#  ['FranklinTownship', 1, 'PA'],
#  ['Franklinton', 1, 'OH'],
#  ['Frederica', 1, 'DE'],
#  ['Frederick', 1, 'MD'],
#  ['Fredericksburg', 1, 'VA'],
#  ['Frederickstown', 1, 'WA'],
#  ['Fredonia', 1, 'NY'],
#  ['Freeport', 1, 'TX'],
#  ['Fremont', 5, 'CA'],
#  ['FrenchLick', 1, 'IN'],
#  ['Fresno', 17, 'CA'],
#  ['Fridley', 1, 'MN'],
#  ['FriendlyHills', 1, 'CO'],
#  ['Friendswood', 1, 'TX'],
#  ['Fritch', 1, 'TX'],
#  ['FruitlandPark', 1, 'FL'],
#  ['Ft.Lauderdale', 1, 'FL'],
#  ['Fullerton', 3, 'CA'],
#  ['Fulshear', 1, 'TX'],
#  ['Fulton', 1, 'KY'],
#  ['Fuqua', 1, 'TX'],
#  ['Gadsden', 1, 'AL'],
#  ['Gainesville', 2, 'FL'],
#  ['Gainesville', 3, 'GA'],
#  ['Gallatin', 1, 'TN'],
#  ['Gallup', 1, 'NM'],
#  ['Galveston', 1, 'TX'],
#  ['GardenCity', 1, 'ID'],
#  ['GardenGrove', 1, 'CA'],
#  ['Gardena', 3, 'CA'],
#  ['Gardner', 1, 'KS'],
#  ['GardnervilleRanchos', 1, 'NV'],
#  ['Garland', 6, 'TX'],
#  ['Gary', 5, 'IN'],
#  ['GastonCounty', 1, 'NC'],
#  ['Gastonia', 3, 'NC'],
#  ['Gautier', 1, 'MS'],
#  ['GeneseeTownship', 1, 'MI'],
#  ['Geneva', 2, 'WI'],
#  ['GenevaTownship', 1, 'OH'],
#  ['Georgetown', 2, 'KY'],
#  ['Germantown', 1, 'PA'],
#  ['Gerrardstown', 1, 'WV'],
#  ['Gibson', 1, 'LA'],
#  ['GibsonCounty', 1, 'TN'],
#  ['Gifford', 1, 'FL'],
#  ['Gilbert', 3, 'AZ'],
#  ['Gilbert', 1, 'MN'],
#  ['Gillette', 1, 'WY'],
#  ['Gilmer', 1, 'TX'],
#  ['Gilroy', 1, 'CA'],
#  ['Girard', 1, 'OH'],
#  ['GladeSpring', 1, 'VA'],
#  ['Gladewater', 1, 'TX'],
#  ['GlenBurnie', 1, 'MD'],
#  ['GlenValley', 1, 'CA'],
#  ['Glendale', 9, 'AZ'],
#  ['Glendale', 1, 'CA'],
#  ['Glendora', 1, 'CA'],
#  ['Glennville', 1, 'GA'],
#  ['Glenoma', 1, 'WA'],
#  ['Glenville', 1, 'NY'],
#  ['Glenwood', 1, 'GA'],
#  ['Golden', 1, 'CO'],
#  ['GoldenShores', 1, 'AZ'],
#  ['GoldenValley', 1, 'AZ'],
#  ['Goleta', 1, 'CA'],
#  ['Gonic', 1, 'NH'],
#  ['GonzalesCounty', 1, 'TX'],
#  ['Goodbee', 1, 'LA'],
#  ['Gooding', 1, 'ID'],
#  ['Goodyear', 1, 'AZ'],
#  ['GooseCreek', 1, 'SC'],
#  ['Gordo', 1, 'AL'],
#  ['Gorham', 1, 'ME'],
#  ['Goshen', 1, 'IN'],
#  ['Grafton', 1, 'WV'],
#  ['Graham', 1, 'WA'],
#  ['GrandCanyonCaverns', 1, 'AZ'],
#  ['GrandForks', 2, 'ND'],
#  ['GrandIsland', 1, 'NE'],
#  ['GrandJunction', 4, 'CO'],
#  ['GrandPrairie', 1, 'TX'],
#  ['GrandPrarie', 1, 'TX'],
#  ['GrandRapids', 1, 'MI'],
#  ['GrandTerrace', 1, 'CA'],
#  ['Grandview', 1, 'MO'],
#  ['GraniteFalls', 1, 'NC'],
#  ['Grant', 1, 'OK'],
#  ['Grant-Valkaria', 1, 'FL'],
#  ['GrantsPass', 1, 'OR'],
#  ['Grapeview', 1, 'WA'],
#  ['GrassValley', 1, 'CA'],
#  ['Gray', 1, 'TN'],
#  ['GraysonCounty', 1, 'VA'],
#  ['GreatFalls', 3, 'MT'],
#  ['Greece', 2, 'NY'],
#  ['Greeley', 5, 'CO'],
#  ['Green', 1, 'OH'],
#  ['GreenBay', 1, 'WI'],
#  ['Greenback', 1, 'TN'],
#  ['Greenbelt', 1, 'MD'],
#  ['GreeneCounty', 1, 'MO'],
#  ['Greeneville', 1, 'TN'],
#  ['Greenfield', 1, 'WI'],
#  ['Greenport', 1, 'NY'],
#  ['Greensboro', 2, 'NC'],
#  ['Greensburg', 1, 'PA'],
#  ['Greenspoint', 1, 'TX'],
#  ['Greenville', 3, 'MS'],
#  ['Greenville', 4, 'NC'],
#  ['Greenville', 3, 'SC'],
#  ['GreenvilleCounty', 2, 'SC'],
#  ['Greenwood', 1, 'IN'],
#  ['Grenada', 1, 'MS'],
#  ['Gresham', 2, 'OR'],
#  ['Gretna', 1, 'LA'],
#  ['Griffin', 1, 'GA'],
#  ['GroverBeach', 1, 'CA'],
#  ['Groveton', 1, 'TX'],
#  ['Grundy', 1, 'VA'],
#  ['GuadalupeCounty', 1, 'TX'],
#  ['Gulfport', 4, 'MS'],
#  ['Gunlock', 1, 'KY'],
#  ['GunnisonCounty', 1, 'CO'],
#  ['Gurnee', 1, 'IL'],
#  ['Guthrie', 2, 'OK'],
#  ['Habersham', 1, 'GA'],
#  ['HaciendaHeights', 1, 'CA'],
#  ['Hackensack', 2, 'NJ'],
#  ['Hackett', 1, 'AR'],
#  ['HallCounty', 2, 'GA'],
#  ['HallandaleBeach', 3, 'FL'],
#  ['Hamilton', 1, 'AL'],
#  ['Hamilton', 1, 'NJ'],
#  ['Hamilton', 2, 'OH'],
#  ['HamiltonCounty', 1, 'TN'],
#  ['Hammett', 1, 'ID'],
#  ['Hammond', 1, 'LA'],
#  ['Hampton', 1, 'GA'],
#  ['Hampton', 1, 'NH'],
#  ['Hampton', 1, 'VA'],
#  ['Hanceville', 1, 'AL'],
#  ['HancockCounty', 1, 'MS'],
#  ['Hanford', 1, 'CA'],
#  ['Hanover', 1, 'CO'],
#  ['Hanover', 1, 'IN'],
#  ['Hanover', 1, 'NM'],
#  ['HappyValley', 1, 'CA'],
#  ['Hardeeville', 2, 'SC'],
#  ['Hardwick', 2, 'NJ'],
#  ['HarkerHeights', 1, 'TX'],
#  ['Harmony', 1, 'IN'],
#  ['Harmony', 1, 'TX'],
#  ['HarrisCounty', 1, 'TX'],
#  ['Harrisburg', 4, 'PA'],
#  ['Harrisonburg', 2, 'VA'],
#  ['Harrisonville', 1, 'MO'],
#  ['Hartford', 1, 'CT'],
#  ['Hartsville', 1, 'SC'],
#  ['Harvey', 1, 'IL'],
#  ['Harvey', 2, 'LA'],
#  ['Hastings', 1, 'MN'],
#  ['Hattiesburg', 2, 'MS'],
#  ['Haughton', 1, 'LA'],
#  ['Havasu', 1, 'AZ'],
#  ['HavredeGrace', 1, 'MD'],
#  ['HawaiianGardens', 1, 'CA'],
#  ['Hawkins', 1, 'WI'],
#  ['Hawthorne', 1, 'CA'],
#  ['Haymarket', 1, 'VA'],
#  ['Haynesville', 1, 'AL'],
#  ['Hays', 2, 'KS'],
#  ['Hayti', 1, 'MO'],
#  ['Hayward', 3, 'CA'],
#  ['Healdton', 1, 'OK'],
#  ['Helena', 1, 'AR'],
#  ['Helena', 1, 'MT'],
#  ['Helena-WestHelena', 1, 'AR'],
#  ['Hemet', 7, 'CA'],
#  ['Henderson', 1, 'NC'],
#  ['Henderson', 4, 'NV'],
#  ['HendersonCounty', 1, 'TX'],
#  ['Hendersonville', 1, 'NC'],
#  ['Hendersonville', 1, 'TN'],
#  ['Henrico', 1, 'VA'],
#  ['HenryCounty', 1, 'GA'],
#  ['HenryCounty', 1, 'IN'],
#  ['Hensley', 1, 'WV'],
#  ['Hereford', 1, 'TX'],
#  ['Hermantown', 1, 'MN'],
#  ['Hernando', 1, 'FL'],
#  ['Herndon', 1, 'VA'],
#  ['Hesperia', 2, 'CA'],
#  ['Hessel', 1, 'MI'],
#  ['Hesston', 1, 'KS'],
#  ['Hialeah', 1, 'FL'],
#  ['Hickory', 2, 'NC'],
#  ['Highgrove', 1, 'CA'],
#  ['Highland', 2, 'CA'],
#  ['HighlandsRanch', 1, 'CO'],
#  ['Hillsboro', 2, 'OR'],
#  ['Hilltop', 1, 'OH'],
#  ['Hillyard', 1, 'WA'],
#  ['Hilo', 4, 'HI'],
#  ['Hiltons', 1, 'VA'],
#  ['HindsCounty', 1, 'MS'],
#  ['Hiram', 1, 'GA'],
#  ['Hiseville', 1, 'KY'],
#  ['Hixson', 1, 'TN'],
#  ['Hobbs', 3, 'NM'],
#  ['HogValley', 1, 'FL'],
#  ['Hohenwald', 2, 'TN'],
#  ['Holiday', 1, 'FL'],
#  ['HollandTownship', 1, 'MI'],
#  ...]

# %%
'making sure that cities have a length'
len(city_kill_state[2][0])
# Out:
# 8

# %%
'make a list of city populations'
city_pop_lst=[]
for i in range(len(city_population)):
    city_pop_lst.append([city_population['City'][i],city_population['Population'][i],city_population['Geographic Area'][i]])
print(len(city_pop_lst))
city_pop_lst
# Out:
# 29523
# [['Abanda', 192, 'AL'],
#  ['Abbeville', 2688, 'AL'],
#  ['Adamsville', 4522, 'AL'],
#  ['Addisontown', 758, 'AL'],
#  ['Akrontown', 356, 'AL'],
#  ['Alabaster', 30352, 'AL'],
#  ['Albertville', 21160, 'AL'],
#  ['AlexanderCity', 14875, 'AL'],
#  ['Alexandria', 3917, 'AL'],
#  ['Aliceville', 2486, 'AL'],
#  ['Allgoodtown', 622, 'AL'],
#  ['Altoonatown', 933, 'AL'],
#  ['Andalusia', 9015, 'AL'],
#  ['Andersontown', 282, 'AL'],
#  ['Anniston', 23106, 'AL'],
#  ['Arab', 8050, 'AL'],
#  ['Ardmoretown', 1194, 'AL'],
#  ['Argotown', 4071, 'AL'],
#  ['Aritontown', 764, 'AL'],
#  ['Arleytown', 357, 'AL'],
#  ['Ashfordtown', 2148, 'AL'],
#  ['Ashlandtown', 2037, 'AL'],
#  ['Ashville', 2212, 'AL'],
#  ['Athens', 21897, 'AL'],
#  ['Atmore', 10194, 'AL'],
#  ['Attalla', 6048, 'AL'],
#  ['Auburn', 53380, 'AL'],
#  ['Autaugavilletown', 870, 'AL'],
#  ['Avontown', 543, 'AL'],
#  ['Axis', 757, 'AL'],
#  ['Babbietown', 603, 'AL'],
#  ['Baileytontown', 610, 'AL'],
#  ['Bakerhilltown', 279, 'AL'],
#  ['Ballplay', 1580, 'AL'],
#  ['Bankstown', 179, 'AL'],
#  ['BayMinette', 8044, 'AL'],
#  ['BayouLaBatre', 2558, 'AL'],
#  ['BearCreektown', 1070, 'AL'],
#  ['Beatricetown', 301, 'AL'],
#  ['Beavertontown', 201, 'AL'],
#  ['Belgreen', 129, 'AL'],
#  ['Belktown', 215, 'AL'],
#  ['Bellamy', 543, 'AL'],
#  ['BelleFontaine', 608, 'AL'],
#  ['Bentontown', 49, 'AL'],
#  ['Berrytown', 1148, 'AL'],
#  ['Bessemer', 27456, 'AL'],
#  ['Billingsleytown', 144, 'AL'],
#  ['Birmingham', 212237, 'AL'],
#  ['Blacktown', 207, 'AL'],
#  ['Blountsvilletown', 1684, 'AL'],
#  ['BlueRidge', 1341, 'AL'],
#  ['BlueSpringstown', 96, 'AL'],
#  ['Boaz', 9551, 'AL'],
#  ['Boligeetown', 328, 'AL'],
#  ['BonAirtown', 116, 'AL'],
#  ['Boykin', 275, 'AL'],
#  ['Brantleytown', 809, 'AL'],
#  ['Brantleyville', 884, 'AL'],
#  ['Brent', 4947, 'AL'],
#  ['Brewton', 5408, 'AL'],
#  ['Bridgeport', 2418, 'AL'],
#  ['Brighton', 2945, 'AL'],
#  ['Brillianttown', 900, 'AL'],
#  ['BristowCove', 683, 'AL'],
#  ['BrookHighland', 6746, 'AL'],
#  ['Brooksidetown', 1363, 'AL'],
#  ['Brookwoodtown', 1828, 'AL'],
#  ['Broomtown', 182, 'AL'],
#  ['Brundidge', 2076, 'AL'],
#  ['Bucks', 32, 'AL'],
#  ['Butlertown', 1894, 'AL'],
#  ['Calera', 11620, 'AL'],
#  ['Calvert', 277, 'AL'],
#  ['Camden', 2020, 'AL'],
#  ['CampHilltown', 1014, 'AL'],
#  ['CarbonHill', 2021, 'AL'],
#  ['Cardifftown', 55, 'AL'],
#  ['Carlisle-Rockledge', 2137, 'AL'],
#  ['Carlton', 65, 'AL'],
#  ['Carolinatown', 297, 'AL'],
#  ['Carrolltontown', 1019, 'AL'],
#  ['Castleberrytown', 583, 'AL'],
#  ['Catherine', 22, 'AL'],
#  ['CedarBlufftown', 1820, 'AL'],
#  ['CenterPoint', 16921, 'AL'],
#  ['Centre', 3489, 'AL'],
#  ['Centreville', 2778, 'AL'],
#  ['Chatomtown', 1288, 'AL'],
#  ['Chelsea', 10183, 'AL'],
#  ['Cherokeetown', 1048, 'AL'],
#  ['Chickasaw', 6106, 'AL'],
#  ['Childersburg', 5175, 'AL'],
#  ['Choccolocco', 2804, 'AL'],
#  ['Chunchula', 210, 'AL'],
#  ['Citronelle', 3905, 'AL'],
#  ['Clanton', 8619, 'AL'],
#  ['Clay', 9708, 'AL'],
#  ['Clayhatcheetown', 589, 'AL'],
#  ['Claytontown', 3008, 'AL'],
#  ['Clevelandtown', 1303, 'AL'],
#  ['Clio', 1399, 'AL'],
#  ['Coalingtown', 1657, 'AL'],
#  ['CoatsBend', 1394, 'AL'],
#  ['CoffeeSpringstown', 228, 'AL'],
#  ['Coffeevilletown', 352, 'AL'],
#  ['Cokertown', 979, 'AL'],
#  ['Collinsvilletown', 1983, 'AL'],
#  ['Colonytown', 268, 'AL'],
#  ['Columbiatown', 740, 'AL'],
#  ['Columbiana', 4197, 'AL'],
#  ['Concord', 1837, 'AL'],
#  ['Coosadatown', 1224, 'AL'],
#  ['Cordova', 2095, 'AL'],
#  ['Cottonwoodtown', 1289, 'AL'],
#  ['CountyLinetown', 258, 'AL'],
#  ['Courtlandtown', 609, 'AL'],
#  ['Cowartstown', 1871, 'AL'],
#  ['Creola', 1926, 'AL'],
#  ['Crossvilletown', 1862, 'AL'],
#  ['Cubatown', 346, 'AL'],
#  ['Cullman', 14775, 'AL'],
#  ['Cullomburg', 171, 'AL'],
#  ['Cussetatown', 123, 'AL'],
#  ['Dadeville', 3230, 'AL'],
#  ['Daleville', 5295, 'AL'],
#  ['Daphne', 21570, 'AL'],
#  ['DauphinIslandtown', 1238, 'AL'],
#  ['Davistontown', 214, 'AL'],
#  ['Daytontown', 52, 'AL'],
#  ['Deatsvilletown', 1154, 'AL'],
#  ['Decatur', 55683, 'AL'],
#  ['DeerPark', 188, 'AL'],
#  ['Delta', 197, 'AL'],
#  ['Demopolis', 7483, 'AL'],
#  ['Detroittown', 237, 'AL'],
#  ['DodgeCitytown', 593, 'AL'],
#  ['Dora', 2025, 'AL'],
#  ['Dothan', 65496, 'AL'],
#  ['DoubleSpringstown', 1083, 'AL'],
#  ['Douglastown', 744, 'AL'],
#  ['Doziertown', 329, 'AL'],
#  ['Dunnavant', 981, 'AL'],
#  ['Duttontown', 315, 'AL'],
#  ['EastBrewton', 2478, 'AL'],
#  ['EastPoint', 201, 'AL'],
#  ['Eclectictown', 1001, 'AL'],
#  ['Edgewater', 883, 'AL'],
#  ['Edwardsvilletown', 202, 'AL'],
#  ['Egypt', 932, 'AL'],
#  ['Elba', 3940, 'AL'],
#  ['Elbertatown', 1498, 'AL'],
#  ['Eldridgetown', 130, 'AL'],
#  ['Elkmonttown', 434, 'AL'],
#  ['Elmoretown', 1262, 'AL'],
#  ['Emelletown', 53, 'AL'],
#  ['EmeraldMountain', 2561, 'AL'],
#  ['Enterprise', 26562, 'AL'],
#  ['Epestown', 192, 'AL'],
#  ['Ethelsvilletown', 81, 'AL'],
#  ['Eufaula', 13137, 'AL'],
#  ['Eunola', 243, 'AL'],
#  ['Eutawtown', 2934, 'AL'],
#  ['Evatown', 519, 'AL'],
#  ['Evergreen', 3944, 'AL'],
#  ['Exceltown', 723, 'AL'],
#  ['Fairfield', 11117, 'AL'],
#  ['Fairford', 186, 'AL'],
#  ['Fairhope', 15326, 'AL'],
#  ['Fairviewtown', 446, 'AL'],
#  ['Falkvilletown', 1279, 'AL'],
#  ['Faunsdaletown', 98, 'AL'],
#  ['Fayette', 4619, 'AL'],
#  ['Fayetteville', 1284, 'AL'],
#  ['Fitzpatrick', 83, 'AL'],
#  ['FivePointstown', 141, 'AL'],
#  ['Flomatontown', 1440, 'AL'],
#  ['Floralatown', 1980, 'AL'],
#  ['Florence', 39319, 'AL'],
#  ['Foley', 14618, 'AL'],
#  ['Forestdale', 10162, 'AL'],
#  ['Forklandtown', 649, 'AL'],
#  ['FortDeposittown', 1344, 'AL'],
#  ['FortPayne', 14012, 'AL'],
#  ['FortRucker', 4636, 'AL'],
#  ['Franklintown', 149, 'AL'],
#  ['Fredonia', 199, 'AL'],
#  ['FriscoCitytown', 1309, 'AL'],
#  ['Fruitdale', 185, 'AL'],
#  ['Fruithursttown', 284, 'AL'],
#  ['Fultontown', 272, 'AL'],
#  ['Fultondale', 8380, 'AL'],
#  ['Fyffetown', 1018, 'AL'],
#  ['Gadsden', 36856, 'AL'],
#  ['Gainesvilletown', 208, 'AL'],
#  ['Gallant', 855, 'AL'],
#  ['Gantttown', 222, 'AL'],
#  ['GardenCitytown', 492, 'AL'],
#  ['Gardendale', 13893, 'AL'],
#  ['Gaylesvilletown', 144, 'AL'],
#  ['Geigertown', 170, 'AL'],
#  ['Geneva', 4452, 'AL'],
#  ['Georgianatown', 1738, 'AL'],
#  ['Geraldinetown', 896, 'AL'],
#  ['Gilbertowntown', 215, 'AL'],
#  ['GlenAllentown', 510, 'AL'],
#  ['Glencoe', 5160, 'AL'],
#  ['Glenwoodtown', 187, 'AL'],
#  ['Goldvilletown', 55, 'AL'],
#  ['GoodHopetown', 2264, 'AL'],
#  ['Goodwatertown', 1475, 'AL'],
#  ['Gordotown', 1750, 'AL'],
#  ['Gordontown', 332, 'AL'],
#  ['Gordonvilletown', 326, 'AL'],
#  ['Goshentown', 266, 'AL'],
#  ['Graham', 211, 'AL'],
#  ['GrandBay', 3672, 'AL'],
#  ['Granttown', 896, 'AL'],
#  ['GraysonValley', 5736, 'AL'],
#  ['Graysville', 2165, 'AL'],
#  ['Greensboro', 2497, 'AL'],
#  ['Greenville', 8135, 'AL'],
#  ['Grimestown', 558, 'AL'],
#  ['GroveHilltown', 1570, 'AL'],
#  ['Guin', 2376, 'AL'],
#  ['Gulfcrest', 161, 'AL'],
#  ['GulfShores', 9741, 'AL'],
#  ['Guntersville', 8197, 'AL'],
#  ['Gurleytown', 801, 'AL'],
#  ['Gu-Wintown', 176, 'AL'],
#  ['Hackleburgtown', 1516, 'AL'],
#  ['Hackneyville', 347, 'AL'],
#  ['Haleburgtown', 103, 'AL'],
#  ['Haleyville', 4173, 'AL'],
#  ['Hamilton', 6885, 'AL'],
#  ['Hammondvilletown', 488, 'AL'],
#  ['Hanceville', 2982, 'AL'],
#  ['Harpersvilletown', 1637, 'AL'],
#  ['Hartford', 2624, 'AL'],
#  ['Hartselle', 14255, 'AL'],
#  ['Harvest', 5281, 'AL'],
#  ['Hatton', 261, 'AL'],
#  ['Haydentown', 444, 'AL'],
#  ['Haynevilletown', 932, 'AL'],
#  ['HazelGreen', 3630, 'AL'],
#  ['Headland', 4510, 'AL'],
#  ['Heathtown', 254, 'AL'],
#  ['Heflin', 3480, 'AL'],
#  ['Helena', 16793, 'AL'],
#  ['Henagar', 2344, 'AL'],
#  ['HighlandLaketown', 412, 'AL'],
#  ['HighlandLakes', 3926, 'AL'],
#  ['Hillsborotown', 552, 'AL'],
#  ['Hissop', 658, 'AL'],
#  ['Hobson', 126, 'AL'],
#  ['HobsonCitytown', 771, 'AL'],
#  ['Hodgestown', 288, 'AL'],
#  ['HokesBluff', 4286, 'AL'],
#  ['Hollins', 545, 'AL'],
#  ['HollisCrossroads', 608, 'AL'],
#  ['HollyPondtown', 798, 'AL'],
#  ['Hollywoodtown', 1000, 'AL'],
#  ['Holt', 3638, 'AL'],
#  ['Holtville', 4096, 'AL'],
#  ['Homewood', 25167, 'AL'],
#  ['Hoover', 81619, 'AL'],
#  ['HornHilltown', 228, 'AL'],
#  ['Hueytown', 16105, 'AL'],
#  ['Huguley', 2540, 'AL'],
#  ['Huntsville', 180105, 'AL'],
#  ['Hurtsborotown', 553, 'AL'],
#  ['Hytoptown', 354, 'AL'],
#  ['Idertown', 723, 'AL'],
#  ['IndianSpringsVillage', 2363, 'AL'],
#  ['Irondale', 12349, 'AL'],
#  ['Ivalee', 879, 'AL'],
#  ['Jackson', 5228, 'AL'],
#  ["Jacksons'Gaptown", 828, 'AL'],
#  ['Jacksonville', 12548, 'AL'],
#  ['Jasper', 14352, 'AL'],
#  ['Jemison', 2585, 'AL'],
#  ['Joppa', 501, 'AL'],
#  ['Kansastown', 226, 'AL'],
#  ['Kellytontown', 217, 'AL'],
#  ['Kennedytown', 447, 'AL'],
#  ['Killentown', 1108, 'AL'],
#  ['Kimberlytown', 2711, 'AL'],
#  ['Kinseytown', 2198, 'AL'],
#  ['Kinstontown', 540, 'AL'],
#  ['Ladonia', 3142, 'AL'],
#  ['LaFayette', 3003, 'AL'],
#  ['Lakeviewtown', 143, 'AL'],
#  ['LakeViewtown', 1943, 'AL'],
#  ['Lanett', 6468, 'AL'],
#  ['Langstontown', 270, 'AL'],
#  ['Leeds', 11773, 'AL'],
#  ['Leesburgtown', 1027, 'AL'],
#  ['Leightontown', 729, 'AL'],
#  ['Leroy', 911, 'AL'],
#  ['Lestertown', 111, 'AL'],
#  ['LevelPlainstown', 2085, 'AL'],
#  ['Lexingtontown', 735, 'AL'],
#  ['Libertyvilletown', 117, 'AL'],
#  ['Lincoln', 6266, 'AL'],
#  ['Linden', 2123, 'AL'],
#  ['Lineville', 2395, 'AL'],
#  ['Lipscomb', 2210, 'AL'],
#  ['Lismantown', 539, 'AL'],
#  ['Littlevilletown', 1011, 'AL'],
#  ['Livingston', 3485, 'AL'],
#  ['Loachapokatown', 180, 'AL'],
#  ['Lockharttown', 516, 'AL'],
#  ['LocustForktown', 1186, 'AL'],
#  ['LookoutMountain', 1621, 'AL'],
#  ['Louisvilletown', 519, 'AL'],
#  ['Lowndesborotown', 115, 'AL'],
#  ['Loxleytown', 1632, 'AL'],
#  ['Luverne', 2800, 'AL'],
#  ['Lynntown', 659, 'AL'],
#  ['McDonaldChapel', 717, 'AL'],
#  ['Macedonia', 292, 'AL'],
#  ['McIntoshtown', 238, 'AL'],
#  ['McKenzietown', 530, 'AL'],
#  ['McMullentown', 10, 'AL'],
#  ['Madison', 42938, 'AL'],
#  ['Madridtown', 350, 'AL'],
#  ['MagnoliaSpringstown', 723, 'AL'],
#  ['Malcolm', 187, 'AL'],
#  ['Malverntown', 1448, 'AL'],
#  ['Maplesvilletown', 708, 'AL'],
#  ['Marbury', 1418, 'AL'],
#  ['Margarettown', 4428, 'AL'],
#  ['Marion', 3686, 'AL'],
#  ['Maytowntown', 385, 'AL'],
#  ['Meadowbrook', 8769, 'AL'],
#  ['Megargel', 62, 'AL'],
#  ['Memphistown', 29, 'AL'],
#  ['Mentonetown', 360, 'AL'],
#  ['Meridianville', 6021, 'AL'],
#  ['Midfield', 5365, 'AL'],
#  ['MidlandCitytown', 2344, 'AL'],
#  ['Midwaytown', 499, 'AL'],
#  ['Mignon', 1284, 'AL'],
#  ['Millbrook', 14640, 'AL'],
#  ['Millerville', 278, 'AL'],
#  ['Millporttown', 1049, 'AL'],
#  ['Millrytown', 546, 'AL'],
#  ['Minor', 1094, 'AL'],
#  ['Mobile', 195111, 'AL'],
#  ['Monroeville', 6519, 'AL'],
#  ['Montevallo', 6323, 'AL'],
#  ['Montgomery', 205764, 'AL'],
#  ['Moody', 11726, 'AL'],
#  ['MooresMill', 5682, 'AL'],
#  ['Mooresvilletown', 53, 'AL'],
#  ['Morristown', 1859, 'AL'],
#  ['MorrisonCrossroads', 219, 'AL'],
#  ['Mossestown', 1029, 'AL'],
#  ['Moulton', 3471, 'AL'],
#  ['Moundvilletown', 2427, 'AL'],
#  ['MountainBrook', 20413, 'AL'],
#  ['MountOlive', 371, 'AL'],
#  ['MountOlive', 4079, 'AL'],
#  ['MountVernontown', 1574, 'AL'],
#  ['Movico', 305, 'AL'],
#  ['Mulgatown', 836, 'AL'],
#  ['Munfordtown', 1292, 'AL'],
#  ['MuscleShoals', 13146, 'AL'],
#  ['Myrtlewoodtown', 130, 'AL'],
#  ['Nanafalia', 94, 'AL'],
#  ['NancesCreek', 407, 'AL'],
#  ['NapierFieldtown', 354, 'AL'],
#  ['NaturalBridgetown', 37, 'AL'],
#  ['Nauvootown', 221, 'AL'],
#  ['Nectartown', 345, 'AL'],
#  ['Needhamtown', 94, 'AL'],
#  ['Newberntown', 186, 'AL'],
#  ['NewBrocktontown', 1146, 'AL'],
#  ['NewHope', 2810, 'AL'],
#  ['NewMarket', 1597, 'AL'],
#  ['NewSitetown', 773, 'AL'],
#  ['Newtontown', 1511, 'AL'],
#  ['NewUnion', 955, 'AL'],
#  ['Newvilletown', 539, 'AL'],
#  ['NorthCourtlandtown', 632, 'AL'],
#  ['NorthJohnstown', 145, 'AL'],
#  ['Northport', 23330, 'AL'],
#  ['Notasulgatown', 965, 'AL'],
#  ['OakGrovetown', 528, 'AL'],
#  ['OakHilltown', 26, 'AL'],
#  ['Oakmantown', 789, 'AL'],
#  ['Odenvilletown', 3585, 'AL'],
#  ['Ohatcheetown', 1170, 'AL'],
#  ['Oneonta', 6567, 'AL'],
#  ['Onychatown', 184, 'AL'],
#  ['Opelika', 26477, 'AL'],
#  ['Opp', 6659, 'AL'],
#  ['OrangeBeach', 5441, 'AL'],
#  ['Orrvilletown', 204, 'AL'],
#  ['OurTown', 641, 'AL'],
#  ['OwensCrossRoadstown', 1521, 'AL'],
#  ['Oxford', 21348, 'AL'],
#  ['Ozark', 14907, 'AL'],
#  ['PaintRocktown', 210, 'AL'],
#  ['Panola', 144, 'AL'],
#  ['Parrishtown', 982, 'AL'],
#  ['Pelham', 21352, 'AL'],
#  ['PellCity', 12695, 'AL'],
#  ['Penningtontown', 221, 'AL'],
#  ['Penton', 201, 'AL'],
#  ['PerdidoBeachtown', 581, 'AL'],
#  ['Peterman', 89, 'AL'],
#  ['Petreytown', 58, 'AL'],
#  ['PhenixCity', 32822, 'AL'],
#  ['PhilCampbelltown', 1148, 'AL'],
#  ['Pickensvilletown', 608, 'AL'],
#  ['Piedmont', 4878, 'AL'],
#  ['PikeRoadtown', 5406, 'AL'],
#  ['Pinckardtown', 647, 'AL'],
#  ['PineAppletown', 132, 'AL'],
#  ['PineHilltown', 975, 'AL'],
#  ['PineLevel', 4183, 'AL'],
#  ['PineRidgetown', 282, 'AL'],
#  ['Pinson', 7163, 'AL'],
#  ['Pisgahtown', 722, 'AL'],
#  ['PleasantGrove', 10110, 'AL'],
#  ['PleasantGrovestown', 420, 'AL'],
#  ['PointClear', 2125, 'AL'],
#  ['Pollardtown', 137, 'AL'],
#  ['Powelltown', 955, 'AL'],
#  ['Prattville', 33960, 'AL'],
#  ['Pricevilletown', 2658, 'AL'],
#  ['Prichard', 22659, 'AL'],
#  ['Providencetown', 223, 'AL'],
#  ['Putnam', 193, 'AL'],
#  ['Raglandtown', 1639, 'AL'],
#  ['RainbowCity', 9602, 'AL'],
#  ['Rainsville', 4948, 'AL'],
#  ['Ranburnetown', 409, 'AL'],
#  ['Ray', 443, 'AL'],
#  ['RedBay', 3158, 'AL'],
#  ['Redland', 3736, 'AL'],
#  ['RedLeveltown', 487, 'AL'],
#  ['RedstoneArsenal', 1946, 'AL'],
#  ['ReeceCitytown', 653, 'AL'],
#  ['Reeltown', 766, 'AL'],
#  ['Reformtown', 1702, 'AL'],
#  ['Rehobethtown', 1297, 'AL'],
#  ['Reptontown', 282, 'AL'],
#  ['Ridgevilletown', 112, 'AL'],
#  ['RiverFallstown', 526, 'AL'],
#  ['Riversidetown', 2208, 'AL'],
#  ['Riverviewtown', 184, 'AL'],
#  ['Roanoke', 6074, 'AL'],
#  ['Robertsdale', 5276, 'AL'],
#  ['RockCreek', 1456, 'AL'],
#  ['Rockfordtown', 477, 'AL'],
#  ['RockMills', 600, 'AL'],
#  ['Rockville', 43, 'AL'],
#  ['Rogersvilletown', 1257, 'AL'],
#  ['Rosatown', 316, 'AL'],
#  ['Russellville', 9830, 'AL'],
#  ['Rutledgetown', 467, 'AL'],
#  ['St.Floriantown', 413, 'AL'],
#  ['St.Stephens', 495, 'AL'],
#  ['Saks', 10744, 'AL'],
#  ['Samson', 1940, 'AL'],
#  ['SandRocktown', 560, 'AL'],
#  ['Sanfordtown', 241, 'AL'],
#  ['Saraland', 13405, 'AL'],
#  ['SardisCitytown', 1704, 'AL'],
#  ['Satsuma', 6168, 'AL'],
#  ['Scottsboro', 14770, 'AL'],
#  ['Sectiontown', 770, 'AL'],
#  ['Selma', 20756, 'AL'],
#  ['Selmont-WestSelmont', 2671, 'AL'],
#  ['Sheffield', 9039, 'AL'],
#  ['Shelby', 1044, 'AL'],
#  ['Shilohtown', 274, 'AL'],
#  ['ShoalCreek', 1400, 'AL'],
#  ['Shortertown', 474, 'AL'],
#  ['Silastown', 452, 'AL'],
#  ['Silverhilltown', 706, 'AL'],
#  ['SimsChapel', 153, 'AL'],
#  ['Sipseytown', 437, 'AL'],
#  ['Skylinetown', 851, 'AL'],
#  ['Slocomb', 1980, 'AL'],
#  ['SmithsStation', 4926, 'AL'],
#  ['SmokeRise', 1825, 'AL'],
#  ['Sneadtown', 835, 'AL'],
#  ['Somervilletown', 724, 'AL'],
#  ['Southside', 8412, 'AL'],
#  ['SouthVinemonttown', 749, 'AL'],
#  ['SpanishFort', 6798, 'AL'],
#  ['SpringGarden', 238, 'AL'],
#  ['Springville', 4080, 'AL'],
#  ['SprucePine', 222, 'AL'],
#  ['StandingRock', 168, 'AL'],
#  ['Steeletown', 1043, 'AL'],
#  ['Sterrett', 712, 'AL'],
#  ['Stevenson', 2046, 'AL'],
#  ['Stewartville', 1767, 'AL'],
#  ['Sulligent', 1927, 'AL'],
#  ['Sumiton', 2520, 'AL'],
#  ['Summerdaletown', 862, 'AL'],
#  ['SusanMooretown', 763, 'AL'],
#  ['SweetWatertown', 258, 'AL'],
#  ['Sylacauga', 12749, 'AL'],
#  ['Sylvaniatown', 1837, 'AL'],
#  ['SylvanSpringstown', 1542, 'AL'],
#  ['Talladega', 15676, 'AL'],
#  ['TalladegaSpringstown', 166, 'AL'],
#  ['Tallassee', 4819, 'AL'],
#  ['Tarrant', 6397, 'AL'],
#  ['Taylortown', 2375, 'AL'],
#  ['Theodore', 6130, 'AL'],
#  ['Thomastontown', 417, 'AL'],
#  ['Thomasville', 4209, 'AL'],
#  ['Thorsbytown', 1980, 'AL'],
#  ['Tibbie', 41, 'AL'],
#  ['TidmoreBend', 1245, 'AL'],
#  ['TillmansCorner', 17398, 'AL'],
#  ['TownCreektown', 1100, 'AL'],
#  ['Toxeytown', 137, 'AL'],
#  ['Traffordtown', 646, 'AL'],
#  ['Trianatown', 496, 'AL'],
#  ['Trinitytown', 2095, 'AL'],
#  ['Troy', 18033, 'AL'],
#  ['Trussville', 19933, 'AL'],
#  ['Tuscaloosa', 90468, 'AL'],
#  ['Tuscumbia', 8423, 'AL'],
#  ['Tuskegee', 9865, 'AL'],
#  ['Twintown', 399, 'AL'],
#  ['Underwood-Petersville', 3247, 'AL'],
#  ['Uniontown', 237, 'AL'],
#  ['UnionGrovetown', 77, 'AL'],
#  ['UnionSprings', 3980, 'AL'],
#  ['Uniontowntown', 1775, 'AL'],
#  ['Uriah', 294, 'AL'],
#  ['Valley', 9524, 'AL'],
#  ['ValleyGrande', 4020, 'AL'],
#  ['ValleyHeadtown', 558, 'AL'],
#  ['Vancetown', 1529, 'AL'],
#  ['Vandiver', 1135, 'AL'],
#  ['Vernon', 2000, 'AL'],
#  ['VestaviaHills', 34033, 'AL'],
#  ['Vinatown', 358, 'AL'],
#  ['Vincenttown', 1988, 'AL'],
#  ['VinegarBend', 192, 'AL'],
#  ['Vredenburghtown', 312, 'AL'],
#  ['Wadleytown', 751, 'AL'],
#  ['Waldotown', 283, 'AL'],
#  ['WalnutGrovetown', 698, 'AL'],
#  ['Warrior', 3176, 'AL'],
#  ['Waterlootown', 203, 'AL'],
#  ['Waverlytown', 145, 'AL'],
#  ['Weaver', 3038, 'AL'],
#  ['Webbtown', 1430, 'AL'],
#  ['Wedoweetown', 823, 'AL'],
#  ['Weogufka', 282, 'AL'],
#  ['WestBloctontown', 1240, 'AL'],
#  ['WestEnd-CobbTown', 3465, 'AL'],
#  ['WestJeffersontown', 338, 'AL'],
#  ['Westovertown', 1275, 'AL'],
#  ['WestPointtown', 586, 'AL'],
#  ['Wetumpka', 6528, 'AL'],
#  ['Whatley', 150, 'AL'],
#  ['WhiteHalltown', 858, 'AL'],
#  ['WhitePlains', 811, 'AL'],
#  ['Whitesboro', 2138, 'AL'],
#  ['Wilsonvilletown', 1827, 'AL'],
#  ['Wiltontown', 687, 'AL'],
#  ['Winfield', 4717, 'AL'],
#  ['Woodlandtown', 184, 'AL'],
#  ['Woodstocktown', 1428, 'AL'],
#  ['Woodvilletown', 746, 'AL'],
#  ['YellowBlufftown', 188, 'AL'],
#  ['York', 2538, 'AL'],
#  ['Adak', 326, 'AK'],
#  ['Akhiok', 71, 'AK'],
#  ['Akiachak', 627, 'AK'],
#  ['Akiak', 346, 'AK'],
#  ['Akutan', 1027, 'AK'],
#  ['Alakanuk', 677, 'AK'],
#  ['Alatna', 37, 'AK'],
#  ['AlcanBorder', 33, 'AK'],
#  ['Aleknagik', 219, 'AK'],
#  ['Aleneva', 37, 'AK'],
#  ['Allakaket', 105, 'AK'],
#  ['Ambler', 258, 'AK'],
#  ['AnaktuvukPass', 324, 'AK'],
#  ['Anchoragemunicipality', 291826, 'AK'],
#  ['AnchorPoint', 1930, 'AK'],
#  ['Anderson', 246, 'AK'],
#  ['Angoon', 459, 'AK'],
#  ['Aniak', 501, 'AK'],
#  ['Anvik', 85, 'AK'],
#  ['ArcticVillage', 152, 'AK'],
#  ['Atka', 61, 'AK'],
#  ['Atmautluak', 277, 'AK'],
#  ['Atqasuk', 233, 'AK'],
#  ['AttuStation', 21, 'AK'],
#  ['Badger', 19482, 'AK'],
#  ['Barrow', 4212, 'AK'],
#  ['BearCreek', 1956, 'AK'],
#  ['Beaver', 84, 'AK'],
#  ['Beluga', 20, 'AK'],
#  ['Bethel', 6080, 'AK'],
#  ['Bettles', 12, 'AK'],
#  ['BigDelta', 591, 'AK'],
#  ['BigLake', 3350, 'AK'],
#  ['BirchCreek', 33, 'AK'],
#  ['BrevigMission', 388, 'AK'],
#  ['Buckland', 416, 'AK'],
#  ['BuffaloSoapstone', 855, 'AK'],
#  ['Butte', 3246, 'AK'],
#  ['Cantwell', 219, 'AK'],
#  ['Central', 96, 'AK'],
#  ['Chalkyitsik', 69, 'AK'],
#  ['Chase', 34, 'AK'],
#  ['Chefornak', 418, 'AK'],
#  ['ChenaRidge', 5791, 'AK'],
#  ['Chenega', 76, 'AK'],
#  ['Chevak', 938, 'AK'],
#  ['Chickaloon', 272, 'AK'],
#  ['Chicken', 7, 'AK'],
#  ['Chignik', 91, 'AK'],
#  ['ChignikLagoon', 78, 'AK'],
#  ['ChignikLake', 73, 'AK'],
#  ['Chiniak', 47, 'AK'],
#  ['Chisana', 0, 'AK'],
#  ['Chistochina', 93, 'AK'],
#  ['Chitina', 126, 'AK'],
#  ['Chuathbaluk', 118, 'AK'],
#  ['Circle', 104, 'AK'],
#  ['ClamGulch', 176, 'AK'],
#  ["Clark'sPoint", 62, 'AK'],
#  ['CoffmanCove', 176, 'AK'],
#  ['Cohoe', 1364, 'AK'],
#  ['ColdBay', 108, 'AK'],
#  ['Coldfoot', 10, 'AK'],
#  ['College', 12964, 'AK'],
#  ['CooperLanding', 289, 'AK'],
#  ['CopperCenter', 328, 'AK'],
#  ['Cordova', 2239, 'AK'],
#  ['CovenantLife', 86, 'AK'],
#  ['Craig', 1201, 'AK'],
#  ['CrookedCreek', 105, 'AK'],
#  ['CrownPoint', 74, 'AK'],
#  ['Deering', 122, 'AK'],
#  ['DeltaJunction', 958, 'AK'],
#  ['Deltana', 2251, 'AK'],
#  ['DiamondRidge', 1156, 'AK'],
#  ['Dillingham', 2329, 'AK'],
#  ['Diomede', 115, 'AK'],
#  ['DotLake', 13, 'AK'],
#  ['DotLakeVillage', 62, 'AK'],
#  ['DryCreek', 94, 'AK'],
#  ['Eagle', 86, 'AK'],
#  ['EagleVillage', 67, 'AK'],
#  ['EdnaBay', 42, 'AK'],
#  ['Eek', 296, 'AK'],
#  ['Egegik', 109, 'AK'],
#  ['EielsonAFB', 2647, 'AK'],
#  ['Ekwok', 115, 'AK'],
#  ['ElfinCove', 20, 'AK'],
#  ['Elim', 330, 'AK'],
#  ['Emmonak', 762, 'AK'],
#  ['Ester', 2422, 'AK'],
#  ['EurekaRoadhouse', 29, 'AK'],
#  ['Evansville', 15, 'AK'],
#  ['ExcursionInlet', 12, 'AK'],
#  ['Fairbanks', 31535, 'AK'],
#  ['FalsePass', 35, 'AK'],
#  ['FarmersLoop', 4853, 'AK'],
#  ['FarmLoop', 1028, 'AK'],
#  ['Ferry', 33, 'AK'],
#  ['Fishhook', 4679, 'AK'],
#  ['Flat', 0, 'AK'],
#  ['FortGreely', 539, 'AK'],
#  ['FortYukon', 583, 'AK'],
#  ['FourMileRoad', 43, 'AK'],
#  ['Fox', 417, 'AK'],
#  ['FoxRiver', 685, 'AK'],
#  ['FritzCreek', 1932, 'AK'],
#  ['FunnyRiver', 877, 'AK'],
#  ['Gakona', 218, 'AK'],
#  ['Galena', 470, 'AK'],
#  ['Gambell', 681, 'AK'],
#  ['GameCreek', 18, 'AK'],
#  ['Gateway', 5552, 'AK'],
#  ['GlacierView', 234, 'AK'],
#  ['Glennallen', 483, 'AK'],
#  ['Goldstream', 3557, 'AK'],
#  ['Golovin', 156, 'AK'],
#  ['GoodnewsBay', 243, 'AK'],
#  ['Grayling', 194, 'AK'],
#  ['Gulkana', 119, 'AK'],
#  ['Gustavus', 442, 'AK'],
#  ['Haines', 1713, 'AK'],
#  ['HalibutCove', 76, 'AK'],
#  ['HappyValley', 593, 'AK'],
#  ['Harding-BirchLakes', 299, 'AK'],
#  ['Healy', 1021, 'AK'],
#  ['HealyLake', 13, 'AK'],
#  ['HobartBay', 1, 'AK'],
#  ['Hollis', 112, 'AK'],
#  ['HolyCross', 178, 'AK'],
#  ['Homer', 5003, 'AK'],
#  ['Hoonah', 760, 'AK'],
#  ['HooperBay', 1093, 'AK'],
#  ['Hope', 192, 'AK'],
#  ['Houston', 1912, 'AK'],
#  ['Hughes', 77, 'AK'],
#  ['Huslia', 275, 'AK'],
#  ['Hydaburg', 376, 'AK'],
#  ['Hyder', 87, 'AK'],
#  ['Igiugig', 50, 'AK'],
#  ['Iliamna', 109, 'AK'],
#  ['IvanofBay', 7, 'AK'],
#  ['Juneauandborough', 31275, 'AK'],
#  ['Kachemak', 472, 'AK'],
#  ['Kake', 557, 'AK'],
#  ['Kaktovik', 239, 'AK'],
#  ['Kalifornsky', 7850, 'AK'],
#  ['Kaltag', 190, 'AK'],
#  ['Karluk', 37, 'AK'],
#  ['Kasaan', 49, 'AK'],
#  ['Kasigluk', 569, 'AK'],
#  ['Kasilof', 549, 'AK'],
#  ['Kenai', 7100, 'AK'],
#  ['KennyLake', 355, 'AK'],
#  ['Ketchikan', 8050, 'AK'],
#  ['Kiana', 361, 'AK'],
#  ['KingCove', 938, 'AK'],
#  ['KingSalmon', 374, 'AK'],
#  ['Kipnuk', 639, 'AK'],
#  ['Kivalina', 374, 'AK'],
#  ['Klawock', 755, 'AK'],
#  ['Klukwan', 95, 'AK'],
#  ['Knik-Fairview', 14923, 'AK'],
#  ['KnikRiver', 744, 'AK'],
#  ['Kobuk', 151, 'AK'],
#  ['Kodiak', 6130, 'AK'],
#  ['KodiakStation', 1301, 'AK'],
#  ['Kokhanok', 170, 'AK'],
#  ['Koliganek', 209, 'AK'],
#  ['Kongiganak', 439, 'AK'],
#  ['Kotlik', 577, 'AK'],
#  ['Kotzebue', 3201, 'AK'],
#  ['Koyuk', 332, 'AK'],
#  ['Koyukuk', 96, 'AK'],
#  ['Kupreanof', 27, 'AK'],
#  ['Kwethluk', 721, 'AK'],
#  ['Kwigillingok', 321, 'AK'],
#  ['LakeLouise', 46, 'AK'],
#  ['LakeMinchumina', 13, 'AK'],
#  ['Lakes', 8364, 'AK'],
#  ['LarsenBay', 87, 'AK'],
#  ['LazyMountain', 1479, 'AK'],
#  ['Levelock', 69, 'AK'],
#  ['LimeVillage', 29, 'AK'],
#  ['Livengood', 13, 'AK'],
#  ['Loring', 4, 'AK'],
#  ['LowellPoint', 80, 'AK'],
#  ['LowerKalskag', 282, 'AK'],
#  ['Lutak', 49, 'AK'],
#  ['McCarthy', 28, 'AK'],
#  ['McGrath', 346, 'AK'],
#  ['McKinleyPark', 185, 'AK'],
#  ['ManleyHotSprings', 89, 'AK'],
#  ['Manokotak', 442, 'AK'],
#  ['Marshall', 414, 'AK'],
#  ['MeadowLakes', 7570, 'AK'],
#  ['Mekoryuk', 191, 'AK'],
#  ['Mendeltna', 39, 'AK'],
#  ['MentastaLake', 112, 'AK'],
#  ['Mertarvik', 0, 'AK'],
#  ['Metlakatla', 1405, 'AK'],
#  ['Minto', 210, 'AK'],
#  ['MooseCreek', 747, 'AK'],
#  ['MoosePass', 219, 'AK'],
#  ['MosquitoLake', 309, 'AK'],
#  ['MountainVillage', 813, 'AK'],
#  ['MudBay', 212, 'AK'],
#  ['Nabesna', 5, 'AK'],
#  ['Naknek', 544, 'AK'],
#  ['Nanwalek', 254, 'AK'],
#  ['Napakiak', 354, 'AK'],
#  ['Napaskiak', 405, 'AK'],
#  ['NaukatiBay', 113, 'AK'],
#  ['Nelchina', 59, 'AK'],
#  ['NelsonLagoon', 52, 'AK'],
#  ['Nenana', 378, 'AK'],
#  ['NewAllakaket', 66, 'AK'],
#  ['Newhalen', 190, 'AK'],
#  ['NewStuyahok', 510, 'AK'],
#  ['Newtok', 354, 'AK'],
#  ['Nightmute', 280, 'AK'],
#  ['Nikiski', 4493, 'AK'],
#  ['Nikolaevsk', 318, 'AK'],
#  ['Nikolai', 94, 'AK'],
#  ['Nikolski', 18, 'AK'],
#  ['Ninilchik', 883, 'AK'],
#  ['Noatak', 514, 'AK'],
#  ['Nome', 3598, 'AK'],
#  ['Nondalton', 164, 'AK'],
#  ['Noorvik', 668, 'AK'],
#  ['NorthPole', 2117, 'AK'],
#  ['Northway', 71, 'AK'],
#  ['NorthwayJunction', 54, 'AK'],
#  ['NorthwayVillage', 98, 'AK'],
#  ['Nuiqsut', 402, 'AK'],
#  ['Nulato', 264, 'AK'],
#  ['NunamIqua', 187, 'AK'],
#  ['Nunapitchuk', 496, 'AK'],
#  ['OldHarbor', 218, 'AK'],
#  ['Oscarville', 70, 'AK'],
#  ['Ouzinkie', 161, 'AK'],
#  ['Palmer', 5937, 'AK'],
#  ['Paxson', 40, 'AK'],
#  ['PedroBay', 42, 'AK'],
#  ['Pelican', 88, 'AK'],
#  ['Perryville', 113, 'AK'],
#  ['Petersburg', 2948, 'AK'],
#  ['Petersville', 4, 'AK'],
#  ['PilotPoint', 68, 'AK'],
#  ['PilotStation', 568, 'AK'],
#  ['PitkasPoint', 109, 'AK'],
#  ['Platinum', 61, 'AK'],
#  ['PleasantValley', 725, 'AK'],
#  ['PointBaker', 15, 'AK'],
#  ['PointHope', 674, 'AK'],
#  ['PointLay', 189, 'AK'],
#  ['PointMacKenzie', 529, 'AK'],
#  ['PointPossession', 3, 'AK'],
#  ['Pope-VannoyLanding', 6, 'AK'],
#  ['PortageCreek', 2, 'AK'],
#  ['PortAlexander', 52, 'AK'],
#  ['PortAlsworth', 159, 'AK'],
#  ['PortClarence', 24, 'AK'],
#  ['PortGraham', 177, 'AK'],
#  ['PortHeiden', 102, 'AK'],
#  ['PortLions', 194, 'AK'],
#  ['PortProtection', 48, 'AK'],
#  ['Primrose', 78, 'AK'],
#  ['PrudhoeBay', 2174, 'AK'],
#  ['Quinhagak', 669, 'AK'],
#  ['Rampart', 24, 'AK'],
#  ['RedDevil', 23, 'AK'],
#  ['RedDogMine', 309, 'AK'],
#  ['Ridgeway', 2022, 'AK'],
#  ['Ruby', 166, 'AK'],
#  ['RussianMission', 312, 'AK'],
#  ['St.George', 102, 'AK'],
#  ["St.Mary's", 507, 'AK'],
#  ['St.Michael', 401, 'AK'],
#  ['St.Paul', 479, 'AK'],
#  ['Salamatof', 980, 'AK'],
#  ['Salcha', 1095, 'AK'],
#  ['SandPoint', 976, 'AK'],
#  ['Savoonga', 671, 'AK'],
#  ['Saxman', 411, 'AK'],
#  ['ScammonBay', 474, 'AK'],
#  ['Selawik', 829, 'AK'],
#  ['Seldovia', 255, 'AK'],
#  ['SeldoviaVillage', 165, 'AK'],
#  ['Seward', 2693, 'AK'],
#  ['Shageluk', 83, 'AK'],
#  ['Shaktoolik', 251, 'AK'],
#  ['Shishmaref', 563, 'AK'],
#  ['Shungnak', 262, 'AK'],
#  ['SilverSprings', 114, 'AK'],
#  ['Sitkaandborough', 8881, 'AK'],
#  ['Skagway', 920, 'AK'],
#  ['Skwentna', 37, 'AK'],
#  ['Slana', 147, 'AK'],
#  ['Sleetmute', 86, 'AK'],
#  ['Soldotna', 4163, 'AK'],
#  ['SouthNaknek', 79, 'AK'],
#  ['SouthVanHorn', 558, 'AK'],
#  ['Stebbins', 556, 'AK'],
#  ['SteeleCreek', 6662, 'AK'],
#  ['Sterling', 5617, 'AK'],
#  ['StevensVillage', 78, 'AK'],
#  ['StonyRiver', 54, 'AK'],
#  ['Sunrise', 18, 'AK'],
#  ['Susitna', 18, 'AK'],
#  ['SusitnaNorth', 1260, 'AK'],
#  ['Sutton-Alpine', 1447, 'AK'],
#  ['Takotna', 52, 'AK'],
#  ['Talkeetna', 876, 'AK'],
#  ['Tanacross', 136, 'AK'],
#  ['Tanaina', 8197, 'AK'],
#  ['Tanana', 246, 'AK'],
#  ['Tatitlek', 88, 'AK'],
#  ['Tazlina', 297, 'AK'],
#  ['Teller', 229, 'AK'],
#  ['TenakeeSprings', 131, 'AK'],
#  ['Tetlin', 127, 'AK'],
#  ['ThorneBay', 471, 'AK'],
#  ['Togiak', 817, 'AK'],
#  ['Tok', 1258, 'AK'],
#  ['ToksookBay', 590, 'AK'],
#  ['Tolsona', 30, 'AK'],
#  ['Tonsina', 78, 'AK'],
#  ['TrapperCreek', 481, 'AK'],
#  ['Tuluksak', 373, 'AK'],
#  ['Tuntutuliak', 408, 'AK'],
#  ['Tununak', 327, 'AK'],
#  ['TwinHills', 74, 'AK'],
#  ['TwoRivers', 719, 'AK'],
#  ['Tyonek', 171, 'AK'],
#  ['Ugashik', 12, 'AK'],
#  ['Unalakleet', 688, 'AK'],
#  ['Unalaska', 4376, 'AK'],
#  ['UpperKalskag', 210, 'AK'],
#  ['Valdez', 3976, 'AK'],
#  ['Venetie', 166, 'AK'],
#  ['Wainwright', 556, 'AK'],
#  ['Wales', 145, 'AK'],
#  ['Wasilla', 7831, 'AK'],
#  ['WhalePass', 31, 'AK'],
#  ['WhiteMountain', 190, 'AK'],
#  ['Whitestone', 97, 'AK'],
#  ['WhitestoneLoggingCamp', 17, 'AK'],
#  ['Whittier', 220, 'AK'],
#  ['Willow', 2102, 'AK'],
#  ['WillowCreek', 191, 'AK'],
#  ['Wiseman', 14, 'AK'],
#  ['WomensBay', 719, 'AK'],
#  ['Wrangellandborough', 2369, 'AK'],
#  ['Yakutat', 662, 'AK'],
#  ['Aguila', 798, 'AZ'],
#  ['Ajo', 3304, 'AZ'],
#  ['AkChin', 30, 'AZ'],
#  ['Ak-ChinVillage', 862, 'AZ'],
#  ['AlamoLake', 25, 'AZ'],
#  ['AliChuk', 161, 'AZ'],
#  ['AliChukson', 132, 'AZ'],
#  ['AliMolina', 71, 'AZ'],
#  ['Alpine', 145, 'AZ'],
#  ['Amado', 295, 'AZ'],
#  ['Anegam', 151, 'AZ'],
#  ['Antares', 126, 'AZ'],
#  ['Anthem', 21700, 'AZ'],
#  ['ApacheJunction', 35840, 'AZ'],
#  ['Arivaca', 695, 'AZ'],
#  ['ArivacaJunction', 1090, 'AZ'],
#  ['ArizonaCity', 10475, 'AZ'],
#  ['ArizonaVillage', 946, 'AZ'],
#  ['Arlington', 194, 'AZ'],
#  ['AshFork', 396, 'AZ'],
#  ['AvenueBandC', 4176, 'AZ'],
#  ['Avondale', 76238, 'AZ'],
#  ['AvraValley', 6050, 'AZ'],
#  ['Aztec', 47, 'AZ'],
#  ['Bagdad', 1876, 'AZ'],
#  ['BearFlat', 18, 'AZ'],
#  ['BeaverDam', 1962, 'AZ'],
#  ['BeaverValley', 231, 'AZ'],
#  ['Benson', 5105, 'AZ'],
#  ['Beyerville', 177, 'AZ'],
#  ['Bisbee', 5575, 'AZ'],
#  ['BitterSprings', 452, 'AZ'],
#  ['BlackCanyonCity', 2837, 'AZ'],
#  ['Blackwater', 1062, 'AZ'],
#  ['Bluewater', 725, 'AZ'],
#  ['Bouse', 996, 'AZ'],
#  ['Bowie', 449, 'AZ'],
#  ['Brenda', 676, 'AZ'],
#  ['Bryce', 175, 'AZ'],
#  ['Buckeyetown', 50876, 'AZ'],
#  ['Buckshot', 153, 'AZ'],
#  ['BullheadCity', 39540, 'AZ'],
#  ['Burnside', 537, 'AZ'],
#  ['Bylas', 1962, 'AZ'],
#  ['CactusFlats', 1518, 'AZ'],
#  ['CactusForest', 594, 'AZ'],
#  ['Cameron', 885, 'AZ'],
#  ['CampoBonito', 74, 'AZ'],
#  ['CampVerdetown', 10873, 'AZ'],
#  ['CaneBeds', 448, 'AZ'],
#  ['CanyonDay', 1209, 'AZ'],
#  ['Carefreetown', 3363, 'AZ'],
#  ['Carrizo', 127, 'AZ'],
#  ['CasaBlanca', 1388, 'AZ'],
#  ['CasaGrande', 48571, 'AZ'],
#  ['CasasAdobes', 66795, 'AZ'],
#  ['Catalina', 7569, 'AZ'],
#  ['CatalinaFoothills', 50796, 'AZ'],
#  ['CaveCreektown', 5015, 'AZ'],
#  ['CedarCreek', 318, 'AZ'],
#  ['CentennialPark', 1264, 'AZ'],
#  ['Central', 645, 'AZ'],
#  ['CentralHeights-MidlandCity', 2534, 'AZ'],
#  ['Chandler', 236123, 'AZ'],
#  ['Charco', 52, 'AZ'],
#  ['ChiawuliTak', 78, 'AZ'],
#  ['Chilchinbito', 506, 'AZ'],
#  ...]

# %%
'making sure that cities have a length'
len(city_pop_lst[0][0])
# Out:
# 6

# %%
'taking care of division by zero'
city_pop_lst[25325][1]=1#the population of this used to be 0...
city_pop_lst[25325]
# Out:
# ['LaredoRanchettesWest', 1, 'TX']

# %%
'taking care of division by zero'
city_pop_lst[3331][1]=1#the population of this used to be 0...
city_pop_lst[3331]
# Out:
# ['UniversityofCaliforniaMerced', 1, 'CA']

# %%
'tried to get method to get variables, did not work'
def get_city(lst,x):
    return lst[x][0]
def get_number(lst,x):
    return lst[x][1]
def get_state(lst,x):
    return lst[x][2]

# %%
print(get_city(city_kill_state,0))
print(get_city(city_pop_lst,0))
# Out:
# 300blockofStateLineRoad
# Abanda

# %%
print(get_number(city_kill_state,0))
print(get_number(city_pop_lst,0))
# Out:
# 1
# 192

# %%
print(get_state(city_kill_state,0))
print(get_state(city_pop_lst,0))
# Out:
# TN
# AL

# %%
def find_city(city_name,lst):
    for i in range(len(lst)):
        if city_name in lst[i][0]:
            print(lst[i])
'''def make_list_copy1(lst):
    x=[]
    for i in range(len(lst)):
        x.append(lst[i])
    return x
def make_list_copy2(lst):
    y=[]
    for i in range(len(lst)):
        y.append(lst[i])
    return y
def make_list_copy3(lst):
    z=[]
    for i in range(len(lst)):
        z.append(lst[i])
    return z'''
killings_per_capita_eq=city_kill_state.copy()
killings_per_capita_in=city_kill_state.copy()
killings_per_capita_is=city_kill_state.copy()

# %%
"making the list of kills per capita, need to find a way to filter out when there's too many responses in the kills per capita section"
print(len(city_kill_state))
def per_capita_eq(city_kill_state,city_pop_lst):
    for i in range(len(city_kill_state)):
        for x in range(len(city_pop_lst)):
            try:
                if city_kill_state[i][0] == city_pop_lst[x][0]:
                    if city_kill_state[i][2] == city_pop_lst[x][2]:
                        per_capita = float(city_kill_state[i][1])/float(city_pop_lst[x][1])
                        city_kill_state[i].append(per_capita)
                #else:
                 #   city_kill_state.pop(i)
            except:
                raise ZeroDivisionError(x)
    print(len(city_kill_state))
    return city_kill_state
                # lst_of_dic[i] = (lst_of_dic[i][0], [per_capita, lst_of_dic[i][1][1]])
           # elif get_state(city_kill_state,i) is not get_state(city_pop_lst,x):
            #    city_kill_state[i].append('wrong state')
def per_capita_in(city_kill_state,city_pop_lst):
    for i in range(len(city_kill_state)):
        for x in range(len(city_pop_lst)):
            try:
                if city_kill_state[i][0] in city_pop_lst[x][0]:
                    if city_kill_state[i][2] == city_pop_lst[x][2]:
                        per_capita = float(city_kill_state[i][1])/float(city_pop_lst[x][1])
                        city_kill_state[i].append(per_capita)
                #else:
                 #   city_kill_state.pop(i)
            except:
                raise ZeroDivisionError(x)
    print(len(city_kill_state))
    return city_kill_state
def per_capita_is(city_kill_state,city_pop_lst):
    for i in range(len(city_kill_state)):
        for x in range(len(city_pop_lst)):
            try:
                if city_kill_state[i][0] is city_pop_lst[x][0]:
                    if city_kill_state[i][2] == city_pop_lst[x][2]:
                        per_capita = float(city_kill_state[i][1])/float(city_pop_lst[x][1])
                        city_kill_state[i].append(per_capita)
                #else:
                 #   city_kill_state.pop(i)
            except:
                raise ZeroDivisionError(x)
    print(len(city_kill_state))
    return city_kill_state
# Out:
# 2473

# %%
per_capita_is(killings_per_capita_is,city_pop_lst)
'is'
no_response=[]
too_many=[]
just_right=[]
no_emptys=[]
for i in range(len(killings_per_capita_is)):
    if len(killings_per_capita_is[i]) == 3:
        no_response.append(killings_per_capita_is[i])
for i in range(len(killings_per_capita_is)):
    if len(killings_per_capita_is[i]) > 4:
        too_many.append(killings_per_capita_is[i])
for i in range(len(killings_per_capita_is)):
    if len(killings_per_capita_is[i]) == 4:
        just_right.append(killings_per_capita_is[i])
for i in range(len(killings_per_capita_is)):
    if len(killings_per_capita_is[i]) == 4:
        no_emptys.append(killings_per_capita_is[i])
print(len(no_response))
print(len(too_many))
print(len(just_right))
print(len(no_emptys))
# Out:
# 2473
# 2473
# 0
# 0
# 0

# %%
per_capita_eq(killings_per_capita_eq,city_pop_lst)
'=='
no_response=[]
too_many=[]
just_right=[]
no_emptys=[]
for i in range(len(killings_per_capita_eq)):
    if len(killings_per_capita_eq[i]) == 3:
        no_response.append(killings_per_capita_eq[i])
for i in range(len(killings_per_capita_eq)):
    if len(killings_per_capita_eq[i]) > 4:
        too_many.append(killings_per_capita_eq[i])
for i in range(len(killings_per_capita_eq)):
    if len(killings_per_capita_eq[i]) == 4:
        just_right.append(killings_per_capita_eq[i])
for i in range(len(killings_per_capita_eq)):
    if len(killings_per_capita_eq[i]) == 4:
        no_emptys.append(killings_per_capita_eq[i])
print(len(no_response))
print(len(too_many))
print(len(just_right))
print(len(no_emptys))
fdgs=[]
for i in range(len(killings_per_capita_eq)):
    if len(killings_per_capita_eq[i])>4:
        fdgs.append(killings_per_capita_eq[i])
killings_per_capita_eq
# Out:
# 2473
# 778
# 10
# 1685
# 1685
# [['Burbank', 2, 'CA', 1.9353590090961872e-05, 0.0004060089321965083],
#  ['Cottonwood', 2, 'AZ', 0.008849557522123894, 0.0001775410563692854],
#  ['ElCerrito', 1, 'CA', 4.2464648180389826e-05, 0.000196078431372549],
#  ['Indianapolis', 16, 'IN', 1.928366023154855e-05, 1.9501611930111097e-05],
#  ['Mesquite', 1, 'TX', 7.1518480375328984e-06, 0.0019801980198019802],
#  ['Midway',
#   1,
#   'FL',
#   0.00033288948069241014,
#   6.205398696866273e-05,
#   0.0005865102639296188],
#  ['Plantation', 1, 'FL', 1.177093755517627e-05, 0.00020329335230737954],
#  ['Reno', 1, 'TX', 0.0003158559696778269, 0.00040096230954290296],
#  ['Sunset', 1, 'TX', 0.002012072434607646, 0.02127659574468085],
#  ['Woodlawn', 1, 'MD', 2.63998521608279e-05, 0.00015787811809283233]]

# %%
per_capita_in(killings_per_capita_in,city_pop_lst)
'in'
no_response=[]
too_many=[]
just_right=[]
no_emptys=[]
for i in range(len(killings_per_capita_in)):
    if len(killings_per_capita_in[i]) == 3:
        no_response.append(killings_per_capita_in[i])
for i in range(len(killings_per_capita_in)):
    if len(killings_per_capita_in[i]) > 4:
        too_many.append(killings_per_capita_in[i])
for i in range(len(killings_per_capita_in)):
    if len(killings_per_capita_in[i]) == 4:
        just_right.append(killings_per_capita_in[i])
for i in range(len(killings_per_capita_in)):
    if len(killings_per_capita_in[i]) == 4:
        no_emptys.append(killings_per_capita_in[i])
print(len(no_response))
print(len(too_many))
print(len(just_right))
print(len(no_emptys))
killings_per_capita_in
# Out:
# 2473
# 459
# 1728
# 286
# 286

# %%
killings_per_capita_is
# Out:
# [['300blockofStateLineRoad', 1, 'TN'],
#  ['Abbeville', 1, 'AL', 0.0003720238095238095, 0.0003720238095238095],
#  ['Aberdeen', 1, 'NC', 0.00015748031496062991],
#  ['Aberdeen',
#   1,
#   'WA',
#   5.918560606060606e-05,
#   5.918560606060606e-05,
#   0.0035842293906810036],
#  ['Abilene', 2, 'TX', 1.7084817576860323e-05, 1.7084817576860323e-05],
#  ['Abingdon', 1, 'MD'],
#  ['Abingdon', 1, 'VA', 0.00012208521548040532],
#  ['AbingtonTownship', 1, 'PA'],
#  ['Acworth', 1, 'GA', 4.895960832313341e-05, 4.895960832313341e-05],
#  ['Ada',
#   1,
#   'OK',
#   5.94883997620464e-05,
#   5.94883997620464e-05,
#   0.0012658227848101266],
#  ['AdamsCounty', 3, 'CO'],
#  ['Addison', 1, 'TX', 7.659313725490196e-05],
#  ['Adelanto', 1, 'CA', 3.1481189988981584e-05, 3.1481189988981584e-05],
#  ['Affton', 1, 'MO', 4.924410301866352e-05, 4.924410301866352e-05],
#  ['Aguanga', 1, 'CA', 0.0008865248226950354, 0.0008865248226950354],
#  ['Ahwatukee', 1, 'AZ'],
#  ['Aiea', 1, 'HI', 0.00010708931248661383, 0.00010708931248661383],
#  ['Aiken', 2, 'SC', 6.774149844194554e-05, 6.774149844194554e-05],
#  ['Aitkin', 1, 'MN', 0.00046189376443418013, 0.00046189376443418013],
#  ['Akron', 6, 'OH', 3.0134096730450506e-05, 3.0134096730450506e-05],
#  ['Alamo', 2, 'TN', 0.0008126777732629012],
#  ['Alamogordo', 2, 'NM', 6.578298194257146e-05, 6.578298194257146e-05],
#  ['Alamosa',
#   2,
#   'CO',
#   0.00022779043280182233,
#   0.00022779043280182233,
#   0.0013717421124828531],
#  ['Albany', 1, 'GA', 1.291422372601183e-05, 1.291422372601183e-05],
#  ['Albany', 1, 'NY', 1.0219097449313277e-05, 1.0219097449313277e-05],
#  ['AlbertLea', 1, 'MN', 5.5506216696269984e-05, 5.5506216696269984e-05],
#  ['Albuquerque',
#   31,
#   'NM',
#   5.679195093175439e-05,
#   5.679195093175439e-05,
#   0.005146082337317397],
#  ['AlderwoodManor', 1, 'WA', 0.00011845534233593936, 0.00011845534233593936],
#  ['Aldie', 1, 'VA'],
#  ['Alexandria', 2, 'LA', 4.190851371456111e-05, 4.190851371456111e-05],
#  ['Alexandria', 1, 'MN', 9.03342366757001e-05, 9.03342366757001e-05],
#  ['Alexandria', 1, 'VA', 7.144592258119829e-06, 7.144592258119829e-06],
#  ['AlgomaTownship', 1, 'MI'],
#  ['Alhambra',
#   1,
#   'CA',
#   1.203528746284105e-05,
#   1.203528746284105e-05,
#   0.0010822510822510823],
#  ['Aliceville', 1, 'CA'],
#  ['Allen',
#   2,
#   'TX',
#   2.373999952520001e-05,
#   2.373999952520001e-05,
#   1.5399185383093235e-05],
#  ['Allentown', 3, 'PA', 2.5416836112240748e-05, 2.5416836112240748e-05],
#  ['Aloha', 2, 'OR', 4.0465351542741524e-05, 4.0465351542741524e-05],
#  ['Alpine',
#   2,
#   'CA',
#   0.00014048890137679124,
#   0.00014048890137679124,
#   0.017543859649122806],
#  ['Alton',
#   2,
#   'IL',
#   7.177462766911897e-05,
#   7.177462766911897e-05,
#   0.003766478342749529,
#   0.0003174099349309633],
#  ['Altoona', 1, 'IA', 6.877106113747335e-05, 6.877106113747335e-05],
#  ['Alvin', 1, 'TX', 4.1260934147549104e-05, 4.1260934147549104e-05],
#  ['Amarillo', 9, 'TX', 4.719578384331e-05, 4.719578384331e-05],
#  ['AmeliaIsland', 1, 'FL'],
#  ['Amite', 1, 'LA', 0.0002414875633904854],
#  ['Amity', 1, 'OR', 0.0006195786864931846, 0.0006195786864931846],
#  ['Anadarko', 1, 'OK', 0.0001478852410529429, 0.0001478852410529429],
#  ['Anaheim', 9, 'CA', 2.6764605296418002e-05, 2.6764605296418002e-05],
#  ['Anchorage', 9, 'AK', 3.084029524442647e-05],
#  ['Anderson', 2, 'CA', 0.0002013693113169553, 0.0002013693113169553],
#  ['AngelFire', 1, 'NM', 0.0008223684210526315],
#  ['Ankeny', 1, 'IA', 2.1938484489491466e-05, 2.1938484489491466e-05],
#  ['Anniston', 1, 'AL', 4.327880204275946e-05, 4.327880204275946e-05],
#  ['AnsonCounty', 1, 'NC'],
#  ['Antelope', 1, 'CA', 2.1848372296263928e-05, 2.1848372296263928e-05],
#  ['Antigo', 1, 'WI', 0.00012144765606023804, 0.00012144765606023804],
#  ['Antioch', 4, 'CA', 3.907318407377017e-05, 3.907318407377017e-05],
#  ['Antioch', 1, 'IL', 6.93000693000693e-05],
#  ['Antioch', 1, 'TN'],
#  ['ApacheJunction', 2, 'AZ', 5.580357142857143e-05, 5.580357142857143e-05],
#  ['Apex', 2, 'NC', 5.3367488525989965e-05],
#  ['Apopka',
#   1,
#   'FL',
#   2.4072023494294932e-05,
#   2.4072023494294932e-05,
#   0.00017458100558659218],
#  ['AppleCreek', 1, 'OH', 0.0008525149190110827],
#  ['AppleValley', 1, 'CA', 1.4464453605265062e-05],
#  ['Appleton', 2, 'WI', 2.7539484736240586e-05, 2.7539484736240586e-05],
#  ['Arab', 1, 'AL', 0.00012422360248447205, 0.00012422360248447205],
#  ['Aragonite', 1, 'UT'],
#  ['Arcata', 1, 'CA', 5.803493703209332e-05, 5.803493703209332e-05],
#  ['Archdale', 2, 'NC', 0.00017520805957074026, 0.00017520805957074026],
#  ['Arcola', 1, 'IL', 0.0003429355281207133, 0.0003429355281207133],
#  ['Ardmore', 1, 'OK', 4.118107317876704e-05, 4.118107317876704e-05],
#  ['Ardsley', 1, 'NY', 0.00022461814914645105],
#  ['Arlington', 1, 'GA', 0.000676132521974307, 0.000676132521974307],
#  ['Arlington', 1, 'TN', 8.682816705739342e-05],
#  ['Arlington', 11, 'TX', 3.01008652630542e-05, 3.01008652630542e-05],
#  ['Arlington', 2, 'VA', 9.632658565600813e-06, 9.632658565600813e-06],
#  ['Arpin', 1, 'WI', 0.003003003003003003],
#  ['Artesia', 1, 'CA', 6.052536012589275e-05, 6.052536012589275e-05],
#  ['Artesia', 2, 'NM', 0.00017697548889478808, 0.00017697548889478808],
#  ['Arundel', 1, 'ME'],
#  ['Arvada', 2, 'CO', 1.8791164394501704e-05, 1.8791164394501704e-05],
#  ['Arvonia', 1, 'VA'],
#  ['AsburyPark', 1, 'NJ', 6.205013651030033e-05, 6.205013651030033e-05],
#  ['AsheCounty', 1, 'NC'],
#  ['Asheville', 1, 'NC', 1.1991414147470411e-05, 1.1991414147470411e-05],
#  ['Ashland', 1, 'CA', 4.561003420752566e-05, 4.561003420752566e-05],
#  ['Ashland', 1, 'WI', 0.00012171372930866602, 0.00012171372930866602],
#  ['Ashtabula', 1, 'OH', 5.229031583350764e-05, 5.229031583350764e-05],
#  ['Ashville', 1, 'AL', 0.0004520795660036166, 0.0004520795660036166],
#  ['Ashwaubenon', 1, 'WI', 5.8951836349702294e-05],
#  ['Aspers', 1, 'PA', 0.002857142857142857, 0.002857142857142857],
#  ['Assaria', 1, 'KS', 0.002421307506053269, 0.002421307506053269],
#  ['Atascadero', 1, 'CA', 3.532320734722713e-05, 3.532320734722713e-05],
#  ['Athens', 3, 'GA', 2.5703857292184315e-05, 2.598482486228043e-05],
#  ['Atlanta',
#   18,
#   'GA',
#   4.285683673688045e-05,
#   4.285683673688045e-05,
#   0.00044492782281985367],
#  ['AtlanticCity', 3, 'NJ', 7.583801001061732e-05, 7.583801001061732e-05],
#  ['Atwater', 3, 'CA', 0.00010650383413802897, 0.00010650383413802897],
#  ['Auburn',
#   1,
#   'CA',
#   7.501875468867217e-05,
#   7.501875468867217e-05,
#   0.0002918855808523059,
#   7.679311933650745e-05],
#  ['Auburn', 1, 'MA'],
#  ['Auburn', 4, 'WA', 5.699629524080935e-05, 5.699629524080935e-05],
#  ['Auburndale', 1, 'FL', 7.403568520026653e-05, 7.403568520026653e-05],
#  ['Augusta', 3, 'GA', 1.4958937715969664e-05, 1.531831457690815e-05],
#  ['Augusta', 1, 'WV'],
#  ['Aurora', 12, 'CO', 3.6914217510874315e-05, 3.6914217510874315e-05],
#  ['Aurora',
#   2,
#   'IL',
#   1.0106165266120597e-05,
#   1.0106165266120597e-05,
#   0.00011933174224343676],
#  ['Aurora', 1, 'MO', 0.00013319126265316994, 0.00013319126265316994],
#  ['Austell', 2, 'GA', 0.000303905181583346, 0.000303905181583346],
#  ['Austin', 1, 'AR', 0.0004906771344455348, 0.0004906771344455348],
#  ['Austin', 1, 'MN', 4.0456347600938586e-05, 4.0456347600938586e-05],
#  ['Austin', 26, 'TX', 3.289515302572148e-05, 3.289515302572148e-05],
#  ['Avella', 1, 'PA', 0.0012437810945273632, 0.0012437810945273632],
#  ['Avenal', 1, 'CA', 6.449532408900354e-05, 6.449532408900354e-05],
#  ['Avon', 1, 'IN', 8.034709946970914e-05],
#  ['Avondale', 3, 'AZ', 3.9350455153597945e-05, 3.9350455153597945e-05],
#  ['Azle', 2, 'TX', 0.00018269845619804512, 0.00018269845619804512],
#  ['Azusa', 4, 'CA', 8.627941588835444e-05, 8.627941588835444e-05],
#  ['BagleyTownship', 1, 'MI'],
#  ['Bailey', 1, 'CO'],
#  ['Bailey', 1, 'NC', 0.0017574692442882249],
#  ['BainbridgeIsland', 1, 'WA', 4.343105320304018e-05, 4.343105320304018e-05],
#  ['Bakersfield', 21, 'CA', 6.0434611189612156e-05, 6.0434611189612156e-05],
#  ['BalchSprings', 1, 'TX', 4.214430209035738e-05, 4.214430209035738e-05],
#  ['BaldwinCounty', 1, 'AL'],
#  ['BaldwinHills', 1, 'CA'],
#  ['Baltimore',
#   16,
#   'MD',
#   2.576651351695195e-05,
#   2.576651351695195e-05,
#   0.0022795269981478843],
#  ['Bandon', 1, 'OR', 0.00032615786040443573, 0.00032615786040443573],
#  ['Bangor', 1, 'ME', 3.0267259904960804e-05, 3.0267259904960804e-05],
#  ['Banning', 1, 'CA', 3.378036009863865e-05, 3.378036009863865e-05],
#  ['Barberton', 1, 'OH', 3.766478342749529e-05, 3.766478342749529e-05],
#  ['Barberville', 1, 'FL'],
#  ['Barbourville', 1, 'KY', 0.000315955766192733, 0.000315955766192733],
#  ['Bardstown', 1, 'KY', 8.547008547008547e-05, 8.547008547008547e-05],
#  ['Barnwell', 1, 'AL'],
#  ['BaronaIndianReservation', 1, 'CA'],
#  ['Barrow', 1, 'AK', 0.00023741690408357076, 0.00023741690408357076],
#  ['BarrowCounty', 1, 'GA'],
#  ['Barstow', 4, 'CA', 0.00017668624939264101, 0.00017668624939264101],
#  ['Bartlesville', 2, 'OK', 5.5944055944055945e-05, 5.5944055944055945e-05],
#  ['Bartlett', 1, 'TN', 1.8310658634391078e-05, 1.8310658634391078e-05],
#  ['Barton', 1, 'MS'],
#  ['Bassett', 1, 'CA'],
#  ['Bassett', 1, 'VA', 0.0009090909090909091, 0.0009090909090909091],
#  ['Bastrop', 1, 'LA', 8.798944126704795e-05, 8.798944126704795e-05],
#  ['Batesville', 1, 'AR', 9.75800156128025e-05, 9.75800156128025e-05],
#  ['Bath', 1, 'NH'],
#  ['BatonRouge', 10, 'LA', 4.3574313813493224e-05, 4.3574313813493224e-05],
#  ['BattleCreek', 1, 'MI', 1.9103291497124954e-05, 1.9103291497124954e-05],
#  ['Baxter', 1, 'KY'],
#  ['BayCity', 1, 'MI', 2.862704683384862e-05, 2.862704683384862e-05],
#  ['BayMinette', 1, 'AL', 0.00012431626056688214, 0.00012431626056688214],
#  ['Baytown', 3, 'TX', 4.178156597309267e-05, 4.178156597309267e-05],
#  ['Beacon', 1, 'NY', 6.43459236857345e-05, 6.43459236857345e-05],
#  ['Beaumont', 3, 'CA', 8.13515199175638e-05, 8.13515199175638e-05],
#  ['Beaumont', 2, 'TX', 1.690674240887266e-05, 1.690674240887266e-05],
#  ['Beaver', 1, 'WA'],
#  ['BeaverDam', 1, 'WI', 6.167509559639817e-05, 6.167509559639817e-05],
#  ['Beaverton', 1, 'MI', 0.0009337068160597573, 0.0009337068160597573],
#  ['Beaverton', 3, 'OR', 3.3406456354464775e-05, 3.3406456354464775e-05],
#  ['Beckley', 1, 'WV', 5.677302146020211e-05, 5.677302146020211e-05],
#  ['Beckville', 1, 'TX', 0.0011806375442739079, 0.0011806375442739079],
#  ['Bedford', 1, 'TX', 2.128610655824943e-05, 2.128610655824943e-05],
#  ['BeechGrove', 1, 'IN', 7.046223224351747e-05, 7.046223224351747e-05],
#  ['BelAir',
#   1,
#   'MD',
#   0.000794912559618442,
#   0.000794912559618442,
#   9.881422924901186e-05,
#   3.2713949227950796e-05,
#   2.0960405793456162e-05],
#  ['Belgrade', 1, 'ME'],
#  ['Bell',
#   1,
#   'CA',
#   2.8187276263494658e-05,
#   2.8187276263494658e-05,
#   0.0003595828838547285,
#   0.0004880429477794046,
#   1.3052103999164665e-05,
#   2.3768777334093934e-05,
#   0.00030211480362537764],
#  ['BellGardens', 1, 'CA', 2.3768777334093934e-05, 2.3768777334093934e-05],
#  ['BelleGlade', 1, 'FL', 5.7250815824125495e-05, 5.7250815824125495e-05],
#  ['Belleville', 2, 'IL', 4.496605063177301e-05, 4.496605063177301e-05],
#  ['Belleville', 1, 'MI', 0.00025056376847907793, 0.00025056376847907793],
#  ['Bellflower', 1, 'CA', 1.3052103999164665e-05, 1.3052103999164665e-05],
#  ['Bellingham', 1, 'WA', 1.2363231748779131e-05, 1.2363231748779131e-05],
#  ['Bellville', 1, 'TX', 0.000244081034903588, 0.000244081034903588],
#  ['Belmont', 1, 'NH', 0.0007686395080707148, 0.0007686395080707148],
#  ['Belton', 2, 'MO', 8.652015919709292e-05, 8.652015919709292e-05],
#  ['Belton', 1, 'SC', 0.00024189646831156264, 0.00024189646831156264],
#  ['Bemidji', 1, 'MN', 7.445461990916536e-05, 7.445461990916536e-05],
#  ['Bend',
#   3,
#   'OR',
#   3.914456086326805e-05,
#   3.914456086326805e-05,
#   0.0003094378545642084],
#  ['Benton',
#   2,
#   'AR',
#   6.518692350314528e-05,
#   6.518692350314528e-05,
#   5.6655618820996573e-05],
#  ['Benton', 1, 'IL', 0.00014110342881332017, 0.00014110342881332017],
#  ['BentonCity', 1, 'WA', 0.0003291639236339697, 0.0003291639236339697],
#  ['BentonHarbor', 1, 'MI', 9.962143853357243e-05, 9.962143853357243e-05],
#  ['BentonTownship', 1, 'MI'],
#  ['Berea', 1, 'KY', 7.374087456677236e-05, 7.374087456677236e-05],
#  ['Bernalillo', 2, 'NM', 0.0002403846153846154],
#  ['Berne', 1, 'NY'],
#  ['Bernice', 1, 'LA', 0.0005920663114268798],
#  ['Bethany', 1, 'OK', 5.249068290378458e-05, 5.249068290378458e-05],
#  ['Beverly', 1, 'MA', 2.53151739152448e-05, 2.53151739152448e-05],
#  ['Beverly', 1, 'OH', 0.0007616146230007616],
#  ['BeverlyHills', 1, 'FL', 0.00011841326228537596, 0.00011841326228537596],
#  ['BexarCounty', 3, 'TX'],
#  ['BibbCounty', 1, 'GA'],
#  ['BigBear', 1, 'MO'],
#  ['BigLake', 1, 'AK', 0.00029850746268656717, 0.00029850746268656717],
#  ['BigSprings', 1, 'NE', 0.0025],
#  ['BigSur', 1, 'CA'],
#  ['Billings', 9, 'MT', 8.639723528847077e-05, 8.639723528847077e-05],
#  ['Biloxi', 2, 'MS', 4.539882871021928e-05, 4.539882871021928e-05],
#  ['Birmingham', 8, 'AL', 3.769371033325952e-05, 3.769371033325952e-05],
#  ['Bisbee', 1, 'AZ', 0.00017937219730941703, 0.00017937219730941703],
#  ['Bismarck', 1, 'ND', 1.632066849458154e-05, 1.632066849458154e-05],
#  ['Bixby', 1, 'OK', 4.788354721317755e-05, 4.788354721317755e-05],
#  ['BlackRiverFalls', 1, 'WI', 0.0002760905577029266, 0.0002760905577029266],
#  ['Blackfoot', 1, 'ID', 8.404067568703252e-05, 8.404067568703252e-05],
#  ['BlackmanTownship', 1, 'MI'],
#  ['Blacksburg', 1, 'SC', 0.0005411255411255411],
#  ['Blackwell', 1, 'OK', 0.0001410039481105471, 0.0001410039481105471],
#  ['Bloomfield', 1, 'NJ'],
#  ['BloomfieldTownship', 1, 'MI'],
#  ['Bloomingdale', 1, 'IL', 4.541738577527478e-05],
#  ['Bloomington', 1, 'MN', 1.2063744827669405e-05, 1.2063744827669405e-05],
#  ['Bloomsburg', 1, 'PA', 6.731740154830023e-05],
#  ['Blountville', 1, 'TN', 0.00032530904359141186, 0.00032530904359141186],
#  ['BlueSprings', 2, 'MO', 3.8040893961008086e-05, 3.8040893961008086e-05],
#  ['BlueSummit', 1, 'MO'],
#  ['Bluefield', 1, 'WV', 9.572125969177755e-05, 9.572125969177755e-05],
#  ['BluffCity', 1, 'TN', 0.0005770340450086555, 0.0005770340450086555],
#  ['Blytheville', 1, 'AR', 6.402048655569782e-05, 6.402048655569782e-05],
#  ['Boerne', 2, 'TX', 0.00019100372457262916, 0.00019100372457262916],
#  ['Bogalusa', 1, 'LA', 8.175277959450622e-05, 8.175277959450622e-05],
#  ['BoilingSprings', 1, 'SC', 0.00012166930283489475, 0.00012166930283489475],
#  ['Boise', 7, 'ID', 3.40349392962547e-05],
#  ['Bolton', 1, 'CT'],
#  ['Bolton', 1, 'VT'],
#  ['BonAqua', 1, 'TN', 0.0008130081300813008],
#  ['Bonaire', 1, 'GA'],
#  ['Boone', 2, 'IA', 0.00015796540557617883, 0.00015796540557617883],
#  ['Booneville', 1, 'KY', 0.012345679012345678, 0.012345679012345678],
#  ['Boonville', 1, 'IN', 0.0001601024655779699, 0.0001601024655779699],
#  ['Boring', 1, 'OR'],
#  ['BossierCity', 1, 'LA', 1.6309222865530456e-05, 1.6309222865530456e-05],
#  ['Boston', 8, 'MA', 1.2953493719174733e-05, 1.2953493719174733e-05],
#  ['Boswell', 1, 'OK', 0.0014104372355430183],
#  ['Boulder', 4, 'CO', 4.107408738512091e-05, 4.107408738512091e-05],
#  ['BoulderCity', 1, 'NV', 6.656460094521733e-05, 6.656460094521733e-05],
#  ['BoulderCreek', 1, 'CA', 0.00020312817387771684, 0.00020312817387771684],
#  ['BowlingGreen', 1, 'KY', 1.7221485525341415e-05, 1.7221485525341415e-05],
#  ['BoxElder', 1, 'SD', 0.0001282051282051282, 0.0001282051282051282],
#  ['BoyleHeights', 1, 'CA'],
#  ['BoyntonBeach', 1, 'FL', 1.465910256974068e-05, 1.465910256974068e-05],
#  ['BoytonBeach', 1, 'FL'],
#  ['Bozeman', 1, 'MT', 2.6824034334763947e-05, 2.6824034334763947e-05],
#  ['Bradenton',
#   3,
#   'FL',
#   6.0549792112380414e-05,
#   6.0549792112380414e-05,
#   0.0025619128949615714,
#   0.00013526918567950222,
#   0.0007156488549618321],
#  ['BradleyCounty', 1, 'TN'],
#  ['Braintree', 1, 'MA', 2.7976723366159355e-05],
#  ['Brandywine', 1, 'WV', 0.0045871559633027525, 0.0045871559633027525],
#  ['Brawley', 1, 'CA', 4.00753416422875e-05, 4.00753416422875e-05],
#  ['Braxton', 1, 'MS', 0.00546448087431694],
#  ['BraxtonCounty', 1, 'WV'],
#  ['BreauxBridge', 1, 'LA', 0.00012286521685710776, 0.00012286521685710776],
#  ['Bremen', 1, 'KY', 0.005076142131979695, 0.005076142131979695],
#  ['Bremerton', 1, 'WA', 2.6504810623128097e-05, 2.6504810623128097e-05],
#  ['Brevard', 1, 'NC', 0.0001314233144959916, 0.0001314233144959916],
#  ['Brick', 1, 'NJ'],
#  ['BrickTownship', 1, 'NJ'],
#  ['Bridgeport', 1, 'CT', 6.9334183832655015e-06, 6.9334183832655015e-06],
#  ['Bridgeton', 1, 'NJ', 3.9449287940352674e-05, 3.9449287940352674e-05],
#  ['Brighton', 1, 'CO', 2.998320940273447e-05, 2.998320940273447e-05],
#  ['BrightonTownship', 1, 'MI'],
#  ['Bristol', 2, 'TN', 7.490075649764063e-05, 7.490075649764063e-05],
#  ['Bristol', 1, 'VA', 5.6069526212503504e-05, 5.6069526212503504e-05],
#  ['BristolTownship', 1, 'PA'],
#  ['Brockton', 2, 'MA', 2.1319688732544504e-05, 2.1319688732544504e-05],
#  ['Brodhead', 1, 'KY', 0.0008257638315441783, 0.0008257638315441783],
#  ['BrokenBow', 1, 'OK', 0.00024271844660194174, 0.00024271844660194174],
#  ['Bronx', 4, 'NY', 0.0006326111023248458],
#  ['Brookhaven', 1, 'MS', 7.991688643810437e-05, 7.991688643810437e-05],
#  ['Brooklet', 1, 'GA', 0.0007168458781362007, 0.0007168458781362007],
#  ['Brooklyn', 5, 'NY'],
#  ['Brooklyn',
#   1,
#   'OH',
#   8.95335303071e-05,
#   8.95335303071e-05,
#   0.0006480881399870382],
#  ['BrooklynCenter', 1, 'MN', 3.321817698644698e-05, 3.321817698644698e-05],
#  ['Brookshire', 1, 'TX', 0.0002126754572522331, 0.0002126754572522331],
#  ['Brooksville', 1, 'AL'],
#  ['Brooksville',
#   3,
#   'FL',
#   0.000388651379712398,
#   0.000388651379712398,
#   0.0008465011286681715,
#   0.0007486897928624906],
#  ['Brookville', 1, 'IN', 0.0003852080123266564],
#  ['Brookville', 1, 'OH', 0.0001699524133242692, 0.0001699524133242692],
#  ['Broomfield', 1, 'CO', 1.7892608563402458e-05, 1.7892608563402458e-05],
#  ['Brownstown', 1, 'IN', 0.00033932813030200206],
#  ['Brownsville', 4, 'TX', 2.285413917028048e-05, 2.285413917028048e-05],
#  ['Bruce', 1, 'FL'],
#  ['Buckeye', 4, 'AZ', 7.862253321802028e-05],
#  ['Buckhannon', 1, 'WV', 0.00017733640716439085, 0.00017733640716439085],
#  ['Buffalo', 1, 'MO', 0.00032425421530479895, 0.00032425421530479895],
#  ['Buffalo',
#   3,
#   'NY',
#   1.148061689181432e-05,
#   1.148061689181432e-05,
#   0.0004945598417408506],
#  ['Buford', 2, 'GA', 0.00016359918200408997, 0.00016359918200408997],
#  ['BullShoals', 1, 'AR', 0.0005128205128205128, 0.0005128205128205128],
#  ['BullheadCity', 1, 'AZ', 2.5290844714213454e-05, 2.5290844714213454e-05],
#  ['Bunch', 1, 'OK'],
#  ['Burbank',
#   2,
#   'CA',
#   1.9353590090961872e-05,
#   0.0004060089321965083,
#   1.9353590090961872e-05,
#   0.0004060089321965083],
#  ['Burien', 2, 'WA', 6.003662233962717e-05, 6.003662233962717e-05],
#  ['Burkesville', 1, 'KY', 0.0006574621959237344, 0.0006574621959237344],
#  ['Burlington',
#   2,
#   'IA',
#   7.793321123796907e-05,
#   7.793321123796907e-05,
#   0.0006738544474393531],
#  ['Burlington', 1, 'NC', 2.001481096011048e-05, 2.001481096011048e-05],
#  ['Burlington',
#   2,
#   'VT',
#   4.7150906476177006e-05,
#   4.7150906476177006e-05,
#   0.00011170688114387846],
#  ['Burnet', 1, 'TX', 0.00016702856188408218, 0.00016702856188408218],
#  ['Burns', 1, 'OR', 0.0003563791874554526, 0.0003563791874554526],
#  ['BurnsFlat', 1, 'OK', 0.0004861448711716091],
#  ['Burnsville', 2, 'MN', 3.316419593406958e-05, 3.316419593406958e-05],
#  ['Burnsville', 1, 'NC', 0.0005906674542232723],
#  ['Bushnell', 1, 'FL', 0.00041356492969396195, 0.00041356492969396195],
#  ['Butte',
#   1,
#   'MT',
#   2.9239766081871346e-05,
#   2.982848620432513e-05,
#   0.001718213058419244,
#   0.0078125],
#  ['ButteCounty', 1, 'CA'],
#  ['Byars', 1, 'OK', 0.00392156862745098],
#  ['Byng', 1, 'OK', 0.000851063829787234],
#  ['Byram', 1, 'NJ', 0.011111111111111112],
#  ['Byron', 1, 'CA', 0.0007830853563038371, 0.0007830853563038371],
#  ['Cabazon', 1, 'CA', 0.0003944773175542406, 0.0003944773175542406],
#  ['Cabot', 1, 'AR', 4.205921938088829e-05, 4.205921938088829e-05],
#  ['Cache', 2, 'OK', 0.000715307582260372, 0.000715307582260372],
#  ['Cade', 1, 'LA', 0.0005803830528148578, 0.0005803830528148578],
#  ['Calabasas', 1, 'CA', 4.336889582791222e-05, 4.336889582791222e-05],
#  ['CalaverasCounty', 1, 'CA'],
#  ['Caldwell', 1, 'ID', 2.1627700759132296e-05, 2.1627700759132296e-05],
#  ['Caledonia', 1, 'WI', 4.0477636106051404e-05],
#  ['Calexico', 1, 'CA', 2.5925541843824535e-05, 2.5925541843824535e-05],
#  ['Calhoun', 1, 'GA', 6.389776357827476e-05, 6.389776357827476e-05],
#  ['Calimesa', 1, 'CA', 0.00012691965985531158, 0.00012691965985531158],
#  ['Callahan', 1, 'FL', 0.0008904719501335708],
#  ['Camarillo', 1, 'CA', 1.5337188079937423e-05, 1.5337188079937423e-05],
#  ['Camden', 3, 'NJ', 3.87877534133223e-05, 3.87877534133223e-05],
#  ['CampCroft', 1, 'SC'],
#  ['CampWood', 1, 'TX', 0.00141643059490085, 0.00141643059490085],
#  ['Campbellton', 1, 'TX'],
#  ['Campbelltown', 1, 'PA', 0.0002765486725663717, 0.0002765486725663717],
#  ['Campo', 1, 'CA', 0.00037257824143070045, 0.00037257824143070045],
#  ['Campobello', 1, 'SC', 0.00199203187250996],
#  ['Canaan', 1, 'NH', 0.0019083969465648854, 0.0019083969465648854],
#  ['CanaanTownship', 1, 'PA'],
#  ['Canandaigua', 1, 'NY', 9.48316737790422e-05, 9.48316737790422e-05],
#  ['Canton', 1, 'NC', 0.0002365744026496333, 0.0008019246190858059],
#  ['Canton',
#   1,
#   'OH',
#   1.369731669565932e-05,
#   1.369731669565932e-05,
#   0.0006285355122564425,
#   5.7182067703568164e-05],
#  ['CantonTownship', 1, 'PA'],
#  ['Cantonment', 1, 'FL'],
#  ['Canutillo', 1, 'TX', 0.00015820281601012498, 0.00015820281601012498],
#  ['CapeCanaveral', 1, 'FL', 0.00010088781275221953, 0.00010088781275221953],
#  ['CapeCoral', 2, 'FL', 1.2961342795113574e-05, 1.2961342795113574e-05],
#  ['CapeGirardeau', 1, 'MO', 2.6356711736643736e-05, 2.6356711736643736e-05],
#  ['CapitolHeights', 1, 'MD', 0.00023057412958266084],
#  ['Carlsbad', 2, 'NM', 7.651694850409365e-05, 7.651694850409365e-05],
#  ['Carmichael', 2, 'CA', 3.238237103720734e-05, 3.238237103720734e-05],
#  ['Carnesville', 1, 'GA', 0.0017331022530329288, 0.0017331022530329288],
#  ['Carollwood', 1, 'FL'],
#  ['Carrizozo', 1, 'NM', 0.001004016064257028],
#  ['CarrollCounty', 1, 'GA'],
#  ['Carrollton', 2, 'GA', 8.200754469411185e-05, 8.200754469411185e-05],
#  ['Carrollton', 2, 'TX', 1.679303424939335e-05, 1.679303424939335e-05],
#  ['Carson',
#   1,
#   'CA',
#   1.090346075844473e-05,
#   1.090346075844473e-05,
#   4.6085073044840775e-05],
#  ['CarsonCity', 3, 'NV', 5.427506603466368e-05, 5.427506603466368e-05],
#  ['CarterCounty', 1, 'KY'],
#  ['Cartersville', 2, 'GA', 0.00010136333688105013, 0.00010136333688105013],
#  ['Carthage', 1, 'TN', 0.0004336513443191674, 0.0007564296520423601],
#  ['Cary', 1, 'NC', 7.394590117869766e-06],
#  ['CasaGrande', 2, 'AZ', 4.117683391324041e-05, 4.117683391324041e-05],
#  ['Casper',
#   5,
#   'WY',
#   9.03897606479138e-05,
#   9.03897606479138e-05,
#   0.012468827930174564],
#  ['Casselberry', 1, 'FL', 3.810830379939789e-05, 3.810830379939789e-05],
#  ['Castaic', 1, 'CA', 5.259006047856955e-05, 5.259006047856955e-05],
#  ['CathedralCity', 3, 'CA', 5.859375e-05, 5.859375e-05],
#  ['CatoTownship', 1, 'MI'],
#  ['Catoosa', 2, 'OK', 0.00027968116347364006, 0.00027968116347364006],
#  ['CaveJunction', 1, 'OR', 0.0005310674455655868, 0.0005310674455655868],
#  ['Cayce', 1, 'SC', 7.982120051085569e-05, 7.982120051085569e-05],
#  ['CañonCity', 1, 'CO', 6.097560975609756e-05, 6.097560975609756e-05],
#  ['CedarHill', 1, 'TX', 2.220840365994492e-05, 2.220840365994492e-05],
#  ['CedarLake', 1, 'TX'],
#  ['CedarRapids', 2, 'IA', 1.58320535756693e-05, 1.58320535756693e-05],
#  ['Cedartown', 1, 'GA', 0.00010256410256410256, 0.00010256410256410256],
#  ['Celina', 1, 'OH', 9.615384615384615e-05, 9.615384615384615e-05],
#  ['Centennial', 5, 'CO', 4.981220797593074e-05, 4.981220797593074e-05],
#  ['Centerville', 1, 'UT', 6.521030322791e-05, 6.521030322791e-05],
#  ['Centralia', 1, 'WA', 6.121449559255632e-05, 6.121449559255632e-05],
#  ['Ceres', 3, 'CA', 6.605456106744171e-05, 6.605456106744171e-05],
#  ['Cerritos', 2, 'CA', 4.078220264676495e-05, 4.078220264676495e-05],
#  ['Chalmette', 1, 'LA', 5.969792848188168e-05, 5.969792848188168e-05],
#  ['Chambersburg', 1, 'PA', 4.933885928557332e-05],
#  ['Chamblee', 1, 'GA', 0.00010109179134654265, 0.00010109179134654265],
#  ['Chandler', 3, 'AZ', 1.2705242606607573e-05, 1.2705242606607573e-05],
#  ['Chanhassen', 1, 'MN', 4.35691878703381e-05, 4.35691878703381e-05],
#  ['Channelview', 1, 'TX', 2.611716158687874e-05, 2.611716158687874e-05],
#  ['Chapeno', 1, 'TX', 0.02127659574468085, 0.02127659574468085],
#  ['Charleston',
#   1,
#   'SC',
#   8.327573428378704e-06,
#   8.327573428378704e-06,
#   1.0259461788634568e-05],
#  ['Charleston', 1, 'TN', 0.0015360983102918587, 0.0015360983102918587],
#  ['Charleston',
#   5,
#   'WV',
#   9.72762645914397e-05,
#   9.72762645914397e-05,
#   0.0003717472118959108],
#  ['CharlestonView', 1, 'CA'],
#  ['Charlotte', 15, 'NC', 2.0507940674629216e-05, 2.0507940674629216e-05],
#  ['Charlottesville', 1, 'VA', 2.3001725129384705e-05, 2.3001725129384705e-05],
#  ['Charlottte', 1, 'NC'],
#  ['ChathamCounty', 1, 'GA'],
#  ['Chatsworth', 1, 'CA'],
#  ['Chattanooga', 5, 'TN', 2.9819769314264586e-05, 2.9819769314264586e-05],
#  ['Chavies', 1, 'KY'],
#  ['CheathamCounty', 1, 'TN'],
#  ['Cheektowaga', 1, 'NY', 1.330176381388172e-05, 1.330176381388172e-05],
#  ['Cheney', 1, 'WA', 9.442870632672332e-05, 9.442870632672332e-05],
#  ['Chesapeake', 2, 'VA', 9.000535531864146e-06, 9.000535531864146e-06],
#  ['Chester',
#   3,
#   'PA',
#   8.830801836806782e-05,
#   8.830801836806782e-05,
#   0.0006537371976465461,
#   0.001185302252074279,
#   0.0033975084937712344,
#   0.0001625047397215752],
#  ['Chester',
#   1,
#   'SC',
#   0.00017834849295523454,
#   0.00017834849295523454,
#   0.0006793478260869565],
#  ['Chester',
#   1,
#   'VA',
#   4.7648544336970506e-05,
#   4.7648544336970506e-05,
#   0.0011918951132300357],
#  ['ChesterfieldCounty', 1, 'SC'],
#  ['Chestertown', 1, 'MD', 0.0001904036557501904],
#  ['Chetopa', 1, 'KS', 0.0008888888888888889, 0.0008888888888888889],
#  ['Cheyenne', 2, 'WY', 3.363266404331887e-05, 3.363266404331887e-05],
#  ['Chicago',
#   34,
#   'IL',
#   1.2613156709568712e-05,
#   1.2613156709568712e-05,
#   0.0011230017175320386,
#   0.0023767913317022022,
#   0.0010437772456560446,
#   0.008214544575984537,
#   0.0012552610204533707],
#  ['Chickasha', 4, 'OK', 0.0002494387627837366, 0.0002494387627837366],
#  ['Chico', 4, 'CA', 4.6410711592235485e-05, 4.6410711592235485e-05],
#  ['Childress', 1, 'TX', 0.0001638001638001638, 0.0001638001638001638],
#  ['Chinle', 1, 'AZ', 0.0002213368747233289, 0.0002213368747233289],
#  ['Chino',
#   3,
#   'CA',
#   3.846992293192106e-05,
#   3.846992293192106e-05,
#   4.01074880680223e-05],
#  ['ChinoHills', 1, 'CA', 1.3369162689340766e-05, 1.3369162689340766e-05],
#  ['Chowchilla', 1, 'CA', 5.341880341880342e-05, 5.341880341880342e-05],
#  ['ChristianCounty', 1, 'KY'],
#  ['ChulaVista', 2, 'CA', 8.199544105347743e-06, 8.199544105347743e-06],
#  ['ChurchHill', 2, 'TN', 0.00029686804215526197, 0.00029686804215526197],
#  ['Cincinnati', 7, 'OH', 2.3573547785265186e-05, 2.3573547785265186e-05],
#  ['CincoRanch', 2, 'TX', 0.00010944511327569225, 0.00010944511327569225],
#  ['Circleville', 1, 'OH', 7.51089079164789e-05, 7.51089079164789e-05],
#  ['Cisco', 1, 'TX', 0.00025647601949217746, 0.00025647601949217746],
#  ['Citra', 1, 'FL'],
#  ['Citronelle', 1, 'AL', 0.00025608194622279127, 0.00025608194622279127],
#  ['CitrusHeights', 4, 'CA', 4.801863122891682e-05, 4.801863122891682e-05],
#  ['CityTerrace', 1, 'CA'],
#  ['ClackamasCounty', 2, 'OR'],
#  ['ClaiborneCounty', 1, 'TN'],
#  ['Clanton', 2, 'AL', 0.00023204548091425919, 0.00023204548091425919],
#  ['Claremont', 1, 'NH', 7.487832272557094e-05, 7.487832272557094e-05],
#  ['Clarendon', 1, 'NY'],
#  ['ClarkCounty', 1, 'WI'],
#  ['Clarkesville', 1, 'GA', 0.0005770340450086555, 0.0005770340450086555],
#  ['Clarksburg', 1, 'WV', 6.032090722644468e-05, 6.032090722644468e-05],
#  ['Clarksdale', 1, 'MS', 5.5673087629439926e-05, 5.5673087629439926e-05],
#  ['Clarksville', 1, 'AR', 0.00010895619960775768, 0.00010895619960775768],
#  ['Clarksville', 1, 'IN', 4.603203829865586e-05],
#  ['Clarksville', 4, 'TN', 3.0091251720843456e-05, 3.0091251720843456e-05],
#  ['Clarksville',
#   1,
#   'TX',
#   0.00030441400304414006,
#   0.00030441400304414006,
#   0.0011560693641618498],
#  ['Clay',
#   1,
#   'AL',
#   0.00010300782859497322,
#   0.00010300782859497322,
#   0.001697792869269949,
#   0.0003324468085106383],
#  ['Claymont', 1, 'DE', 0.00012116806009935781, 0.00012116806009935781],
#  ['Clayton', 1, 'GA', 0.0004885197850512946, 0.0004885197850512946],
#  ['CleElum',
#   1,
#   'WA',
#   0.0005341880341880342,
#   0.0005341880341880342,
#   0.0018796992481203006],
#  ['ClearCreekCanyon', 1, 'CO'],
#  ['Clearfield', 1, 'UT', 3.320935175345377e-05, 3.320935175345377e-05],
#  ['ClearlakePark', 1, 'CA'],
#  ['Clearwater', 3, 'FL', 2.7859033291544782e-05, 2.7859033291544782e-05],
#  ['Clendenin', 1, 'WV', 0.0008149959250203749],
#  ['Clermont', 2, 'FL', 6.958458005705935e-05, 6.958458005705935e-05],
#  ['Cleveland',
#   6,
#   'OH',
#   1.5120396154379245e-05,
#   1.5120396154379245e-05,
#   0.00013009258255458468,
#   0.0003362663229277588],
#  ['Clinton', 1, 'IL', 0.0001384083044982699, 0.0001384083044982699],
#  ['Clinton', 1, 'LA', 0.0006049606775559589],
#  ['Clinton', 1, 'MD', 2.7800945232137893e-05, 2.7800945232137893e-05],
#  ['Clinton', 1, 'MO', 0.00011101243339253997, 0.00011101243339253997],
#  ['Clinton', 1, 'MS', 3.965736040609137e-05, 3.965736040609137e-05],
#  ['Clinton', 1, 'NC', 0.00011575413821044102, 0.00011575413821044102],
#  ['Clinton', 2, 'TN', 0.000203231378924906, 0.000203231378924906],
#  ['Clinton', 1, 'UT', 4.895721139723881e-05, 4.895721139723881e-05],
#  ['Cloverdale', 1, 'CA', 0.00011603620329542818, 0.00011603620329542818],
#  ['Clovis', 1, 'CA', 1.0456860223149397e-05, 1.0456860223149397e-05],
#  ['Clovis', 1, 'NM', 2.6472534745201854e-05, 2.6472534745201854e-05],
#  ['Clute', 1, 'TX', 8.91981090000892e-05, 8.91981090000892e-05],
#  ['CoalCounty', 1, 'OK'],
#  ['Coalinga', 1, 'CA', 7.473841554559044e-05, 7.473841554559044e-05],
#  ['CobbCounty', 2, 'GA'],
#  ['Cochran', 1, 'GA', 0.0001941747572815534, 0.0001941747572815534],
#  ['CochranCounty', 1, 'TX'],
#  ['CockeCounty', 1, 'TN'],
#  ['Cocoa',
#   2,
#   'FL',
#   0.00011668611435239207,
#   0.00011668611435239207,
#   0.0001780785326328911,
#   0.00033755274261603374],
#  ['CocoaBeach', 1, 'FL', 8.903926631644555e-05, 8.903926631644555e-05],
#  ["Coeurd'Alene", 2, 'ID', 4.531345583070893e-05, 4.531345583070893e-05],
#  ['Cofield', 1, 'NC', 0.002421307506053269],
#  ['Cohasset', 1, 'MN', 0.00037064492216456633, 0.00037064492216456633],
#  ['Colbert', 1, 'OK', 0.0008771929824561404],
#  ['Colby', 1, 'KS', 0.00018563207722294413, 0.00018563207722294413],
#  ['ColebrookTownship', 1, 'OH'],
#  ['Coleman', 1, 'FL', 0.001422475106685633, 0.001422475106685633],
#  ['Collierville', 1, 'TN', 2.274536563175253e-05],
#  ['ColoradoCity', 2, 'CO', 0.0009119927040583675, 0.0009119927040583675],
#  ['ColoradoSprings', 15, 'CO', 3.602071911763646e-05, 3.602071911763646e-05],
#  ['Colton', 2, 'CA', 3.8347969475016295e-05, 3.8347969475016295e-05],
#  ['Colton', 1, 'OR'],
#  ['Columbia', 1, 'MD', 1.0038648797871806e-05, 1.0038648797871806e-05],
#  ['Columbia', 3, 'MO', 2.7649769585253457e-05, 2.7649769585253457e-05],
#  ['Columbia', 1, 'TN', 2.8834232000230674e-05, 2.8834232000230674e-05],
#  ['ColumbiaHeights', 1, 'MN', 5.1292572835453425e-05, 5.1292572835453425e-05],
#  ['ColumbiaTownship', 1, 'MI'],
#  ['Columbua', 1, 'IN'],
#  ['Columbus', 3, 'GA', 1.5799036258788214e-05, 1.5799036258788214e-05],
#  ['Columbus',
#   3,
#   'MS',
#   0.0001269035532994924,
#   0.0001269035532994924,
#   0.0021849963583394027],
#  ['Columbus',
#   28,
#   'OH',
#   3.5576653075538126e-05,
#   3.5576653075538126e-05,
#   0.013102480112306972],
#  ['Commerce', 1, 'GA', 0.0001528117359413203, 0.0001528117359413203],
#  ['CommerceCity', 1, 'CO', 2.1780323655609524e-05, 2.1780323655609524e-05],
#  ['Compton', 3, 'CA', 3.1102586698460425e-05, 3.1102586698460425e-05],
#  ['Concord', 1, 'CA', 8.192222304144445e-06, 8.192222304144445e-06],
#  ['Concord', 1, 'VA', 0.0006858710562414266, 0.0006858710562414266],
#  ['ConeyIsland', 1, 'NY'],
#  ['Conroe', 3, 'TX', 5.3374134894230254e-05, 5.3374134894230254e-05],
#  ['Constantia', 1, 'NY', 0.0008460236886632825, 0.0008460236886632825],
#  ['Converse', 1, 'LA', 0.0022727272727272726],
#  ['Coolin', 1, 'ID'],
#  ['CoonRapids', 1, 'MN', 1.6266510508165787e-05, 1.6266510508165787e-05],
#  ['CoosBay', 1, 'OR', 6.262917266862904e-05, 6.262917266862904e-05],
#  ['CopperCenter', 1, 'AK', 0.003048780487804878, 0.003048780487804878],
#  ['CoralSprings', 1, 'FL', 8.257911078813503e-06, 8.257911078813503e-06],
#  ['Corning', 1, 'CA', 0.00013049719431032232, 0.00013049719431032232],
#  ['Corning', 1, 'WI'],
#  ['Corona',
#   1,
#   'CA',
#   6.56279942772389e-06,
#   6.56279942772389e-06,
#   5.287648054145516e-05],
#  ['CorpusChristi', 4, 'TX', 1.3105515783955572e-05, 1.3105515783955572e-05],
#  ['Cosby', 1, 'TN'],
#  ['Cottonwood',
#   2,
#   'AZ',
#   0.008849557522123894,
#   0.0001775410563692854,
#   0.008849557522123894,
#   0.0001775410563692854],
#  ['Cottonwood', 1, 'CA', 0.00030156815440289503, 0.00030156815440289503],
#  ['CottonwoodHeights',
#   1,
#   'UT',
#   2.9910567403463644e-05,
#   2.9910567403463644e-05],
#  ['Counce', 1, 'TN'],
#  ['Council', 1, 'ID', 0.0011918951132300357, 0.0011918951132300357],
#  ['CouncilBluffs', 1, 'IA', 1.606941989394183e-05, 1.606941989394183e-05],
#  ['Coushatta', 1, 'LA', 0.0005091649694501018],
#  ['Covina',
#   1,
#   'CA',
#   2.0922252908193154e-05,
#   2.0922252908193154e-05,
#   9.425248355294162e-06],
#  ['Covington', 2, 'GA', 0.00015246226558926666, 0.00015246226558926666],
#  ['Covington', 1, 'LA', 0.00011409013120365089, 0.00011409013120365089],
#  ['CranburyTownship', 1, 'NJ'],
#  ['Crandon', 2, 'WI', 0.0010416666666666667, 0.0010416666666666667],
#  ['CrawfordCounty', 1, 'OH'],
#  ['Crawfordsville', 1, 'IN', 6.283380458686774e-05, 6.283380458686774e-05],
#  ['CrenshawCounty', 1, 'AL'],
#  ['CrescentCity', 1, 'CA', 0.00013083867591259977, 0.00013083867591259977],
#  ['CrescentCity', 1, 'FL', 0.0006341154090044388, 0.0006341154090044388],
#  ['Creston', 1, 'IA', 0.00012764871074802145, 0.00012764871074802145],
#  ['Crestwood', 1, 'KY', 0.00022070183182520416, 0.00022070183182520416],
#  ['Crowell', 1, 'TX', 0.0010548523206751054, 0.0010548523206751054],
#  ['Crowley', 1, 'LA', 7.538635506973238e-05, 7.538635506973238e-05],
#  ['Crownpoint', 1, 'NM', 0.0004389815627743635, 0.0004389815627743635],
#  ['Crystal',
#   1,
#   'MN',
#   4.514468872737122e-05,
#   4.514468872737122e-05,
#   0.00039231071008238524],
#  ['CrystalSprings', 1, 'FL', 0.0007535795026375283, 0.0007535795026375283],
#  ['Culpeper', 1, 'VA', 6.105378838756945e-05],
#  ['CumberlandCounty', 1, 'KY'],
#  ['Cumming', 3, 'GA', 0.0005524861878453039, 0.0005524861878453039],
#  ['Cushing', 1, 'OK', 0.0001277791975466394, 0.0001277791975466394],
#  ['DadeCity',
#   1,
#   'FL',
#   0.00015535187199005747,
#   0.00015535187199005747,
#   0.00032123353678124],
#  ['Dadeville', 1, 'AL', 0.00030959752321981426, 0.00030959752321981426],
#  ['DakotaCity', 1, 'IA', 0.0011862396204033216, 0.0011862396204033216],
#  ['Dalhart', 1, 'TX', 0.00012610340479192938, 0.00012610340479192938],
#  ['Dallas', 1, 'NC', 0.0002228163992869875],
#  ['Dallas', 1, 'OR', 6.857299595419324e-05, 6.857299595419324e-05],
#  ['Dallas',
#   15,
#   'TX',
#   1.25227914804945e-05,
#   1.25227914804945e-05,
#   0.00211118930330753],
#  ['Dalton', 1, 'IL', 0.001838235294117647],
#  ['Danbury', 1, 'CT', 1.2362009073714661e-05, 1.2362009073714661e-05],
#  ['Danville', 1, 'CA', 2.378743547658127e-05],
#  ['Danville', 1, 'IL', 3.0278257183516515e-05, 3.0278257183516515e-05],
#  ['Danville', 2, 'VA', 4.645221228661015e-05, 4.645221228661015e-05],
#  ['DarlingtonCounty', 2, 'SC'],
#  ['Davenport', 2, 'IA', 2.006319907709284e-05, 2.006319907709284e-05],
#  ['DavidsonCounty', 1, 'NC'],
#  ['Davidsonville', 1, 'MD'],
#  ['Davie', 1, 'FL', 1.0870510479172103e-05],
#  ['DaviessCounty', 1, 'KY'],
#  ['Dayton', 5, 'OH', 3.532894783327563e-05, 3.532894783327563e-05],
#  ['DeKalbCounty', 1, 'GA'],
#  ['DeLand',
#   3,
#   'FL',
#   0.00011098368539824646,
#   0.00011098368539824646,
#   0.0028517110266159697,
#   0.0020689655172413794,
#   0.0008486562942008486],
#  ['DeRidder', 1, 'LA', 9.453582907922102e-05, 9.453582907922102e-05],
#  ['DeSoto', 1, 'TX', 2.038860684649418e-05, 2.038860684649418e-05],
#  ['Dearborn',
#   2,
#   'MI',
#   2.03763512067894e-05,
#   2.03763512067894e-05,
#   3.461764807698965e-05],
#  ['DearbornCounty', 1, 'IN'],
#  ['DearbornHeights', 1, 'MI', 1.7308824038494823e-05, 1.7308824038494823e-05],
#  ['Decatur',
#   1,
#   'GA',
#   5.17196793379881e-05,
#   5.17196793379881e-05,
#   5.9887411666067796e-05],
#  ['DecaturCounty', 1, 'TN'],
#  ['DeerPark', 1, 'AL', 0.005319148936170213, 0.005319148936170213],
#  ['DeerPark', 1, 'WA', 0.0002738225629791895, 0.0002738225629791895],
#  ['Deerfield', 1, 'IL', 5.486968449931413e-05],
#  ['Defiance', 1, 'OH', 6.062810719049351e-05, 6.062810719049351e-05],
#  ['DelCity', 1, 'OK', 4.687792987061691e-05, 4.687792987061691e-05],
#  ['DelMar', 1, 'CA', 0.0002403268445085316, 0.0002403268445085316],
#  ['DelRio', 1, 'TX', 2.8096990812284005e-05, 2.8096990812284005e-05],
#  ['Deland', 1, 'FL'],
#  ['Delano', 3, 'CA', 5.656001960747346e-05, 5.656001960747346e-05],
#  ['Delaware', 1, 'OH', 2.8774494288262883e-05, 2.8774494288262883e-05],
#  ['Delhi', 1, 'CA', 9.298000929800093e-05, 9.298000929800093e-05],
#  ['DelrayBeach', 2, 'FL', 3.304583457255213e-05, 3.304583457255213e-05],
#  ['Deltona', 4, 'FL', 4.6958277570378716e-05, 4.6958277570378716e-05],
#  ['Deming', 1, 'NM', 6.731740154830023e-05, 6.731740154830023e-05],
#  ['Demopolis', 1, 'AL', 0.00013363624214887077, 0.00013363624214887077],
#  ['DenhamSprings', 2, 'LA', 0.0001957905041605482, 0.0001957905041605482],
#  ['Denton', 2, 'TX', 1.763932864715169e-05, 1.763932864715169e-05],
#  ['DentonCounty', 1, 'TX'],
#  ['Denver', 26, 'CO', 4.332192522635706e-05, 4.332192522635706e-05],
#  ['Deptford', 1, 'NJ'],
#  ['Derry', 1, 'NH', 4.542357483533954e-05, 4.542357483533954e-05],
#  ['DesMoines',
#   4,
#   'IA',
#   1.966249330246322e-05,
#   1.966249330246322e-05,
#   7.06601423801869e-05],
#  ['DesMoines', 2, 'WA', 6.74013412866916e-05, 6.74013412866916e-05],
#  ['DesertHotSprings', 2, 'CA', 7.710694733595497e-05, 7.710694733595497e-05],
#  ['Desha', 1, 'AR'],
#  ['Detroit',
#   9,
#   'MI',
#   1.2608980115638357e-05,
#   1.2608980115638357e-05,
#   0.004312410158121706],
#  ["Devil'sLake", 1, 'ND'],
#  ['Dickson', 1, 'TN', 6.878525244187646e-05, 6.878525244187646e-05],
#  ['Dilley', 1, 'TX', 0.00025680534155110427, 0.00025680534155110427],
#  ['Dillon', 1, 'MT', 0.00024189646831156264, 0.00024189646831156264],
#  ['Dinosaur', 1, 'CO', 0.0029498525073746312],
#  ['Dinuba', 1, 'CA', 4.6613527245606674e-05, 4.6613527245606674e-05],
#  ['DistrictHeights', 1, 'MD', 0.00017132088401576153, 0.00017132088401576153],
#  ['Dolton', 1, 'IL', 4.31909471774716e-05],
#  ['Douglas', 1, 'AZ', 5.7544021176199794e-05, 5.7544021176199794e-05],
#  ['Douglas',
#   1,
#   'GA',
#   8.628872206402623e-05,
#   8.628872206402623e-05,
#   3.2298698362455994e-05],
#  ['Douglas', 2, 'WY', 0.000326797385620915, 0.000326797385620915],
#  ['DouglasCity', 1, 'CA', 0.001402524544179523, 0.001402524544179523],
#  ['Douglasville', 2, 'GA', 6.459739672491199e-05, 6.459739672491199e-05],
#  ['Dover', 1, 'AR', 0.000725689404934688, 0.000725689404934688],
#  ['Dover',
#   1,
#   'DE',
#   2.7741559630482425e-05,
#   2.7741559630482425e-05,
#   0.0002898550724637681],
#  ['DoverTownship', 1, 'PA'],
#  ['Downey', 1, 'CA', 8.946784525641484e-06, 8.946784525641484e-06],
#  ['Draper', 1, 'UT', 2.3655201778871172e-05, 2.3655201778871172e-05],
#  ['Duarte', 1, 'CA', 4.690211528539937e-05, 4.690211528539937e-05],
#  ['Dublin', 1, 'NC', 0.0029585798816568047],
#  ['Dumas', 1, 'TX', 6.806888571234089e-05, 6.806888571234089e-05],
#  ['Dundalk', 1, 'MD', 1.572401213893737e-05, 1.572401213893737e-05],
#  ['Dundee', 1, 'FL', 0.0002690341673392521],
#  ['Dunsmuir', 2, 'CA', 0.0012121212121212121, 0.0012121212121212121],
#  ['Dunwoody', 1, 'GA', 2.161367713489096e-05, 2.161367713489096e-05],
#  ['Durham', 1, 'CA', 0.0001812250815512867, 0.0001812250815512867],
#  ['Durham', 6, 'NC', 2.6277755879647878e-05, 2.6277755879647878e-05],
#  ['Dyer', 1, 'IN', 6.101281269066504e-05],
#  ['Dyersburg', 1, 'TN', 5.832604257801108e-05, 5.832604257801108e-05],
#  ['Eagan', 2, 'MN', 3.114973678472417e-05, 3.114973678472417e-05],
#  ['Eagar', 3, 'AZ', 0.0006141248720573184],
#  ['EagleMountain', 1, 'UT', 4.669624095260332e-05, 4.669624095260332e-05],
#  ['EastBatonRouge', 2, 'LA'],
#  ['EastBernstadt', 1, 'KY', 0.0013966480446927375, 0.0013966480446927375],
#  ['EastFlatRock', 1, 'NC', 0.0002002002002002002, 0.0002002002002002002],
#  ['EastHartford', 2, 'CT', 3.9022867400296575e-05, 3.9022867400296575e-05],
#  ['EastHollywood', 1, 'CA'],
#  ['EastLosAngeles', 1, 'CA', 7.905388312673918e-06, 7.905388312673918e-06],
#  ['EastPoint', 3, 'GA', 8.89890840056953e-05, 8.89890840056953e-05],
#  ['EastRidge', 1, 'TN', 4.7666714333381e-05, 4.7666714333381e-05],
#  ['EastSt.Louis', 1, 'IL', 3.7028808412945274e-05, 3.7028808412945274e-05],
#  ['EastStroudsburg', 1, 'PA', 0.0001016260162601626],
#  ['EastTroy', 1, 'WI', 0.000233590282644242],
#  ['EastWenatchee', 1, 'WA', 7.581501137225171e-05, 7.581501137225171e-05],
#  ['Eastaboga', 1, 'AL'],
#  ['EatonCounty', 1, 'MI'],
#  ['EatonRapidsTownship', 1, 'MI'],
#  ['EauClaire', 4, 'WI', 6.071368941912178e-05, 6.071368941912178e-05],
#  ['EbeyIsland', 1, 'WA'],
#  ['Eclectic', 1, 'AL', 0.000999000999000999],
#  ['Eden', 1, 'GA'],
#  ['Edgewater', 1, 'FL', 4.819277108433735e-05, 4.819277108433735e-05],
#  ['Edgewood', 1, 'NM', 0.0002677376171352075],
#  ['Edinburg', 1, 'NY'],
#  ['Edinburg', 2, 'TX', 2.5940337224383918e-05, 2.5940337224383918e-05],
#  ['Edmond', 2, 'OK', 2.4568515447454087e-05, 2.4568515447454087e-05],
#  ['Edmonton', 1, 'KY', 0.0006269592476489029, 0.0006269592476489029],
#  ['Edmund', 1, 'SC'],
#  ['Efland', 1, 'NC', 0.0013623978201634877, 0.0013623978201634877],
#  ['Ehrenberg', 1, 'AZ', 0.0006802721088435374, 0.0006802721088435374],
#  ['ElCajon', 2, 'CA', 2.010494782766039e-05, 2.010494782766039e-05],
#  ['ElCerrito',
#   1,
#   'CA',
#   4.2464648180389826e-05,
#   0.000196078431372549,
#   4.2464648180389826e-05,
#   0.000196078431372549],
#  ['ElMonte',
#   2,
#   'CA',
#   1.762502753910553e-05,
#   1.762502753910553e-05,
#   0.0005372011818426001,
#   9.942334460131238e-05],
#  ['ElPaso', 11, 'TX', 1.6945993119926795e-05, 1.6945993119926795e-05],
#  ['ElSereno', 1, 'CA'],
#  ['Elberton', 1, 'GA', 0.0002149151085321298, 0.0002149151085321298],
#  ['Eldorado', 1, 'NM', 0.0001631321370309951],
#  ['EldoradoSprings', 1, 'CO', 0.0017094017094017094, 0.0017094017094017094],
#  ['Elgin',
#   1,
#   'IL',
#   9.24316929788886e-06,
#   9.24316929788886e-06,
#   4.5485558335228565e-05],
#  ['Elizabethon', 1, 'TN'],
#  ['Elizabethton', 1, 'TN', 7.054176072234762e-05, 7.054176072234762e-05],
#  ['Elizabethtown', 3, 'KY', 0.00010514878553152712, 0.00010514878553152712],
#  ['ElkGrove', 2, 'CA', 1.3070613992092278e-05, 1.3070613992092278e-05],
#  ['ElkPlain', 1, 'WA', 7.039774727208729e-05, 7.039774727208729e-05],
#  ['Elkhart', 2, 'IN', 3.925494121572553e-05, 3.925494121572553e-05],
#  ['Elkhorn', 1, 'WI', 9.916699722332408e-05, 9.916699722332408e-05],
#  ['Elkins', 1, 'WV', 0.000140964195094446, 0.000140964195094446],
#  ['Elko', 1, 'NV', 5.465376837732962e-05, 5.465376837732962e-05],
#  ['Elkridge', 1, 'MD', 6.413134098634002e-05, 6.413134098634002e-05],
#  ['Elkton', 3, 'MD', 0.0001942627727773101],
#  ['EllisCounty', 2, 'TX'],
#  ['Elmira',
#   1,
#   'NY',
#   3.424657534246575e-05,
#   3.424657534246575e-05,
#   0.000244081034903588,
#   0.00020132876988121604],
#  ['Elsmere', 1, 'KY', 0.00011832919181161993, 0.00011832919181161993],
#  ['Elyria', 1, 'OH', 1.8337520400491445e-05, 1.8337520400491445e-05],
#  ['Emeryville', 2, 'CA', 0.0001984126984126984, 0.0001984126984126984],
#  ['Emporia', 1, 'VA', 0.00016871941960519654, 0.00016871941960519654],
#  ['Encinitas', 1, 'CA', 1.680163984004839e-05, 1.680163984004839e-05],
#  ['England', 1, 'AR', 0.00035398230088495576, 0.00035398230088495576],
#  ['Englewood', 1, 'CO', 3.305238803503553e-05, 3.305238803503553e-05],
#  ['Englewood', 2, 'FL', 0.00013456233600215298, 0.00013456233600215298],
#  ['Englewood', 1, 'OH', 7.426661715558857e-05, 7.426661715558857e-05],
#  ['English', 1, 'IN', 0.0015503875968992248],
#  ['Enid',
#   1,
#   'OK',
#   2.025152392717552e-05,
#   2.025152392717552e-05,
#   0.0011627906976744186],
#  ['Enoree', 1, 'SC', 0.0015037593984962407, 0.0015037593984962407],
#  ['Epping', 1, 'NH', 0.000594883997620464, 0.000594883997620464],
#  ['Erie',
#   1,
#   'PA',
#   9.824533825869962e-06,
#   9.824533825869962e-06,
#   0.0006138735420503376],
#  ['Ernul', 1, 'NC'],
#  ['Escalon', 1, 'CA', 0.00014021312394840157, 0.00014021312394840157],
#  ['Escondido', 1, 'CA', 6.948739151281e-06, 6.948739151281e-06],
#  ['Essex', 1, 'MD', 2.5469920024451123e-05, 2.5469920024451123e-05],
#  ['EstillSprings', 1, 'TN', 0.00048661800486618007],
#  ['Euclid',
#   1,
#   'OH',
#   2.044153720359771e-05,
#   2.044153720359771e-05,
#   4.485310607759587e-05],
#  ['Eufaula', 1, 'AL', 7.61208799573723e-05, 7.61208799573723e-05],
#  ['Eufaula', 1, 'OK', 0.00035549235691432633, 0.00035549235691432633],
#  ['Eugene', 5, 'OR', 3.201331754009668e-05, 3.201331754009668e-05],
#  ['Euless', 2, 'TX', 3.9003841878425025e-05, 3.9003841878425025e-05],
#  ['Eureka',
#   1,
#   'CA',
#   3.677687470118789e-05,
#   3.677687470118789e-05,
#   0.0029498525073746312],
#  ['Eustis', 2, 'FL', 0.00010777023386140747, 0.00010777023386140747],
#  ['EvangelineParish', 1, 'LA'],
#  ['Evans', 2, 'CO', 0.00010789232346118574, 0.00010789232346118574],
#  ['Evansville', 4, 'IN', 3.406313602261792e-05, 3.406313602261792e-05],
#  ['Everett', 1, 'MA', 2.3999808001535988e-05, 2.3999808001535988e-05],
#  ['Everett', 1, 'WA', 9.706947262155525e-06, 9.706947262155525e-06],
#  ['Everton', 1, 'MO', 0.003134796238244514, 0.003134796238244514],
#  ['FairOaks',
#   2,
#   'CA',
#   6.469979296066253e-05,
#   6.469979296066253e-05,
#   0.00013617484850548105],
#  ['Fairbanks', 9, 'AK', 0.0002853971777390201, 0.0002853971777390201],
#  ['Fairborn', 1, 'OH', 3.0909990108803164e-05, 3.0909990108803164e-05],
#  ['Fairchance', 1, 'PA', 0.0005063291139240507],
#  ['Fairchild', 1, 'WI', 0.0018181818181818182],
#  ['Fairfax', 1, 'OK', 0.0007246376811594203],
#  ['Fairfax',
#   1,
#   'VA',
#   4.4316419233325945e-05,
#   4.4316419233325945e-05,
#   8.312551953449709e-05],
#  ['Fairfield', 1, 'CA', 9.494782616951985e-06, 9.494782616951985e-06],
#  ['Fairfield', 1, 'CT'],
#  ['Fairfield',
#   1,
#   'OH',
#   2.3523876734885908e-05,
#   2.3523876734885908e-05,
#   0.0007739938080495357,
#   0.0017857142857142857],
#  ['Fairfield', 2, 'TX', 0.0006777363605557439, 0.0006777363605557439],
#  ['Fairhope', 1, 'AL', 6.524859715516116e-05, 6.524859715516116e-05],
#  ['Fairland', 1, 'OK', 0.000946073793755913],
#  ['Fairmont', 1, 'MN', 9.375585974123383e-05, 9.375585974123383e-05],
#  ['Fairmont', 1, 'WV', 5.3464499572284e-05, 5.3464499572284e-05],
#  ['Fairview', 1, 'OH', 0.012048192771084338, 5.943183168905266e-05],
#  ['Fairview', 2, 'TN', 0.00025906735751295336, 0.00025906735751295336],
#  ['FalconHeights', 1, 'MN', 0.00018793459875963165, 0.00018793459875963165],
#  ['FallRiver', 1, 'MA', 1.1254037385912196e-05, 1.1254037385912196e-05],
#  ['FallsChurch',
#   1,
#   'VA',
#   8.10898475510866e-05,
#   8.10898475510866e-05,
#   3.42383675146369e-05],
#  ['FarmersBranch', 1, 'TX', 3.49454850433324e-05, 3.49454850433324e-05],
#  ['Farmington', 1, 'AR', 0.00016739203213927018, 0.00016739203213927018],
#  ['Farmington', 3, 'NM', 6.53922444798047e-05, 6.53922444798047e-05],
#  ['Farmville', 1, 'VA', 0.00012171372930866602],
#  ['Fayetteville', 2, 'AR', 2.718129926610492e-05, 2.718129926610492e-05],
#  ['Fayetteville', 3, 'NC', 1.4957818950559422e-05, 1.4957818950559422e-05],
#  ['FederalHeights', 1, 'CO', 8.720676724513822e-05, 8.720676724513822e-05],
#  ['FederalWay', 4, 'WA', 4.4789823752043534e-05, 4.4789823752043534e-05],
#  ['Fife',
#   1,
#   'WA',
#   0.00010901558922925978,
#   0.00010901558922925978,
#   0.0004679457182966776],
#  ['Findlay', 1, 'OH', 2.4270666472501336e-05, 2.4270666472501336e-05],
#  ['FinneyCounty', 1, 'KS'],
#  ['Fishers', 1, 'IN', 1.3021850665416569e-05],
#  ['Fisty', 1, 'KY'],
#  ['Flagstaff', 9, 'AZ', 0.0001366327614999241, 0.0001366327614999241],
#  ['Flatwoods', 2, 'KY', 0.000269432843863667, 0.000269432843863667],
#  ['Fletcher', 1, 'NC', 0.00013914011409489355],
#  ['Flint', 2, 'MI', 1.9524767167151533e-05, 1.9524767167151533e-05],
#  ['FloralCity', 2, 'FL', 0.00038336208548974505, 0.00038336208548974505],
#  ['Florence', 1, 'AZ', 3.9160401002506263e-05],
#  ['Florence', 2, 'CA', 3.155221102118731e-05],
#  ['Florence', 1, 'MS', 0.0002414875633904854],
#  ['Florence', 1, 'OR', 0.00011811953697141507, 0.00011811953697141507],
#  ['Florence', 1, 'SC', 2.6986183074265975e-05, 2.6986183074265975e-05],
#  ['FloridaCity', 1, 'FL', 8.89284126278346e-05, 8.89284126278346e-05],
#  ['Florissant', 1, 'MO', 1.9172514283523142e-05, 1.9172514283523142e-05],
#  ['FloydCounty', 2, 'GA'],
# ...
#  ['FortDodge', 1, 'IA', 3.967309370784734e-05, 3.967309370784734e-05],
#  ['FortLauderdale', 2, 'FL', 1.2083058947203073e-05, 1.2083058947203073e-05],
#  ['FortLittleton', 1, 'PA'],
#  ['FortLupton', 1, 'CO', 0.00013555645926528398, 0.00013555645926528398],
#  ['FortMadison', 1, 'IA', 9.04895484571532e-05, 9.04895484571532e-05],
#  ['FortMeade', 1, 'MD', 0.00010721561059290233, 0.00010721561059290233],
#  ['FortMorgan', 1, 'CO', 8.837825894829872e-05, 8.837825894829872e-05],
#  ['FortMyers',
#   1,
#   'FL',
#   1.6051879675109956e-05,
#   1.6051879675109956e-05,
#   0.00015931177314003505,
#   0.00018224895206852561,
#   2.537620219757911e-05],
#  ['FortPierce',
#   5,
#   'FL',
#   0.00012022120702091849,
#   0.00012022120702091849,
#   0.0007723200494284832,
#   0.0009877518767285659],
#  ['FortSmith', 1, 'AR', 1.1599716966906008e-05, 1.1599716966906008e-05],
#  ['FortSmith', 1, 'OK'],
#  ['FortStockton', 1, 'TX', 0.00012072920439454304, 0.00012072920439454304],
#  ['FortSumner', 1, 'NM', 0.0009699321047526673],
#  ['FortValley', 1, 'GA', 0.00010188487009679063, 0.00010188487009679063],
#  ['FortWaltonBeach', 2, 'FL', 0.00010252729789306403, 0.00010252729789306403],
#  ['FortWashington', 1, 'MD', 4.216384871611081e-05, 4.216384871611081e-05],
#  ['FortWayne', 4, 'IN', 1.5767212869199145e-05, 1.5767212869199145e-05],
#  ['FortWorth', 14, 'TX', 1.888813636155131e-05, 1.888813636155131e-05],
#  ['Fountain', 1, 'CO', 3.869070649230055e-05, 3.869070649230055e-05],
#  ['FountainInn', 2, 'SC', 0.00025644313373509426, 0.00025644313373509426],
#  ['FountainValley', 1, 'CA', 1.8078932619818126e-05, 1.8078932619818126e-05],
#  ['FoxCrossing', 1, 'WI'],
#  ['Frametown', 1, 'WV'],
#  ['Franklin',
#   1,
#   'LA',
#   0.00013054830287206266,
#   0.00013054830287206266,
#   0.00025926886180969663],
#  ['Franklin',
#   2,
#   'NC',
#   0.0005201560468140442,
#   0.0009886307464162135,
#   0.001718213058419244],
#  ['Franklin', 1, 'TN', 1.6003328692368014e-05, 1.6003328692368014e-05],
#  ['Franklin', 1, 'WI', 2.820794900002821e-05, 2.820794900002821e-05],
#  ['FranklinCounty', 1, 'MO'],
#  ['FranklinCounty', 1, 'OH'],
#  ['FranklinTownship', 1, 'PA'],
#  ['Franklinton', 1, 'OH'],
#  ['Frederica', 1, 'DE', 0.0012919896640826874],
#  ['Frederick',
#   1,
#   'MD',
#   1.5328254571651926e-05,
#   1.5328254571651926e-05,
#   0.0003940110323089047],
#  ['Fredericksburg', 1, 'VA', 4.117598616486865e-05, 4.117598616486865e-05],
#  ['Frederickstown', 1, 'WA'],
#  ['Fredonia', 1, 'NY', 8.904719501335708e-05],
#  ['Freeport', 1, 'TX', 8.299443937256204e-05, 8.299443937256204e-05],
#  ['Fremont', 5, 'CA', 2.3354773014961067e-05, 2.3354773014961067e-05],
#  ['FrenchLick', 1, 'IN', 0.0005534034311012728],
#  ['Fresno', 17, 'CA', 3.4366692610150306e-05, 3.4366692610150306e-05],
#  ['Fridley', 1, 'MN', 3.675389591296677e-05, 3.675389591296677e-05],
#  ['FriendlyHills', 1, 'CO'],
#  ['Friendswood', 1, 'TX', 2.7929060187124703e-05, 2.7929060187124703e-05],
#  ['Fritch', 1, 'TX', 0.0004723665564478035, 0.0004723665564478035],
#  ['FruitlandPark', 1, 'FL', 0.0002452182442373713, 0.0002452182442373713],
#  ['Ft.Lauderdale', 1, 'FL'],
#  ['Fullerton', 3, 'CA', 2.2195751733118283e-05, 2.2195751733118283e-05],
#  ['Fulshear', 1, 'TX', 0.0008818342151675485, 0.0008818342151675485],
#  ['Fulton', 1, 'KY', 0.00040899795501022495, 0.00040899795501022495],
#  ['Fuqua', 1, 'TX'],
#  ['Gadsden', 1, 'AL', 2.7132624267419144e-05, 2.7132624267419144e-05],
#  ['Gainesville', 2, 'FL', 1.6083117551506183e-05, 1.6083117551506183e-05],
#  ['Gainesville', 3, 'GA', 8.874689385871494e-05, 8.874689385871494e-05],
#  ['Gallatin', 1, 'TN', 3.3027280533720854e-05, 3.3027280533720854e-05],
#  ['Gallup', 1, 'NM', 4.612971676353907e-05, 4.612971676353907e-05],
#  ['Galveston', 1, 'TX', 2.0945478918375467e-05, 2.0945478918375467e-05],
#  ['GardenCity', 1, 'ID', 9.11410864017499e-05, 9.11410864017499e-05],
#  ['GardenGrove', 1, 'CA', 5.851957187081219e-06, 5.851957187081219e-06],
#  ['Gardena', 3, 'CA', 5.099525744105798e-05, 5.099525744105798e-05],
#  ['Gardner', 1, 'KS', 5.2293050253621294e-05, 5.2293050253621294e-05],
#  ['GardnervilleRanchos', 1, 'NV', 8.84016973125884e-05, 8.84016973125884e-05],
#  ['Garland', 6, 'TX', 2.6446164424619615e-05, 2.6446164424619615e-05],
#  ['Gary', 5, 'IN', 6.227115351084763e-05, 6.227115351084763e-05],
#  ['GastonCounty', 1, 'NC'],
#  ['Gastonia', 3, 'NC', 4.181709203941958e-05, 4.181709203941958e-05],
#  ['Gautier', 1, 'MS', 5.384449709239716e-05, 5.384449709239716e-05],
#  ['GeneseeTownship', 1, 'MI'],
#  ['Geneva', 2, 'WI', 0.0011961722488038277, 0.00026140373807345446],
#  ['GenevaTownship', 1, 'OH'],
#  ['Georgetown', 2, 'KY', 6.873324627122139e-05, 6.873324627122139e-05],
#  ['Germantown', 1, 'PA'],
#  ['Gerrardstown', 1, 'WV'],
#  ['Gibson', 1, 'LA'],
#  ['GibsonCounty', 1, 'TN'],
#  ['Gifford', 1, 'FL', 0.00010427528675703858, 0.00010427528675703858],
#  ['Gilbert', 3, 'AZ', 1.4391733388341736e-05],
#  ['Gilbert', 1, 'MN', 0.0005558643690939411, 0.0005558643690939411],
#  ['Gillette', 1, 'WY', 3.437961976140544e-05, 3.437961976140544e-05],
#  ['Gilmer', 1, 'TX', 0.00020387359836901122, 0.00020387359836901122],
#  ['Gilroy', 1, 'CA', 2.048298887773704e-05, 2.048298887773704e-05],
#  ['Girard', 1, 'OH', 0.0001004217714400482, 0.0001004217714400482],
#  ['GladeSpring', 1, 'VA', 0.0006868131868131869],
#  ['Gladewater', 1, 'TX', 0.0001552553951249806, 0.0001552553951249806],
#  ['GlenBurnie', 1, 'MD', 1.4784369964073982e-05, 1.4784369964073982e-05],
#  ['GlenValley', 1, 'CA'],
#  ['Glendale', 9, 'AZ', 3.969636690028714e-05, 3.969636690028714e-05],
#  ['Glendale', 1, 'CA', 5.2159671185432845e-06, 5.2159671185432845e-06],
#  ['Glendora', 1, 'CA', 1.9970842569848022e-05, 1.9970842569848022e-05],
#  ['Glennville', 1, 'GA', 0.0002801905295601009, 0.0002801905295601009],
#  ['Glenoma', 1, 'WA'],
#  ['Glenville', 1, 'NY', 0.00015114873035066505],
#  ['Glenwood', 1, 'GA', 0.0013386880856760374, 0.0013386880856760374],
#  ['Golden', 1, 'CO', 5.300259712725924e-05, 5.300259712725924e-05],
#  ['GoldenShores', 1, 'AZ', 0.0004885197850512946, 0.0004885197850512946],
#  ['GoldenValley', 1, 'AZ', 0.00011947431302270011, 0.00011947431302270011],
#  ['Goleta', 1, 'CA', 3.345824411134904e-05, 3.345824411134904e-05],
#  ['Gonic', 1, 'NH'],
#  ['GonzalesCounty', 1, 'TX'],
#  ['Goodbee', 1, 'LA'],
#  ['Gooding', 1, 'ID', 0.0002803476310625175, 0.0002803476310625175],
#  ['Goodyear',
#   1,
#   'AZ',
#   1.5319800842589045e-05,
#   1.5319800842589045e-05,
#   0.002188183807439825],
#  ['GooseCreek', 1, 'SC', 2.7825699816350382e-05, 2.7825699816350382e-05],
#  ['Gordo',
#   1,
#   'AL',
#   0.0005714285714285715,
#   0.0030120481927710845,
#   0.003067484662576687],
#  ['Gorham', 1, 'ME', 0.00014530659691950015, 0.00014530659691950015],
#  ['Goshen',
#   1,
#   'IN',
#   3.152684510860998e-05,
#   3.152684510860998e-05,
#   0.002564102564102564],
#  ['Grafton', 1, 'WV', 0.00019364833462432224, 0.00019364833462432224],
#  ['Graham', 1, 'WA', 4.256949470009791e-05, 4.256949470009791e-05],
#  ['GrandCanyonCaverns', 1, 'AZ'],
#  ['GrandForks',
#   2,
#   'ND',
#   3.785154623566373e-05,
#   3.785154623566373e-05,
#   0.0008449514152936206],
#  ['GrandIsland', 1, 'NE', 2.0610057708161584e-05, 2.0610057708161584e-05],
#  ['GrandJunction', 4, 'CO', 6.8299013079261e-05, 6.8299013079261e-05],
#  ['GrandPrairie', 1, 'TX', 5.7013842961070946e-06, 5.7013842961070946e-06],
#  ['GrandPrarie', 1, 'TX'],
#  ['GrandRapids',
#   1,
#   'MI',
#   5.3180174430972136e-06,
#   9.35103796521414e-05,
#   5.3180174430972136e-06],
#  ['GrandTerrace', 1, 'CA', 8.305647840531562e-05, 8.305647840531562e-05],
#  ['Grandview', 1, 'MO', 4.0858018386108277e-05, 4.0858018386108277e-05],
#  ['GraniteFalls', 1, 'NC', 0.00021177467174925878],
#  ['Grant', 1, 'OK', 0.0034602076124567475, 0.0034602076124567475],
#  ['Grant-Valkaria', 1, 'FL', 0.00025974025974025974],
#  ['GrantsPass', 1, 'OR', 2.895780847305476e-05, 2.895780847305476e-05],
#  ['Grapeview', 1, 'WA', 0.0010482180293501049, 0.0010482180293501049],
#  ['GrassValley', 1, 'CA', 7.776049766718506e-05, 7.776049766718506e-05, 0.5],
#  ['Gray',
#   1,
#   'TN',
#   0.0008183306055646482,
#   0.0008183306055646482,
#   0.0006657789613848203],
#  ['GraysonCounty', 1, 'VA'],
#  ['GreatFalls', 3, 'MT', 5.127766857533544e-05, 5.127766857533544e-05],
#  ['Greece', 2, 'NY', 0.00013775053378331842, 0.00013775053378331842],
#  ['Greeley', 5, 'CO', 5.382768680898707e-05, 5.382768680898707e-05],
#  ['Green',
#   1,
#   'OH',
#   3.89120199229542e-05,
#   3.33022512321833e-05,
#   3.89120199229542e-05,
#   0.00267379679144385,
#   0.0002155636990730761,
#   0.00027662517289073305,
#   0.0004297378599054577,
#   0.0007309941520467836,
#   0.0002628811777076761,
#   7.560293339381567e-05,
#   0.0006775067750677507],
#  ['GreenBay', 1, 'WI', 9.610117531737412e-06, 9.610117531737412e-06],
#  ['Greenback', 1, 'TN', 0.0009398496240601503, 0.0009398496240601503],
#  ['Greenbelt', 1, 'MD', 4.3350095370209814e-05, 4.3350095370209814e-05],
#  ['GreeneCounty', 1, 'MO'],
#  ['Greeneville', 1, 'TN', 6.639224538573895e-05],
#  ['Greenfield', 1, 'WI', 2.7233115468409585e-05, 2.7233115468409585e-05],
#  ['Greenport', 1, 'NY', 0.0004551661356395084, 0.00047080979284369113],
#  ['Greensboro', 2, 'NC', 7.416581994022235e-06, 7.416581994022235e-06],
#  ['Greensburg',
#   1,
#   'PA',
#   6.715014773032501e-05,
#   6.715014773032501e-05,
#   0.0004723665564478035,
#   0.0004640371229698376],
#  ['Greenspoint', 1, 'TX'],
#  ['Greenville', 3, 'MS', 8.72093023255814e-05, 8.72093023255814e-05],
#  ['Greenville', 4, 'NC', 4.730704638455898e-05, 4.730704638455898e-05],
#  ['Greenville', 3, 'SC', 5.13619476450547e-05, 5.13619476450547e-05],
#  ['GreenvilleCounty', 2, 'SC'],
#  ['Greenwood', 1, 'IN', 2.0083950914823965e-05, 2.0083950914823965e-05],
#  ['Grenada', 1, 'MS', 7.638252367858234e-05, 7.638252367858234e-05],
#  ['Gresham', 2, 'OR', 1.8940470102467945e-05, 1.8940470102467945e-05],
#  ['Gretna', 1, 'LA', 5.638249887235002e-05, 5.638249887235002e-05],
#  ['Griffin',
#   1,
#   'GA',
#   4.229581694370427e-05,
#   0.0006891798759476223,
#   4.229581694370427e-05],
#  ['GroverBeach', 1, 'CA', 7.601094557616297e-05, 7.601094557616297e-05],
#  ['Groveton', 1, 'TX', 0.000946073793755913, 0.000946073793755913],
#  ['Grundy', 1, 'VA', 0.0009794319294809011],
#  ['GuadalupeCounty', 1, 'TX'],
#  ['Gulfport', 4, 'MS', 5.90031419173071e-05, 5.90031419173071e-05],
#  ['Gunlock', 1, 'KY'],
#  ['GunnisonCounty', 1, 'CO'],
#  ['Gurnee', 1, 'IL', 3.195398625978591e-05],
#  ['Guthrie', 2, 'OK', 0.00019625159454420566, 0.00019625159454420566],
#  ['Habersham', 1, 'GA'],
#  ['HaciendaHeights', 1, 'CA', 1.8505496132351307e-05, 1.8505496132351307e-05],
#  ['Hackensack', 2, 'NJ', 4.650081376424087e-05, 4.650081376424087e-05],
#  ['Hackett', 1, 'AR', 0.0012315270935960591, 0.0012315270935960591],
#  ['HallCounty', 2, 'GA'],
#  ['HallandaleBeach', 3, 'FL', 8.083420903726457e-05, 8.083420903726457e-05],
#  ['Hamilton', 1, 'AL', 0.00014524328249818446, 0.00014524328249818446],
#  ['Hamilton', 1, 'NJ', 7.822277847309137e-05],
#  ['Hamilton', 2, 'OH', 3.201178033516334e-05, 3.201178033516334e-05],
#  ['HamiltonCounty', 1, 'TN'],
#  ['Hammett', 1, 'ID'],
#  ['Hammond', 1, 'LA', 4.9952545082171936e-05, 4.9952545082171936e-05],
#  ['Hampton', 1, 'GA', 0.0001431229426077, 0.0001431229426077],
#  ['Hampton',
#   1,
#   'NH',
#   0.00010356255178127589,
#   0.00010356255178127589,
#   0.00043956043956043956,
#   0.002849002849002849],
#  ['Hampton', 1, 'VA', 7.276113973049274e-06, 7.276113973049274e-06],
#  ['Hanceville', 1, 'AL', 0.00033534540576794097, 0.00033534540576794097],
#  ['HancockCounty', 1, 'MS'],
#  ['Hanford', 1, 'CA', 1.852984231104193e-05, 1.852984231104193e-05],
#  ['Hanover', 1, 'CO'],
#  ['Hanover', 1, 'IN', 0.0002820078962210942],
#  ['Hanover', 1, 'NM', 0.005988023952095809, 0.005988023952095809],
#  ['HappyValley', 1, 'CA'],
#  ['Hardeeville', 2, 'SC', 0.0006775067750677507, 0.0006775067750677507],
#  ['Hardwick', 2, 'NJ'],
#  ['HarkerHeights', 1, 'TX', 3.745318352059925e-05, 3.745318352059925e-05],
#  ['Harmony', 1, 'IN', 0.001524390243902439, 0.0012674271229404308],
#  ['Harmony', 1, 'TX'],
#  ['HarrisCounty', 1, 'TX'],
#  ['Harrisburg', 4, 'PA', 8.076239702794379e-05, 8.076239702794379e-05],
#  ['Harrisonburg', 2, 'VA', 4.088808929958703e-05, 4.088808929958703e-05],
#  ['Harrisonville', 1, 'MO', 9.981036031540073e-05, 9.981036031540073e-05],
#  ['Hartford',
#   1,
#   'CT',
#   8.014425966740132e-06,
#   1.9511433700148287e-05,
#   8.014425966740132e-06,
#   0.0007220216606498195,
#   1.5805778592653473e-05],
#  ['Hartsville',
#   1,
#   'SC',
#   0.00012879958784131891,
#   0.00012879958784131891,
#   0.00030759766225776686],
#  ['Harvey', 1, 'IL', 3.955383276639507e-05, 3.955383276639507e-05],
#  ['Harvey', 2, 'LA', 9.828975820719482e-05, 9.828975820719482e-05],
#  ['Hastings', 1, 'MN', 4.510193036261952e-05, 4.510193036261952e-05],
#  ['Hattiesburg',
#   2,
#   'MS',
#   4.3488660331818475e-05,
#   4.3488660331818475e-05,
#   0.00033846674564224065],
#  ['Haughton', 1, 'LA', 0.00028951939779965256],
#  ['Havasu', 1, 'AZ', 1.9037828164562987e-05],
#  ['HavredeGrace', 1, 'MD', 7.720815318097592e-05, 7.720815318097592e-05],
#  ['HawaiianGardens', 1, 'CA', 7.015574575557738e-05, 7.015574575557738e-05],
#  ['Hawkins', 1, 'WI', 0.003278688524590164],
#  ['Hawthorne', 1, 'CA', 1.1863381300938394e-05, 1.1863381300938394e-05],
#  ['Haymarket', 1, 'VA', 0.0005611672278338945],
#  ['Haynesville', 1, 'AL'],
#  ['Hays',
#   2,
#   'KS',
#   9.751340809361287e-05,
#   9.751340809361287e-05,
#   0.00018474043968224645],
#  ['Hayti',
#   1,
#   'MO',
#   0.0003402517863218782,
#   0.0003402517863218782,
#   0.001597444089456869],
#  ['Hayward', 3, 'CA', 2.0806458324663975e-05, 2.0806458324663975e-05],
#  ['Healdton', 1, 'OK', 0.0003586800573888092, 0.0003586800573888092],
#  ['Helena', 1, 'AR', 8.141996417521577e-05],
#  ['Helena',
#   1,
#   'MT',
#   3.5473572188719404e-05,
#   0.0005040322580645161,
#   3.5473572188719404e-05,
#   0.0009587727708533077,
#   0.000333889816360601,
#   0.0002871912693854107,
#   0.00012155099064057372,
#   0.00012685525815045033,
#   0.0006108735491753207],
#  ['Helena-WestHelena', 1, 'AR', 8.141996417521577e-05, 8.141996417521577e-05],
#  ['Hemet',
#   7,
#   'CA',
#   8.89939865491946e-05,
#   0.0004018831094270295,
#   8.89939865491946e-05],
#  ['Henderson',
#   1,
#   'NC',
#   6.50702758979698e-05,
#   6.50702758979698e-05,
#   7.61208799573723e-05,
#   0.0008244023083264633],
#  ['Henderson', 4, 'NV', 1.552017817164541e-05, 1.552017817164541e-05],
#  ['HendersonCounty', 1, 'TX'],
#  ['Hendersonville', 1, 'NC', 7.61208799573723e-05, 7.61208799573723e-05],
#  ['Hendersonville', 1, 'TN', 1.9465856887020166e-05, 1.9465856887020166e-05],
#  ['Henrico', 1, 'VA'],
#  ['HenryCounty', 1, 'GA'],
#  ['HenryCounty', 1, 'IN'],
#  ['Hensley', 1, 'WV'],
#  ['Hereford', 1, 'TX', 6.506180871828237e-05, 6.506180871828237e-05],
#  ['Hermantown', 1, 'MN', 0.00010622477161674102, 0.00010622477161674102],
#  ['Hernando',
#   1,
#   'FL',
#   0.0001104484205875856,
#   0.0001104484205875856,
#   0.00043497172683775554],
#  ['Herndon', 1, 'VA', 4.29331959471063e-05],
#  ['Hesperia', 2, 'CA', 2.2179588125048518e-05, 2.2179588125048518e-05],
#  ['Hessel', 1, 'MI'],
#  ['Hesston', 1, 'KS', 0.00026961445133459155, 0.00026961445133459155],
#  ['Hialeah',
#   1,
#   'FL',
#   4.450992348744152e-06,
#   4.450992348744152e-06,
#   4.59896983075791e-05],
#  ['Hickory', 2, 'NC', 4.9987503124218944e-05, 4.9987503124218944e-05],
#  ['Highgrove', 1, 'CA', 0.00025075225677031093, 0.00025075225677031093],
#  ['Highland',
#   2,
#   'CA',
#   3.766194636938837e-05,
#   0.000847457627118644,
#   3.766194636938837e-05,
#   0.0004966476285075739,
#   4.6844989928327164e-05],
#  ['HighlandsRanch', 1, 'CO', 1.0339871578794992e-05, 1.0339871578794992e-05],
#  ['Hillsboro', 2, 'OR', 2.1831439455960528e-05, 2.1831439455960528e-05],
#  ['Hilltop', 1, 'OH', 0.0018796992481203006, 0.0018796992481203006],
#  ['Hillyard', 1, 'WA'],
#  ['Hilo', 4, 'HI', 9.245775836164852e-05, 9.245775836164852e-05],
#  ['Hiltons', 1, 'VA'],
#  ['HindsCounty', 1, 'MS'],
#  ['Hiram', 1, 'GA', 0.0002820078962210942, 0.0002820078962210942],
#  ['Hiseville', 1, 'KY', 0.004166666666666667, 0.004166666666666667],
#  ['Hixson', 1, 'TN'],
#  ['Hobbs',
#   3,
#   'NM',
#   8.791981712678038e-05,
#   8.791981712678038e-05,
#   0.0005564830272676684],
#  ['HogValley', 1, 'FL'],
#  ['Hohenwald', 2, 'TN', 0.0005323396326856535, 0.0005323396326856535],
#  ['Holiday', 1, 'FL', 4.463687898942106e-05, 4.463687898942106e-05],
#  ['HollandTownship', 1, 'MI'],
#  ...]

# %%
#find_city('phoenix',city_kill_state)

# %%
def autocorrect(user_word, valid_words, diff_function, limit):
    if user_word in valid_words:
        return user_word
    a=min(valid_words,key=lambda word: diff_function(user_word,word,limit))
    if diff_function(user_word,a,limit)>limit:
            return user_word
    else:
        return a

# %%
"goddammit, it's dividing every time it sees an instance of a city"
# Out:
# "goddammit, it's dividing every time it sees an instance of a city"

# %%
city_population['City'][1201]
# Out:
# 'Phoenix'

# %%
 #lst_of_dic[i][1].append(autocorrect(lst_of_dic[i][0], city_pop_dic_lst[x][0], lambda w1, w2, limit: abs(len(w2) - len(w1)), 3))

# %%
'''NOTE TO LARRY LATER: I HEAVILY LEAN TOWARDS JUST USING ==, MESS AROUND WITH THE CLEANING OF Population A BIT TO SEE JUST HOW MUCH WE REALLY NEED TO CLEAN THE SHIT
ONE PARTICULAR NOTE IS ANCHORAGE, WHY IS IT EMPTY?'''
'having a space messed things up about as much as keeping CDP'
'spaces and city no lowercase did about the same, one more knocked off'
'lower case removed 3 from the good list'
# Out:
# 'spaces and city no lowercase did about the same, one more knocked off'

# %%
'suggestions for how to fix this:'
'1, Shave off a bunch of redundant cities in the CityPopulation2000 excel sheet'
"2, ignore cities that don't have enough shootings"
"3, manually do this"
'4, repurpose some code from a cs61a project'

'''
possible additions: 
drop a city if it isn't in the population excel
make it so cities can only be run once
    --combine with repurposed project?

'''
"I don't know if these things will work though"
# Out:
# "I don't know if these things will work though"
